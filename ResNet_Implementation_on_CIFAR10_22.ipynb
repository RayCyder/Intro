# %% [markdown]
# <a href="https://colab.research.google.com/github/RayCyder/Intro/blob/main/ResNet_Implementation_on_CIFAR10_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##The Resnet Research paper can be accessed from here https://arxiv.org/pdf/1512.03385v1.pdf

# %%
import torch
import random
import numpy as np
seed_seed =777 #555 #4242 42
random.seed(seed_seed)
torch.manual_seed(seed_seed)
torch.cuda.manual_seed_all(seed_seed)
np.random.seed(seed_seed)

# %% [markdown]
# #**Downloading the CIFAR10 datset and loading the data in Normalized form as torch.FloatTensor datatype and generating a validation set by dividing the training set in 80-20 ratio**
# # **CIFAR10**
# The CIFAR10 and CIFAR-100 are labeled subsets of the 80 million tiny images dataset. They were collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton.
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.
#
# Here are the classes in the dataset:
# 1. airplane
# 2. automobile
# 3. bird
# 4. cat
# 5. deer
# 6. dog
# 7. frog
# 8. horse
# 9. ship
# 10. truck
#
# The classes are completely mutually exclusive. There is no overlap between automobiles and trucks. "Automobile" includes sedans, SUVs, things of that sort. "Truck" includes only big trucks. Neither includes pickup trucks.
#
# More can be read from their page at https://www.cs.toronto.edu/~kriz/cifar.html

# %% [markdown]
# #**download dataset to local data directory**
#
# #**Image Augmentation**
# In this cell, we perform some simple data augmentation by randomly flipping and cropping the given image data. We do this by defining a torchvision transform, and you can learn about all the transforms that are used to pre-process and augment data from the [PyTorch documentation](https://pytorch.org/docs/stable/torchvision/transforms.html)
#
#
# we split train data to two part one is about 0.1 part of train data used as val data ,the last 0.9 part is used as train data
#
# test data only used once to check model at last
#
# so we choose 1000 for each class from 50,000 train data set  and split it to train data(0.9) and val data(0.1)
# choose 100 for each class from 10,000 test data as test data;
#
# we use val data to choose best learning rate,and use test data for accuracy and loss validation to avoid data leaking caused  validation loss overfit(val loss become much higher than lowest val loss at the end of training and training loss is very low)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import Subset, random_split, DataLoader
def sub_dataset(trainset, each_class_len,need_random=False):
  subset_indices = []
  targets = np.array(trainset.targets)
  for c in np.unique(targets):
    class_idx = np.where(targets == c)[0]
    # print(class_idx.shape,class_idx[:10])
    if need_random:
      np.random.shuffle(class_idx)
    subset_indices.extend(class_idx[:each_class_len])
  # Convert subset_indices to a numpy array to allow advanced indexing
  subset_indices = np.array(subset_indices)
  return subset_indices

def sub_sub_indices(subset_indices, val_ratio=0.1,need_random=True):
  # train_set,val_set = random_split(train_subset,[n_train,n_val])
  train_indices = []
  val_indices = []
  val_ratio = 0.1
  subset_labels = targets[subset_indices]
  for c in np.unique(subset_labels):
    class_idx = np.where(subset_labels == c)[0]
    if need_random:
      np.random.shuffle(class_idx)
    n_val = int(len(class_idx)*val_ratio)
    val_indices.extend(subset_indices[class_idx[:n_val]])
    train_indices.extend(subset_indices[class_idx[n_val:]])
  return train_indices, val_indices

transform = transforms.Compose([
    #transforms.Resize(40),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])
batch_size = 128
# --- Load full CIFAR-10 train set ---
trainset_full = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)
# --- Class names ---
classes = trainset_full.classes
# classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
#            'dog', 'frog', 'horse', 'ship', 'truck']
print(classes)
targets = np.array(trainset_full.targets)

# --- (Optional) use only a subset for speed
subset_indices = sub_dataset(trainset_full, 1000, need_random=False)
#train_subset = Subset(trainset_full, subset_indices)

# --- Split subset_indices into train/validation ---
train_indices, val_indices = sub_sub_indices(subset_indices, val_ratio=0.1, need_random=True)
train_set = Subset(trainset_full,train_indices)
val_set  = Subset(trainset_full, val_indices)
train_labels = [classes[x] for x in targets[train_indices]]
val_labels = [classes[x] for x in targets[val_indices]]
# --- DataLoaders ---
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set,batch_size = batch_size,shuffle=False)
#use all
train_loader = torch.utils.data.DataLoader(trainset_full, batch_size=batch_size, shuffle=True)
train_labels = [classes[x] for x in targets]
# --- Test Set ---
testset = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform_test)
test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)
test_targets = np.array(testset.targets)
test_labels = [classes[x] for x in test_targets]
# use part of test
# test_indices = sub_dataset(testset, 100, need_random=False)
# test_set_sub =  Subset(testset, test_indices)
# test_labels = [classes[x] for x in test_targets[test_indices]]
# test_loader =  DataLoader(test_set_sub,batch_size = batch_size, shuffle=False)
#test_loader = val_loader
val_loader = test_loader# = val_loader
val_labels = test_labels# = val_labels
print(f"Batch size:{batch_size}, \
      Train batches:{len(train_loader)}, \
      Val batches:{len(val_loader)},\
      Test batches:{len(test_loader)}")
# check train and val set is balanced or not
from collections import Counter
print("Train class counts:",Counter(train_labels))
print("Val class counts:", Counter(val_labels))
print("Test class counts:", Counter(test_labels))
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Batch size:128,       Train batches:391,       Val batches:79,      Test batches:79
# Train class counts: Counter({'frog': 5000, 'truck': 5000, 'deer': 5000, 'automobile': 5000, 'bird': 5000, 'horse': 5000, 'ship': 5000, 'cat': 5000, 'dog': 5000, 'airplane': 5000})
# Val class counts: Counter({'cat': 1000, 'ship': 1000, 'airplane': 1000, 'frog': 1000, 'automobile': 1000, 'truck': 1000, 'dog': 1000, 'horse': 1000, 'deer': 1000, 'bird': 1000})
# Test class counts: Counter({'cat': 1000, 'ship': 1000, 'airplane': 1000, 'frog': 1000, 'automobile': 1000, 'truck': 1000, 'dog': 1000, 'horse': 1000, 'deer': 1000, 'bird': 1000})

# %% [markdown]
# #**Visualizing the Data**
# Obtaining a batch of training data and plot the same with its lables using matplotlib library. You can also see how the transformations which you applied in the previous step show up in these visualizations.

# %%
import matplotlib.pyplot as plt
import numpy as np
print(classes)
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
  img = img / 2 + 0.5  # unnormalize
  plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display
print(images[0].shape)
# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
  ax = fig.add_subplot(2, 20//2, idx+1, xticks=[], yticks=[])
  imshow(images[idx])
  ax.set_title(classes[labels[idx]])
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# (3, 32, 32)

# %% [markdown]
# #**Defining the Network Architecture**
# In this section the entire Research Paper is implemented to define the Residual Network approach taken by the researchers
#
# NOTE:
#
# Output volume for a convolutional layer
# To compute the output size of a given convolutional layer we can perform the following calculation (taken from Stanford's cs231n course):
#
# We can compute the spatial size of the output volume as a function of the input volume size (W), the kernel/filter size (F), the stride with which they are applied (S), and the amount of zero padding used (P) on the border. The correct formula for calculating how many neurons define the output_W is given by (W−F+2P)/S+1.
#
# For example for a 7x7 input and a 3x3 filter with stride 1 and pad 0 we would get a 5x5 output. With stride 2 we would get a 3x3 output.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models

# choose device
device = (
    "cuda" if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
def initialize_model(device):
  # Load a pre-defined ResNet18
  ResNet18 = models.resnet18(weights=None)   # train from scratch
  # or use pretrained weights:
  # model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

  # Adjust the final layer for your dataset (e.g. 10 classes for CIFAR-10)
  num_ftrs = ResNet18.fc.in_features
  ResNet18.fc = nn.Linear(num_ftrs, 10)
  ResNet18 = ResNet18.to(device)
  if device == "cuda":
    import torch.backends.cudnn as cudnn
    ResNet18 = torch.nn.DataParallel(ResNet18)
    # cudnn.benchmark = True
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
  return ResNet18
resnet18 = initialize_model(device)
# Out:
# Using device: cuda

# %% [markdown]
# #**Specifying the Loss Function and Optimizer**
# We use CrossEntropyLoss as Loss function and
#
# [Stochastic Gradient Descent](https://leon.bottou.org/publications/pdf/compstat-2010.pdf)
# Adam
# MuonMVR2
# AdaOrth
#  as Optimizer with momentum and weight decay specified by the research paper of **ON THE CONVERGENCE OF MUON AND BEYOND**

# %%
import torch.optim as optim
# specify loss function (categorical cross-entropy)
# specify optimizer
# optimizer = optim.SGD(ResNet18.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0001)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# #**AdaOrthL+ method:** similar like MuonMVR2 use two random batches to decrease noise
#
#
# ![alt text](https://github.com/RayCyder/Intro/blob/main/image.png?raw=1)

# %%
import torch
#fix for mps
def _compile_for_device(fn):
    # Inductor doesn't support MPS; use AOTAutograd there.
    if torch.backends.mps.is_available():
        return torch.compile(fn, backend="aot_eager", dynamic=True)
    # Inductor is fine on CUDA/CPU
    return torch.compile(fn, backend="inductor", dynamic=True)

@_compile_for_device
def zeropower_via_newtonschulz5(G, steps=3, eps=1e-7):
    """
    Newton-Schulz iteration to compute the zeroth power / orthogonalization of G.
    """
    assert len(G.shape) == 2
    a, b, c = (3.4445, -4.7750,  2.0315)
    d_type = G.dtype
    X = G.bfloat16()
    #x_flat = X.reshape(-1)      # 把矩阵展平成一个 1D 向量
    X /= (X.norm() + eps) # ensure top singular value <= 1
    if G.size(0) > G.size(1):
        X = X.T
    for _ in range(steps):
        A = X @ X.T
        B = b * A + c * A @ A
        X = a * X + B @ X
    if G.size(0) > G.size(1):
        X = X.T
    return X.to(d_type)
class AdaOrth(torch.optim.Optimizer):
    def __init__(self, params, nu=1, lr=1e-3, weight_decay=0,adamw_betas=(0.95, 0.99),gamma=0.025,eps=1e-8):
        r"""
    AdaOrth: Adaptive Orthogonalized Gradient Method (Algorithm 1)

    变体：
      - nu=0  (AdaOrth-L↓):   M_t = α_t g_t + (1-α_t) M_{t-1}, g_t=∇f(X_t​;ξ_t​)
      - nu=1  (AdaOrth-L↑):   M_t​=(1−α_t​)(M_{t−1}​−∇f(X_{t-1}​;ξ_t))+∇f(X_t​;ξ_t​)

    其它：
      - α_t = ( Σ_{i=1..t} g_i^2 / max_{1..t} g_i^2 )^{-p}
      - γ_t = ( Σ_{i=1..t} m_i^2 / α_i )^{-p}
      - η_t = θ γ_t ||M_t||_F
      - X_{t+1} = X_t - η_t Orth(M_t)

    仅对二维参数（权重矩阵）使用正交化步；其它参数退化为普通 SGD。
    """
        defaults = dict(lr=lr, weight_decay=weight_decay, adamw_betas=adamw_betas, gamma=gamma, eps=eps)
        super(AdaOrth, self).__init__(params, defaults)
        self.nu = nu
        if nu == 0:
            self.p = 0.5
        else:
            self.p = 2.0/3.0
    @torch.no_grad()
    def update_last_grad(self):
        for group in self.param_groups:
            for p in group['params']:
                state = self.state[p]
                if "last_grad" not in state:
                    state["last_grad"] = torch.zeros_like(p)
                state["last_grad"].zero_().add_(p.grad, alpha=1.0)
    @torch.no_grad()
    def step(self):
        for group in self.param_groups:
            lr = group['lr']
            beta1, beta2 = group['adamw_betas']
            eps = group['eps']
            weight_decay = group['weight_decay']
            # momentum = group['momentum']
            gamma = group['gamma']
            for p in group['params']:
                if p.grad is None:
                    continue
                grad = p.grad
                state = self.state[p]
                if len(state) == 0:
                    state['step'] = 0
                    state['last_grad'] = torch.zeros_like(p)
                    if len(p.shape) != 2:
                        # For bias vectors - AdamW style moments
                        state['exp_avg'] = torch.zeros_like(p)
                        state['exp_avg_sq'] = torch.zeros_like(p)
                    else:
                        state['m_t'] = torch.zeros_like(p)
                        state['m_t_norm_square_div_alpha_sum'] = 0.0
                        state['g_sum'] = 0.0
                        state['g_max'] = 0.0

                last_grad = state['last_grad']
                state['step'] += 1

                if len(p.shape) == 2:
                    g_square = grad.norm().pow(2)
                    last_grad = state['last_grad']
                    state['g_sum'] += g_square
                    state['g_max'] = max(state['g_max'], g_square)
                    alpha = (state['g_sum']/(state['g_max']+eps)).pow(-self.p)
                    m_t = state['m_t']
                    if self.nu == 0:
                        m_t = (1-alpha)*m_t + alpha*grad
                    else:
                        m_t = (1-alpha)*(m_t - last_grad) + grad
                    state['m_t'] = m_t
                    m_t_norm = m_t.norm()
                    state['m_t_norm_square_div_alpha_sum'] = state['m_t_norm_square_div_alpha_sum'] + m_t_norm.pow(2)/(alpha+eps)
                    update =  zeropower_via_newtonschulz5(m_t)
                    adjusted_lr = lr*state['m_t_norm_square_div_alpha_sum'].pow(-self.p)*m_t_norm
                    p.data.mul_(1 - lr * weight_decay)
                    p.data.add_(update, alpha=-adjusted_lr)
                    if self.nu == 0:
                        state['last_grad'] = p.grad
                else:
                    # For bias vectors - use simple update
                    step = state['step']
                    # Compute momentum-like term with correction
                    c_t = (grad - last_grad).mul(gamma * (beta1 / (1. - beta1))).add(grad)
                    c_t_norm = torch.norm(c_t)
                    # avoid inductor lowering bug: compute norm explicitly and detach
                    # c_t_norm = torch.sqrt(torch.sum((c_t.detach() * c_t.detach()), dim=None))
                    if c_t_norm > 1.:
                        c_t = c_t / c_t_norm
                    exp_avg = state['exp_avg']
                    exp_avg_sq = state['exp_avg_sq']
                    exp_avg.lerp_(c_t, 1 - beta1)
                    exp_avg_sq.lerp_(c_t.square(), 1 - beta2)
                    g = exp_avg / (eps + exp_avg_sq.sqrt())
                    bias_correction1 = 1 - beta1**step
                    bias_correction2 = 1 - beta2**step
                    scale = bias_correction1 / bias_correction2**0.5
                    p.data.mul_(1 - lr * weight_decay)
                    p.data.add_(g, alpha=-lr / scale)

# %% [markdown]
# #**Muon-MVR2 method from ON THE CONVERGENCE OF MUON AND BEYOND**
#
# fixed some error for mac M1
#
# mvr2 only works with 2 dim weights, other dims use method like adam

# %%
'''
Muon-MVR For LLM Pretraining.
'''
import torch
import math

#fix for mps
def _compile_for_device(fn):
    # Inductor doesn't support MPS; use AOTAutograd there.
    if torch.backends.mps.is_available():
        return torch.compile(fn, backend="aot_eager", dynamic=True)
    # Inductor is fine on CUDA/CPU
    return torch.compile(fn, backend="inductor", dynamic=True)


@_compile_for_device
def zeropower_via_newtonschulz5(G, steps=3, eps=1e-7):
    """
    Newton-Schulz iteration to compute the zeroth power / orthogonalization of G.
    """
    assert len(G.shape) == 2
    a, b, c = (3.4445, -4.7750,  2.0315)
    d_type = G.dtype
    X = G.bfloat16()
    #x_flat = X.reshape(-1)      # 把矩阵展平成一个 1D 向量
    X /= (X.norm() + eps) # ensure top singular value <= 1
    if G.size(0) > G.size(1):
        X = X.T
    for _ in range(steps):
        A = X @ X.T
        B = b * A + c * A @ A
        X = a * X + B @ X
    if G.size(0) > G.size(1):
        X = X.T
    return X.to(d_type)

class MuonMVR(torch.optim.Optimizer):
    r'''
    Standard MVR:\\(nabla f(X_t;\xi_t) - \\nabla f(X_{t-1};\xi_{t})
    Approximate MVR:
        1.\\(nabla f(X_t;\xi_t) - \\nabla f(X_{t-1};\xi_{t-1})
        2.\\(nabla f(X_t;\xi_t) - \\nabla f(X_{t};\xi_{t-1}), It has low computational complexity
         and is more convenient in practice
    '''
    def __init__(self, params, lr=3e-3, momentum = 0.95 ,adamw_betas=(0.95, 0.99), eps=1e-8,
                 weight_decay=0.0, gamma=0.025, is_approx=False):
        if lr < 0.0:
            raise ValueError(f"Invalid learning rate: {lr}")
        if not 0.0 <= momentum < 1.0:
            raise ValueError(f"Invalid momentum parameter: {momentum}")
        if not 0.0 <= adamw_betas[0] < 1.0:
            raise ValueError(f"Invalid beta1 parameter: {adamw_betas[0]}")
        if not 0.0 <= adamw_betas[1] < 1.0:
            raise ValueError(f"Invalid beta2 parameter: {adamw_betas[1]}")

        defaults = dict(lr=lr, momentum=momentum,adamw_betas=adamw_betas, eps=eps,
                       weight_decay=weight_decay, gamma=gamma)
        super().__init__(params, defaults)
        self.is_approx = is_approx

    def adjust_lr_for_muon(self, lr, param_shape):
        A, B = param_shape[:2]
        # We adjust the learning rate and weight decay based on the size of the parameter matrix
        # as describted in the paper
        adjusted_ratio = 0.2 * math.sqrt(max(A, B))
        # adjusted_ratio = math.sqrt(A*B)
        adjusted_lr = lr * adjusted_ratio
        return adjusted_lr

    @torch.no_grad()
    def update_last_grad(self):
        if not self.is_approx:
            for group in self.param_groups:
                for p in group['params']:
                    state = self.state[p]
                    if "last_grad" not in state:
                        state["last_grad"] = torch.zeros_like(p)
                    state["last_grad"].zero_().add_(p.grad, alpha=1.0)

    @torch.no_grad()
    def step(self):
        for group in self.param_groups:
            lr = group['lr']
            beta1, beta2 = group['adamw_betas']
            eps = group['eps']
            weight_decay = group['weight_decay']
            momentum = group['momentum']
            gamma = group['gamma']

            for p in group['params']:
                if p.grad is None:
                    continue

                grad = p.grad
                state = self.state[p]

                # State initialization
                if len(state) == 0:
                    state['step'] = 0
                    state['exp_avg'] = torch.zeros_like(p)
                    state['last_grad'] = torch.zeros_like(p)
                    # state['previous_grad'] = torch.zeros_like(p)
                    if len(p.shape) != 2:  # Only for 2D tensors
                        state['exp_avg_sq'] = torch.zeros_like(p)

                state['step'] += 1
                last_grad = state['last_grad']
                if len(p.shape) == 2:
                    exp_avg = state['exp_avg']

                    # Compute momentum-like term with correction
                    c_t = (grad - last_grad).mul(gamma * (momentum / (1. - momentum))).add(grad)
                    c_t_norm = torch.norm(c_t)
                    if c_t_norm > 1.:
                        c_t = c_t / c_t_norm
                    # Update moving averages
                    exp_avg.mul_(momentum).add_(c_t, alpha=1 - momentum)
                    update = zeropower_via_newtonschulz5(exp_avg.mul(1./(1.- momentum))) # whiten the update
                    adjusted_lr = self.adjust_lr_for_muon(lr, p.shape)
                    p.data.mul_(1 - lr * weight_decay)
                    p.data.add_(update, alpha=-adjusted_lr)
                else:
                    # For bias vectors - use simple update
                    step = state['step']
                    # Compute momentum-like term with correction
                    c_t = (grad - last_grad).mul(gamma * (beta1 / (1. - beta1))).add(grad)
                    c_t_norm = torch.norm(c_t)
                    # avoid inductor lowering bug: compute norm explicitly and detach
                    # c_t_norm = torch.sqrt(torch.sum((c_t.detach() * c_t.detach()), dim=None))
                    if c_t_norm > 1.:
                        c_t = c_t / c_t_norm
                    exp_avg = state['exp_avg']
                    exp_avg_sq = state['exp_avg_sq']
                    exp_avg.lerp_(c_t, 1 - beta1)
                    exp_avg_sq.lerp_(c_t.square(), 1 - beta2)
                    g = exp_avg / (eps + exp_avg_sq.sqrt())
                    bias_correction1 = 1 - beta1**step
                    bias_correction2 = 1 - beta2**step
                    scale = bias_correction1 / bias_correction2**0.5
                    p.data.mul_(1 - lr * weight_decay)
                    p.data.add_(g, alpha=-lr / scale)

                if self.is_approx:
                    state['last_grad'].copy_(grad)

# %% [markdown]
# #**MuonMVR Training Loop**
# Here we train the architecture on training data and check its validation loss by using the validation set and saving the model only if there is an improvement ie decrease in the validation loss.

# %% [markdown]
# ## MVR2 Usage
# 3.  **Optimizer Modes**
#     MuonMVR can be initialized in different modes to trade off between precision and computational cost.
#
#     **Exact Variance Reduction (`is_approx=False`)**
#     To achieve the most precise variance reduction, you must manually manage the model state. Before calculating the gradient for the previous batch, you need to load the model state from the previous iteration. This ensures that the gradient is computed with the correct model weights.
#     ```python
#     optimizer = MuonMVR(model.parameters(), lr=1e-3, is_approx=False)
#     old_state_dict = {}
#
#     for batch_idx, (inputs, targets) in enumerate(trainloader):
#         # Store the current model state
#         cur_state_dict = {k: v.data.clone() for k, v in net.state_dict().items()}
#
#         if old_state_dict:
#             # Load the previous model state to compute the old gradient
#             net.load_state_dict(old_state_dict)
#             optimizer.zero_grad()
#             outputs = net(inputs)
#             loss = criterion(outputs, targets)
#             loss.backward()
#             optimizer.update_last_grad()
#
#         # Restore the current model state to compute the new gradient
#         net.load_state_dict(cur_state_dict)
#         old_state_dict = {k: v.data.clone() for k, v in cur_state_dict.items()}
#
#         # Standard forward/backward pass and step
#         optimizer.zero_grad()
#         outputs = net(inputs)
#         loss = criterion(outputs, targets)
#         loss.backward()
#         optimizer.step()
#     ```

# %%
import time
class BaseOptimizer(object):
  def __init__(self,model,criterion,epochs):
    self.model = model
    self.epochs = epochs
    self.criterion = criterion
    self.optimizer,self.scheduler = None, None
  def initialize_optimzer(self):
    raise Exception("non implemetation")
  def zero_grad(self,inputs=None,labels=None):
    self.optimizer.zero_grad()
  def step(self):
    self.optimizer.step()
  def epoch_step(self):
    if self.scheduler:
      self.scheduler.step()

class MuonMVR2Optimizer(BaseOptimizer):
  def __init__(self,model,criterion,epochs):
    super().__init__(model,criterion,epochs)
    self.old_state_dict = {}
  def initialize_optimizer(self, learning_rate):
    optimizer = MuonMVR(self.model.parameters(), lr=learning_rate,weight_decay=0.01,gamma=0.1,is_approx=False)
    # Cosine annealing: lr → eta_min by the end
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=self.epochs,   # period (usually = total epochs)
        eta_min=0.1*learning_rate      # minimum LR (here 0.1× of 0.01)
    )
    self.optimizer,self.scheduler =  optimizer, scheduler
  def zero_grad(self,inputs=None,labels=None):
    model, old_state_dict = self.model, self.old_state_dict
    optimizer = self.optimizer
    # Store the current model state
    cur_state_dict = {k: v.data.clone() for k, v in model.state_dict().items()}
    if self.old_state_dict:
        # Load the previous model state to compute the old gradient
        model.load_state_dict(old_state_dict)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.update_last_grad()
    #restore state
    model.load_state_dict(cur_state_dict)
    self.old_state_dict = {k: v.data.clone() for k, v in cur_state_dict.items()}
    self.optimizer.zero_grad()
def val_once(model, criterion, val_loader):
  model.eval()
  val_loss = 0.0
  with torch.no_grad():
    for inputs, labels in val_loader:
      inputs, labels = inputs.to(device),labels.to(device)
      outputs = model(inputs)
      loss = criterion(outputs,labels)
      val_loss += loss.item()
  val_loss = val_loss/max(1,len(val_loader))
  return val_loss
def train_once(model,criterion,optimizer,train_loader,val_loader,learning_rate,epochs=100):
  losses = []
  val_losses = []
  accs =[]
  elapsed_all = []
  #optimizer = MuonMVR2Optimizer(model,criterion,epochs)
  #optimizer.initialize_optimizer(learning_rate)
  start = time.time()
  for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad(inputs, labels)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss+=loss.item()
    # step the scheduler once per epoch
    optimizer.epoch_step()
    losses.append(running_loss/max(1, len(train_loader)))
    current_lr = optimizer.scheduler.get_last_lr()[0]  # single param group
    #val_loss = val_once(model,criterion,val_loader)
    val_loss, acc = test_model(model, criterion, val_loader)
    val_losses.append(val_loss)
    accs.append(acc)
    elapsed = time.time() - start
    elapsed_all.append(elapsed)
    print(f"[{epoch+1}] time: {elapsed} loss: {losses[-1]:.3f} val_loss:{val_loss} current_lr={current_lr:.6f}")

  print(f"Training finished!")
  return losses, val_losses, accs, elapsed_all


def train_with_mvr2_once(model,criterion,train_loader,val_loader,learning_rate,epochs):
  optimizer = MuonMVR2Optimizer(model,criterion,epochs)
  optimizer.initialize_optimizer(learning_rate)
  return train_once(model,criterion,optimizer,train_loader,val_loader,learning_rate,epochs)


  # track test loss
def test_model(ResNet18, criterion, test_loader):
  test_loss = 0.0
  class_correct = list(0. for i in range(10))
  class_total = list(0. for i in range(10))
  train_on_gpu = device != 'cpu'

  ResNet18.eval()
  # iterate over test data
  for batch_idx, (data, target) in enumerate(test_loader):
    # move tensors to GPU if CUDA is available
    data, target = data.to(device), target.to(device)
    count = data.size(0)
    # forward pass: compute predicted outputs by passing inputs to the model
    output = ResNet18(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss
    test_loss += loss.item() #*count
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(count):
      label = target.data[i]
      class_correct[label] += correct[i].item()
      class_total[label] += 1

  # average test loss
  test_loss = test_loss/max(1, len(test_loader))
  print('Test Loss: {:.6f}\n'.format(test_loss))

  for i in range(10):
    if class_total[i] > 0:
      print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
          classes[i], 100 * class_correct[i] / class_total[i],
          np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
      print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
  acc = 100. * np.sum(class_correct) / np.sum(class_total)
  print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
      acc,
      np.sum(class_correct), np.sum(class_total)))
  return test_loss, acc

# %% [markdown]
# ##**grid search learning rate for MuonMVR2**

# %%
learning_rates = [1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 5e-2, 1e-1]
#42
result_mvr2 = [1.662683129310608, 1.5963122844696045, 1.4677045345306396,
           1.3441717624664307, 1.3620641231536865, 1.5036698579788208, 1.4877097606658936]
epochs = 100
def grids_search_val(get_optimizer):
  result = []
  for ii, learning_rate in enumerate(learning_rates):
    print(f".........Learning rate {ii+1}/{len(learning_rates)}: {learning_rate}............")
    model = initialize_model(device)
    optimizer = get_optimizer(model, learning_rate)
    train_losses, val_losses, acc, time_cost = train_once(model,criterion,optimizer,train_loader,val_loader,learning_rate,epochs)
    result.append(min(val_losses))
  return result
def muonmvr2_optimizer(model,learning_rate):
  optimizer = MuonMVR2Optimizer(model,criterion,epochs)
  optimizer.initialize_optimizer(learning_rate)
  return optimizer
#4242
#on val
result_mvr2 = [1.5750100761651993, 1.268349602818489, 1.1231343746185303,
          1.0403755232691765, 1.0844867303967476, 1.323870301246643, 1.095424696803093]
#on test
# result_mvr2 = [1.5052119940519333, 1.2015319392085075, 1.0384493470191956,
#                1.053267389535904, 1.0702569410204887, 1.2238388806581497, 1.1795140504837036]


if not result_mvr2:
  result_mvr2 = grids_search_val(muonmvr2_optimizer)
  #result = [x.cpu() for x in result]

# %%
plt.figure(figsize=(6,4))
plt.xscale('log')   # good practice for learning rates
plt.xlabel("Learning rate")
plt.ylabel("Min Validation Loss")
print(result_mvr2)
plt.title("Learning Rate Grid Search")
plt.xticks(learning_rates, labels=[str(lr) for lr in learning_rates],rotation=45)
plt.plot(learning_rates, result_mvr2, label="Grid Search(Validataion Loss)", linewidth=2, marker='o')
# Out:
# [1.5750100761651993, 1.268349602818489, 1.1231343746185303, 1.0403755232691765, 1.0844867303967476, 1.323870301246643, 1.095424696803093]

# %%
min_index = result_mvr2.index(min(result_mvr2))
learning_rate = learning_rates[min_index]
print(f"Best learning rate: {learning_rate}, Min val loss: {result_mvr2[min_index]}")
print([float(x) for x in result_mvr2])
# Out:
# Best learning rate: 0.005, Min val loss: 1.0403755232691765
# [1.5750100761651993, 1.268349602818489, 1.1231343746185303, 1.0403755232691765, 1.0844867303967476, 1.323870301246643, 1.095424696803093]

# %%
# import torch
# torch._dynamo.config.verbose = True
# import os
# os.environ["TORCH_LOGS"] = "recompiles,graph_breaks,guards"

# %% [markdown]
# #**training Model with MuonMVR2 using best learning rate**

# %%
learning_rate = 0.05 #from paper
model_mvr2 = initialize_model(device)
losses_mvr2,losses_mvr2_val, mvr2_acc, mvr2_time_cost = train_with_mvr2_once(model_mvr2,criterion,train_loader,test_loader,learning_rate,epochs)
# Out:
# W1118 15:39:40.004000 1825 torch/_inductor/utils.py:1436] [0/0] Not enough SMs to use max_autotune_gemm mode
# Test Loss: 3.322546
#
# Test Accuracy of airplane: 42% (420/1000)
# Test Accuracy of automobile: 57% (578/1000)
# Test Accuracy of  bird:  0% ( 0/1000)
# Test Accuracy of   cat:  6% (67/1000)
# Test Accuracy of  deer: 35% (350/1000)
# Test Accuracy of   dog: 62% (628/1000)
# Test Accuracy of  frog: 18% (184/1000)
# Test Accuracy of horse: 30% (304/1000)
# Test Accuracy of  ship: 37% (372/1000)
# Test Accuracy of truck: 42% (425/1000)
#
# Test Accuracy (Overall): 33% (3328/10000)
# [1] time: 51.1079785823822 loss: 2.611 val_loss:3.3225462693202346 current_lr=0.049989
# Test Loss: 1.756331
#
# Test Accuracy of airplane: 58% (583/1000)
# Test Accuracy of automobile: 57% (578/1000)
# Test Accuracy of  bird: 43% (431/1000)
# Test Accuracy of   cat: 40% (402/1000)
# Test Accuracy of  deer: 34% (346/1000)
# Test Accuracy of   dog: 38% (387/1000)
# Test Accuracy of  frog: 59% (596/1000)
# Test Accuracy of horse: 36% (364/1000)
# Test Accuracy of  ship: 28% (288/1000)
# Test Accuracy of truck: 36% (364/1000)
#
# Test Accuracy (Overall): 43% (4339/10000)
# [2] time: 94.7037444114685 loss: 1.873 val_loss:1.756331114829341 current_lr=0.049956
# Test Loss: 1.323069
#
# Test Accuracy of airplane: 67% (673/1000)
# Test Accuracy of automobile: 67% (672/1000)
# Test Accuracy of  bird: 27% (272/1000)
# Test Accuracy of   cat: 41% (414/1000)
# Test Accuracy of  deer: 42% (426/1000)
# Test Accuracy of   dog: 36% (369/1000)
# Test Accuracy of  frog: 51% (515/1000)
# Test Accuracy of horse: 68% (685/1000)
# Test Accuracy of  ship: 68% (683/1000)
# Test Accuracy of truck: 50% (508/1000)
#
# Test Accuracy (Overall): 52% (5217/10000)
# [3] time: 138.56216883659363 loss: 1.471 val_loss:1.323068903971322 current_lr=0.049900
# Test Loss: 1.235613
#
# Test Accuracy of airplane: 36% (364/1000)
# Test Accuracy of automobile: 59% (592/1000)
# Test Accuracy of  bird: 49% (493/1000)
# Test Accuracy of   cat: 41% (411/1000)
# Test Accuracy of  deer: 67% (671/1000)
# Test Accuracy of   dog: 34% (343/1000)
# Test Accuracy of  frog: 63% (630/1000)
# Test Accuracy of horse: 69% (694/1000)
# Test Accuracy of  ship: 85% (852/1000)
# Test Accuracy of truck: 57% (572/1000)
#
# Test Accuracy (Overall): 56% (5622/10000)
# [4] time: 182.30721855163574 loss: 1.270 val_loss:1.2356126014190385 current_lr=0.049823
# Test Loss: 1.400387
#
# Test Accuracy of airplane: 48% (489/1000)
# Test Accuracy of automobile: 67% (671/1000)
# Test Accuracy of  bird: 11% (119/1000)
# Test Accuracy of   cat: 33% (331/1000)
# Test Accuracy of  deer: 50% (507/1000)
# Test Accuracy of   dog: 54% (546/1000)
# Test Accuracy of  frog: 41% (417/1000)
# Test Accuracy of horse: 71% (710/1000)
# Test Accuracy of  ship: 77% (776/1000)
# Test Accuracy of truck: 47% (474/1000)
#
# Test Accuracy (Overall): 50% (5040/10000)
# [5] time: 226.26370096206665 loss: 1.383 val_loss:1.4003869612005693 current_lr=0.049723
# Test Loss: 1.349872
#
# Test Accuracy of airplane: 38% (388/1000)
# Test Accuracy of automobile: 36% (365/1000)
# Test Accuracy of  bird: 16% (166/1000)
# Test Accuracy of   cat: 36% (366/1000)
# Test Accuracy of  deer: 52% (529/1000)
# Test Accuracy of   dog: 55% (551/1000)
# Test Accuracy of  frog: 44% (443/1000)
# Test Accuracy of horse: 80% (804/1000)
# Test Accuracy of  ship: 84% (848/1000)
# Test Accuracy of truck: 72% (723/1000)
#
# Test Accuracy (Overall): 51% (5183/10000)
# [6] time: 270.6701922416687 loss: 1.153 val_loss:1.3498719055441362 current_lr=0.049601
# Test Loss: 1.107746
#
# Test Accuracy of airplane: 75% (753/1000)
# Test Accuracy of automobile: 52% (526/1000)
# Test Accuracy of  bird: 45% (456/1000)
# Test Accuracy of   cat: 47% (478/1000)
# Test Accuracy of  deer: 67% (670/1000)
# Test Accuracy of   dog: 38% (383/1000)
# Test Accuracy of  frog: 48% (481/1000)
# Test Accuracy of horse: 76% (765/1000)
# Test Accuracy of  ship: 78% (785/1000)
# Test Accuracy of truck: 76% (767/1000)
#
# Test Accuracy (Overall): 60% (6064/10000)
# [7] time: 314.78723311424255 loss: 1.186 val_loss:1.1077457032626188 current_lr=0.049458
# Test Loss: 1.059063
#
# Test Accuracy of airplane: 49% (498/1000)
# Test Accuracy of automobile: 77% (770/1000)
# Test Accuracy of  bird: 56% (567/1000)
# Test Accuracy of   cat: 41% (419/1000)
# Test Accuracy of  deer: 66% (666/1000)
# Test Accuracy of   dog: 56% (564/1000)
# Test Accuracy of  frog: 70% (706/1000)
# Test Accuracy of horse: 53% (533/1000)
# Test Accuracy of  ship: 90% (908/1000)
# Test Accuracy of truck: 61% (617/1000)
#
# Test Accuracy (Overall): 62% (6248/10000)
# [8] time: 358.95839405059814 loss: 1.051 val_loss:1.0590626831296124 current_lr=0.049293
# Test Loss: 0.932276
#
# Test Accuracy of airplane: 72% (724/1000)
# Test Accuracy of automobile: 81% (815/1000)
# Test Accuracy of  bird: 52% (527/1000)
# Test Accuracy of   cat: 59% (599/1000)
# Test Accuracy of  deer: 65% (652/1000)
# Test Accuracy of   dog: 44% (444/1000)
# Test Accuracy of  frog: 73% (735/1000)
# Test Accuracy of horse: 72% (729/1000)
# Test Accuracy of  ship: 82% (822/1000)
# Test Accuracy of truck: 70% (706/1000)
#
# Test Accuracy (Overall): 67% (6753/10000)
# [9] time: 402.1705017089844 loss: 0.981 val_loss:0.9322758354718172 current_lr=0.049107
# Test Loss: 1.215043
#
# Test Accuracy of airplane: 80% (802/1000)
# Test Accuracy of automobile: 90% (904/1000)
# Test Accuracy of  bird: 44% (445/1000)
# Test Accuracy of   cat: 40% (405/1000)
# Test Accuracy of  deer: 49% (495/1000)
# Test Accuracy of   dog: 42% (429/1000)
# Test Accuracy of  frog: 75% (753/1000)
# Test Accuracy of horse: 50% (501/1000)
# Test Accuracy of  ship: 58% (584/1000)
# Test Accuracy of truck: 38% (388/1000)
#
# Test Accuracy (Overall): 57% (5706/10000)
# [10] time: 445.6880841255188 loss: 0.932 val_loss:1.2150426469271696 current_lr=0.048899
# Test Loss: 0.931164
#
# Test Accuracy of airplane: 66% (668/1000)
# Test Accuracy of automobile: 74% (745/1000)
# Test Accuracy of  bird: 48% (488/1000)
# Test Accuracy of   cat: 57% (573/1000)
# Test Accuracy of  deer: 76% (767/1000)
# Test Accuracy of   dog: 55% (553/1000)
# Test Accuracy of  frog: 67% (674/1000)
# Test Accuracy of horse: 66% (666/1000)
# Test Accuracy of  ship: 78% (784/1000)
# Test Accuracy of truck: 82% (828/1000)
#
# Test Accuracy (Overall): 67% (6746/10000)
# [11] time: 489.3100619316101 loss: 0.927 val_loss:0.9311639176139349 current_lr=0.048670
# Test Loss: 0.941057
#
# Test Accuracy of airplane: 73% (739/1000)
# Test Accuracy of automobile: 79% (799/1000)
# Test Accuracy of  bird: 36% (363/1000)
# Test Accuracy of   cat: 40% (404/1000)
# Test Accuracy of  deer: 68% (689/1000)
# Test Accuracy of   dog: 65% (658/1000)
# Test Accuracy of  frog: 87% (870/1000)
# Test Accuracy of horse: 60% (606/1000)
# Test Accuracy of  ship: 84% (844/1000)
# Test Accuracy of truck: 79% (795/1000)
#
# Test Accuracy (Overall): 67% (6767/10000)
# [12] time: 532.6344602108002 loss: 0.923 val_loss:0.9410569516918327 current_lr=0.048420
# Test Loss: 0.947336
#
# Test Accuracy of airplane: 74% (741/1000)
# Test Accuracy of automobile: 71% (714/1000)
# Test Accuracy of  bird: 54% (544/1000)
# Test Accuracy of   cat: 48% (483/1000)
# Test Accuracy of  deer: 69% (690/1000)
# Test Accuracy of   dog: 65% (655/1000)
# Test Accuracy of  frog: 54% (544/1000)
# Test Accuracy of horse: 66% (661/1000)
# Test Accuracy of  ship: 83% (836/1000)
# Test Accuracy of truck: 82% (827/1000)
#
# Test Accuracy (Overall): 66% (6695/10000)
# [13] time: 576.7588937282562 loss: 0.868 val_loss:0.9473357630681388 current_lr=0.048149
# Test Loss: 0.941075
#
# Test Accuracy of airplane: 80% (803/1000)
# Test Accuracy of automobile: 79% (791/1000)
# Test Accuracy of  bird: 54% (542/1000)
# Test Accuracy of   cat: 30% (304/1000)
# Test Accuracy of  deer: 76% (767/1000)
# Test Accuracy of   dog: 63% (635/1000)
# Test Accuracy of  frog: 77% (779/1000)
# Test Accuracy of horse: 75% (759/1000)
# Test Accuracy of  ship: 60% (601/1000)
# Test Accuracy of truck: 79% (792/1000)
#
# Test Accuracy (Overall): 67% (6773/10000)
# [14] time: 621.2471959590912 loss: 0.852 val_loss:0.9410749447496631 current_lr=0.047859
# Test Loss: 0.888855
#
# Test Accuracy of airplane: 77% (771/1000)
# Test Accuracy of automobile: 84% (842/1000)
# Test Accuracy of  bird: 52% (525/1000)
# Test Accuracy of   cat: 52% (526/1000)
# Test Accuracy of  deer: 70% (705/1000)
# Test Accuracy of   dog: 45% (451/1000)
# Test Accuracy of  frog: 81% (812/1000)
# Test Accuracy of horse: 67% (676/1000)
# Test Accuracy of  ship: 84% (848/1000)
# Test Accuracy of truck: 75% (758/1000)
#
# Test Accuracy (Overall): 69% (6914/10000)
# [15] time: 665.7122182846069 loss: 0.848 val_loss:0.88885466056534 current_lr=0.047548
# Test Loss: 0.874626
#
# Test Accuracy of airplane: 70% (703/1000)
# Test Accuracy of automobile: 80% (804/1000)
# Test Accuracy of  bird: 58% (588/1000)
# Test Accuracy of   cat: 50% (505/1000)
# Test Accuracy of  deer: 64% (640/1000)
# Test Accuracy of   dog: 68% (682/1000)
# Test Accuracy of  frog: 84% (848/1000)
# Test Accuracy of horse: 70% (705/1000)
# Test Accuracy of  ship: 75% (755/1000)
# Test Accuracy of truck: 82% (821/1000)
#
# Test Accuracy (Overall): 70% (7051/10000)
# [16] time: 710.238115310669 loss: 0.815 val_loss:0.8746258872973768 current_lr=0.047217
# Test Loss: 1.268037
#
# Test Accuracy of airplane: 71% (715/1000)
# Test Accuracy of automobile: 79% (796/1000)
# Test Accuracy of  bird: 58% (589/1000)
# Test Accuracy of   cat: 27% (277/1000)
# Test Accuracy of  deer: 29% (291/1000)
# Test Accuracy of   dog: 58% (580/1000)
# Test Accuracy of  frog: 81% (815/1000)
# Test Accuracy of horse: 48% (485/1000)
# Test Accuracy of  ship: 53% (530/1000)
# Test Accuracy of truck: 56% (565/1000)
#
# Test Accuracy (Overall): 56% (5643/10000)
# [17] time: 754.4391882419586 loss: 0.866 val_loss:1.2680366522149196 current_lr=0.046867
# Test Loss: 1.046108
#
# Test Accuracy of airplane: 70% (704/1000)
# Test Accuracy of automobile: 59% (593/1000)
# Test Accuracy of  bird: 54% (541/1000)
# Test Accuracy of   cat: 48% (489/1000)
# Test Accuracy of  deer: 59% (598/1000)
# Test Accuracy of   dog: 64% (641/1000)
# Test Accuracy of  frog: 56% (562/1000)
# Test Accuracy of horse: 59% (590/1000)
# Test Accuracy of  ship: 89% (895/1000)
# Test Accuracy of truck: 76% (762/1000)
#
# Test Accuracy (Overall): 63% (6375/10000)
# [18] time: 798.7641091346741 loss: 0.912 val_loss:1.0461079221737535 current_lr=0.046497
# Test Loss: 0.860433
#
# Test Accuracy of airplane: 75% (756/1000)
# Test Accuracy of automobile: 81% (810/1000)
# Test Accuracy of  bird: 54% (544/1000)
# Test Accuracy of   cat: 43% (434/1000)
# Test Accuracy of  deer: 74% (743/1000)
# Test Accuracy of   dog: 65% (656/1000)
# Test Accuracy of  frog: 76% (760/1000)
# Test Accuracy of horse: 70% (702/1000)
# Test Accuracy of  ship: 88% (883/1000)
# Test Accuracy of truck: 75% (750/1000)
#
# Test Accuracy (Overall): 70% (7038/10000)
# [19] time: 843.1156666278839 loss: 0.882 val_loss:0.8604334909704667 current_lr=0.046109
# Test Loss: 0.994860
#
# Test Accuracy of airplane: 66% (669/1000)
# Test Accuracy of automobile: 76% (768/1000)
# Test Accuracy of  bird: 61% (614/1000)
# Test Accuracy of   cat: 45% (453/1000)
# Test Accuracy of  deer: 65% (654/1000)
# Test Accuracy of   dog: 69% (693/1000)
# Test Accuracy of  frog: 81% (815/1000)
# Test Accuracy of horse: 61% (612/1000)
# Test Accuracy of  ship: 72% (724/1000)
# Test Accuracy of truck: 63% (633/1000)
#
# Test Accuracy (Overall): 66% (6635/10000)
# [20] time: 886.6538121700287 loss: 0.822 val_loss:0.9948603699478922 current_lr=0.045703
# Test Loss: 0.883575
#
# Test Accuracy of airplane: 79% (797/1000)
# Test Accuracy of automobile: 90% (908/1000)
# Test Accuracy of  bird: 55% (551/1000)
# Test Accuracy of   cat: 58% (585/1000)
# Test Accuracy of  deer: 62% (620/1000)
# Test Accuracy of   dog: 62% (628/1000)
# Test Accuracy of  frog: 65% (653/1000)
# Test Accuracy of horse: 71% (712/1000)
# Test Accuracy of  ship: 82% (821/1000)
# Test Accuracy of truck: 68% (682/1000)
#
# Test Accuracy (Overall): 69% (6957/10000)
# [21] time: 930.5280132293701 loss: 0.812 val_loss:0.8835746147964574 current_lr=0.045278
# Test Loss: 0.871943
#
# Test Accuracy of airplane: 80% (800/1000)
# Test Accuracy of automobile: 80% (800/1000)
# Test Accuracy of  bird: 62% (628/1000)
# Test Accuracy of   cat: 53% (535/1000)
# Test Accuracy of  deer: 64% (647/1000)
# Test Accuracy of   dog: 52% (526/1000)
# Test Accuracy of  frog: 70% (707/1000)
# Test Accuracy of horse: 84% (848/1000)
# Test Accuracy of  ship: 80% (801/1000)
# Test Accuracy of truck: 72% (725/1000)
#
# Test Accuracy (Overall): 70% (7017/10000)
# [22] time: 975.0851423740387 loss: 0.814 val_loss:0.8719431207149844 current_lr=0.044837
# Test Loss: 0.869289
#
# Test Accuracy of airplane: 72% (729/1000)
# Test Accuracy of automobile: 85% (854/1000)
# Test Accuracy of  bird: 48% (483/1000)
# Test Accuracy of   cat: 56% (561/1000)
# Test Accuracy of  deer: 80% (804/1000)
# Test Accuracy of   dog: 49% (498/1000)
# Test Accuracy of  frog: 72% (721/1000)
# Test Accuracy of horse: 79% (792/1000)
# Test Accuracy of  ship: 85% (850/1000)
# Test Accuracy of truck: 70% (707/1000)
#
# Test Accuracy (Overall): 69% (6999/10000)
# [23] time: 1018.9103727340698 loss: 0.821 val_loss:0.8692891771280313 current_lr=0.044377
# Test Loss: 0.850753
#
# Test Accuracy of airplane: 72% (727/1000)
# Test Accuracy of automobile: 73% (737/1000)
# Test Accuracy of  bird: 64% (641/1000)
# Test Accuracy of   cat: 63% (630/1000)
# Test Accuracy of  deer: 59% (595/1000)
# Test Accuracy of   dog: 57% (576/1000)
# Test Accuracy of  frog: 75% (750/1000)
# Test Accuracy of horse: 73% (733/1000)
# Test Accuracy of  ship: 86% (863/1000)
# Test Accuracy of truck: 80% (800/1000)
#
# Test Accuracy (Overall): 70% (7052/10000)
# [24] time: 1063.188404083252 loss: 0.817 val_loss:0.8507525121109395 current_lr=0.043902
# Test Loss: 0.874212
#
# Test Accuracy of airplane: 76% (762/1000)
# Test Accuracy of automobile: 91% (913/1000)
# Test Accuracy of  bird: 68% (686/1000)
# Test Accuracy of   cat: 51% (518/1000)
# Test Accuracy of  deer: 53% (539/1000)
# Test Accuracy of   dog: 61% (619/1000)
# Test Accuracy of  frog: 85% (854/1000)
# Test Accuracy of horse: 71% (714/1000)
# Test Accuracy of  ship: 70% (709/1000)
# Test Accuracy of truck: 71% (712/1000)
#
# Test Accuracy (Overall): 70% (7026/10000)
# [25] time: 1108.1487383842468 loss: 0.781 val_loss:0.8742118259019489 current_lr=0.043410
# Test Loss: 0.886654
#
# Test Accuracy of airplane: 78% (781/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 75% (750/1000)
# Test Accuracy of   cat: 50% (508/1000)
# Test Accuracy of  deer: 54% (541/1000)
# Test Accuracy of   dog: 42% (428/1000)
# Test Accuracy of  frog: 83% (833/1000)
# Test Accuracy of horse: 81% (810/1000)
# Test Accuracy of  ship: 80% (801/1000)
# Test Accuracy of truck: 63% (630/1000)
#
# Test Accuracy (Overall): 69% (6948/10000)
# [26] time: 1152.618861913681 loss: 0.786 val_loss:0.8866535070576246 current_lr=0.042902
# Test Loss: 0.978388
#
# Test Accuracy of airplane: 70% (707/1000)
# Test Accuracy of automobile: 78% (783/1000)
# Test Accuracy of  bird: 57% (570/1000)
# Test Accuracy of   cat: 54% (544/1000)
# Test Accuracy of  deer: 69% (692/1000)
# Test Accuracy of   dog: 35% (355/1000)
# Test Accuracy of  frog: 88% (884/1000)
# Test Accuracy of horse: 63% (638/1000)
# Test Accuracy of  ship: 87% (873/1000)
# Test Accuracy of truck: 58% (588/1000)
#
# Test Accuracy (Overall): 66% (6634/10000)
# [27] time: 1197.4359970092773 loss: 0.761 val_loss:0.9783881827245785 current_lr=0.042380
# Test Loss: 0.878750
#
# Test Accuracy of airplane: 76% (761/1000)
# Test Accuracy of automobile: 79% (790/1000)
# Test Accuracy of  bird: 56% (568/1000)
# Test Accuracy of   cat: 49% (494/1000)
# Test Accuracy of  deer: 75% (756/1000)
# Test Accuracy of   dog: 52% (529/1000)
# Test Accuracy of  frog: 86% (861/1000)
# Test Accuracy of horse: 79% (791/1000)
# Test Accuracy of  ship: 80% (806/1000)
# Test Accuracy of truck: 73% (739/1000)
#
# Test Accuracy (Overall): 70% (7095/10000)
# [28] time: 1242.3463406562805 loss: 0.770 val_loss:0.8787502842613414 current_lr=0.041842
# Test Loss: 0.898730
#
# Test Accuracy of airplane: 63% (637/1000)
# Test Accuracy of automobile: 68% (688/1000)
# Test Accuracy of  bird: 51% (517/1000)
# Test Accuracy of   cat: 42% (423/1000)
# Test Accuracy of  deer: 81% (810/1000)
# Test Accuracy of   dog: 69% (692/1000)
# Test Accuracy of  frog: 75% (757/1000)
# Test Accuracy of horse: 79% (799/1000)
# Test Accuracy of  ship: 83% (830/1000)
# Test Accuracy of truck: 80% (805/1000)
#
# Test Accuracy (Overall): 69% (6958/10000)
# [29] time: 1286.2421743869781 loss: 0.747 val_loss:0.8987296940405157 current_lr=0.041290
# Test Loss: 0.835030
#
# Test Accuracy of airplane: 80% (806/1000)
# Test Accuracy of automobile: 83% (835/1000)
# Test Accuracy of  bird: 56% (561/1000)
# Test Accuracy of   cat: 58% (583/1000)
# Test Accuracy of  deer: 81% (813/1000)
# Test Accuracy of   dog: 62% (625/1000)
# Test Accuracy of  frog: 73% (739/1000)
# Test Accuracy of horse: 70% (703/1000)
# Test Accuracy of  ship: 77% (776/1000)
# Test Accuracy of truck: 70% (706/1000)
#
# Test Accuracy (Overall): 71% (7147/10000)
# [30] time: 1330.5593891143799 loss: 0.744 val_loss:0.8350297318229193 current_lr=0.040725
# Test Loss: 0.948547
#
# Test Accuracy of airplane: 71% (718/1000)
# Test Accuracy of automobile: 79% (792/1000)
# Test Accuracy of  bird: 69% (691/1000)
# Test Accuracy of   cat: 63% (632/1000)
# Test Accuracy of  deer: 54% (544/1000)
# Test Accuracy of   dog: 40% (403/1000)
# Test Accuracy of  frog: 84% (847/1000)
# Test Accuracy of horse: 71% (717/1000)
# Test Accuracy of  ship: 77% (779/1000)
# Test Accuracy of truck: 61% (614/1000)
#
# Test Accuracy (Overall): 67% (6737/10000)
# [31] time: 1375.2561962604523 loss: 0.757 val_loss:0.948547038850905 current_lr=0.040147
# Test Loss: 0.811699
#
# Test Accuracy of airplane: 76% (764/1000)
# Test Accuracy of automobile: 84% (846/1000)
# Test Accuracy of  bird: 64% (642/1000)
# Test Accuracy of   cat: 58% (580/1000)
# Test Accuracy of  deer: 61% (610/1000)
# Test Accuracy of   dog: 49% (495/1000)
# Test Accuracy of  frog: 83% (837/1000)
# Test Accuracy of horse: 81% (812/1000)
# Test Accuracy of  ship: 86% (862/1000)
# Test Accuracy of truck: 78% (780/1000)
#
# Test Accuracy (Overall): 72% (7228/10000)
# [32] time: 1418.975601196289 loss: 0.823 val_loss:0.8116993292977538 current_lr=0.039556
# Test Loss: 0.853227
#
# Test Accuracy of airplane: 75% (754/1000)
# Test Accuracy of automobile: 78% (782/1000)
# Test Accuracy of  bird: 68% (682/1000)
# Test Accuracy of   cat: 39% (394/1000)
# Test Accuracy of  deer: 74% (745/1000)
# Test Accuracy of   dog: 53% (531/1000)
# Test Accuracy of  frog: 73% (731/1000)
# Test Accuracy of horse: 82% (825/1000)
# Test Accuracy of  ship: 87% (872/1000)
# Test Accuracy of truck: 80% (803/1000)
#
# Test Accuracy (Overall): 71% (7119/10000)
# [33] time: 1463.017177581787 loss: 0.761 val_loss:0.8532266594186614 current_lr=0.038953
# Test Loss: 0.835672
#
# Test Accuracy of airplane: 67% (675/1000)
# Test Accuracy of automobile: 81% (811/1000)
# Test Accuracy of  bird: 76% (762/1000)
# Test Accuracy of   cat: 60% (602/1000)
# Test Accuracy of  deer: 63% (637/1000)
# Test Accuracy of   dog: 49% (496/1000)
# Test Accuracy of  frog: 75% (753/1000)
# Test Accuracy of horse: 78% (786/1000)
# Test Accuracy of  ship: 92% (924/1000)
# Test Accuracy of truck: 66% (669/1000)
#
# Test Accuracy (Overall): 71% (7115/10000)
# [34] time: 1506.7027280330658 loss: 0.734 val_loss:0.8356719443315193 current_lr=0.038339
# Test Loss: 0.813857
#
# Test Accuracy of airplane: 66% (662/1000)
# Test Accuracy of automobile: 77% (775/1000)
# Test Accuracy of  bird: 62% (629/1000)
# Test Accuracy of   cat: 60% (609/1000)
# Test Accuracy of  deer: 60% (607/1000)
# Test Accuracy of   dog: 59% (596/1000)
# Test Accuracy of  frog: 74% (741/1000)
# Test Accuracy of horse: 80% (806/1000)
# Test Accuracy of  ship: 88% (880/1000)
# Test Accuracy of truck: 88% (882/1000)
#
# Test Accuracy (Overall): 71% (7187/10000)
# [35] time: 1549.8116011619568 loss: 0.737 val_loss:0.8138573184798036 current_lr=0.037715
# Test Loss: 0.812079
#
# Test Accuracy of airplane: 68% (686/1000)
# Test Accuracy of automobile: 77% (777/1000)
# Test Accuracy of  bird: 59% (594/1000)
# Test Accuracy of   cat: 62% (625/1000)
# Test Accuracy of  deer: 57% (573/1000)
# Test Accuracy of   dog: 60% (605/1000)
# Test Accuracy of  frog: 79% (790/1000)
# Test Accuracy of horse: 79% (793/1000)
# Test Accuracy of  ship: 85% (851/1000)
# Test Accuracy of truck: 87% (872/1000)
#
# Test Accuracy (Overall): 71% (7166/10000)
# [36] time: 1593.668579339981 loss: 0.720 val_loss:0.8120785148083409 current_lr=0.037080
# Test Loss: 1.203459
#
# Test Accuracy of airplane: 47% (479/1000)
# Test Accuracy of automobile: 44% (445/1000)
# Test Accuracy of  bird: 77% (777/1000)
# Test Accuracy of   cat: 50% (509/1000)
# Test Accuracy of  deer: 41% (415/1000)
# Test Accuracy of   dog: 58% (586/1000)
# Test Accuracy of  frog: 44% (446/1000)
# Test Accuracy of horse: 57% (578/1000)
# Test Accuracy of  ship: 87% (873/1000)
# Test Accuracy of truck: 67% (675/1000)
#
# Test Accuracy (Overall): 57% (5783/10000)
# [37] time: 1636.9770996570587 loss: 0.766 val_loss:1.2034590387646156 current_lr=0.036436
# Test Loss: 0.795829
#
# Test Accuracy of airplane: 79% (799/1000)
# Test Accuracy of automobile: 78% (785/1000)
# Test Accuracy of  bird: 53% (535/1000)
# Test Accuracy of   cat: 40% (400/1000)
# Test Accuracy of  deer: 77% (773/1000)
# Test Accuracy of   dog: 61% (619/1000)
# Test Accuracy of  frog: 86% (869/1000)
# Test Accuracy of horse: 82% (824/1000)
# Test Accuracy of  ship: 85% (854/1000)
# Test Accuracy of truck: 81% (813/1000)
#
# Test Accuracy (Overall): 72% (7271/10000)
# [38] time: 1680.354979276657 loss: 0.751 val_loss:0.7958292523516884 current_lr=0.035783
# Test Loss: 0.795076
#
# Test Accuracy of airplane: 81% (815/1000)
# Test Accuracy of automobile: 83% (839/1000)
# Test Accuracy of  bird: 67% (673/1000)
# Test Accuracy of   cat: 42% (420/1000)
# Test Accuracy of  deer: 67% (670/1000)
# Test Accuracy of   dog: 63% (631/1000)
# Test Accuracy of  frog: 79% (795/1000)
# Test Accuracy of horse: 76% (765/1000)
# Test Accuracy of  ship: 83% (838/1000)
# Test Accuracy of truck: 82% (827/1000)
#
# Test Accuracy (Overall): 72% (7273/10000)
# [39] time: 1723.638510942459 loss: 0.715 val_loss:0.7950761785990075 current_lr=0.035122
# Test Loss: 0.795390
#
# Test Accuracy of airplane: 79% (793/1000)
# Test Accuracy of automobile: 83% (832/1000)
# Test Accuracy of  bird: 55% (558/1000)
# Test Accuracy of   cat: 55% (551/1000)
# Test Accuracy of  deer: 71% (711/1000)
# Test Accuracy of   dog: 49% (490/1000)
# Test Accuracy of  frog: 87% (877/1000)
# Test Accuracy of horse: 80% (808/1000)
# Test Accuracy of  ship: 84% (844/1000)
# Test Accuracy of truck: 82% (829/1000)
#
# Test Accuracy (Overall): 72% (7293/10000)
# [40] time: 1767.2982113361359 loss: 0.720 val_loss:0.7953902158556105 current_lr=0.034453
# Test Loss: 0.773797
#
# Test Accuracy of airplane: 81% (814/1000)
# Test Accuracy of automobile: 80% (804/1000)
# Test Accuracy of  bird: 62% (621/1000)
# Test Accuracy of   cat: 60% (609/1000)
# Test Accuracy of  deer: 76% (762/1000)
# Test Accuracy of   dog: 64% (646/1000)
# Test Accuracy of  frog: 80% (809/1000)
# Test Accuracy of horse: 68% (683/1000)
# Test Accuracy of  ship: 82% (829/1000)
# Test Accuracy of truck: 79% (798/1000)
#
# Test Accuracy (Overall): 73% (7375/10000)
# [41] time: 1811.2773094177246 loss: 0.688 val_loss:0.7737968088705328 current_lr=0.033777
# Test Loss: 0.782319
#
# Test Accuracy of airplane: 82% (826/1000)
# Test Accuracy of automobile: 90% (907/1000)
# Test Accuracy of  bird: 71% (713/1000)
# Test Accuracy of   cat: 54% (547/1000)
# Test Accuracy of  deer: 71% (718/1000)
# Test Accuracy of   dog: 49% (493/1000)
# Test Accuracy of  frog: 82% (822/1000)
# Test Accuracy of horse: 80% (804/1000)
# Test Accuracy of  ship: 76% (762/1000)
# Test Accuracy of truck: 75% (752/1000)
#
# Test Accuracy (Overall): 73% (7344/10000)
# [42] time: 1854.371732711792 loss: 0.673 val_loss:0.7823185777362389 current_lr=0.033096
# Test Loss: 0.767539
#
# Test Accuracy of airplane: 85% (850/1000)
# Test Accuracy of automobile: 85% (854/1000)
# Test Accuracy of  bird: 64% (641/1000)
# Test Accuracy of   cat: 55% (555/1000)
# Test Accuracy of  deer: 74% (747/1000)
# Test Accuracy of   dog: 52% (522/1000)
# Test Accuracy of  frog: 77% (770/1000)
# Test Accuracy of horse: 84% (843/1000)
# Test Accuracy of  ship: 84% (848/1000)
# Test Accuracy of truck: 75% (758/1000)
#
# Test Accuracy (Overall): 73% (7388/10000)
# [43] time: 1897.8490180969238 loss: 0.729 val_loss:0.7675388621378548 current_lr=0.032408
# Test Loss: 0.783461
#
# Test Accuracy of airplane: 82% (823/1000)
# Test Accuracy of automobile: 81% (816/1000)
# Test Accuracy of  bird: 51% (512/1000)
# Test Accuracy of   cat: 54% (548/1000)
# Test Accuracy of  deer: 74% (740/1000)
# Test Accuracy of   dog: 57% (573/1000)
# Test Accuracy of  frog: 85% (858/1000)
# Test Accuracy of horse: 87% (879/1000)
# Test Accuracy of  ship: 81% (810/1000)
# Test Accuracy of truck: 80% (800/1000)
#
# Test Accuracy (Overall): 73% (7359/10000)
# [44] time: 1941.2926461696625 loss: 0.660 val_loss:0.783461483973491 current_lr=0.031716
# Test Loss: 0.761228
#
# Test Accuracy of airplane: 82% (825/1000)
# Test Accuracy of automobile: 80% (809/1000)
# Test Accuracy of  bird: 64% (647/1000)
# Test Accuracy of   cat: 51% (512/1000)
# Test Accuracy of  deer: 66% (667/1000)
# Test Accuracy of   dog: 65% (657/1000)
# Test Accuracy of  frog: 82% (820/1000)
# Test Accuracy of horse: 83% (835/1000)
# Test Accuracy of  ship: 86% (866/1000)
# Test Accuracy of truck: 79% (791/1000)
#
# Test Accuracy (Overall): 74% (7429/10000)
# [45] time: 1985.1351206302643 loss: 0.664 val_loss:0.7612280634385121 current_lr=0.031020
# Test Loss: 0.776426
#
# Test Accuracy of airplane: 78% (787/1000)
# Test Accuracy of automobile: 85% (859/1000)
# Test Accuracy of  bird: 66% (666/1000)
# Test Accuracy of   cat: 60% (607/1000)
# Test Accuracy of  deer: 69% (694/1000)
# Test Accuracy of   dog: 57% (570/1000)
# Test Accuracy of  frog: 77% (778/1000)
# Test Accuracy of horse: 78% (781/1000)
# Test Accuracy of  ship: 89% (897/1000)
# Test Accuracy of truck: 73% (739/1000)
#
# Test Accuracy (Overall): 73% (7378/10000)
# [46] time: 2028.9793775081635 loss: 0.642 val_loss:0.7764260508591616 current_lr=0.030320
# Test Loss: 0.749205
#
# Test Accuracy of airplane: 77% (777/1000)
# Test Accuracy of automobile: 87% (872/1000)
# Test Accuracy of  bird: 71% (712/1000)
# Test Accuracy of   cat: 55% (556/1000)
# Test Accuracy of  deer: 66% (669/1000)
# Test Accuracy of   dog: 64% (646/1000)
# Test Accuracy of  frog: 76% (769/1000)
# Test Accuracy of horse: 76% (768/1000)
# Test Accuracy of  ship: 83% (833/1000)
# Test Accuracy of truck: 85% (857/1000)
#
# Test Accuracy (Overall): 74% (7459/10000)
# [47] time: 2072.30774641037 loss: 0.657 val_loss:0.7492053818099106 current_lr=0.029617
# Test Loss: 0.770360
#
# Test Accuracy of airplane: 72% (724/1000)
# Test Accuracy of automobile: 87% (878/1000)
# Test Accuracy of  bird: 57% (570/1000)
# Test Accuracy of   cat: 51% (513/1000)
# Test Accuracy of  deer: 60% (605/1000)
# Test Accuracy of   dog: 72% (722/1000)
# Test Accuracy of  frog: 88% (884/1000)
# Test Accuracy of horse: 79% (795/1000)
# Test Accuracy of  ship: 87% (877/1000)
# Test Accuracy of truck: 84% (842/1000)
#
# Test Accuracy (Overall): 74% (7410/10000)
# [48] time: 2116.419028043747 loss: 0.665 val_loss:0.7703604532193534 current_lr=0.028913
# Test Loss: 0.752213
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 83% (833/1000)
# Test Accuracy of  bird: 63% (635/1000)
# Test Accuracy of   cat: 53% (538/1000)
# Test Accuracy of  deer: 78% (782/1000)
# Test Accuracy of   dog: 69% (699/1000)
# Test Accuracy of  frog: 72% (724/1000)
# Test Accuracy of horse: 81% (818/1000)
# Test Accuracy of  ship: 79% (793/1000)
# Test Accuracy of truck: 82% (828/1000)
#
# Test Accuracy (Overall): 74% (7489/10000)
# [49] time: 2160.443786382675 loss: 0.638 val_loss:0.7522126572041572 current_lr=0.028207
# Test Loss: 0.793160
#
# Test Accuracy of airplane: 86% (869/1000)
# Test Accuracy of automobile: 82% (824/1000)
# Test Accuracy of  bird: 64% (645/1000)
# Test Accuracy of   cat: 59% (596/1000)
# Test Accuracy of  deer: 55% (555/1000)
# Test Accuracy of   dog: 68% (682/1000)
# Test Accuracy of  frog: 77% (778/1000)
# Test Accuracy of horse: 78% (783/1000)
# Test Accuracy of  ship: 75% (756/1000)
# Test Accuracy of truck: 80% (804/1000)
#
# Test Accuracy (Overall): 72% (7292/10000)
# [50] time: 2203.9907467365265 loss: 0.636 val_loss:0.7931602684002889 current_lr=0.027500
# Test Loss: 0.773057
#
# Test Accuracy of airplane: 76% (762/1000)
# Test Accuracy of automobile: 82% (829/1000)
# Test Accuracy of  bird: 64% (646/1000)
# Test Accuracy of   cat: 63% (633/1000)
# Test Accuracy of  deer: 63% (633/1000)
# Test Accuracy of   dog: 64% (648/1000)
# Test Accuracy of  frog: 73% (738/1000)
# Test Accuracy of horse: 79% (793/1000)
# Test Accuracy of  ship: 85% (854/1000)
# Test Accuracy of truck: 86% (867/1000)
#
# Test Accuracy (Overall): 74% (7403/10000)
# [51] time: 2247.622879266739 loss: 0.623 val_loss:0.7730565795415565 current_lr=0.026793
# Test Loss: 0.734589
#
# Test Accuracy of airplane: 76% (762/1000)
# Test Accuracy of automobile: 84% (842/1000)
# Test Accuracy of  bird: 56% (563/1000)
# Test Accuracy of   cat: 49% (498/1000)
# Test Accuracy of  deer: 75% (755/1000)
# Test Accuracy of   dog: 63% (631/1000)
# Test Accuracy of  frog: 85% (854/1000)
# Test Accuracy of horse: 86% (860/1000)
# Test Accuracy of  ship: 90% (908/1000)
# Test Accuracy of truck: 87% (873/1000)
#
# Test Accuracy (Overall): 75% (7546/10000)
# [52] time: 2291.183760404587 loss: 0.648 val_loss:0.7345890953570982 current_lr=0.026087
# Test Loss: 0.774761
#
# Test Accuracy of airplane: 81% (815/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 65% (653/1000)
# Test Accuracy of   cat: 58% (582/1000)
# Test Accuracy of  deer: 68% (685/1000)
# Test Accuracy of   dog: 54% (542/1000)
# Test Accuracy of  frog: 88% (889/1000)
# Test Accuracy of horse: 75% (756/1000)
# Test Accuracy of  ship: 80% (800/1000)
# Test Accuracy of truck: 70% (701/1000)
#
# Test Accuracy (Overall): 73% (7312/10000)
# [53] time: 2334.6010432243347 loss: 0.603 val_loss:0.7747612655917301 current_lr=0.025383
# Test Loss: 0.777813
#
# Test Accuracy of airplane: 78% (785/1000)
# Test Accuracy of automobile: 81% (815/1000)
# Test Accuracy of  bird: 59% (598/1000)
# Test Accuracy of   cat: 44% (446/1000)
# Test Accuracy of  deer: 77% (776/1000)
# Test Accuracy of   dog: 77% (775/1000)
# Test Accuracy of  frog: 79% (795/1000)
# Test Accuracy of horse: 81% (811/1000)
# Test Accuracy of  ship: 76% (769/1000)
# Test Accuracy of truck: 80% (806/1000)
#
# Test Accuracy (Overall): 73% (7376/10000)
# [54] time: 2378.621136188507 loss: 0.605 val_loss:0.7778131539308573 current_lr=0.024680
# Test Loss: 0.736307
#
# Test Accuracy of airplane: 79% (793/1000)
# Test Accuracy of automobile: 78% (781/1000)
# Test Accuracy of  bird: 72% (723/1000)
# Test Accuracy of   cat: 68% (686/1000)
# Test Accuracy of  deer: 74% (744/1000)
# Test Accuracy of   dog: 53% (537/1000)
# Test Accuracy of  frog: 71% (715/1000)
# Test Accuracy of horse: 79% (796/1000)
# Test Accuracy of  ship: 87% (878/1000)
# Test Accuracy of truck: 81% (812/1000)
#
# Test Accuracy (Overall): 74% (7465/10000)
# [55] time: 2421.4997622966766 loss: 0.597 val_loss:0.7363074014458475 current_lr=0.023980
# Test Loss: 0.754890
#
# Test Accuracy of airplane: 78% (789/1000)
# Test Accuracy of automobile: 86% (868/1000)
# Test Accuracy of  bird: 57% (574/1000)
# Test Accuracy of   cat: 59% (593/1000)
# Test Accuracy of  deer: 83% (833/1000)
# Test Accuracy of   dog: 58% (589/1000)
# Test Accuracy of  frog: 78% (781/1000)
# Test Accuracy of horse: 73% (732/1000)
# Test Accuracy of  ship: 85% (856/1000)
# Test Accuracy of truck: 80% (800/1000)
#
# Test Accuracy (Overall): 74% (7415/10000)
# [56] time: 2464.866158723831 loss: 0.584 val_loss:0.7548902412004108 current_lr=0.023284
# Test Loss: 0.735209
#
# Test Accuracy of airplane: 78% (784/1000)
# Test Accuracy of automobile: 85% (859/1000)
# Test Accuracy of  bird: 75% (757/1000)
# Test Accuracy of   cat: 53% (537/1000)
# Test Accuracy of  deer: 72% (722/1000)
# Test Accuracy of   dog: 63% (630/1000)
# Test Accuracy of  frog: 84% (846/1000)
# Test Accuracy of horse: 75% (750/1000)
# Test Accuracy of  ship: 87% (878/1000)
# Test Accuracy of truck: 76% (762/1000)
#
# Test Accuracy (Overall): 75% (7525/10000)
# [57] time: 2508.476989507675 loss: 0.575 val_loss:0.735208500412446 current_lr=0.022592
# Test Loss: 0.733930
#
# Test Accuracy of airplane: 78% (782/1000)
# Test Accuracy of automobile: 87% (875/1000)
# Test Accuracy of  bird: 63% (633/1000)
# Test Accuracy of   cat: 53% (535/1000)
# Test Accuracy of  deer: 75% (751/1000)
# Test Accuracy of   dog: 78% (789/1000)
# Test Accuracy of  frog: 83% (838/1000)
# Test Accuracy of horse: 74% (745/1000)
# Test Accuracy of  ship: 83% (830/1000)
# Test Accuracy of truck: 80% (803/1000)
#
# Test Accuracy (Overall): 75% (7581/10000)
# [58] time: 2552.275813102722 loss: 0.581 val_loss:0.7339299509796915 current_lr=0.021904
# Test Loss: 0.733556
#
# Test Accuracy of airplane: 77% (774/1000)
# Test Accuracy of automobile: 84% (846/1000)
# Test Accuracy of  bird: 69% (692/1000)
# Test Accuracy of   cat: 53% (533/1000)
# Test Accuracy of  deer: 70% (702/1000)
# Test Accuracy of   dog: 72% (722/1000)
# Test Accuracy of  frog: 78% (780/1000)
# Test Accuracy of horse: 81% (812/1000)
# Test Accuracy of  ship: 85% (858/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 75% (7594/10000)
# [59] time: 2596.508887052536 loss: 0.573 val_loss:0.7335559322109705 current_lr=0.021223
# Test Loss: 0.700872
#
# Test Accuracy of airplane: 78% (782/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 67% (677/1000)
# Test Accuracy of   cat: 65% (654/1000)
# Test Accuracy of  deer: 80% (801/1000)
# Test Accuracy of   dog: 58% (587/1000)
# Test Accuracy of  frog: 83% (832/1000)
# Test Accuracy of horse: 76% (768/1000)
# Test Accuracy of  ship: 86% (864/1000)
# Test Accuracy of truck: 75% (751/1000)
#
# Test Accuracy (Overall): 76% (7609/10000)
# [60] time: 2639.6473565101624 loss: 0.554 val_loss:0.7008721934089178 current_lr=0.020547
# Test Loss: 0.739509
#
# Test Accuracy of airplane: 76% (760/1000)
# Test Accuracy of automobile: 81% (817/1000)
# Test Accuracy of  bird: 62% (628/1000)
# Test Accuracy of   cat: 67% (674/1000)
# Test Accuracy of  deer: 72% (729/1000)
# Test Accuracy of   dog: 62% (627/1000)
# Test Accuracy of  frog: 77% (771/1000)
# Test Accuracy of horse: 83% (833/1000)
# Test Accuracy of  ship: 87% (878/1000)
# Test Accuracy of truck: 76% (766/1000)
#
# Test Accuracy (Overall): 74% (7483/10000)
# [61] time: 2683.393394947052 loss: 0.541 val_loss:0.739509060035778 current_lr=0.019878
# Test Loss: 0.710771
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 87% (875/1000)
# Test Accuracy of  bird: 66% (666/1000)
# Test Accuracy of   cat: 56% (560/1000)
# Test Accuracy of  deer: 71% (716/1000)
# Test Accuracy of   dog: 68% (681/1000)
# Test Accuracy of  frog: 80% (807/1000)
# Test Accuracy of horse: 81% (818/1000)
# Test Accuracy of  ship: 85% (852/1000)
# Test Accuracy of truck: 83% (831/1000)
#
# Test Accuracy (Overall): 76% (7654/10000)
# [62] time: 2727.25395154953 loss: 0.560 val_loss:0.7107706360424622 current_lr=0.019217
# Test Loss: 0.700631
#
# Test Accuracy of airplane: 75% (757/1000)
# Test Accuracy of automobile: 85% (859/1000)
# Test Accuracy of  bird: 61% (611/1000)
# Test Accuracy of   cat: 59% (590/1000)
# Test Accuracy of  deer: 76% (764/1000)
# Test Accuracy of   dog: 58% (587/1000)
# Test Accuracy of  frog: 84% (841/1000)
# Test Accuracy of horse: 83% (837/1000)
# Test Accuracy of  ship: 87% (875/1000)
# Test Accuracy of truck: 85% (857/1000)
#
# Test Accuracy (Overall): 75% (7578/10000)
# [63] time: 2770.433202981949 loss: 0.528 val_loss:0.7006307376336448 current_lr=0.018564
# Test Loss: 0.711444
#
# Test Accuracy of airplane: 78% (788/1000)
# Test Accuracy of automobile: 81% (810/1000)
# Test Accuracy of  bird: 71% (713/1000)
# Test Accuracy of   cat: 58% (583/1000)
# Test Accuracy of  deer: 76% (767/1000)
# Test Accuracy of   dog: 64% (640/1000)
# Test Accuracy of  frog: 89% (896/1000)
# Test Accuracy of horse: 74% (745/1000)
# Test Accuracy of  ship: 90% (905/1000)
# Test Accuracy of truck: 77% (776/1000)
#
# Test Accuracy (Overall): 76% (7623/10000)
# [64] time: 2814.1155812740326 loss: 0.528 val_loss:0.7114439640618577 current_lr=0.017920
# Test Loss: 0.743863
#
# Test Accuracy of airplane: 69% (698/1000)
# Test Accuracy of automobile: 79% (795/1000)
# Test Accuracy of  bird: 75% (751/1000)
# Test Accuracy of   cat: 53% (538/1000)
# Test Accuracy of  deer: 80% (800/1000)
# Test Accuracy of   dog: 69% (698/1000)
# Test Accuracy of  frog: 83% (832/1000)
# Test Accuracy of horse: 79% (790/1000)
# Test Accuracy of  ship: 81% (816/1000)
# Test Accuracy of truck: 81% (813/1000)
#
# Test Accuracy (Overall): 75% (7531/10000)
# [65] time: 2857.333167076111 loss: 0.521 val_loss:0.743862777571135 current_lr=0.017285
# Test Loss: 0.698571
#
# Test Accuracy of airplane: 80% (808/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 74% (747/1000)
# Test Accuracy of   cat: 54% (543/1000)
# Test Accuracy of  deer: 71% (718/1000)
# Test Accuracy of   dog: 61% (615/1000)
# Test Accuracy of  frog: 82% (827/1000)
# Test Accuracy of horse: 83% (834/1000)
# Test Accuracy of  ship: 86% (863/1000)
# Test Accuracy of truck: 79% (793/1000)
#
# Test Accuracy (Overall): 76% (7614/10000)
# [66] time: 2900.822914838791 loss: 0.509 val_loss:0.6985714073422589 current_lr=0.016661
# Test Loss: 0.721621
#
# Test Accuracy of airplane: 72% (726/1000)
# Test Accuracy of automobile: 84% (845/1000)
# Test Accuracy of  bird: 63% (638/1000)
# Test Accuracy of   cat: 56% (563/1000)
# Test Accuracy of  deer: 88% (884/1000)
# Test Accuracy of   dog: 62% (621/1000)
# Test Accuracy of  frog: 77% (773/1000)
# Test Accuracy of horse: 83% (838/1000)
# Test Accuracy of  ship: 87% (879/1000)
# Test Accuracy of truck: 84% (844/1000)
#
# Test Accuracy (Overall): 76% (7611/10000)
# [67] time: 2944.56632399559 loss: 0.498 val_loss:0.7216214137741283 current_lr=0.016047
# Test Loss: 0.726914
#
# Test Accuracy of airplane: 81% (812/1000)
# Test Accuracy of automobile: 87% (872/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 53% (537/1000)
# Test Accuracy of  deer: 81% (817/1000)
# Test Accuracy of   dog: 59% (590/1000)
# Test Accuracy of  frog: 79% (795/1000)
# Test Accuracy of horse: 83% (835/1000)
# Test Accuracy of  ship: 88% (887/1000)
# Test Accuracy of truck: 74% (748/1000)
#
# Test Accuracy (Overall): 76% (7632/10000)
# [68] time: 2988.6408874988556 loss: 0.489 val_loss:0.7269138573091242 current_lr=0.015444
# Test Loss: 0.712713
#
# Test Accuracy of airplane: 83% (833/1000)
# Test Accuracy of automobile: 86% (865/1000)
# Test Accuracy of  bird: 68% (689/1000)
# Test Accuracy of   cat: 60% (607/1000)
# Test Accuracy of  deer: 71% (719/1000)
# Test Accuracy of   dog: 66% (666/1000)
# Test Accuracy of  frog: 81% (819/1000)
# Test Accuracy of horse: 82% (825/1000)
# Test Accuracy of  ship: 82% (829/1000)
# Test Accuracy of truck: 80% (808/1000)
#
# Test Accuracy (Overall): 76% (7660/10000)
# [69] time: 3033.6789560317993 loss: 0.484 val_loss:0.7127129518533055 current_lr=0.014853
# Test Loss: 0.751198
#
# Test Accuracy of airplane: 76% (768/1000)
# Test Accuracy of automobile: 83% (830/1000)
# Test Accuracy of  bird: 67% (675/1000)
# Test Accuracy of   cat: 65% (655/1000)
# Test Accuracy of  deer: 66% (669/1000)
# Test Accuracy of   dog: 60% (608/1000)
# Test Accuracy of  frog: 71% (719/1000)
# Test Accuracy of horse: 87% (878/1000)
# Test Accuracy of  ship: 87% (878/1000)
# Test Accuracy of truck: 87% (874/1000)
#
# Test Accuracy (Overall): 75% (7554/10000)
# [70] time: 3079.0410239696503 loss: 0.473 val_loss:0.7511983766585966 current_lr=0.014275
# Test Loss: 0.730953
#
# Test Accuracy of airplane: 75% (757/1000)
# Test Accuracy of automobile: 87% (870/1000)
# Test Accuracy of  bird: 60% (606/1000)
# Test Accuracy of   cat: 51% (515/1000)
# Test Accuracy of  deer: 71% (718/1000)
# Test Accuracy of   dog: 70% (705/1000)
# Test Accuracy of  frog: 87% (872/1000)
# Test Accuracy of horse: 85% (850/1000)
# Test Accuracy of  ship: 81% (814/1000)
# Test Accuracy of truck: 85% (853/1000)
#
# Test Accuracy (Overall): 75% (7560/10000)
# [71] time: 3123.4780263900757 loss: 0.465 val_loss:0.7309528136555152 current_lr=0.013710
# Test Loss: 0.693895
#
# Test Accuracy of airplane: 81% (810/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 65% (651/1000)
# Test Accuracy of   cat: 59% (597/1000)
# Test Accuracy of  deer: 78% (784/1000)
# Test Accuracy of   dog: 61% (612/1000)
# Test Accuracy of  frog: 88% (888/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 81% (816/1000)
# Test Accuracy of truck: 79% (799/1000)
#
# Test Accuracy (Overall): 77% (7708/10000)
# [72] time: 3167.9712250232697 loss: 0.464 val_loss:0.6938950890981699 current_lr=0.013158
# Test Loss: 0.680376
#
# Test Accuracy of airplane: 81% (819/1000)
# Test Accuracy of automobile: 81% (818/1000)
# Test Accuracy of  bird: 71% (719/1000)
# Test Accuracy of   cat: 63% (631/1000)
# Test Accuracy of  deer: 72% (720/1000)
# Test Accuracy of   dog: 66% (661/1000)
# Test Accuracy of  frog: 83% (834/1000)
# Test Accuracy of horse: 82% (827/1000)
# Test Accuracy of  ship: 87% (871/1000)
# Test Accuracy of truck: 85% (852/1000)
#
# Test Accuracy (Overall): 77% (7752/10000)
# [73] time: 3213.1347692012787 loss: 0.445 val_loss:0.6803755745103087 current_lr=0.012620
# Test Loss: 0.710407
#
# Test Accuracy of airplane: 85% (852/1000)
# Test Accuracy of automobile: 87% (872/1000)
# Test Accuracy of  bird: 63% (635/1000)
# Test Accuracy of   cat: 52% (522/1000)
# Test Accuracy of  deer: 77% (770/1000)
# Test Accuracy of   dog: 69% (695/1000)
# Test Accuracy of  frog: 88% (889/1000)
# Test Accuracy of horse: 80% (809/1000)
# Test Accuracy of  ship: 82% (826/1000)
# Test Accuracy of truck: 84% (848/1000)
#
# Test Accuracy (Overall): 77% (7718/10000)
# [74] time: 3256.9669630527496 loss: 0.437 val_loss:0.7104067285604114 current_lr=0.012098
# Test Loss: 0.719617
#
# Test Accuracy of airplane: 84% (841/1000)
# Test Accuracy of automobile: 83% (836/1000)
# Test Accuracy of  bird: 62% (624/1000)
# Test Accuracy of   cat: 53% (539/1000)
# Test Accuracy of  deer: 76% (760/1000)
# Test Accuracy of   dog: 75% (757/1000)
# Test Accuracy of  frog: 75% (754/1000)
# Test Accuracy of horse: 83% (834/1000)
# Test Accuracy of  ship: 89% (898/1000)
# Test Accuracy of truck: 83% (833/1000)
#
# Test Accuracy (Overall): 76% (7676/10000)
# [75] time: 3300.917465209961 loss: 0.430 val_loss:0.7196170246299309 current_lr=0.011590
# Test Loss: 0.708205
#
# Test Accuracy of airplane: 79% (797/1000)
# Test Accuracy of automobile: 84% (843/1000)
# Test Accuracy of  bird: 73% (733/1000)
# Test Accuracy of   cat: 55% (558/1000)
# Test Accuracy of  deer: 80% (809/1000)
# Test Accuracy of   dog: 64% (644/1000)
# Test Accuracy of  frog: 83% (833/1000)
# Test Accuracy of horse: 79% (792/1000)
# Test Accuracy of  ship: 90% (909/1000)
# Test Accuracy of truck: 84% (842/1000)
#
# Test Accuracy (Overall): 77% (7760/10000)
# [76] time: 3345.1415770053864 loss: 0.419 val_loss:0.7082048624376708 current_lr=0.011098
# Test Loss: 0.679970
#
# Test Accuracy of airplane: 81% (815/1000)
# Test Accuracy of automobile: 88% (883/1000)
# Test Accuracy of  bird: 69% (690/1000)
# Test Accuracy of   cat: 49% (495/1000)
# Test Accuracy of  deer: 81% (811/1000)
# Test Accuracy of   dog: 73% (735/1000)
# Test Accuracy of  frog: 87% (870/1000)
# Test Accuracy of horse: 78% (780/1000)
# Test Accuracy of  ship: 87% (875/1000)
# Test Accuracy of truck: 82% (823/1000)
#
# Test Accuracy (Overall): 77% (7777/10000)
# [77] time: 3388.543235063553 loss: 0.408 val_loss:0.6799695378617395 current_lr=0.010623
# Test Loss: 0.679114
#
# Test Accuracy of airplane: 81% (819/1000)
# Test Accuracy of automobile: 85% (856/1000)
# Test Accuracy of  bird: 63% (632/1000)
# Test Accuracy of   cat: 60% (605/1000)
# Test Accuracy of  deer: 78% (786/1000)
# Test Accuracy of   dog: 64% (641/1000)
# Test Accuracy of  frog: 83% (835/1000)
# Test Accuracy of horse: 83% (833/1000)
# Test Accuracy of  ship: 89% (897/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 77% (7770/10000)
# [78] time: 3432.1367881298065 loss: 0.405 val_loss:0.6791140844550314 current_lr=0.010163
# Test Loss: 0.744557
#
# Test Accuracy of airplane: 80% (804/1000)
# Test Accuracy of automobile: 85% (858/1000)
# Test Accuracy of  bird: 63% (630/1000)
# Test Accuracy of   cat: 61% (610/1000)
# Test Accuracy of  deer: 76% (760/1000)
# Test Accuracy of   dog: 73% (736/1000)
# Test Accuracy of  frog: 74% (749/1000)
# Test Accuracy of horse: 83% (837/1000)
# Test Accuracy of  ship: 86% (862/1000)
# Test Accuracy of truck: 81% (814/1000)
#
# Test Accuracy (Overall): 76% (7660/10000)
# [79] time: 3475.0425062179565 loss: 0.387 val_loss:0.7445572369460818 current_lr=0.009722
# Test Loss: 0.707538
#
# Test Accuracy of airplane: 80% (806/1000)
# Test Accuracy of automobile: 84% (843/1000)
# Test Accuracy of  bird: 68% (687/1000)
# Test Accuracy of   cat: 53% (531/1000)
# Test Accuracy of  deer: 84% (848/1000)
# Test Accuracy of   dog: 65% (652/1000)
# Test Accuracy of  frog: 88% (881/1000)
# Test Accuracy of horse: 83% (833/1000)
# Test Accuracy of  ship: 87% (872/1000)
# Test Accuracy of truck: 83% (835/1000)
#
# Test Accuracy (Overall): 77% (7788/10000)
# [80] time: 3518.656883955002 loss: 0.381 val_loss:0.7075381633601611 current_lr=0.009297
# Test Loss: 0.702281
#
# Test Accuracy of airplane: 83% (832/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 66% (668/1000)
# Test Accuracy of   cat: 60% (600/1000)
# Test Accuracy of  deer: 79% (798/1000)
# Test Accuracy of   dog: 67% (679/1000)
# Test Accuracy of  frog: 83% (836/1000)
# Test Accuracy of horse: 81% (812/1000)
# Test Accuracy of  ship: 86% (861/1000)
# Test Accuracy of truck: 87% (876/1000)
#
# Test Accuracy (Overall): 78% (7828/10000)
# [81] time: 3562.8476209640503 loss: 0.376 val_loss:0.7022813592530504 current_lr=0.008891
# Test Loss: 0.707094
#
# Test Accuracy of airplane: 84% (840/1000)
# Test Accuracy of automobile: 84% (846/1000)
# Test Accuracy of  bird: 71% (717/1000)
# Test Accuracy of   cat: 63% (638/1000)
# Test Accuracy of  deer: 74% (744/1000)
# Test Accuracy of   dog: 64% (644/1000)
# Test Accuracy of  frog: 84% (849/1000)
# Test Accuracy of horse: 82% (825/1000)
# Test Accuracy of  ship: 87% (879/1000)
# Test Accuracy of truck: 85% (853/1000)
#
# Test Accuracy (Overall): 78% (7835/10000)
# [82] time: 3606.338483810425 loss: 0.359 val_loss:0.7070940423615372 current_lr=0.008503
# Test Loss: 0.743252
#
# Test Accuracy of airplane: 86% (869/1000)
# Test Accuracy of automobile: 87% (871/1000)
# Test Accuracy of  bird: 62% (623/1000)
# Test Accuracy of   cat: 60% (608/1000)
# Test Accuracy of  deer: 79% (796/1000)
# Test Accuracy of   dog: 58% (585/1000)
# Test Accuracy of  frog: 86% (862/1000)
# Test Accuracy of horse: 87% (875/1000)
# Test Accuracy of  ship: 81% (811/1000)
# Test Accuracy of truck: 84% (840/1000)
#
# Test Accuracy (Overall): 77% (7740/10000)
# [83] time: 3650.297047138214 loss: 0.347 val_loss:0.7432518148724037 current_lr=0.008133
# Test Loss: 0.728775
#
# Test Accuracy of airplane: 86% (860/1000)
# Test Accuracy of automobile: 84% (849/1000)
# Test Accuracy of  bird: 73% (731/1000)
# Test Accuracy of   cat: 58% (582/1000)
# Test Accuracy of  deer: 73% (733/1000)
# Test Accuracy of   dog: 68% (682/1000)
# Test Accuracy of  frog: 77% (770/1000)
# Test Accuracy of horse: 82% (824/1000)
# Test Accuracy of  ship: 83% (836/1000)
# Test Accuracy of truck: 85% (853/1000)
#
# Test Accuracy (Overall): 77% (7720/10000)
# [84] time: 3694.496486186981 loss: 0.343 val_loss:0.7287745034392876 current_lr=0.007783
# Test Loss: 0.742795
#
# Test Accuracy of airplane: 78% (787/1000)
# Test Accuracy of automobile: 83% (833/1000)
# Test Accuracy of  bird: 72% (726/1000)
# Test Accuracy of   cat: 55% (552/1000)
# Test Accuracy of  deer: 67% (679/1000)
# Test Accuracy of   dog: 72% (729/1000)
# Test Accuracy of  frog: 82% (827/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 88% (881/1000)
# Test Accuracy of truck: 85% (854/1000)
#
# Test Accuracy (Overall): 77% (7715/10000)
# [85] time: 3738.636412858963 loss: 0.332 val_loss:0.7427947083605996 current_lr=0.007452
# Test Loss: 0.759553
#
# Test Accuracy of airplane: 81% (810/1000)
# Test Accuracy of automobile: 87% (870/1000)
# Test Accuracy of  bird: 71% (713/1000)
# Test Accuracy of   cat: 56% (564/1000)
# Test Accuracy of  deer: 85% (859/1000)
# Test Accuracy of   dog: 57% (576/1000)
# Test Accuracy of  frog: 84% (848/1000)
# Test Accuracy of horse: 82% (821/1000)
# Test Accuracy of  ship: 89% (896/1000)
# Test Accuracy of truck: 81% (813/1000)
#
# Test Accuracy (Overall): 77% (7770/10000)
# [86] time: 3782.970090150833 loss: 0.324 val_loss:0.7595526334605639 current_lr=0.007141
# Test Loss: 0.737748
#
# Test Accuracy of airplane: 76% (760/1000)
# Test Accuracy of automobile: 80% (809/1000)
# Test Accuracy of  bird: 73% (737/1000)
# Test Accuracy of   cat: 61% (617/1000)
# Test Accuracy of  deer: 75% (756/1000)
# Test Accuracy of   dog: 66% (665/1000)
# Test Accuracy of  frog: 83% (830/1000)
# Test Accuracy of horse: 81% (814/1000)
# Test Accuracy of  ship: 89% (890/1000)
# Test Accuracy of truck: 86% (864/1000)
#
# Test Accuracy (Overall): 77% (7742/10000)
# [87] time: 3827.1694617271423 loss: 0.317 val_loss:0.7377484508707554 current_lr=0.006851
# Test Loss: 0.752340
#
# Test Accuracy of airplane: 76% (768/1000)
# Test Accuracy of automobile: 88% (886/1000)
# Test Accuracy of  bird: 77% (775/1000)
# Test Accuracy of   cat: 54% (549/1000)
# Test Accuracy of  deer: 70% (707/1000)
# Test Accuracy of   dog: 66% (665/1000)
# Test Accuracy of  frog: 85% (850/1000)
# Test Accuracy of horse: 77% (776/1000)
# Test Accuracy of  ship: 89% (894/1000)
# Test Accuracy of truck: 79% (790/1000)
#
# Test Accuracy (Overall): 76% (7660/10000)
# [88] time: 3870.9639852046967 loss: 0.311 val_loss:0.7523397543007815 current_lr=0.006580
# Test Loss: 0.746165
#
# Test Accuracy of airplane: 83% (832/1000)
# Test Accuracy of automobile: 86% (862/1000)
# Test Accuracy of  bird: 72% (725/1000)
# Test Accuracy of   cat: 58% (587/1000)
# Test Accuracy of  deer: 78% (783/1000)
# Test Accuracy of   dog: 65% (657/1000)
# Test Accuracy of  frog: 83% (838/1000)
# Test Accuracy of horse: 80% (804/1000)
# Test Accuracy of  ship: 88% (886/1000)
# Test Accuracy of truck: 79% (793/1000)
#
# Test Accuracy (Overall): 77% (7767/10000)
# [89] time: 3915.2728502750397 loss: 0.298 val_loss:0.7461652510528323 current_lr=0.006330
# Test Loss: 0.779334
#
# Test Accuracy of airplane: 82% (825/1000)
# Test Accuracy of automobile: 83% (831/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 51% (512/1000)
# Test Accuracy of  deer: 75% (755/1000)
# Test Accuracy of   dog: 71% (710/1000)
# Test Accuracy of  frog: 85% (852/1000)
# Test Accuracy of horse: 82% (822/1000)
# Test Accuracy of  ship: 86% (869/1000)
# Test Accuracy of truck: 82% (821/1000)
#
# Test Accuracy (Overall): 77% (7736/10000)
# [90] time: 3958.7472553253174 loss: 0.292 val_loss:0.7793344674231131 current_lr=0.006101
# Test Loss: 0.778928
#
# Test Accuracy of airplane: 80% (806/1000)
# Test Accuracy of automobile: 85% (850/1000)
# Test Accuracy of  bird: 74% (740/1000)
# Test Accuracy of   cat: 58% (584/1000)
# Test Accuracy of  deer: 78% (789/1000)
# Test Accuracy of   dog: 69% (694/1000)
# Test Accuracy of  frog: 80% (805/1000)
# Test Accuracy of horse: 82% (827/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 82% (820/1000)
#
# Test Accuracy (Overall): 78% (7800/10000)
# [91] time: 4002.792602777481 loss: 0.284 val_loss:0.7789284707624701 current_lr=0.005893
# Test Loss: 0.759992
#
# Test Accuracy of airplane: 79% (790/1000)
# Test Accuracy of automobile: 84% (848/1000)
# Test Accuracy of  bird: 71% (711/1000)
# Test Accuracy of   cat: 61% (612/1000)
# Test Accuracy of  deer: 73% (734/1000)
# Test Accuracy of   dog: 69% (694/1000)
# Test Accuracy of  frog: 85% (851/1000)
# Test Accuracy of horse: 81% (812/1000)
# Test Accuracy of  ship: 87% (878/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 77% (7796/10000)
# [92] time: 4047.2454273700714 loss: 0.273 val_loss:0.7599923572962797 current_lr=0.005707
# Test Loss: 0.770917
#
# Test Accuracy of airplane: 83% (830/1000)
# Test Accuracy of automobile: 84% (844/1000)
# Test Accuracy of  bird: 73% (734/1000)
# Test Accuracy of   cat: 58% (589/1000)
# Test Accuracy of  deer: 75% (755/1000)
# Test Accuracy of   dog: 67% (679/1000)
# Test Accuracy of  frog: 86% (869/1000)
# Test Accuracy of horse: 82% (828/1000)
# Test Accuracy of  ship: 86% (862/1000)
# Test Accuracy of truck: 86% (861/1000)
#
# Test Accuracy (Overall): 78% (7851/10000)
# [93] time: 4091.6169743537903 loss: 0.264 val_loss:0.770917002158829 current_lr=0.005542
# Test Loss: 0.763368
#
# Test Accuracy of airplane: 80% (806/1000)
# Test Accuracy of automobile: 86% (862/1000)
# Test Accuracy of  bird: 74% (746/1000)
# Test Accuracy of   cat: 56% (568/1000)
# Test Accuracy of  deer: 81% (814/1000)
# Test Accuracy of   dog: 73% (738/1000)
# Test Accuracy of  frog: 84% (843/1000)
# Test Accuracy of horse: 79% (794/1000)
# Test Accuracy of  ship: 88% (882/1000)
# Test Accuracy of truck: 82% (827/1000)
#
# Test Accuracy (Overall): 78% (7880/10000)
# [94] time: 4136.412358999252 loss: 0.258 val_loss:0.7633683062806914 current_lr=0.005399
# Test Loss: 0.770011
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 86% (869/1000)
# Test Accuracy of  bird: 74% (741/1000)
# Test Accuracy of   cat: 56% (566/1000)
# Test Accuracy of  deer: 74% (741/1000)
# Test Accuracy of   dog: 67% (677/1000)
# Test Accuracy of  frog: 83% (839/1000)
# Test Accuracy of horse: 81% (813/1000)
# Test Accuracy of  ship: 87% (878/1000)
# Test Accuracy of truck: 83% (830/1000)
#
# Test Accuracy (Overall): 77% (7793/10000)
# [95] time: 4180.861571073532 loss: 0.258 val_loss:0.7700108021874971 current_lr=0.005277
# Test Loss: 0.812439
#
# Test Accuracy of airplane: 81% (811/1000)
# Test Accuracy of automobile: 82% (829/1000)
# Test Accuracy of  bird: 65% (651/1000)
# Test Accuracy of   cat: 60% (608/1000)
# Test Accuracy of  deer: 76% (765/1000)
# Test Accuracy of   dog: 71% (716/1000)
# Test Accuracy of  frog: 83% (838/1000)
# Test Accuracy of horse: 84% (842/1000)
# Test Accuracy of  ship: 84% (847/1000)
# Test Accuracy of truck: 85% (858/1000)
#
# Test Accuracy (Overall): 77% (7765/10000)
# [96] time: 4224.372326135635 loss: 0.252 val_loss:0.8124394590341593 current_lr=0.005177
# Test Loss: 0.807953
#
# Test Accuracy of airplane: 82% (820/1000)
# Test Accuracy of automobile: 88% (888/1000)
# Test Accuracy of  bird: 70% (708/1000)
# Test Accuracy of   cat: 53% (536/1000)
# Test Accuracy of  deer: 78% (781/1000)
# Test Accuracy of   dog: 65% (653/1000)
# Test Accuracy of  frog: 85% (852/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 84% (842/1000)
# Test Accuracy of truck: 83% (835/1000)
#
# Test Accuracy (Overall): 77% (7762/10000)
# [97] time: 4268.431731939316 loss: 0.249 val_loss:0.8079533139361611 current_lr=0.005100
# Test Loss: 0.811162
#
# Test Accuracy of airplane: 82% (823/1000)
# Test Accuracy of automobile: 85% (853/1000)
# Test Accuracy of  bird: 74% (748/1000)
# Test Accuracy of   cat: 54% (548/1000)
# Test Accuracy of  deer: 78% (780/1000)
# Test Accuracy of   dog: 68% (680/1000)
# Test Accuracy of  frog: 83% (838/1000)
# Test Accuracy of horse: 80% (804/1000)
# Test Accuracy of  ship: 86% (868/1000)
# Test Accuracy of truck: 86% (867/1000)
#
# Test Accuracy (Overall): 78% (7809/10000)
# [98] time: 4312.324131965637 loss: 0.245 val_loss:0.8111621741252609 current_lr=0.005044
# Test Loss: 0.856999
#
# Test Accuracy of airplane: 82% (820/1000)
# Test Accuracy of automobile: 85% (856/1000)
# Test Accuracy of  bird: 64% (649/1000)
# Test Accuracy of   cat: 60% (600/1000)
# Test Accuracy of  deer: 74% (745/1000)
# Test Accuracy of   dog: 66% (669/1000)
# Test Accuracy of  frog: 84% (848/1000)
# Test Accuracy of horse: 81% (810/1000)
# Test Accuracy of  ship: 84% (845/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 77% (7722/10000)
# [99] time: 4355.702141046524 loss: 0.238 val_loss:0.8569994489603405 current_lr=0.005011
# Test Loss: 0.834637
#
# Test Accuracy of airplane: 80% (803/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 69% (690/1000)
# Test Accuracy of   cat: 56% (565/1000)
# Test Accuracy of  deer: 79% (793/1000)
# Test Accuracy of   dog: 66% (664/1000)
# Test Accuracy of  frog: 79% (794/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 86% (862/1000)
# Test Accuracy of truck: 83% (837/1000)
#
# Test Accuracy (Overall): 77% (7744/10000)
# [100] time: 4399.524459838867 loss: 0.239 val_loss:0.8346369636209705 current_lr=0.005000
# Training finished!

# %% [markdown]
# #**SGD learning rate search**

# %%
#optimizer = optim.SGD(ResNet18.parameters(), lr=learning_rate, weight_decay=0.01)
class SGDOptimizer(BaseOptimizer):
  def __init__(self,model,criterion,epochs):
    super().__init__(model,criterion,epochs)
  def initialize_optimizer(self, learning_rate):
    optimizer = optim.SGD(self.model.parameters(), lr=learning_rate, weight_decay=0.01)
    # Cosine annealing: lr → eta_min by the end
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=self.epochs,   # period (usually = total epochs)
        eta_min=0.1*learning_rate      # minimum LR (here 0.1× of 0.01)
    )
    self.optimizer,self.scheduler =  optimizer, scheduler

# %%
def get_sgd(model, learning_rate):
    optimizer = SGDOptimizer(model, criterion, epochs)
    optimizer.initialize_optimizer(learning_rate)
    return optimizer
#42
result_sgd = [2.1374309062957764, 1.7963900566101074, 1.6781493425369263,
              1.566157341003418, 1.650704264640808, 1.8818279504776, 1.6078990697860718]
#4242
result_sgd = [2.134641095995903, 1.8067056089639664, 1.6009894460439682,
              1.5199674665927887, 1.5001121312379837, 1.4520547837018967, 1.1808870360255241]
#on test loader
# result_sgd = [2.1170716881752014, 1.7379798740148544, 1.599516600370407,
#               1.45152348279953, 1.5359051153063774, 1.442203849554062, 1.3702829629182816]

if not result_sgd:
    result_sgd = grids_search_val(get_sgd)
    #result_sgd = [float(x.cpu()) for x in result_sgd]
print(result_sgd)
min_index = result_sgd.index(min(result_sgd))
learning_rate = learning_rates[min_index]
print(f"Best learning rate: {learning_rate}, Min val loss: {result_sgd[min_index]}")
plt.figure(figsize=(6,4))
plt.xscale('log')   # good practice for learning rates
plt.xlabel("Learning rate")
plt.ylabel("Min Validation Loss")
plt.title("Learning Rate Grid Search")
plt.xticks(learning_rates, labels=[str(lr) for lr in learning_rates],rotation=45)
plt.plot(learning_rates, result_sgd, label="Grid Search(Validataion Loss)", linewidth=2, marker='o')
# Out:
# [2.134641095995903, 1.8067056089639664, 1.6009894460439682, 1.5199674665927887, 1.5001121312379837, 1.4520547837018967, 1.1808870360255241]
# Best learning rate: 0.1, Min val loss: 1.1808870360255241

# %% [markdown]
# #**SGD Training Model with best learning rate**

# %%
learning_rate = 0.1 #from paper
model_sgd = initialize_model(device)
optimizer = SGDOptimizer(model_sgd,criterion,epochs)
optimizer.initialize_optimizer(learning_rate)
losses_sgd,losses_sgd_val,sgd_acc, sgd_time_cost = train_once(model_sgd,criterion,optimizer,train_loader,test_loader,learning_rate,epochs)
print("Training finished!")
# Out:
# Test Loss: 1.553712
#
# Test Accuracy of airplane: 65% (652/1000)
# Test Accuracy of automobile:  4% (44/1000)
# Test Accuracy of  bird: 16% (161/1000)
# Test Accuracy of   cat: 25% (258/1000)
# Test Accuracy of  deer: 48% (488/1000)
# Test Accuracy of   dog: 42% (420/1000)
# Test Accuracy of  frog: 49% (491/1000)
# Test Accuracy of horse: 79% (790/1000)
# Test Accuracy of  ship: 61% (612/1000)
# Test Accuracy of truck: 74% (744/1000)
#
# Test Accuracy (Overall): 46% (4660/10000)
# [1] time: 25.99707341194153 loss: 1.646 val_loss:1.553711984730974 current_lr=0.099978
# Test Loss: 1.316220
#
# Test Accuracy of airplane: 69% (699/1000)
# Test Accuracy of automobile: 50% (507/1000)
# Test Accuracy of  bird: 29% (298/1000)
# Test Accuracy of   cat: 52% (525/1000)
# Test Accuracy of  deer: 29% (298/1000)
# Test Accuracy of   dog: 38% (381/1000)
# Test Accuracy of  frog: 86% (861/1000)
# Test Accuracy of horse: 45% (455/1000)
# Test Accuracy of  ship: 90% (902/1000)
# Test Accuracy of truck: 61% (616/1000)
#
# Test Accuracy (Overall): 55% (5542/10000)
# [2] time: 52.176839113235474 loss: 1.146 val_loss:1.3162195260011698 current_lr=0.099911
# Test Loss: 1.272874
#
# Test Accuracy of airplane: 53% (532/1000)
# Test Accuracy of automobile: 61% (619/1000)
# Test Accuracy of  bird: 47% (476/1000)
# Test Accuracy of   cat: 59% (596/1000)
# Test Accuracy of  deer: 74% (741/1000)
# Test Accuracy of   dog: 63% (639/1000)
# Test Accuracy of  frog: 34% (345/1000)
# Test Accuracy of horse: 45% (451/1000)
# Test Accuracy of  ship: 77% (773/1000)
# Test Accuracy of truck: 42% (423/1000)
#
# Test Accuracy (Overall): 55% (5595/10000)
# [3] time: 78.26332354545593 loss: 0.992 val_loss:1.2728738256647616 current_lr=0.099800
# Test Loss: 1.396707
#
# Test Accuracy of airplane: 66% (663/1000)
# Test Accuracy of automobile: 91% (919/1000)
# Test Accuracy of  bird: 48% (482/1000)
# Test Accuracy of   cat: 24% (244/1000)
# Test Accuracy of  deer: 40% (406/1000)
# Test Accuracy of   dog: 27% (279/1000)
# Test Accuracy of  frog: 63% (630/1000)
# Test Accuracy of horse: 73% (735/1000)
# Test Accuracy of  ship: 74% (745/1000)
# Test Accuracy of truck: 58% (582/1000)
#
# Test Accuracy (Overall): 56% (5685/10000)
# [4] time: 104.6604335308075 loss: 0.918 val_loss:1.3967072888265681 current_lr=0.099645
# Test Loss: 1.190181
#
# Test Accuracy of airplane: 78% (788/1000)
# Test Accuracy of automobile: 64% (646/1000)
# Test Accuracy of  bird: 64% (641/1000)
# Test Accuracy of   cat: 70% (708/1000)
# Test Accuracy of  deer: 51% (519/1000)
# Test Accuracy of   dog: 24% (248/1000)
# Test Accuracy of  frog: 68% (684/1000)
# Test Accuracy of horse: 32% (327/1000)
# Test Accuracy of  ship: 79% (793/1000)
# Test Accuracy of truck: 61% (617/1000)
#
# Test Accuracy (Overall): 59% (5971/10000)
# [5] time: 131.42141127586365 loss: 0.872 val_loss:1.1901807815213747 current_lr=0.099446
# Test Loss: 1.263691
#
# Test Accuracy of airplane: 91% (915/1000)
# Test Accuracy of automobile: 51% (514/1000)
# Test Accuracy of  bird: 53% (537/1000)
# Test Accuracy of   cat: 64% (642/1000)
# Test Accuracy of  deer: 55% (557/1000)
# Test Accuracy of   dog: 26% (260/1000)
# Test Accuracy of  frog: 80% (807/1000)
# Test Accuracy of horse: 44% (441/1000)
# Test Accuracy of  ship: 31% (311/1000)
# Test Accuracy of truck: 64% (649/1000)
#
# Test Accuracy (Overall): 56% (5633/10000)
# [6] time: 157.75140404701233 loss: 0.837 val_loss:1.263691398161876 current_lr=0.099203
# Test Loss: 1.350478
#
# Test Accuracy of airplane: 69% (692/1000)
# Test Accuracy of automobile: 64% (645/1000)
# Test Accuracy of  bird: 68% (687/1000)
# Test Accuracy of   cat: 37% (373/1000)
# Test Accuracy of  deer: 32% (329/1000)
# Test Accuracy of   dog: 39% (392/1000)
# Test Accuracy of  frog: 62% (628/1000)
# Test Accuracy of horse: 61% (611/1000)
# Test Accuracy of  ship: 94% (941/1000)
# Test Accuracy of truck: 27% (274/1000)
#
# Test Accuracy (Overall): 55% (5572/10000)
# [7] time: 183.88737869262695 loss: 0.818 val_loss:1.3504777422434167 current_lr=0.098916
# Test Loss: 1.138225
#
# Test Accuracy of airplane: 48% (488/1000)
# Test Accuracy of automobile: 89% (895/1000)
# Test Accuracy of  bird: 61% (612/1000)
# Test Accuracy of   cat: 60% (604/1000)
# Test Accuracy of  deer: 54% (546/1000)
# Test Accuracy of   dog: 53% (535/1000)
# Test Accuracy of  frog: 55% (551/1000)
# Test Accuracy of horse: 58% (580/1000)
# Test Accuracy of  ship: 78% (789/1000)
# Test Accuracy of truck: 53% (538/1000)
#
# Test Accuracy (Overall): 61% (6138/10000)
# [8] time: 210.2972447872162 loss: 0.795 val_loss:1.1382251155527332 current_lr=0.098586
# Test Loss: 1.210709
#
# Test Accuracy of airplane: 54% (548/1000)
# Test Accuracy of automobile: 74% (743/1000)
# Test Accuracy of  bird: 63% (636/1000)
# Test Accuracy of   cat: 57% (575/1000)
# Test Accuracy of  deer: 49% (490/1000)
# Test Accuracy of   dog: 55% (555/1000)
# Test Accuracy of  frog: 72% (720/1000)
# Test Accuracy of horse: 64% (643/1000)
# Test Accuracy of  ship: 53% (536/1000)
# Test Accuracy of truck: 54% (540/1000)
#
# Test Accuracy (Overall): 59% (5986/10000)
# [9] time: 236.60335397720337 loss: 0.788 val_loss:1.2107086838046206 current_lr=0.098213
# Test Loss: 1.150502
#
# Test Accuracy of airplane: 73% (730/1000)
# Test Accuracy of automobile: 57% (576/1000)
# Test Accuracy of  bird: 70% (704/1000)
# Test Accuracy of   cat: 52% (525/1000)
# Test Accuracy of  deer: 57% (571/1000)
# Test Accuracy of   dog: 42% (420/1000)
# Test Accuracy of  frog: 62% (629/1000)
# Test Accuracy of horse: 50% (501/1000)
# Test Accuracy of  ship: 83% (833/1000)
# Test Accuracy of truck: 61% (610/1000)
#
# Test Accuracy (Overall): 60% (6099/10000)
# [10] time: 262.8657681941986 loss: 0.761 val_loss:1.1505022735535344 current_lr=0.097798
# Test Loss: 1.101092
#
# Test Accuracy of airplane: 73% (732/1000)
# Test Accuracy of automobile: 78% (783/1000)
# Test Accuracy of  bird: 38% (385/1000)
# Test Accuracy of   cat: 39% (397/1000)
# Test Accuracy of  deer: 78% (789/1000)
# Test Accuracy of   dog: 59% (593/1000)
# Test Accuracy of  frog: 74% (748/1000)
# Test Accuracy of horse: 80% (806/1000)
# Test Accuracy of  ship: 68% (680/1000)
# Test Accuracy of truck: 42% (424/1000)
#
# Test Accuracy (Overall): 63% (6337/10000)
# [11] time: 288.75395917892456 loss: 0.755 val_loss:1.1010920201675802 current_lr=0.097340
# Test Loss: 1.065195
#
# Test Accuracy of airplane: 73% (732/1000)
# Test Accuracy of automobile: 67% (678/1000)
# Test Accuracy of  bird: 30% (302/1000)
# Test Accuracy of   cat: 57% (576/1000)
# Test Accuracy of  deer: 42% (427/1000)
# Test Accuracy of   dog: 65% (654/1000)
# Test Accuracy of  frog: 90% (904/1000)
# Test Accuracy of horse: 60% (605/1000)
# Test Accuracy of  ship: 67% (674/1000)
# Test Accuracy of truck: 83% (836/1000)
#
# Test Accuracy (Overall): 63% (6388/10000)
# [12] time: 314.5357897281647 loss: 0.745 val_loss:1.0651951371868955 current_lr=0.096840
# Test Loss: 1.011076
#
# Test Accuracy of airplane: 74% (743/1000)
# Test Accuracy of automobile: 59% (599/1000)
# Test Accuracy of  bird: 53% (531/1000)
# Test Accuracy of   cat: 57% (577/1000)
# Test Accuracy of  deer: 58% (587/1000)
# Test Accuracy of   dog: 63% (636/1000)
# Test Accuracy of  frog: 60% (601/1000)
# Test Accuracy of horse: 76% (768/1000)
# Test Accuracy of  ship: 66% (667/1000)
# Test Accuracy of truck: 89% (892/1000)
#
# Test Accuracy (Overall): 66% (6601/10000)
# [13] time: 340.10364270210266 loss: 0.727 val_loss:1.0110755970206442 current_lr=0.096299
# Test Loss: 0.978345
#
# Test Accuracy of airplane: 81% (814/1000)
# Test Accuracy of automobile: 88% (880/1000)
# Test Accuracy of  bird: 31% (315/1000)
# Test Accuracy of   cat: 38% (387/1000)
# Test Accuracy of  deer: 82% (824/1000)
# Test Accuracy of   dog: 77% (775/1000)
# Test Accuracy of  frog: 72% (720/1000)
# Test Accuracy of horse: 63% (638/1000)
# Test Accuracy of  ship: 73% (739/1000)
# Test Accuracy of truck: 54% (549/1000)
#
# Test Accuracy (Overall): 66% (6641/10000)
# [14] time: 365.7388129234314 loss: 0.718 val_loss:0.9783448063874547 current_lr=0.095717
# Test Loss: 1.105581
#
# Test Accuracy of airplane: 76% (762/1000)
# Test Accuracy of automobile: 76% (762/1000)
# Test Accuracy of  bird: 69% (699/1000)
# Test Accuracy of   cat: 45% (455/1000)
# Test Accuracy of  deer: 61% (610/1000)
# Test Accuracy of   dog: 52% (528/1000)
# Test Accuracy of  frog: 78% (782/1000)
# Test Accuracy of horse: 58% (586/1000)
# Test Accuracy of  ship: 78% (787/1000)
# Test Accuracy of truck: 29% (295/1000)
#
# Test Accuracy (Overall): 62% (6266/10000)
# [15] time: 391.5011365413666 loss: 0.712 val_loss:1.1055810293064843 current_lr=0.095095
# Test Loss: 1.092136
#
# Test Accuracy of airplane: 88% (889/1000)
# Test Accuracy of automobile: 38% (382/1000)
# Test Accuracy of  bird: 49% (493/1000)
# Test Accuracy of   cat: 42% (425/1000)
# Test Accuracy of  deer: 69% (695/1000)
# Test Accuracy of   dog: 53% (532/1000)
# Test Accuracy of  frog: 74% (741/1000)
# Test Accuracy of horse: 80% (804/1000)
# Test Accuracy of  ship: 79% (798/1000)
# Test Accuracy of truck: 64% (642/1000)
#
# Test Accuracy (Overall): 64% (6401/10000)
# [16] time: 417.3106915950775 loss: 0.703 val_loss:1.092136151428464 current_lr=0.094434
# Test Loss: 0.864827
#
# Test Accuracy of airplane: 84% (841/1000)
# Test Accuracy of automobile: 84% (844/1000)
# Test Accuracy of  bird: 54% (543/1000)
# Test Accuracy of   cat: 55% (554/1000)
# Test Accuracy of  deer: 73% (735/1000)
# Test Accuracy of   dog: 37% (373/1000)
# Test Accuracy of  frog: 86% (861/1000)
# Test Accuracy of horse: 72% (729/1000)
# Test Accuracy of  ship: 90% (906/1000)
# Test Accuracy of truck: 68% (688/1000)
#
# Test Accuracy (Overall): 70% (7074/10000)
# [17] time: 443.98222517967224 loss: 0.704 val_loss:0.8648265532300442 current_lr=0.093733
# Test Loss: 0.880203
#
# Test Accuracy of airplane: 77% (774/1000)
# Test Accuracy of automobile: 78% (784/1000)
# Test Accuracy of  bird: 62% (627/1000)
# Test Accuracy of   cat: 50% (508/1000)
# Test Accuracy of  deer: 69% (692/1000)
# Test Accuracy of   dog: 52% (525/1000)
# Test Accuracy of  frog: 77% (772/1000)
# Test Accuracy of horse: 64% (644/1000)
# Test Accuracy of  ship: 81% (814/1000)
# Test Accuracy of truck: 88% (887/1000)
#
# Test Accuracy (Overall): 70% (7027/10000)
# [18] time: 471.276887178421 loss: 0.690 val_loss:0.8802028238018856 current_lr=0.092995
# Test Loss: 1.168264
#
# Test Accuracy of airplane: 67% (677/1000)
# Test Accuracy of automobile: 55% (559/1000)
# Test Accuracy of  bird: 87% (873/1000)
# Test Accuracy of   cat: 43% (438/1000)
# Test Accuracy of  deer: 68% (680/1000)
# Test Accuracy of   dog: 29% (293/1000)
# Test Accuracy of  frog: 58% (583/1000)
# Test Accuracy of horse: 68% (680/1000)
# Test Accuracy of  ship: 81% (815/1000)
# Test Accuracy of truck: 50% (508/1000)
#
# Test Accuracy (Overall): 61% (6106/10000)
# [19] time: 497.3519833087921 loss: 0.684 val_loss:1.1682641445835935 current_lr=0.092219
# Test Loss: 1.073101
#
# Test Accuracy of airplane: 74% (742/1000)
# Test Accuracy of automobile: 36% (368/1000)
# Test Accuracy of  bird: 54% (545/1000)
# Test Accuracy of   cat: 37% (378/1000)
# Test Accuracy of  deer: 68% (683/1000)
# Test Accuracy of   dog: 59% (595/1000)
# Test Accuracy of  frog: 84% (841/1000)
# Test Accuracy of horse: 78% (787/1000)
# Test Accuracy of  ship: 71% (711/1000)
# Test Accuracy of truck: 72% (720/1000)
#
# Test Accuracy (Overall): 63% (6370/10000)
# [20] time: 523.663492679596 loss: 0.682 val_loss:1.073101039928726 current_lr=0.091406
# Test Loss: 1.060301
#
# Test Accuracy of airplane: 78% (786/1000)
# Test Accuracy of automobile: 66% (665/1000)
# Test Accuracy of  bird: 55% (550/1000)
# Test Accuracy of   cat: 46% (466/1000)
# Test Accuracy of  deer: 69% (698/1000)
# Test Accuracy of   dog: 23% (234/1000)
# Test Accuracy of  frog: 78% (788/1000)
# Test Accuracy of horse: 65% (651/1000)
# Test Accuracy of  ship: 91% (919/1000)
# Test Accuracy of truck: 70% (707/1000)
#
# Test Accuracy (Overall): 64% (6464/10000)
# [21] time: 549.5587677955627 loss: 0.677 val_loss:1.0603009620799293 current_lr=0.090557
# Test Loss: 0.848690
#
# Test Accuracy of airplane: 70% (708/1000)
# Test Accuracy of automobile: 76% (763/1000)
# Test Accuracy of  bird: 66% (662/1000)
# Test Accuracy of   cat: 46% (467/1000)
# Test Accuracy of  deer: 79% (791/1000)
# Test Accuracy of   dog: 74% (740/1000)
# Test Accuracy of  frog: 65% (651/1000)
# Test Accuracy of horse: 68% (686/1000)
# Test Accuracy of  ship: 82% (828/1000)
# Test Accuracy of truck: 80% (807/1000)
#
# Test Accuracy (Overall): 71% (7103/10000)
# [22] time: 575.6643199920654 loss: 0.670 val_loss:0.8486897854865352 current_lr=0.089673
# Test Loss: 1.146075
#
# Test Accuracy of airplane: 76% (761/1000)
# Test Accuracy of automobile: 85% (859/1000)
# Test Accuracy of  bird: 58% (588/1000)
# Test Accuracy of   cat: 59% (599/1000)
# Test Accuracy of  deer: 57% (570/1000)
# Test Accuracy of   dog: 33% (334/1000)
# Test Accuracy of  frog: 88% (882/1000)
# Test Accuracy of horse: 61% (610/1000)
# Test Accuracy of  ship: 78% (788/1000)
# Test Accuracy of truck: 21% (212/1000)
#
# Test Accuracy (Overall): 62% (6203/10000)
# [23] time: 602.2109425067902 loss: 0.657 val_loss:1.1460750193535527 current_lr=0.088755
# Test Loss: 1.046218
#
# Test Accuracy of airplane: 74% (742/1000)
# Test Accuracy of automobile: 87% (879/1000)
# Test Accuracy of  bird: 57% (575/1000)
# Test Accuracy of   cat: 73% (734/1000)
# Test Accuracy of  deer: 73% (730/1000)
# Test Accuracy of   dog: 48% (488/1000)
# Test Accuracy of  frog: 54% (544/1000)
# Test Accuracy of horse: 50% (500/1000)
# Test Accuracy of  ship: 73% (732/1000)
# Test Accuracy of truck: 49% (491/1000)
#
# Test Accuracy (Overall): 64% (6415/10000)
# [24] time: 628.184175491333 loss: 0.660 val_loss:1.0462175147442878 current_lr=0.087804
# Test Loss: 0.796925
#
# Test Accuracy of airplane: 71% (713/1000)
# Test Accuracy of automobile: 81% (818/1000)
# Test Accuracy of  bird: 62% (624/1000)
# Test Accuracy of   cat: 51% (517/1000)
# Test Accuracy of  deer: 71% (716/1000)
# Test Accuracy of   dog: 57% (571/1000)
# Test Accuracy of  frog: 91% (913/1000)
# Test Accuracy of horse: 83% (834/1000)
# Test Accuracy of  ship: 83% (836/1000)
# Test Accuracy of truck: 79% (792/1000)
#
# Test Accuracy (Overall): 73% (7334/10000)
# [25] time: 653.8573937416077 loss: 0.653 val_loss:0.7969251757935633 current_lr=0.086820
# Test Loss: 1.134245
#
# Test Accuracy of airplane: 60% (605/1000)
# Test Accuracy of automobile: 83% (834/1000)
# Test Accuracy of  bird: 52% (521/1000)
# Test Accuracy of   cat: 16% (167/1000)
# Test Accuracy of  deer: 42% (420/1000)
# Test Accuracy of   dog: 87% (879/1000)
# Test Accuracy of  frog: 52% (527/1000)
# Test Accuracy of horse: 73% (738/1000)
# Test Accuracy of  ship: 63% (636/1000)
# Test Accuracy of truck: 84% (846/1000)
#
# Test Accuracy (Overall): 61% (6173/10000)
# [26] time: 679.5114388465881 loss: 0.648 val_loss:1.1342447045483166 current_lr=0.085805
# Test Loss: 0.836080
#
# Test Accuracy of airplane: 80% (808/1000)
# Test Accuracy of automobile: 78% (783/1000)
# Test Accuracy of  bird: 58% (585/1000)
# Test Accuracy of   cat: 48% (488/1000)
# Test Accuracy of  deer: 77% (776/1000)
# Test Accuracy of   dog: 58% (580/1000)
# Test Accuracy of  frog: 82% (824/1000)
# Test Accuracy of horse: 69% (698/1000)
# Test Accuracy of  ship: 92% (920/1000)
# Test Accuracy of truck: 76% (765/1000)
#
# Test Accuracy (Overall): 72% (7227/10000)
# [27] time: 705.0388100147247 loss: 0.644 val_loss:0.8360799754722209 current_lr=0.084759
# Test Loss: 0.978996
#
# Test Accuracy of airplane: 63% (634/1000)
# Test Accuracy of automobile: 79% (797/1000)
# Test Accuracy of  bird: 61% (616/1000)
# Test Accuracy of   cat: 40% (409/1000)
# Test Accuracy of  deer: 49% (496/1000)
# Test Accuracy of   dog: 81% (810/1000)
# Test Accuracy of  frog: 66% (664/1000)
# Test Accuracy of horse: 63% (632/1000)
# Test Accuracy of  ship: 78% (787/1000)
# Test Accuracy of truck: 83% (836/1000)
#
# Test Accuracy (Overall): 66% (6681/10000)
# [28] time: 730.9611356258392 loss: 0.633 val_loss:0.9789961323707919 current_lr=0.083684
# Test Loss: 0.821867
#
# Test Accuracy of airplane: 72% (728/1000)
# Test Accuracy of automobile: 77% (772/1000)
# Test Accuracy of  bird: 66% (661/1000)
# Test Accuracy of   cat: 52% (529/1000)
# Test Accuracy of  deer: 73% (730/1000)
# Test Accuracy of   dog: 58% (589/1000)
# Test Accuracy of  frog: 77% (770/1000)
# Test Accuracy of horse: 80% (806/1000)
# Test Accuracy of  ship: 75% (754/1000)
# Test Accuracy of truck: 90% (907/1000)
#
# Test Accuracy (Overall): 72% (7246/10000)
# [29] time: 756.3502736091614 loss: 0.641 val_loss:0.8218665236159216 current_lr=0.082581
# Test Loss: 0.805296
#
# Test Accuracy of airplane: 79% (791/1000)
# Test Accuracy of automobile: 78% (786/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 39% (399/1000)
# Test Accuracy of  deer: 76% (763/1000)
# Test Accuracy of   dog: 70% (701/1000)
# Test Accuracy of  frog: 66% (663/1000)
# Test Accuracy of horse: 72% (726/1000)
# Test Accuracy of  ship: 87% (872/1000)
# Test Accuracy of truck: 83% (834/1000)
#
# Test Accuracy (Overall): 72% (7291/10000)
# [30] time: 782.1569504737854 loss: 0.629 val_loss:0.805296497254432 current_lr=0.081450
# Test Loss: 1.237400
#
# Test Accuracy of airplane: 67% (678/1000)
# Test Accuracy of automobile: 74% (749/1000)
# Test Accuracy of  bird: 64% (640/1000)
# Test Accuracy of   cat: 57% (579/1000)
# Test Accuracy of  deer: 55% (558/1000)
# Test Accuracy of   dog: 26% (262/1000)
# Test Accuracy of  frog: 47% (472/1000)
# Test Accuracy of horse: 58% (581/1000)
# Test Accuracy of  ship: 91% (912/1000)
# Test Accuracy of truck: 44% (444/1000)
#
# Test Accuracy (Overall): 58% (5875/10000)
# [31] time: 808.1745829582214 loss: 0.624 val_loss:1.2374004540564139 current_lr=0.080294
# Test Loss: 1.071470
#
# Test Accuracy of airplane: 75% (752/1000)
# Test Accuracy of automobile: 74% (741/1000)
# Test Accuracy of  bird: 68% (685/1000)
# Test Accuracy of   cat: 79% (791/1000)
# Test Accuracy of  deer: 44% (440/1000)
# Test Accuracy of   dog: 30% (304/1000)
# Test Accuracy of  frog: 71% (711/1000)
# Test Accuracy of horse: 42% (420/1000)
# Test Accuracy of  ship: 92% (928/1000)
# Test Accuracy of truck: 69% (697/1000)
#
# Test Accuracy (Overall): 64% (6469/10000)
# [32] time: 834.0017778873444 loss: 0.620 val_loss:1.0714695468733582 current_lr=0.079112
# Test Loss: 0.763750
#
# Test Accuracy of airplane: 77% (770/1000)
# Test Accuracy of automobile: 88% (884/1000)
# Test Accuracy of  bird: 67% (678/1000)
# Test Accuracy of   cat: 48% (485/1000)
# Test Accuracy of  deer: 70% (701/1000)
# Test Accuracy of   dog: 74% (747/1000)
# Test Accuracy of  frog: 70% (709/1000)
# Test Accuracy of horse: 79% (793/1000)
# Test Accuracy of  ship: 80% (800/1000)
# Test Accuracy of truck: 87% (877/1000)
#
# Test Accuracy (Overall): 74% (7444/10000)
# [33] time: 859.2355444431305 loss: 0.611 val_loss:0.7637502347366719 current_lr=0.077907
# Test Loss: 0.925619
#
# Test Accuracy of airplane: 64% (642/1000)
# Test Accuracy of automobile: 56% (569/1000)
# Test Accuracy of  bird: 69% (696/1000)
# Test Accuracy of   cat: 70% (708/1000)
# Test Accuracy of  deer: 53% (534/1000)
# Test Accuracy of   dog: 57% (572/1000)
# Test Accuracy of  frog: 75% (758/1000)
# Test Accuracy of horse: 65% (654/1000)
# Test Accuracy of  ship: 85% (854/1000)
# Test Accuracy of truck: 88% (882/1000)
#
# Test Accuracy (Overall): 68% (6869/10000)
# [34] time: 884.5506420135498 loss: 0.608 val_loss:0.9256192181683793 current_lr=0.076679
# Test Loss: 1.033319
#
# Test Accuracy of airplane: 70% (706/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 65% (653/1000)
# Test Accuracy of   cat: 28% (282/1000)
# Test Accuracy of  deer: 63% (630/1000)
# Test Accuracy of   dog: 53% (537/1000)
# Test Accuracy of  frog: 88% (888/1000)
# Test Accuracy of horse: 74% (747/1000)
# Test Accuracy of  ship: 95% (952/1000)
# Test Accuracy of truck: 39% (391/1000)
#
# Test Accuracy (Overall): 66% (6652/10000)
# [35] time: 909.736067533493 loss: 0.601 val_loss:1.0333188749566864 current_lr=0.075430
# Test Loss: 0.797315
#
# Test Accuracy of airplane: 80% (808/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 58% (589/1000)
# Test Accuracy of   cat: 71% (718/1000)
# Test Accuracy of  deer: 62% (623/1000)
# Test Accuracy of   dog: 49% (491/1000)
# Test Accuracy of  frog: 82% (821/1000)
# Test Accuracy of horse: 85% (857/1000)
# Test Accuracy of  ship: 81% (816/1000)
# Test Accuracy of truck: 66% (662/1000)
#
# Test Accuracy (Overall): 72% (7285/10000)
# [36] time: 935.0649371147156 loss: 0.596 val_loss:0.7973151320143591 current_lr=0.074160
# Test Loss: 0.855921
#
# Test Accuracy of airplane: 74% (749/1000)
# Test Accuracy of automobile: 58% (585/1000)
# Test Accuracy of  bird: 73% (732/1000)
# Test Accuracy of   cat: 57% (575/1000)
# Test Accuracy of  deer: 67% (670/1000)
# Test Accuracy of   dog: 62% (627/1000)
# Test Accuracy of  frog: 80% (808/1000)
# Test Accuracy of horse: 75% (757/1000)
# Test Accuracy of  ship: 75% (756/1000)
# Test Accuracy of truck: 87% (872/1000)
#
# Test Accuracy (Overall): 71% (7131/10000)
# [37] time: 960.537534236908 loss: 0.593 val_loss:0.855920802188825 current_lr=0.072872
# Test Loss: 0.829062
#
# Test Accuracy of airplane: 77% (772/1000)
# Test Accuracy of automobile: 76% (763/1000)
# Test Accuracy of  bird: 60% (603/1000)
# Test Accuracy of   cat: 72% (725/1000)
# Test Accuracy of  deer: 58% (589/1000)
# Test Accuracy of   dog: 54% (547/1000)
# Test Accuracy of  frog: 76% (760/1000)
# Test Accuracy of horse: 73% (738/1000)
# Test Accuracy of  ship: 86% (867/1000)
# Test Accuracy of truck: 80% (807/1000)
#
# Test Accuracy (Overall): 71% (7171/10000)
# [38] time: 986.0367608070374 loss: 0.584 val_loss:0.8290618258186534 current_lr=0.071566
# Test Loss: 1.143910
#
# Test Accuracy of airplane: 49% (492/1000)
# Test Accuracy of automobile: 76% (769/1000)
# Test Accuracy of  bird: 45% (451/1000)
# Test Accuracy of   cat: 51% (511/1000)
# Test Accuracy of  deer: 51% (514/1000)
# Test Accuracy of   dog: 80% (804/1000)
# Test Accuracy of  frog: 51% (516/1000)
# Test Accuracy of horse: 75% (759/1000)
# Test Accuracy of  ship: 61% (611/1000)
# Test Accuracy of truck: 89% (891/1000)
#
# Test Accuracy (Overall): 63% (6318/10000)
# [39] time: 1012.3367040157318 loss: 0.579 val_loss:1.1439098293268228 current_lr=0.070243
# Test Loss: 0.927895
#
# Test Accuracy of airplane: 77% (776/1000)
# Test Accuracy of automobile: 70% (708/1000)
# Test Accuracy of  bird: 65% (658/1000)
# Test Accuracy of   cat: 48% (484/1000)
# Test Accuracy of  deer: 52% (520/1000)
# Test Accuracy of   dog: 75% (756/1000)
# Test Accuracy of  frog: 88% (880/1000)
# Test Accuracy of horse: 76% (761/1000)
# Test Accuracy of  ship: 67% (679/1000)
# Test Accuracy of truck: 68% (684/1000)
#
# Test Accuracy (Overall): 69% (6906/10000)
# [40] time: 1038.3982973098755 loss: 0.577 val_loss:0.9278953279121013 current_lr=0.068906
# Test Loss: 0.948612
#
# Test Accuracy of airplane: 62% (620/1000)
# Test Accuracy of automobile: 72% (728/1000)
# Test Accuracy of  bird: 50% (507/1000)
# Test Accuracy of   cat: 55% (555/1000)
# Test Accuracy of  deer: 80% (806/1000)
# Test Accuracy of   dog: 62% (624/1000)
# Test Accuracy of  frog: 69% (692/1000)
# Test Accuracy of horse: 72% (727/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 69% (698/1000)
#
# Test Accuracy (Overall): 68% (6861/10000)
# [41] time: 1064.1332519054413 loss: 0.567 val_loss:0.9486117408245425 current_lr=0.067555
# Test Loss: 0.934932
#
# Test Accuracy of airplane: 73% (735/1000)
# Test Accuracy of automobile: 69% (693/1000)
# Test Accuracy of  bird: 48% (488/1000)
# Test Accuracy of   cat: 59% (590/1000)
# Test Accuracy of  deer: 68% (683/1000)
# Test Accuracy of   dog: 61% (617/1000)
# Test Accuracy of  frog: 53% (535/1000)
# Test Accuracy of horse: 78% (787/1000)
# Test Accuracy of  ship: 84% (843/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 68% (6837/10000)
# [42] time: 1089.7519285678864 loss: 0.560 val_loss:0.9349322341665437 current_lr=0.066191
# Test Loss: 0.940503
#
# Test Accuracy of airplane: 80% (800/1000)
# Test Accuracy of automobile: 72% (727/1000)
# Test Accuracy of  bird: 69% (698/1000)
# Test Accuracy of   cat: 60% (608/1000)
# Test Accuracy of  deer: 52% (520/1000)
# Test Accuracy of   dog: 57% (575/1000)
# Test Accuracy of  frog: 72% (726/1000)
# Test Accuracy of horse: 54% (543/1000)
# Test Accuracy of  ship: 92% (928/1000)
# Test Accuracy of truck: 78% (785/1000)
#
# Test Accuracy (Overall): 69% (6910/10000)
# [43] time: 1115.5451157093048 loss: 0.555 val_loss:0.9405027635489838 current_lr=0.064816
# Test Loss: 0.813538
#
# Test Accuracy of airplane: 84% (846/1000)
# Test Accuracy of automobile: 91% (910/1000)
# Test Accuracy of  bird: 77% (773/1000)
# Test Accuracy of   cat: 56% (569/1000)
# Test Accuracy of  deer: 71% (711/1000)
# Test Accuracy of   dog: 46% (463/1000)
# Test Accuracy of  frog: 73% (733/1000)
# Test Accuracy of horse: 78% (785/1000)
# Test Accuracy of  ship: 71% (711/1000)
# Test Accuracy of truck: 76% (765/1000)
#
# Test Accuracy (Overall): 72% (7266/10000)
# [44] time: 1141.489964723587 loss: 0.553 val_loss:0.81353776213489 current_lr=0.063432
# Test Loss: 1.082201
#
# Test Accuracy of airplane: 65% (653/1000)
# Test Accuracy of automobile: 84% (840/1000)
# Test Accuracy of  bird: 58% (584/1000)
# Test Accuracy of   cat: 41% (416/1000)
# Test Accuracy of  deer: 58% (586/1000)
# Test Accuracy of   dog: 52% (523/1000)
# Test Accuracy of  frog: 77% (779/1000)
# Test Accuracy of horse: 78% (782/1000)
# Test Accuracy of  ship: 90% (902/1000)
# Test Accuracy of truck: 36% (367/1000)
#
# Test Accuracy (Overall): 64% (6432/10000)
# [45] time: 1167.5503270626068 loss: 0.541 val_loss:1.0822007599510723 current_lr=0.062040
# Test Loss: 0.731526
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 82% (827/1000)
# Test Accuracy of  bird: 74% (748/1000)
# Test Accuracy of   cat: 52% (525/1000)
# Test Accuracy of  deer: 79% (799/1000)
# Test Accuracy of   dog: 65% (651/1000)
# Test Accuracy of  frog: 70% (706/1000)
# Test Accuracy of horse: 76% (760/1000)
# Test Accuracy of  ship: 88% (886/1000)
# Test Accuracy of truck: 78% (786/1000)
#
# Test Accuracy (Overall): 75% (7536/10000)
# [46] time: 1194.143201828003 loss: 0.536 val_loss:0.7315264517747904 current_lr=0.060640
# Test Loss: 0.837483
#
# Test Accuracy of airplane: 70% (705/1000)
# Test Accuracy of automobile: 79% (795/1000)
# Test Accuracy of  bird: 48% (480/1000)
# Test Accuracy of   cat: 52% (525/1000)
# Test Accuracy of  deer: 60% (605/1000)
# Test Accuracy of   dog: 66% (665/1000)
# Test Accuracy of  frog: 70% (709/1000)
# Test Accuracy of horse: 91% (914/1000)
# Test Accuracy of  ship: 83% (839/1000)
# Test Accuracy of truck: 93% (933/1000)
#
# Test Accuracy (Overall): 71% (7170/10000)
# [47] time: 1220.1092464923859 loss: 0.528 val_loss:0.8374831555764887 current_lr=0.059235
# Test Loss: 0.909556
#
# Test Accuracy of airplane: 75% (755/1000)
# Test Accuracy of automobile: 77% (772/1000)
# Test Accuracy of  bird: 61% (611/1000)
# Test Accuracy of   cat: 47% (470/1000)
# Test Accuracy of  deer: 48% (483/1000)
# Test Accuracy of   dog: 82% (829/1000)
# Test Accuracy of  frog: 57% (571/1000)
# Test Accuracy of horse: 79% (799/1000)
# Test Accuracy of  ship: 83% (830/1000)
# Test Accuracy of truck: 88% (881/1000)
#
# Test Accuracy (Overall): 70% (7001/10000)
# [48] time: 1245.7549347877502 loss: 0.517 val_loss:0.9095556558687475 current_lr=0.057826
# Test Loss: 0.838975
#
# Test Accuracy of airplane: 77% (776/1000)
# Test Accuracy of automobile: 82% (827/1000)
# Test Accuracy of  bird: 68% (685/1000)
# Test Accuracy of   cat: 63% (638/1000)
# Test Accuracy of  deer: 51% (516/1000)
# Test Accuracy of   dog: 82% (825/1000)
# Test Accuracy of  frog: 67% (674/1000)
# Test Accuracy of horse: 64% (649/1000)
# Test Accuracy of  ship: 79% (794/1000)
# Test Accuracy of truck: 83% (835/1000)
#
# Test Accuracy (Overall): 72% (7219/10000)
# [49] time: 1271.381160736084 loss: 0.519 val_loss:0.8389752320473707 current_lr=0.056413
# Test Loss: 0.778010
#
# Test Accuracy of airplane: 82% (823/1000)
# Test Accuracy of automobile: 81% (818/1000)
# Test Accuracy of  bird: 52% (522/1000)
# Test Accuracy of   cat: 52% (523/1000)
# Test Accuracy of  deer: 69% (692/1000)
# Test Accuracy of   dog: 75% (759/1000)
# Test Accuracy of  frog: 84% (841/1000)
# Test Accuracy of horse: 68% (684/1000)
# Test Accuracy of  ship: 86% (863/1000)
# Test Accuracy of truck: 82% (821/1000)
#
# Test Accuracy (Overall): 73% (7346/10000)
# [50] time: 1297.0666718482971 loss: 0.505 val_loss:0.7780095572713055 current_lr=0.055000
# Test Loss: 0.874491
#
# Test Accuracy of airplane: 73% (739/1000)
# Test Accuracy of automobile: 77% (778/1000)
# Test Accuracy of  bird: 41% (417/1000)
# Test Accuracy of   cat: 56% (565/1000)
# Test Accuracy of  deer: 69% (691/1000)
# Test Accuracy of   dog: 70% (705/1000)
# Test Accuracy of  frog: 87% (873/1000)
# Test Accuracy of horse: 76% (765/1000)
# Test Accuracy of  ship: 84% (843/1000)
# Test Accuracy of truck: 81% (815/1000)
#
# Test Accuracy (Overall): 71% (7191/10000)
# [51] time: 1322.6465306282043 loss: 0.496 val_loss:0.87449123965034 current_lr=0.053587
# Test Loss: 1.040654
#
# Test Accuracy of airplane: 54% (544/1000)
# Test Accuracy of automobile: 66% (665/1000)
# Test Accuracy of  bird: 82% (824/1000)
# Test Accuracy of   cat: 65% (657/1000)
# Test Accuracy of  deer: 52% (520/1000)
# Test Accuracy of   dog: 45% (451/1000)
# Test Accuracy of  frog: 68% (686/1000)
# Test Accuracy of horse: 61% (618/1000)
# Test Accuracy of  ship: 95% (950/1000)
# Test Accuracy of truck: 73% (732/1000)
#
# Test Accuracy (Overall): 66% (6647/10000)
# [52] time: 1348.9109292030334 loss: 0.491 val_loss:1.0406536407108549 current_lr=0.052174
# Test Loss: 0.798856
#
# Test Accuracy of airplane: 88% (883/1000)
# Test Accuracy of automobile: 76% (760/1000)
# Test Accuracy of  bird: 74% (747/1000)
# Test Accuracy of   cat: 51% (513/1000)
# Test Accuracy of  deer: 68% (688/1000)
# Test Accuracy of   dog: 51% (513/1000)
# Test Accuracy of  frog: 80% (802/1000)
# Test Accuracy of horse: 88% (885/1000)
# Test Accuracy of  ship: 88% (888/1000)
# Test Accuracy of truck: 69% (697/1000)
#
# Test Accuracy (Overall): 73% (7376/10000)
# [53] time: 1375.5512201786041 loss: 0.478 val_loss:0.798856081087378 current_lr=0.050765
# Test Loss: 0.915220
#
# Test Accuracy of airplane: 65% (651/1000)
# Test Accuracy of automobile: 54% (540/1000)
# Test Accuracy of  bird: 56% (567/1000)
# Test Accuracy of   cat: 64% (643/1000)
# Test Accuracy of  deer: 68% (685/1000)
# Test Accuracy of   dog: 57% (579/1000)
# Test Accuracy of  frog: 90% (903/1000)
# Test Accuracy of horse: 66% (668/1000)
# Test Accuracy of  ship: 84% (842/1000)
# Test Accuracy of truck: 94% (945/1000)
#
# Test Accuracy (Overall): 70% (7023/10000)
# [54] time: 1401.390930891037 loss: 0.471 val_loss:0.915219623831254 current_lr=0.049360
# Test Loss: 0.779008
#
# Test Accuracy of airplane: 78% (787/1000)
# Test Accuracy of automobile: 87% (878/1000)
# Test Accuracy of  bird: 65% (655/1000)
# Test Accuracy of   cat: 66% (667/1000)
# Test Accuracy of  deer: 84% (840/1000)
# Test Accuracy of   dog: 64% (644/1000)
# Test Accuracy of  frog: 74% (745/1000)
# Test Accuracy of horse: 71% (713/1000)
# Test Accuracy of  ship: 63% (636/1000)
# Test Accuracy of truck: 82% (821/1000)
#
# Test Accuracy (Overall): 73% (7386/10000)
# [55] time: 1426.7410652637482 loss: 0.460 val_loss:0.7790083945552005 current_lr=0.047960
# Test Loss: 0.820646
#
# Test Accuracy of airplane: 73% (738/1000)
# Test Accuracy of automobile: 80% (808/1000)
# Test Accuracy of  bird: 60% (609/1000)
# Test Accuracy of   cat: 66% (667/1000)
# Test Accuracy of  deer: 49% (495/1000)
# Test Accuracy of   dog: 76% (761/1000)
# Test Accuracy of  frog: 85% (857/1000)
# Test Accuracy of horse: 80% (809/1000)
# Test Accuracy of  ship: 70% (700/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 73% (7324/10000)
# [56] time: 1452.0469691753387 loss: 0.452 val_loss:0.8206461668014526 current_lr=0.046568
# Test Loss: 0.672842
#
# Test Accuracy of airplane: 84% (845/1000)
# Test Accuracy of automobile: 78% (783/1000)
# Test Accuracy of  bird: 71% (717/1000)
# Test Accuracy of   cat: 53% (534/1000)
# Test Accuracy of  deer: 85% (850/1000)
# Test Accuracy of   dog: 74% (745/1000)
# Test Accuracy of  frog: 80% (802/1000)
# Test Accuracy of horse: 84% (843/1000)
# Test Accuracy of  ship: 79% (797/1000)
# Test Accuracy of truck: 87% (874/1000)
#
# Test Accuracy (Overall): 77% (7790/10000)
# [57] time: 1477.610845565796 loss: 0.447 val_loss:0.67284202198439 current_lr=0.045184
# Test Loss: 0.808463
#
# Test Accuracy of airplane: 84% (840/1000)
# Test Accuracy of automobile: 79% (797/1000)
# Test Accuracy of  bird: 74% (742/1000)
# Test Accuracy of   cat: 60% (601/1000)
# Test Accuracy of  deer: 84% (844/1000)
# Test Accuracy of   dog: 42% (424/1000)
# Test Accuracy of  frog: 66% (667/1000)
# Test Accuracy of horse: 73% (735/1000)
# Test Accuracy of  ship: 86% (863/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 73% (7393/10000)
# [58] time: 1503.4377732276917 loss: 0.434 val_loss:0.8084628589545624 current_lr=0.043809
# Test Loss: 0.956201
#
# Test Accuracy of airplane: 65% (650/1000)
# Test Accuracy of automobile: 84% (849/1000)
# Test Accuracy of  bird: 59% (592/1000)
# Test Accuracy of   cat: 53% (536/1000)
# Test Accuracy of  deer: 77% (778/1000)
# Test Accuracy of   dog: 83% (839/1000)
# Test Accuracy of  frog: 67% (670/1000)
# Test Accuracy of horse: 70% (706/1000)
# Test Accuracy of  ship: 62% (627/1000)
# Test Accuracy of truck: 71% (710/1000)
#
# Test Accuracy (Overall): 69% (6957/10000)
# [59] time: 1528.9958238601685 loss: 0.427 val_loss:0.956201468841939 current_lr=0.042445
# Test Loss: 0.745426
#
# Test Accuracy of airplane: 79% (791/1000)
# Test Accuracy of automobile: 77% (776/1000)
# Test Accuracy of  bird: 77% (774/1000)
# Test Accuracy of   cat: 73% (737/1000)
# Test Accuracy of  deer: 82% (826/1000)
# Test Accuracy of   dog: 52% (526/1000)
# Test Accuracy of  frog: 79% (798/1000)
# Test Accuracy of horse: 73% (730/1000)
# Test Accuracy of  ship: 69% (695/1000)
# Test Accuracy of truck: 89% (895/1000)
#
# Test Accuracy (Overall): 75% (7548/10000)
# [60] time: 1554.835381269455 loss: 0.423 val_loss:0.7454258452487897 current_lr=0.041094
# Test Loss: 0.916432
#
# Test Accuracy of airplane: 86% (860/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 69% (696/1000)
# Test Accuracy of   cat: 58% (580/1000)
# Test Accuracy of  deer: 66% (661/1000)
# Test Accuracy of   dog: 49% (495/1000)
# Test Accuracy of  frog: 54% (544/1000)
# Test Accuracy of horse: 91% (913/1000)
# Test Accuracy of  ship: 72% (724/1000)
# Test Accuracy of truck: 67% (670/1000)
#
# Test Accuracy (Overall): 70% (7032/10000)
# [61] time: 1581.1413404941559 loss: 0.409 val_loss:0.916431937036635 current_lr=0.039757
# Test Loss: 0.981486
#
# Test Accuracy of airplane: 79% (797/1000)
# Test Accuracy of automobile: 77% (778/1000)
# Test Accuracy of  bird: 64% (645/1000)
# Test Accuracy of   cat: 87% (870/1000)
# Test Accuracy of  deer: 57% (572/1000)
# Test Accuracy of   dog: 36% (368/1000)
# Test Accuracy of  frog: 64% (645/1000)
# Test Accuracy of horse: 76% (764/1000)
# Test Accuracy of  ship: 63% (637/1000)
# Test Accuracy of truck: 79% (797/1000)
#
# Test Accuracy (Overall): 68% (6873/10000)
# [62] time: 1607.1784226894379 loss: 0.397 val_loss:0.9814860088915764 current_lr=0.038434
# Test Loss: 0.997532
#
# Test Accuracy of airplane: 86% (863/1000)
# Test Accuracy of automobile: 82% (823/1000)
# Test Accuracy of  bird: 78% (784/1000)
# Test Accuracy of   cat: 57% (573/1000)
# Test Accuracy of  deer: 70% (706/1000)
# Test Accuracy of   dog: 54% (543/1000)
# Test Accuracy of  frog: 60% (607/1000)
# Test Accuracy of horse: 79% (798/1000)
# Test Accuracy of  ship: 53% (533/1000)
# Test Accuracy of truck: 58% (582/1000)
#
# Test Accuracy (Overall): 68% (6812/10000)
# [63] time: 1632.9410681724548 loss: 0.390 val_loss:0.9975319006774999 current_lr=0.037128
# Test Loss: 0.697573
#
# Test Accuracy of airplane: 75% (759/1000)
# Test Accuracy of automobile: 86% (860/1000)
# Test Accuracy of  bird: 82% (820/1000)
# Test Accuracy of   cat: 68% (686/1000)
# Test Accuracy of  deer: 70% (701/1000)
# Test Accuracy of   dog: 62% (625/1000)
# Test Accuracy of  frog: 74% (743/1000)
# Test Accuracy of horse: 80% (804/1000)
# Test Accuracy of  ship: 91% (913/1000)
# Test Accuracy of truck: 77% (778/1000)
#
# Test Accuracy (Overall): 76% (7689/10000)
# [64] time: 1659.0669708251953 loss: 0.382 val_loss:0.6975732287274131 current_lr=0.035840
# Test Loss: 0.712886
#
# Test Accuracy of airplane: 77% (771/1000)
# Test Accuracy of automobile: 80% (805/1000)
# Test Accuracy of  bird: 72% (722/1000)
# Test Accuracy of   cat: 50% (506/1000)
# Test Accuracy of  deer: 85% (850/1000)
# Test Accuracy of   dog: 63% (639/1000)
# Test Accuracy of  frog: 86% (864/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 87% (873/1000)
# Test Accuracy of truck: 82% (821/1000)
#
# Test Accuracy (Overall): 77% (7706/10000)
# [65] time: 1685.1649231910706 loss: 0.367 val_loss:0.7128861950168127 current_lr=0.034570
# Test Loss: 0.672695
#
# Test Accuracy of airplane: 80% (803/1000)
# Test Accuracy of automobile: 80% (805/1000)
# Test Accuracy of  bird: 64% (643/1000)
# Test Accuracy of   cat: 52% (523/1000)
# Test Accuracy of  deer: 78% (781/1000)
# Test Accuracy of   dog: 72% (721/1000)
# Test Accuracy of  frog: 90% (900/1000)
# Test Accuracy of horse: 87% (878/1000)
# Test Accuracy of  ship: 88% (882/1000)
# Test Accuracy of truck: 85% (853/1000)
#
# Test Accuracy (Overall): 77% (7789/10000)
# [66] time: 1710.9464266300201 loss: 0.358 val_loss:0.6726949992059152 current_lr=0.033321
# Test Loss: 0.736789
#
# Test Accuracy of airplane: 78% (784/1000)
# Test Accuracy of automobile: 79% (796/1000)
# Test Accuracy of  bird: 71% (713/1000)
# Test Accuracy of   cat: 56% (564/1000)
# Test Accuracy of  deer: 80% (803/1000)
# Test Accuracy of   dog: 71% (710/1000)
# Test Accuracy of  frog: 74% (744/1000)
# Test Accuracy of horse: 86% (864/1000)
# Test Accuracy of  ship: 72% (720/1000)
# Test Accuracy of truck: 91% (913/1000)
#
# Test Accuracy (Overall): 76% (7611/10000)
# [67] time: 1737.2046263217926 loss: 0.346 val_loss:0.7367894921121718 current_lr=0.032093
# Test Loss: 0.967921
#
# Test Accuracy of airplane: 80% (800/1000)
# Test Accuracy of automobile: 76% (760/1000)
# Test Accuracy of  bird: 78% (788/1000)
# Test Accuracy of   cat: 51% (511/1000)
# Test Accuracy of  deer: 83% (839/1000)
# Test Accuracy of   dog: 53% (538/1000)
# Test Accuracy of  frog: 52% (528/1000)
# Test Accuracy of horse: 86% (866/1000)
# Test Accuracy of  ship: 68% (685/1000)
# Test Accuracy of truck: 65% (656/1000)
#
# Test Accuracy (Overall): 69% (6971/10000)
# [68] time: 1763.1513857841492 loss: 0.335 val_loss:0.9679209182534037 current_lr=0.030888
# Test Loss: 0.888440
#
# Test Accuracy of airplane: 83% (834/1000)
# Test Accuracy of automobile: 83% (837/1000)
# Test Accuracy of  bird: 56% (560/1000)
# Test Accuracy of   cat: 57% (579/1000)
# Test Accuracy of  deer: 79% (795/1000)
# Test Accuracy of   dog: 40% (400/1000)
# Test Accuracy of  frog: 73% (739/1000)
# Test Accuracy of horse: 89% (891/1000)
# Test Accuracy of  ship: 71% (715/1000)
# Test Accuracy of truck: 87% (870/1000)
#
# Test Accuracy (Overall): 72% (7220/10000)
# [69] time: 1788.9633548259735 loss: 0.328 val_loss:0.888439689255968 current_lr=0.029706
# Test Loss: 0.761417
#
# Test Accuracy of airplane: 83% (837/1000)
# Test Accuracy of automobile: 92% (920/1000)
# Test Accuracy of  bird: 65% (658/1000)
# Test Accuracy of   cat: 55% (551/1000)
# Test Accuracy of  deer: 70% (709/1000)
# Test Accuracy of   dog: 69% (698/1000)
# Test Accuracy of  frog: 74% (744/1000)
# Test Accuracy of horse: 78% (782/1000)
# Test Accuracy of  ship: 89% (894/1000)
# Test Accuracy of truck: 81% (815/1000)
#
# Test Accuracy (Overall): 76% (7608/10000)
# [70] time: 1814.9051568508148 loss: 0.317 val_loss:0.7614168260670915 current_lr=0.028550
# Test Loss: 0.860604
#
# Test Accuracy of airplane: 86% (865/1000)
# Test Accuracy of automobile: 72% (729/1000)
# Test Accuracy of  bird: 80% (805/1000)
# Test Accuracy of   cat: 43% (432/1000)
# Test Accuracy of  deer: 71% (712/1000)
# Test Accuracy of   dog: 77% (775/1000)
# Test Accuracy of  frog: 71% (715/1000)
# Test Accuracy of horse: 80% (800/1000)
# Test Accuracy of  ship: 82% (821/1000)
# Test Accuracy of truck: 68% (685/1000)
#
# Test Accuracy (Overall): 73% (7339/10000)
# [71] time: 1840.5762991905212 loss: 0.306 val_loss:0.8606038976319229 current_lr=0.027419
# Test Loss: 0.723208
#
# Test Accuracy of airplane: 71% (716/1000)
# Test Accuracy of automobile: 87% (871/1000)
# Test Accuracy of  bird: 88% (881/1000)
# Test Accuracy of   cat: 66% (664/1000)
# Test Accuracy of  deer: 78% (786/1000)
# Test Accuracy of   dog: 57% (571/1000)
# Test Accuracy of  frog: 77% (774/1000)
# Test Accuracy of horse: 76% (766/1000)
# Test Accuracy of  ship: 90% (907/1000)
# Test Accuracy of truck: 81% (818/1000)
#
# Test Accuracy (Overall): 77% (7754/10000)
# [72] time: 1866.4031193256378 loss: 0.299 val_loss:0.7232076970836784 current_lr=0.026316
# Test Loss: 0.693040
#
# Test Accuracy of airplane: 82% (827/1000)
# Test Accuracy of automobile: 87% (875/1000)
# Test Accuracy of  bird: 73% (730/1000)
# Test Accuracy of   cat: 66% (662/1000)
# Test Accuracy of  deer: 87% (874/1000)
# Test Accuracy of   dog: 62% (622/1000)
# Test Accuracy of  frog: 73% (733/1000)
# Test Accuracy of horse: 85% (859/1000)
# Test Accuracy of  ship: 78% (783/1000)
# Test Accuracy of truck: 81% (816/1000)
#
# Test Accuracy (Overall): 77% (7781/10000)
# [73] time: 1891.888469696045 loss: 0.284 val_loss:0.6930395647694793 current_lr=0.025241
# Test Loss: 0.772795
#
# Test Accuracy of airplane: 80% (803/1000)
# Test Accuracy of automobile: 85% (859/1000)
# Test Accuracy of  bird: 81% (815/1000)
# Test Accuracy of   cat: 63% (633/1000)
# Test Accuracy of  deer: 67% (677/1000)
# Test Accuracy of   dog: 64% (640/1000)
# Test Accuracy of  frog: 70% (707/1000)
# Test Accuracy of horse: 79% (791/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 75% (754/1000)
#
# Test Accuracy (Overall): 75% (7583/10000)
# [74] time: 1917.9286043643951 loss: 0.283 val_loss:0.7727950366237496 current_lr=0.024195
# Test Loss: 0.702612
#
# Test Accuracy of airplane: 78% (786/1000)
# Test Accuracy of automobile: 84% (841/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 64% (644/1000)
# Test Accuracy of  deer: 74% (748/1000)
# Test Accuracy of   dog: 71% (719/1000)
# Test Accuracy of  frog: 70% (703/1000)
# Test Accuracy of horse: 88% (886/1000)
# Test Accuracy of  ship: 90% (906/1000)
# Test Accuracy of truck: 82% (823/1000)
#
# Test Accuracy (Overall): 78% (7826/10000)
# [75] time: 1944.0900514125824 loss: 0.262 val_loss:0.7026116738591013 current_lr=0.023180
# Test Loss: 0.778577
#
# Test Accuracy of airplane: 75% (750/1000)
# Test Accuracy of automobile: 82% (828/1000)
# Test Accuracy of  bird: 73% (730/1000)
# Test Accuracy of   cat: 63% (638/1000)
# Test Accuracy of  deer: 74% (743/1000)
# Test Accuracy of   dog: 76% (768/1000)
# Test Accuracy of  frog: 66% (667/1000)
# Test Accuracy of horse: 77% (778/1000)
# Test Accuracy of  ship: 93% (930/1000)
# Test Accuracy of truck: 77% (775/1000)
#
# Test Accuracy (Overall): 76% (7607/10000)
# [76] time: 1970.1575150489807 loss: 0.250 val_loss:0.7785773841263373 current_lr=0.022196
# Test Loss: 0.729631
#
# Test Accuracy of airplane: 85% (856/1000)
# Test Accuracy of automobile: 90% (902/1000)
# Test Accuracy of  bird: 71% (712/1000)
# Test Accuracy of   cat: 57% (575/1000)
# Test Accuracy of  deer: 68% (686/1000)
# Test Accuracy of   dog: 71% (717/1000)
# Test Accuracy of  frog: 68% (688/1000)
# Test Accuracy of horse: 87% (874/1000)
# Test Accuracy of  ship: 87% (871/1000)
# Test Accuracy of truck: 80% (808/1000)
#
# Test Accuracy (Overall): 76% (7689/10000)
# [77] time: 1996.146232843399 loss: 0.243 val_loss:0.729631312663042 current_lr=0.021245
# Test Loss: 0.757947
#
# Test Accuracy of airplane: 71% (714/1000)
# Test Accuracy of automobile: 87% (873/1000)
# Test Accuracy of  bird: 64% (648/1000)
# Test Accuracy of   cat: 71% (714/1000)
# Test Accuracy of  deer: 80% (807/1000)
# Test Accuracy of   dog: 73% (738/1000)
# Test Accuracy of  frog: 64% (642/1000)
# Test Accuracy of horse: 83% (832/1000)
# Test Accuracy of  ship: 91% (914/1000)
# Test Accuracy of truck: 83% (831/1000)
#
# Test Accuracy (Overall): 77% (7713/10000)
# [78] time: 2021.9612126350403 loss: 0.229 val_loss:0.7579468914979621 current_lr=0.020327
# Test Loss: 0.741877
#
# Test Accuracy of airplane: 84% (842/1000)
# Test Accuracy of automobile: 91% (912/1000)
# Test Accuracy of  bird: 77% (775/1000)
# Test Accuracy of   cat: 56% (566/1000)
# Test Accuracy of  deer: 75% (758/1000)
# Test Accuracy of   dog: 66% (666/1000)
# Test Accuracy of  frog: 78% (789/1000)
# Test Accuracy of horse: 76% (764/1000)
# Test Accuracy of  ship: 84% (840/1000)
# Test Accuracy of truck: 80% (807/1000)
#
# Test Accuracy (Overall): 77% (7719/10000)
# [79] time: 2048.076669692993 loss: 0.218 val_loss:0.741876783627498 current_lr=0.019443
# Test Loss: 0.726498
#
# Test Accuracy of airplane: 81% (814/1000)
# Test Accuracy of automobile: 90% (901/1000)
# Test Accuracy of  bird: 62% (622/1000)
# Test Accuracy of   cat: 67% (675/1000)
# Test Accuracy of  deer: 78% (789/1000)
# Test Accuracy of   dog: 65% (654/1000)
# Test Accuracy of  frog: 89% (899/1000)
# Test Accuracy of horse: 82% (825/1000)
# Test Accuracy of  ship: 87% (873/1000)
# Test Accuracy of truck: 77% (778/1000)
#
# Test Accuracy (Overall): 78% (7830/10000)
# [80] time: 2073.8565883636475 loss: 0.217 val_loss:0.7264984861204896 current_lr=0.018594
# Test Loss: 0.728619
#
# Test Accuracy of airplane: 79% (798/1000)
# Test Accuracy of automobile: 80% (806/1000)
# Test Accuracy of  bird: 71% (714/1000)
# Test Accuracy of   cat: 74% (748/1000)
# Test Accuracy of  deer: 80% (806/1000)
# Test Accuracy of   dog: 52% (525/1000)
# Test Accuracy of  frog: 86% (860/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 82% (827/1000)
# Test Accuracy of truck: 92% (924/1000)
#
# Test Accuracy (Overall): 78% (7844/10000)
# [81] time: 2100.099805355072 loss: 0.204 val_loss:0.7286192993574505 current_lr=0.017781
# Test Loss: 0.690356
#
# Test Accuracy of airplane: 75% (750/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 80% (807/1000)
# Test Accuracy of   cat: 74% (743/1000)
# Test Accuracy of  deer: 76% (760/1000)
# Test Accuracy of   dog: 60% (601/1000)
# Test Accuracy of  frog: 82% (826/1000)
# Test Accuracy of horse: 82% (823/1000)
# Test Accuracy of  ship: 86% (868/1000)
# Test Accuracy of truck: 89% (896/1000)
#
# Test Accuracy (Overall): 79% (7940/10000)
# [82] time: 2126.3054077625275 loss: 0.190 val_loss:0.6903558762013158 current_lr=0.017005
# Test Loss: 0.666329
#
# Test Accuracy of airplane: 85% (852/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 73% (734/1000)
# Test Accuracy of   cat: 67% (674/1000)
# Test Accuracy of  deer: 75% (758/1000)
# Test Accuracy of   dog: 69% (696/1000)
# Test Accuracy of  frog: 77% (771/1000)
# Test Accuracy of horse: 88% (883/1000)
# Test Accuracy of  ship: 86% (865/1000)
# Test Accuracy of truck: 85% (857/1000)
#
# Test Accuracy (Overall): 79% (7983/10000)
# [83] time: 2152.2421400547028 loss: 0.186 val_loss:0.6663290994076789 current_lr=0.016267
# Test Loss: 0.746098
#
# Test Accuracy of airplane: 86% (867/1000)
# Test Accuracy of automobile: 82% (821/1000)
# Test Accuracy of  bird: 60% (608/1000)
# Test Accuracy of   cat: 69% (699/1000)
# Test Accuracy of  deer: 73% (734/1000)
# Test Accuracy of   dog: 66% (662/1000)
# Test Accuracy of  frog: 93% (935/1000)
# Test Accuracy of horse: 78% (789/1000)
# Test Accuracy of  ship: 81% (817/1000)
# Test Accuracy of truck: 90% (904/1000)
#
# Test Accuracy (Overall): 78% (7836/10000)
# [84] time: 2178.27956199646 loss: 0.184 val_loss:0.7460980969893781 current_lr=0.015566
# Test Loss: 0.683554
#
# Test Accuracy of airplane: 77% (779/1000)
# Test Accuracy of automobile: 89% (894/1000)
# Test Accuracy of  bird: 84% (842/1000)
# Test Accuracy of   cat: 67% (679/1000)
# Test Accuracy of  deer: 74% (740/1000)
# Test Accuracy of   dog: 68% (681/1000)
# Test Accuracy of  frog: 82% (825/1000)
# Test Accuracy of horse: 75% (754/1000)
# Test Accuracy of  ship: 92% (925/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 79% (7999/10000)
# [85] time: 2203.9636363983154 loss: 0.171 val_loss:0.6835541280010079 current_lr=0.014905
# Test Loss: 0.700650
#
# Test Accuracy of airplane: 83% (838/1000)
# Test Accuracy of automobile: 87% (878/1000)
# Test Accuracy of  bird: 74% (749/1000)
# Test Accuracy of   cat: 52% (521/1000)
# Test Accuracy of  deer: 72% (727/1000)
# Test Accuracy of   dog: 79% (792/1000)
# Test Accuracy of  frog: 86% (861/1000)
# Test Accuracy of horse: 85% (850/1000)
# Test Accuracy of  ship: 88% (881/1000)
# Test Accuracy of truck: 81% (813/1000)
#
# Test Accuracy (Overall): 79% (7910/10000)
# [86] time: 2230.2366576194763 loss: 0.150 val_loss:0.7006495677972142 current_lr=0.014283
# Test Loss: 0.749195
#
# Test Accuracy of airplane: 85% (855/1000)
# Test Accuracy of automobile: 93% (933/1000)
# Test Accuracy of  bird: 81% (811/1000)
# Test Accuracy of   cat: 51% (516/1000)
# Test Accuracy of  deer: 81% (814/1000)
# Test Accuracy of   dog: 71% (710/1000)
# Test Accuracy of  frog: 81% (810/1000)
# Test Accuracy of horse: 80% (806/1000)
# Test Accuracy of  ship: 76% (769/1000)
# Test Accuracy of truck: 80% (803/1000)
#
# Test Accuracy (Overall): 78% (7827/10000)
# [87] time: 2256.3675599098206 loss: 0.155 val_loss:0.7491947118240067 current_lr=0.013701
# Test Loss: 0.708793
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 91% (915/1000)
# Test Accuracy of  bird: 77% (778/1000)
# Test Accuracy of   cat: 53% (539/1000)
# Test Accuracy of  deer: 81% (813/1000)
# Test Accuracy of   dog: 69% (691/1000)
# Test Accuracy of  frog: 77% (773/1000)
# Test Accuracy of horse: 87% (872/1000)
# Test Accuracy of  ship: 90% (901/1000)
# Test Accuracy of truck: 82% (827/1000)
#
# Test Accuracy (Overall): 79% (7948/10000)
# [88] time: 2282.6899547576904 loss: 0.149 val_loss:0.7087925163250935 current_lr=0.013160
# Test Loss: 0.715941
#
# Test Accuracy of airplane: 86% (860/1000)
# Test Accuracy of automobile: 84% (847/1000)
# Test Accuracy of  bird: 74% (740/1000)
# Test Accuracy of   cat: 69% (690/1000)
# Test Accuracy of  deer: 76% (769/1000)
# Test Accuracy of   dog: 66% (664/1000)
# Test Accuracy of  frog: 79% (797/1000)
# Test Accuracy of horse: 86% (869/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 85% (852/1000)
#
# Test Accuracy (Overall): 79% (7992/10000)
# [89] time: 2308.6729774475098 loss: 0.146 val_loss:0.7159409251394151 current_lr=0.012660
# Test Loss: 0.706505
#
# Test Accuracy of airplane: 88% (881/1000)
# Test Accuracy of automobile: 83% (835/1000)
# Test Accuracy of  bird: 68% (688/1000)
# Test Accuracy of   cat: 74% (747/1000)
# Test Accuracy of  deer: 80% (800/1000)
# Test Accuracy of   dog: 70% (701/1000)
# Test Accuracy of  frog: 79% (799/1000)
# Test Accuracy of horse: 81% (813/1000)
# Test Accuracy of  ship: 89% (892/1000)
# Test Accuracy of truck: 84% (848/1000)
#
# Test Accuracy (Overall): 80% (8004/10000)
# [90] time: 2334.423225879669 loss: 0.137 val_loss:0.7065047489691384 current_lr=0.012202
# Test Loss: 0.754217
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 81% (811/1000)
# Test Accuracy of  bird: 70% (706/1000)
# Test Accuracy of   cat: 73% (731/1000)
# Test Accuracy of  deer: 75% (755/1000)
# Test Accuracy of   dog: 61% (616/1000)
# Test Accuracy of  frog: 85% (851/1000)
# Test Accuracy of horse: 79% (798/1000)
# Test Accuracy of  ship: 80% (803/1000)
# Test Accuracy of truck: 94% (945/1000)
#
# Test Accuracy (Overall): 78% (7864/10000)
# [91] time: 2360.6018562316895 loss: 0.128 val_loss:0.7542172255395334 current_lr=0.011787
# Test Loss: 0.735257
#
# Test Accuracy of airplane: 66% (664/1000)
# Test Accuracy of automobile: 85% (855/1000)
# Test Accuracy of  bird: 85% (854/1000)
# Test Accuracy of   cat: 55% (552/1000)
# Test Accuracy of  deer: 82% (825/1000)
# Test Accuracy of   dog: 71% (715/1000)
# Test Accuracy of  frog: 85% (859/1000)
# Test Accuracy of horse: 85% (856/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 87% (872/1000)
#
# Test Accuracy (Overall): 79% (7937/10000)
# [92] time: 2386.636519432068 loss: 0.121 val_loss:0.7352574094186856 current_lr=0.011414
# Test Loss: 0.686271
#
# Test Accuracy of airplane: 86% (865/1000)
# Test Accuracy of automobile: 91% (916/1000)
# Test Accuracy of  bird: 72% (727/1000)
# Test Accuracy of   cat: 70% (700/1000)
# Test Accuracy of  deer: 80% (807/1000)
# Test Accuracy of   dog: 66% (666/1000)
# Test Accuracy of  frog: 81% (819/1000)
# Test Accuracy of horse: 87% (876/1000)
# Test Accuracy of  ship: 86% (866/1000)
# Test Accuracy of truck: 83% (833/1000)
#
# Test Accuracy (Overall): 80% (8075/10000)
# [93] time: 2412.725177526474 loss: 0.124 val_loss:0.6862711178351052 current_lr=0.011084
# Test Loss: 0.788422
#
# Test Accuracy of airplane: 82% (823/1000)
# Test Accuracy of automobile: 87% (870/1000)
# Test Accuracy of  bird: 58% (582/1000)
# Test Accuracy of   cat: 60% (609/1000)
# Test Accuracy of  deer: 69% (693/1000)
# Test Accuracy of   dog: 67% (679/1000)
# Test Accuracy of  frog: 95% (951/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 85% (859/1000)
# Test Accuracy of truck: 88% (889/1000)
#
# Test Accuracy (Overall): 77% (7791/10000)
# [94] time: 2439.2760832309723 loss: 0.126 val_loss:0.7884215957756284 current_lr=0.010797
# Test Loss: 0.667073
#
# Test Accuracy of airplane: 88% (887/1000)
# Test Accuracy of automobile: 89% (898/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 67% (670/1000)
# Test Accuracy of  deer: 81% (817/1000)
# Test Accuracy of   dog: 70% (709/1000)
# Test Accuracy of  frog: 81% (818/1000)
# Test Accuracy of horse: 82% (822/1000)
# Test Accuracy of  ship: 87% (870/1000)
# Test Accuracy of truck: 86% (862/1000)
#
# Test Accuracy (Overall): 81% (8123/10000)
# [95] time: 2465.2502195835114 loss: 0.120 val_loss:0.6670732762240157 current_lr=0.010554
# Test Loss: 0.687806
#
# Test Accuracy of airplane: 82% (821/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 82% (827/1000)
# Test Accuracy of   cat: 60% (606/1000)
# Test Accuracy of  deer: 77% (778/1000)
# Test Accuracy of   dog: 68% (684/1000)
# Test Accuracy of  frog: 83% (830/1000)
# Test Accuracy of horse: 90% (900/1000)
# Test Accuracy of  ship: 83% (831/1000)
# Test Accuracy of truck: 88% (889/1000)
#
# Test Accuracy (Overall): 80% (8066/10000)
# [96] time: 2491.2284274101257 loss: 0.118 val_loss:0.6878063184551045 current_lr=0.010355
# Test Loss: 0.737781
#
# Test Accuracy of airplane: 86% (869/1000)
# Test Accuracy of automobile: 94% (944/1000)
# Test Accuracy of  bird: 70% (705/1000)
# Test Accuracy of   cat: 72% (727/1000)
# Test Accuracy of  deer: 74% (749/1000)
# Test Accuracy of   dog: 71% (710/1000)
# Test Accuracy of  frog: 80% (801/1000)
# Test Accuracy of horse: 80% (802/1000)
# Test Accuracy of  ship: 88% (888/1000)
# Test Accuracy of truck: 72% (724/1000)
#
# Test Accuracy (Overall): 79% (7919/10000)
# [97] time: 2516.9953610897064 loss: 0.114 val_loss:0.7377811157250707 current_lr=0.010200
# Test Loss: 0.826271
#
# Test Accuracy of airplane: 76% (763/1000)
# Test Accuracy of automobile: 83% (832/1000)
# Test Accuracy of  bird: 82% (828/1000)
# Test Accuracy of   cat: 74% (740/1000)
# Test Accuracy of  deer: 73% (737/1000)
# Test Accuracy of   dog: 55% (556/1000)
# Test Accuracy of  frog: 83% (830/1000)
# Test Accuracy of horse: 70% (704/1000)
# Test Accuracy of  ship: 90% (908/1000)
# Test Accuracy of truck: 84% (847/1000)
#
# Test Accuracy (Overall): 77% (7745/10000)
# [98] time: 2542.8812601566315 loss: 0.119 val_loss:0.8262711174880402 current_lr=0.010089
# Test Loss: 0.747832
#
# Test Accuracy of airplane: 85% (856/1000)
# Test Accuracy of automobile: 91% (914/1000)
# Test Accuracy of  bird: 76% (762/1000)
# Test Accuracy of   cat: 65% (651/1000)
# Test Accuracy of  deer: 70% (709/1000)
# Test Accuracy of   dog: 67% (675/1000)
# Test Accuracy of  frog: 91% (915/1000)
# Test Accuracy of horse: 74% (743/1000)
# Test Accuracy of  ship: 82% (823/1000)
# Test Accuracy of truck: 86% (863/1000)
#
# Test Accuracy (Overall): 79% (7911/10000)
# [99] time: 2568.758811712265 loss: 0.119 val_loss:0.7478316362145581 current_lr=0.010022
# Test Loss: 0.720954
#
# Test Accuracy of airplane: 79% (799/1000)
# Test Accuracy of automobile: 85% (855/1000)
# Test Accuracy of  bird: 78% (783/1000)
# Test Accuracy of   cat: 61% (612/1000)
# Test Accuracy of  deer: 82% (822/1000)
# Test Accuracy of   dog: 70% (703/1000)
# Test Accuracy of  frog: 87% (870/1000)
# Test Accuracy of horse: 83% (837/1000)
# Test Accuracy of  ship: 85% (857/1000)
# Test Accuracy of truck: 88% (883/1000)
#
# Test Accuracy (Overall): 80% (8021/10000)
# [100] time: 2595.5063059329987 loss: 0.119 val_loss:0.7209540424467642 current_lr=0.010000
# Training finished!
# Training finished!

# %% [markdown]
# #**Adam Optimizer Learning Rate Search**

# %%
class AdamOptimizer(BaseOptimizer):
  def __init__(self,model,criterion,epochs):
    super().__init__(model,criterion,epochs)
  def initialize_optimizer(self, learning_rate):
    optimizer = optim.Adam(self.model.parameters(), lr=learning_rate, weight_decay=0.01)
    # Cosine annealing: lr → eta_min by the end
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=self.epochs,   # period (usually = total epochs)
        eta_min=0.1*learning_rate      # minimum LR (here 0.1× of 0.01)
    )
    self.optimizer,self.scheduler =  optimizer, scheduler

# %%
def get_adam(model, learning_rate):
    optimizer = AdamOptimizer(model, criterion, epochs)
    optimizer.initialize_optimizer(learning_rate)
    return optimizer
#42
result_adam = [2.1293160915374756, 1.8071961402893066, 1.66524338722229,
               1.6158260107040405, 1.6555125713348389, 1.9691908359527588, 1.6998178958892822]
#4242
#on val
result_adam = [1.495948240160942, 1.1622637659311295, 0.9822162389755249,
               1.0455565676093102, 1.199973076581955, 1.6418260782957077, 1.936485394835472]
#on test loader
# result_adam = [1.5130819529294968, 1.1102985590696335, 0.8878192976117134,
#                1.0387712642550468, 1.2745014354586601, 1.5895605832338333, 1.947695329785347]
if not result_adam:
    result_adam = grids_search_val(get_adam)
print(result_adam)
min_index = result_adam.index(min(result_adam))
learning_rate = learning_rates[min_index]
print(f"Best learning rate: {learning_rate}, Min val loss: {result_adam[min_index]}")
plt.figure(figsize=(6,4))
plt.xscale('log')   # good practice for learning rates
plt.xlabel("Learning rate")
plt.ylabel("Min Validation Loss")
plt.title("Learning Rate Grid Search")
plt.xticks(learning_rates, labels=[str(lr) for lr in learning_rates],rotation=45)
plt.plot(learning_rates, result_adam, label="Grid Search(Validataion Loss)", linewidth=2, marker='o')
# Out:
# [1.495948240160942, 1.1622637659311295, 0.9822162389755249, 1.0455565676093102, 1.199973076581955, 1.6418260782957077, 1.936485394835472]
# Best learning rate: 0.001, Min val loss: 0.9822162389755249

# %% [markdown]
# #**Adam Training with best learning rate**

# %%
learning_rate = 0.01
model_adam = initialize_model(device)
optimizer = AdamOptimizer(model_adam,criterion,epochs)
optimizer.initialize_optimizer(learning_rate)
losses_adam,losses_adam_val, adam_acc ,adam_time_cost = train_once(model_adam,criterion,optimizer,train_loader,test_loader,learning_rate,epochs)
print("Training finished!")
# Out:
# Test Loss: 1.957966
#
# Test Accuracy of airplane: 17% (177/1000)
# Test Accuracy of automobile: 64% (640/1000)
# Test Accuracy of  bird:  5% (51/1000)
# Test Accuracy of   cat:  9% (96/1000)
# Test Accuracy of  deer: 20% (208/1000)
# Test Accuracy of   dog: 16% (169/1000)
# Test Accuracy of  frog: 68% (684/1000)
# Test Accuracy of horse: 15% (154/1000)
# Test Accuracy of  ship: 83% (835/1000)
# Test Accuracy of truck:  3% (36/1000)
#
# Test Accuracy (Overall): 30% (3050/10000)
# [1] time: 27.32223653793335 loss: 1.813 val_loss:1.9579656093935423 current_lr=0.009998
# Test Loss: 1.793220
#
# Test Accuracy of airplane: 41% (411/1000)
# Test Accuracy of automobile: 14% (143/1000)
# Test Accuracy of  bird: 30% (302/1000)
# Test Accuracy of   cat: 23% (230/1000)
# Test Accuracy of  deer: 38% (385/1000)
# Test Accuracy of   dog: 36% (369/1000)
# Test Accuracy of  frog: 42% (423/1000)
# Test Accuracy of horse: 25% (257/1000)
# Test Accuracy of  ship: 84% (847/1000)
# Test Accuracy of truck:  9% (90/1000)
#
# Test Accuracy (Overall): 34% (3457/10000)
# [2] time: 54.43224334716797 loss: 1.578 val_loss:1.7932204641873324 current_lr=0.009991
# Test Loss: 2.414488
#
# Test Accuracy of airplane: 14% (149/1000)
# Test Accuracy of automobile:  0% ( 4/1000)
# Test Accuracy of  bird: 22% (223/1000)
# Test Accuracy of   cat: 22% (220/1000)
# Test Accuracy of  deer:  0% ( 0/1000)
# Test Accuracy of   dog: 91% (913/1000)
# Test Accuracy of  frog:  3% (30/1000)
# Test Accuracy of horse:  0% ( 1/1000)
# Test Accuracy of  ship: 49% (494/1000)
# Test Accuracy of truck:  0% ( 0/1000)
#
# Test Accuracy (Overall): 20% (2034/10000)
# [3] time: 81.10653352737427 loss: 1.519 val_loss:2.4144878493079656 current_lr=0.009980
# Test Loss: 1.613781
#
# Test Accuracy of airplane: 83% (830/1000)
# Test Accuracy of automobile: 18% (188/1000)
# Test Accuracy of  bird: 36% (369/1000)
# Test Accuracy of   cat: 11% (115/1000)
# Test Accuracy of  deer:  8% (83/1000)
# Test Accuracy of   dog: 58% (585/1000)
# Test Accuracy of  frog: 46% (463/1000)
# Test Accuracy of horse: 50% (503/1000)
# Test Accuracy of  ship: 37% (374/1000)
# Test Accuracy of truck: 41% (413/1000)
#
# Test Accuracy (Overall): 39% (3923/10000)
# [4] time: 108.10559701919556 loss: 1.494 val_loss:1.6137810462637792 current_lr=0.009965
# Test Loss: 2.150145
#
# Test Accuracy of airplane: 74% (740/1000)
# Test Accuracy of automobile: 16% (165/1000)
# Test Accuracy of  bird: 27% (274/1000)
# Test Accuracy of   cat: 18% (184/1000)
# Test Accuracy of  deer: 27% (273/1000)
# Test Accuracy of   dog: 23% (236/1000)
# Test Accuracy of  frog: 37% (370/1000)
# Test Accuracy of horse: 21% (211/1000)
# Test Accuracy of  ship: 75% (750/1000)
# Test Accuracy of truck:  2% (20/1000)
#
# Test Accuracy (Overall): 32% (3223/10000)
# [5] time: 135.29424405097961 loss: 1.471 val_loss:2.150144936163214 current_lr=0.009945
# Test Loss: 1.587889
#
# Test Accuracy of airplane: 46% (467/1000)
# Test Accuracy of automobile: 19% (191/1000)
# Test Accuracy of  bird: 12% (126/1000)
# Test Accuracy of   cat: 42% (425/1000)
# Test Accuracy of  deer: 41% (415/1000)
# Test Accuracy of   dog: 54% (545/1000)
# Test Accuracy of  frog: 43% (430/1000)
# Test Accuracy of horse: 51% (516/1000)
# Test Accuracy of  ship: 63% (638/1000)
# Test Accuracy of truck: 51% (511/1000)
#
# Test Accuracy (Overall): 42% (4264/10000)
# [6] time: 162.09083890914917 loss: 1.458 val_loss:1.587888618058796 current_lr=0.009920
# Test Loss: 1.659545
#
# Test Accuracy of airplane: 40% (404/1000)
# Test Accuracy of automobile: 78% (785/1000)
# Test Accuracy of  bird:  5% (52/1000)
# Test Accuracy of   cat:  1% (17/1000)
# Test Accuracy of  deer: 27% (278/1000)
# Test Accuracy of   dog: 63% (637/1000)
# Test Accuracy of  frog: 35% (351/1000)
# Test Accuracy of horse: 72% (723/1000)
# Test Accuracy of  ship: 24% (241/1000)
# Test Accuracy of truck: 50% (500/1000)
#
# Test Accuracy (Overall): 39% (3988/10000)
# [7] time: 189.16166400909424 loss: 1.454 val_loss:1.6595445629916614 current_lr=0.009892
# Test Loss: 2.008689
#
# Test Accuracy of airplane: 72% (727/1000)
# Test Accuracy of automobile:  9% (98/1000)
# Test Accuracy of  bird: 57% (579/1000)
# Test Accuracy of   cat: 10% (105/1000)
# Test Accuracy of  deer:  5% (54/1000)
# Test Accuracy of   dog: 50% (502/1000)
# Test Accuracy of  frog: 10% (105/1000)
# Test Accuracy of horse: 32% (325/1000)
# Test Accuracy of  ship: 58% (582/1000)
# Test Accuracy of truck:  2% (24/1000)
#
# Test Accuracy (Overall): 31% (3101/10000)
# [8] time: 215.7412257194519 loss: 1.450 val_loss:2.0086886414998695 current_lr=0.009859
# Test Loss: 1.488529
#
# Test Accuracy of airplane: 66% (663/1000)
# Test Accuracy of automobile: 61% (613/1000)
# Test Accuracy of  bird: 44% (445/1000)
# Test Accuracy of   cat:  9% (94/1000)
# Test Accuracy of  deer: 36% (363/1000)
# Test Accuracy of   dog: 32% (326/1000)
# Test Accuracy of  frog: 74% (745/1000)
# Test Accuracy of horse: 39% (391/1000)
# Test Accuracy of  ship: 58% (583/1000)
# Test Accuracy of truck: 40% (408/1000)
#
# Test Accuracy (Overall): 46% (4631/10000)
# [9] time: 243.34078669548035 loss: 1.440 val_loss:1.4885290951668462 current_lr=0.009821
# Test Loss: 1.733747
#
# Test Accuracy of airplane: 28% (286/1000)
# Test Accuracy of automobile: 39% (391/1000)
# Test Accuracy of  bird: 40% (404/1000)
# Test Accuracy of   cat:  3% (36/1000)
# Test Accuracy of  deer: 38% (386/1000)
# Test Accuracy of   dog: 55% (559/1000)
# Test Accuracy of  frog: 25% (250/1000)
# Test Accuracy of horse: 71% (716/1000)
# Test Accuracy of  ship: 44% (447/1000)
# Test Accuracy of truck: 28% (280/1000)
#
# Test Accuracy (Overall): 37% (3755/10000)
# [10] time: 269.93703532218933 loss: 1.435 val_loss:1.7337468756905086 current_lr=0.009780
# Test Loss: 1.742124
#
# Test Accuracy of airplane: 69% (699/1000)
# Test Accuracy of automobile: 40% (403/1000)
# Test Accuracy of  bird: 16% (163/1000)
# Test Accuracy of   cat: 18% (188/1000)
# Test Accuracy of  deer: 29% (298/1000)
# Test Accuracy of   dog: 18% (180/1000)
# Test Accuracy of  frog: 75% (757/1000)
# Test Accuracy of horse: 22% (222/1000)
# Test Accuracy of  ship: 66% (666/1000)
# Test Accuracy of truck: 22% (221/1000)
#
# Test Accuracy (Overall): 37% (3797/10000)
# [11] time: 296.672443151474 loss: 1.426 val_loss:1.742124236082729 current_lr=0.009734
# Test Loss: 1.763884
#
# Test Accuracy of airplane: 46% (469/1000)
# Test Accuracy of automobile: 20% (208/1000)
# Test Accuracy of  bird: 58% (580/1000)
# Test Accuracy of   cat: 32% (322/1000)
# Test Accuracy of  deer: 17% (170/1000)
# Test Accuracy of   dog: 50% (502/1000)
# Test Accuracy of  frog: 15% (158/1000)
# Test Accuracy of horse: 35% (352/1000)
# Test Accuracy of  ship: 61% (612/1000)
# Test Accuracy of truck:  9% (91/1000)
#
# Test Accuracy (Overall): 34% (3464/10000)
# [12] time: 323.3622159957886 loss: 1.421 val_loss:1.7638835922072205 current_lr=0.009684
# Test Loss: 2.515163
#
# Test Accuracy of airplane:  8% (81/1000)
# Test Accuracy of automobile:  2% (26/1000)
# Test Accuracy of  bird:  6% (62/1000)
# Test Accuracy of   cat: 12% (123/1000)
# Test Accuracy of  deer: 46% (469/1000)
# Test Accuracy of   dog: 25% (257/1000)
# Test Accuracy of  frog: 57% (574/1000)
# Test Accuracy of horse: 83% (835/1000)
# Test Accuracy of  ship:  5% (50/1000)
# Test Accuracy of truck:  2% (22/1000)
#
# Test Accuracy (Overall): 24% (2499/10000)
# [13] time: 350.7073760032654 loss: 1.413 val_loss:2.515162821057477 current_lr=0.009630
# Test Loss: 2.120014
#
# Test Accuracy of airplane: 69% (696/1000)
# Test Accuracy of automobile:  8% (87/1000)
# Test Accuracy of  bird: 29% (295/1000)
# Test Accuracy of   cat:  0% ( 1/1000)
# Test Accuracy of  deer: 62% (621/1000)
# Test Accuracy of   dog: 16% (169/1000)
# Test Accuracy of  frog:  4% (46/1000)
# Test Accuracy of horse: 69% (699/1000)
# Test Accuracy of  ship: 18% (189/1000)
# Test Accuracy of truck: 20% (201/1000)
#
# Test Accuracy (Overall): 30% (3004/10000)
# [14] time: 377.61435556411743 loss: 1.411 val_loss:2.1200144773797143 current_lr=0.009572
# Test Loss: 1.665503
#
# Test Accuracy of airplane: 39% (394/1000)
# Test Accuracy of automobile: 72% (723/1000)
# Test Accuracy of  bird:  7% (75/1000)
# Test Accuracy of   cat: 21% (212/1000)
# Test Accuracy of  deer:  0% ( 9/1000)
# Test Accuracy of   dog: 71% (714/1000)
# Test Accuracy of  frog: 69% (693/1000)
# Test Accuracy of horse: 36% (360/1000)
# Test Accuracy of  ship: 60% (600/1000)
# Test Accuracy of truck: 35% (355/1000)
#
# Test Accuracy (Overall): 41% (4135/10000)
# [15] time: 404.19104409217834 loss: 1.409 val_loss:1.6655031653899182 current_lr=0.009510
# Test Loss: 1.640249
#
# Test Accuracy of airplane: 77% (777/1000)
# Test Accuracy of automobile: 84% (843/1000)
# Test Accuracy of  bird: 44% (447/1000)
# Test Accuracy of   cat: 22% (221/1000)
# Test Accuracy of  deer:  1% (14/1000)
# Test Accuracy of   dog: 43% (430/1000)
# Test Accuracy of  frog: 69% (690/1000)
# Test Accuracy of horse: 26% (269/1000)
# Test Accuracy of  ship: 21% (215/1000)
# Test Accuracy of truck:  4% (42/1000)
#
# Test Accuracy (Overall): 39% (3948/10000)
# [16] time: 430.807363986969 loss: 1.411 val_loss:1.640248638165148 current_lr=0.009443
# Test Loss: 1.666311
#
# Test Accuracy of airplane: 69% (691/1000)
# Test Accuracy of automobile: 25% (250/1000)
# Test Accuracy of  bird: 51% (519/1000)
# Test Accuracy of   cat: 22% (223/1000)
# Test Accuracy of  deer: 41% (413/1000)
# Test Accuracy of   dog: 35% (355/1000)
# Test Accuracy of  frog: 65% (655/1000)
# Test Accuracy of horse: 22% (227/1000)
# Test Accuracy of  ship: 52% (520/1000)
# Test Accuracy of truck: 24% (241/1000)
#
# Test Accuracy (Overall): 40% (4094/10000)
# [17] time: 458.0379502773285 loss: 1.399 val_loss:1.6663105125668682 current_lr=0.009373
# Test Loss: 1.551693
#
# Test Accuracy of airplane: 35% (352/1000)
# Test Accuracy of automobile: 58% (582/1000)
# Test Accuracy of  bird:  6% (69/1000)
# Test Accuracy of   cat: 18% (187/1000)
# Test Accuracy of  deer: 12% (127/1000)
# Test Accuracy of   dog: 65% (655/1000)
# Test Accuracy of  frog: 62% (623/1000)
# Test Accuracy of horse: 69% (698/1000)
# Test Accuracy of  ship: 61% (610/1000)
# Test Accuracy of truck: 59% (593/1000)
#
# Test Accuracy (Overall): 44% (4496/10000)
# [18] time: 484.6982011795044 loss: 1.404 val_loss:1.5516934515554694 current_lr=0.009299
# Test Loss: 1.802789
#
# Test Accuracy of airplane: 23% (236/1000)
# Test Accuracy of automobile:  2% (26/1000)
# Test Accuracy of  bird: 33% (332/1000)
# Test Accuracy of   cat: 39% (397/1000)
# Test Accuracy of  deer:  3% (32/1000)
# Test Accuracy of   dog: 64% (648/1000)
# Test Accuracy of  frog: 30% (308/1000)
# Test Accuracy of horse: 19% (199/1000)
# Test Accuracy of  ship: 81% (813/1000)
# Test Accuracy of truck: 35% (356/1000)
#
# Test Accuracy (Overall): 33% (3347/10000)
# [19] time: 511.15991616249084 loss: 1.406 val_loss:1.8027889426750472 current_lr=0.009222
# Test Loss: 1.747066
#
# Test Accuracy of airplane: 17% (179/1000)
# Test Accuracy of automobile: 42% (429/1000)
# Test Accuracy of  bird:  2% (29/1000)
# Test Accuracy of   cat:  2% (23/1000)
# Test Accuracy of  deer: 47% (477/1000)
# Test Accuracy of   dog: 16% (161/1000)
# Test Accuracy of  frog: 86% (867/1000)
# Test Accuracy of horse: 46% (466/1000)
# Test Accuracy of  ship: 51% (514/1000)
# Test Accuracy of truck: 64% (649/1000)
#
# Test Accuracy (Overall): 37% (3794/10000)
# [20] time: 537.747284412384 loss: 1.394 val_loss:1.747065630140184 current_lr=0.009141
# Test Loss: 1.840758
#
# Test Accuracy of airplane: 92% (929/1000)
# Test Accuracy of automobile: 28% (282/1000)
# Test Accuracy of  bird: 23% (237/1000)
# Test Accuracy of   cat: 15% (151/1000)
# Test Accuracy of  deer: 29% (294/1000)
# Test Accuracy of   dog: 24% (249/1000)
# Test Accuracy of  frog: 35% (353/1000)
# Test Accuracy of horse: 72% (729/1000)
# Test Accuracy of  ship: 13% (131/1000)
# Test Accuracy of truck: 29% (295/1000)
#
# Test Accuracy (Overall): 36% (3650/10000)
# [21] time: 564.562819480896 loss: 1.395 val_loss:1.8407575103301037 current_lr=0.009056
# Test Loss: 1.732501
#
# Test Accuracy of airplane: 37% (373/1000)
# Test Accuracy of automobile: 17% (178/1000)
# Test Accuracy of  bird: 38% (383/1000)
# Test Accuracy of   cat:  3% (35/1000)
# Test Accuracy of  deer:  0% ( 0/1000)
# Test Accuracy of   dog: 86% (869/1000)
# Test Accuracy of  frog: 19% (194/1000)
# Test Accuracy of horse: 33% (331/1000)
# Test Accuracy of  ship: 84% (847/1000)
# Test Accuracy of truck: 36% (363/1000)
#
# Test Accuracy (Overall): 35% (3573/10000)
# [22] time: 591.4333488941193 loss: 1.396 val_loss:1.7325007568431805 current_lr=0.008967
# Test Loss: 2.288521
#
# Test Accuracy of airplane: 18% (182/1000)
# Test Accuracy of automobile: 92% (921/1000)
# Test Accuracy of  bird:  0% ( 9/1000)
# Test Accuracy of   cat:  6% (66/1000)
# Test Accuracy of  deer:  6% (65/1000)
# Test Accuracy of   dog:  3% (37/1000)
# Test Accuracy of  frog: 59% (598/1000)
# Test Accuracy of horse:  2% (23/1000)
# Test Accuracy of  ship: 53% (535/1000)
# Test Accuracy of truck: 44% (443/1000)
#
# Test Accuracy (Overall): 28% (2879/10000)
# [23] time: 618.0850944519043 loss: 1.392 val_loss:2.288521040844012 current_lr=0.008875
# Test Loss: 1.388613
#
# Test Accuracy of airplane: 68% (682/1000)
# Test Accuracy of automobile: 56% (567/1000)
# Test Accuracy of  bird: 37% (373/1000)
# Test Accuracy of   cat: 18% (189/1000)
# Test Accuracy of  deer: 24% (242/1000)
# Test Accuracy of   dog: 52% (529/1000)
# Test Accuracy of  frog: 67% (672/1000)
# Test Accuracy of horse: 61% (613/1000)
# Test Accuracy of  ship: 52% (522/1000)
# Test Accuracy of truck: 55% (557/1000)
#
# Test Accuracy (Overall): 49% (4946/10000)
# [24] time: 644.7050502300262 loss: 1.384 val_loss:1.3886134564122068 current_lr=0.008780
# Test Loss: 1.772047
#
# Test Accuracy of airplane: 15% (158/1000)
# Test Accuracy of automobile: 90% (904/1000)
# Test Accuracy of  bird: 27% (277/1000)
# Test Accuracy of   cat:  7% (74/1000)
# Test Accuracy of  deer: 71% (711/1000)
# Test Accuracy of   dog: 67% (677/1000)
# Test Accuracy of  frog: 15% (150/1000)
# Test Accuracy of horse: 23% (232/1000)
# Test Accuracy of  ship: 30% (307/1000)
# Test Accuracy of truck:  4% (47/1000)
#
# Test Accuracy (Overall): 35% (3537/10000)
# [25] time: 672.0604603290558 loss: 1.389 val_loss:1.7720474713965306 current_lr=0.008682
# Test Loss: 1.514097
#
# Test Accuracy of airplane: 46% (464/1000)
# Test Accuracy of automobile: 37% (370/1000)
# Test Accuracy of  bird: 46% (466/1000)
# Test Accuracy of   cat:  3% (33/1000)
# Test Accuracy of  deer: 52% (526/1000)
# Test Accuracy of   dog: 40% (408/1000)
# Test Accuracy of  frog: 50% (507/1000)
# Test Accuracy of horse: 55% (559/1000)
# Test Accuracy of  ship: 74% (743/1000)
# Test Accuracy of truck: 46% (466/1000)
#
# Test Accuracy (Overall): 45% (4542/10000)
# [26] time: 698.9344062805176 loss: 1.387 val_loss:1.514097191110442 current_lr=0.008580
# Test Loss: 2.136140
#
# Test Accuracy of airplane: 57% (579/1000)
# Test Accuracy of automobile: 23% (231/1000)
# Test Accuracy of  bird:  7% (73/1000)
# Test Accuracy of   cat:  0% ( 2/1000)
# Test Accuracy of  deer: 54% (546/1000)
# Test Accuracy of   dog: 10% (103/1000)
# Test Accuracy of  frog: 32% (326/1000)
# Test Accuracy of horse: 91% (914/1000)
# Test Accuracy of  ship:  3% (34/1000)
# Test Accuracy of truck: 22% (221/1000)
#
# Test Accuracy (Overall): 30% (3029/10000)
# [27] time: 725.3833432197571 loss: 1.378 val_loss:2.1361397957500023 current_lr=0.008476
# Test Loss: 2.225627
#
# Test Accuracy of airplane: 52% (524/1000)
# Test Accuracy of automobile: 31% (312/1000)
# Test Accuracy of  bird: 18% (187/1000)
# Test Accuracy of   cat:  0% ( 1/1000)
# Test Accuracy of  deer:  0% ( 0/1000)
# Test Accuracy of   dog: 95% (956/1000)
# Test Accuracy of  frog:  0% ( 1/1000)
# Test Accuracy of horse: 24% (243/1000)
# Test Accuracy of  ship: 60% (603/1000)
# Test Accuracy of truck: 16% (160/1000)
#
# Test Accuracy (Overall): 29% (2987/10000)
# [28] time: 751.8961100578308 loss: 1.381 val_loss:2.225626784034922 current_lr=0.008368
# Test Loss: 2.075625
#
# Test Accuracy of airplane: 89% (894/1000)
# Test Accuracy of automobile: 40% (403/1000)
# Test Accuracy of  bird: 11% (114/1000)
# Test Accuracy of   cat:  0% ( 1/1000)
# Test Accuracy of  deer:  0% ( 2/1000)
# Test Accuracy of   dog: 48% (486/1000)
# Test Accuracy of  frog:  0% ( 1/1000)
# Test Accuracy of horse: 81% (814/1000)
# Test Accuracy of  ship:  2% (20/1000)
# Test Accuracy of truck: 30% (302/1000)
#
# Test Accuracy (Overall): 30% (3037/10000)
# [29] time: 779.0421104431152 loss: 1.378 val_loss:2.0756251917609685 current_lr=0.008258
# Test Loss: 1.849477
#
# Test Accuracy of airplane: 78% (780/1000)
# Test Accuracy of automobile: 19% (195/1000)
# Test Accuracy of  bird: 38% (387/1000)
# Test Accuracy of   cat:  7% (75/1000)
# Test Accuracy of  deer: 37% (371/1000)
# Test Accuracy of   dog: 59% (593/1000)
# Test Accuracy of  frog: 27% (274/1000)
# Test Accuracy of horse: 56% (566/1000)
# Test Accuracy of  ship: 13% (135/1000)
# Test Accuracy of truck: 19% (198/1000)
#
# Test Accuracy (Overall): 35% (3574/10000)
# [30] time: 805.649879693985 loss: 1.376 val_loss:1.8494770496706419 current_lr=0.008145
# Test Loss: 1.432489
#
# Test Accuracy of airplane: 50% (501/1000)
# Test Accuracy of automobile: 41% (414/1000)
# Test Accuracy of  bird: 28% (285/1000)
# Test Accuracy of   cat: 22% (224/1000)
# Test Accuracy of  deer: 39% (392/1000)
# Test Accuracy of   dog: 50% (504/1000)
# Test Accuracy of  frog: 49% (494/1000)
# Test Accuracy of horse: 50% (504/1000)
# Test Accuracy of  ship: 82% (823/1000)
# Test Accuracy of truck: 65% (652/1000)
#
# Test Accuracy (Overall): 47% (4793/10000)
# [31] time: 832.1564743518829 loss: 1.375 val_loss:1.4324888277657424 current_lr=0.008029
# Test Loss: 2.967660
#
# Test Accuracy of airplane:  5% (53/1000)
# Test Accuracy of automobile: 98% (982/1000)
# Test Accuracy of  bird:  3% (32/1000)
# Test Accuracy of   cat:  0% ( 6/1000)
# Test Accuracy of  deer: 48% (482/1000)
# Test Accuracy of   dog:  2% (22/1000)
# Test Accuracy of  frog: 11% (111/1000)
# Test Accuracy of horse: 47% (475/1000)
# Test Accuracy of  ship:  0% ( 4/1000)
# Test Accuracy of truck:  0% ( 3/1000)
#
# Test Accuracy (Overall): 21% (2170/10000)
# [32] time: 858.7397315502167 loss: 1.367 val_loss:2.9676598989510836 current_lr=0.007911
# Test Loss: 1.554053
#
# Test Accuracy of airplane: 47% (471/1000)
# Test Accuracy of automobile: 87% (876/1000)
# Test Accuracy of  bird: 26% (261/1000)
# Test Accuracy of   cat: 34% (342/1000)
# Test Accuracy of  deer: 17% (175/1000)
# Test Accuracy of   dog: 26% (263/1000)
# Test Accuracy of  frog: 65% (654/1000)
# Test Accuracy of horse: 54% (546/1000)
# Test Accuracy of  ship: 73% (732/1000)
# Test Accuracy of truck: 10% (108/1000)
#
# Test Accuracy (Overall): 44% (4428/10000)
# [33] time: 885.8213136196136 loss: 1.367 val_loss:1.5540533488309836 current_lr=0.007791
# Test Loss: 1.515392
#
# Test Accuracy of airplane: 40% (407/1000)
# Test Accuracy of automobile: 81% (811/1000)
# Test Accuracy of  bird: 76% (760/1000)
# Test Accuracy of   cat: 16% (162/1000)
# Test Accuracy of  deer: 20% (208/1000)
# Test Accuracy of   dog: 38% (382/1000)
# Test Accuracy of  frog: 43% (436/1000)
# Test Accuracy of horse: 27% (277/1000)
# Test Accuracy of  ship: 53% (537/1000)
# Test Accuracy of truck: 33% (334/1000)
#
# Test Accuracy (Overall): 43% (4314/10000)
# [34] time: 912.5134558677673 loss: 1.362 val_loss:1.5153923200655588 current_lr=0.007668
# Test Loss: 1.884138
#
# Test Accuracy of airplane: 54% (545/1000)
# Test Accuracy of automobile: 48% (486/1000)
# Test Accuracy of  bird: 32% (328/1000)
# Test Accuracy of   cat: 12% (121/1000)
# Test Accuracy of  deer: 24% (245/1000)
# Test Accuracy of   dog: 38% (381/1000)
# Test Accuracy of  frog: 31% (312/1000)
# Test Accuracy of horse: 11% (110/1000)
# Test Accuracy of  ship: 90% (909/1000)
# Test Accuracy of truck:  8% (85/1000)
#
# Test Accuracy (Overall): 35% (3522/10000)
# [35] time: 939.1331028938293 loss: 1.363 val_loss:1.8841383125208602 current_lr=0.007543
# Test Loss: 1.362907
#
# Test Accuracy of airplane: 41% (417/1000)
# Test Accuracy of automobile: 70% (701/1000)
# Test Accuracy of  bird: 44% (449/1000)
# Test Accuracy of   cat: 25% (259/1000)
# Test Accuracy of  deer: 36% (369/1000)
# Test Accuracy of   dog: 28% (288/1000)
# Test Accuracy of  frog: 75% (759/1000)
# Test Accuracy of horse: 44% (442/1000)
# Test Accuracy of  ship: 77% (770/1000)
# Test Accuracy of truck: 55% (558/1000)
#
# Test Accuracy (Overall): 50% (5012/10000)
# [36] time: 965.7943184375763 loss: 1.357 val_loss:1.362907038459295 current_lr=0.007416
# Test Loss: 1.523747
#
# Test Accuracy of airplane: 51% (511/1000)
# Test Accuracy of automobile: 67% (678/1000)
# Test Accuracy of  bird: 21% (211/1000)
# Test Accuracy of   cat:  8% (89/1000)
# Test Accuracy of  deer: 20% (205/1000)
# Test Accuracy of   dog: 64% (643/1000)
# Test Accuracy of  frog: 33% (330/1000)
# Test Accuracy of horse: 71% (711/1000)
# Test Accuracy of  ship: 80% (803/1000)
# Test Accuracy of truck: 23% (233/1000)
#
# Test Accuracy (Overall): 44% (4414/10000)
# [37] time: 993.1360096931458 loss: 1.352 val_loss:1.523747296272954 current_lr=0.007287
# Test Loss: 1.762104
#
# Test Accuracy of airplane: 47% (475/1000)
# Test Accuracy of automobile: 28% (284/1000)
# Test Accuracy of  bird: 16% (168/1000)
# Test Accuracy of   cat: 28% (287/1000)
# Test Accuracy of  deer: 32% (326/1000)
# Test Accuracy of   dog: 70% (705/1000)
# Test Accuracy of  frog: 20% (206/1000)
# Test Accuracy of horse: 66% (664/1000)
# Test Accuracy of  ship: 13% (139/1000)
# Test Accuracy of truck: 47% (479/1000)
#
# Test Accuracy (Overall): 37% (3733/10000)
# [38] time: 1020.0125427246094 loss: 1.354 val_loss:1.7621043829978267 current_lr=0.007157
# Test Loss: 1.594988
#
# Test Accuracy of airplane: 70% (708/1000)
# Test Accuracy of automobile: 49% (499/1000)
# Test Accuracy of  bird: 57% (570/1000)
# Test Accuracy of   cat: 38% (383/1000)
# Test Accuracy of  deer: 11% (116/1000)
# Test Accuracy of   dog: 54% (543/1000)
# Test Accuracy of  frog: 36% (369/1000)
# Test Accuracy of horse: 28% (285/1000)
# Test Accuracy of  ship: 53% (536/1000)
# Test Accuracy of truck: 25% (250/1000)
#
# Test Accuracy (Overall): 42% (4259/10000)
# [39] time: 1046.6392059326172 loss: 1.342 val_loss:1.5949883551537236 current_lr=0.007024
# Test Loss: 1.670061
#
# Test Accuracy of airplane: 84% (844/1000)
# Test Accuracy of automobile: 68% (680/1000)
# Test Accuracy of  bird: 56% (568/1000)
# Test Accuracy of   cat:  5% (51/1000)
# Test Accuracy of  deer: 41% (410/1000)
# Test Accuracy of   dog: 26% (267/1000)
# Test Accuracy of  frog: 46% (465/1000)
# Test Accuracy of horse: 47% (478/1000)
# Test Accuracy of  ship: 16% (162/1000)
# Test Accuracy of truck: 15% (155/1000)
#
# Test Accuracy (Overall): 40% (4080/10000)
# [40] time: 1073.1341261863708 loss: 1.335 val_loss:1.670060945462577 current_lr=0.006891
# Test Loss: 1.450189
#
# Test Accuracy of airplane: 37% (376/1000)
# Test Accuracy of automobile: 74% (749/1000)
# Test Accuracy of  bird: 23% (237/1000)
# Test Accuracy of   cat: 30% (302/1000)
# Test Accuracy of  deer: 25% (259/1000)
# Test Accuracy of   dog: 31% (311/1000)
# Test Accuracy of  frog: 75% (754/1000)
# Test Accuracy of horse: 56% (566/1000)
# Test Accuracy of  ship: 51% (515/1000)
# Test Accuracy of truck: 69% (693/1000)
#
# Test Accuracy (Overall): 47% (4762/10000)
# [41] time: 1100.3030104637146 loss: 1.332 val_loss:1.4501893309098255 current_lr=0.006755
# Test Loss: 1.698688
#
# Test Accuracy of airplane: 59% (597/1000)
# Test Accuracy of automobile: 21% (219/1000)
# Test Accuracy of  bird: 54% (546/1000)
# Test Accuracy of   cat: 26% (269/1000)
# Test Accuracy of  deer: 11% (113/1000)
# Test Accuracy of   dog: 63% (634/1000)
# Test Accuracy of  frog: 47% (475/1000)
# Test Accuracy of horse: 51% (512/1000)
# Test Accuracy of  ship: 14% (141/1000)
# Test Accuracy of truck: 55% (554/1000)
#
# Test Accuracy (Overall): 40% (4060/10000)
# [42] time: 1126.870272397995 loss: 1.325 val_loss:1.6986880785302272 current_lr=0.006619
# Test Loss: 1.746144
#
# Test Accuracy of airplane: 57% (574/1000)
# Test Accuracy of automobile: 49% (492/1000)
# Test Accuracy of  bird:  3% (37/1000)
# Test Accuracy of   cat:  2% (26/1000)
# Test Accuracy of  deer: 26% (266/1000)
# Test Accuracy of   dog: 33% (330/1000)
# Test Accuracy of  frog: 18% (188/1000)
# Test Accuracy of horse: 93% (937/1000)
# Test Accuracy of  ship: 57% (570/1000)
# Test Accuracy of truck: 43% (436/1000)
#
# Test Accuracy (Overall): 38% (3856/10000)
# [43] time: 1153.3032865524292 loss: 1.322 val_loss:1.7461436851115166 current_lr=0.006482
# Test Loss: 1.609568
#
# Test Accuracy of airplane: 14% (148/1000)
# Test Accuracy of automobile: 55% (555/1000)
# Test Accuracy of  bird: 38% (385/1000)
# Test Accuracy of   cat:  9% (95/1000)
# Test Accuracy of  deer: 15% (154/1000)
# Test Accuracy of   dog: 53% (536/1000)
# Test Accuracy of  frog: 84% (842/1000)
# Test Accuracy of horse: 23% (237/1000)
# Test Accuracy of  ship: 86% (861/1000)
# Test Accuracy of truck: 35% (352/1000)
#
# Test Accuracy (Overall): 41% (4165/10000)
# [44] time: 1180.0103888511658 loss: 1.317 val_loss:1.6095681356478342 current_lr=0.006343
# Test Loss: 1.419462
#
# Test Accuracy of airplane: 45% (453/1000)
# Test Accuracy of automobile: 66% (662/1000)
# Test Accuracy of  bird: 43% (432/1000)
# Test Accuracy of   cat: 23% (238/1000)
# Test Accuracy of  deer: 18% (187/1000)
# Test Accuracy of   dog: 68% (681/1000)
# Test Accuracy of  frog: 57% (570/1000)
# Test Accuracy of horse: 52% (528/1000)
# Test Accuracy of  ship: 71% (717/1000)
# Test Accuracy of truck: 41% (412/1000)
#
# Test Accuracy (Overall): 48% (4880/10000)
# [45] time: 1207.2167429924011 loss: 1.318 val_loss:1.4194623050810415 current_lr=0.006204
# Test Loss: 1.435113
#
# Test Accuracy of airplane: 35% (359/1000)
# Test Accuracy of automobile: 55% (550/1000)
# Test Accuracy of  bird: 28% (287/1000)
# Test Accuracy of   cat: 21% (212/1000)
# Test Accuracy of  deer: 40% (405/1000)
# Test Accuracy of   dog: 32% (325/1000)
# Test Accuracy of  frog: 79% (799/1000)
# Test Accuracy of horse: 40% (407/1000)
# Test Accuracy of  ship: 88% (886/1000)
# Test Accuracy of truck: 55% (556/1000)
#
# Test Accuracy (Overall): 47% (4786/10000)
# [46] time: 1233.781245470047 loss: 1.314 val_loss:1.4351127630547633 current_lr=0.006064
# Test Loss: 1.425142
#
# Test Accuracy of airplane: 52% (521/1000)
# Test Accuracy of automobile: 47% (473/1000)
# Test Accuracy of  bird: 10% (103/1000)
# Test Accuracy of   cat: 14% (147/1000)
# Test Accuracy of  deer: 69% (695/1000)
# Test Accuracy of   dog: 40% (400/1000)
# Test Accuracy of  frog: 26% (268/1000)
# Test Accuracy of horse: 70% (707/1000)
# Test Accuracy of  ship: 76% (768/1000)
# Test Accuracy of truck: 76% (767/1000)
#
# Test Accuracy (Overall): 48% (4849/10000)
# [47] time: 1260.567730665207 loss: 1.302 val_loss:1.4251422308668305 current_lr=0.005923
# Test Loss: 1.633929
#
# Test Accuracy of airplane: 28% (286/1000)
# Test Accuracy of automobile: 32% (322/1000)
# Test Accuracy of  bird: 13% (134/1000)
# Test Accuracy of   cat: 17% (172/1000)
# Test Accuracy of  deer: 21% (214/1000)
# Test Accuracy of   dog: 50% (507/1000)
# Test Accuracy of  frog: 87% (879/1000)
# Test Accuracy of horse: 70% (708/1000)
# Test Accuracy of  ship: 53% (536/1000)
# Test Accuracy of truck: 46% (460/1000)
#
# Test Accuracy (Overall): 42% (4218/10000)
# [48] time: 1287.2026941776276 loss: 1.301 val_loss:1.6339289176313183 current_lr=0.005783
# Test Loss: 1.693497
#
# Test Accuracy of airplane: 36% (366/1000)
# Test Accuracy of automobile: 43% (433/1000)
# Test Accuracy of  bird:  6% (65/1000)
# Test Accuracy of   cat:  3% (35/1000)
# Test Accuracy of  deer: 14% (141/1000)
# Test Accuracy of   dog: 36% (362/1000)
# Test Accuracy of  frog: 19% (195/1000)
# Test Accuracy of horse: 80% (801/1000)
# Test Accuracy of  ship: 83% (833/1000)
# Test Accuracy of truck: 83% (838/1000)
#
# Test Accuracy (Overall): 40% (4069/10000)
# [49] time: 1314.078383922577 loss: 1.293 val_loss:1.693497177920764 current_lr=0.005641
# Test Loss: 1.366702
#
# Test Accuracy of airplane: 68% (689/1000)
# Test Accuracy of automobile: 71% (713/1000)
# Test Accuracy of  bird: 22% (228/1000)
# Test Accuracy of   cat: 24% (240/1000)
# Test Accuracy of  deer: 32% (323/1000)
# Test Accuracy of   dog: 62% (626/1000)
# Test Accuracy of  frog: 51% (515/1000)
# Test Accuracy of horse: 64% (645/1000)
# Test Accuracy of  ship: 37% (372/1000)
# Test Accuracy of truck: 70% (709/1000)
#
# Test Accuracy (Overall): 50% (5060/10000)
# [50] time: 1340.8024933338165 loss: 1.292 val_loss:1.3667020511023606 current_lr=0.005500
# Test Loss: 1.478400
#
# Test Accuracy of airplane: 46% (468/1000)
# Test Accuracy of automobile: 62% (623/1000)
# Test Accuracy of  bird: 27% (272/1000)
# Test Accuracy of   cat: 11% (117/1000)
# Test Accuracy of  deer: 52% (525/1000)
# Test Accuracy of   dog: 50% (500/1000)
# Test Accuracy of  frog: 34% (346/1000)
# Test Accuracy of horse: 70% (704/1000)
# Test Accuracy of  ship: 35% (355/1000)
# Test Accuracy of truck: 75% (754/1000)
#
# Test Accuracy (Overall): 46% (4664/10000)
# [51] time: 1367.3295533657074 loss: 1.281 val_loss:1.4783999165402184 current_lr=0.005359
# Test Loss: 2.031321
#
# Test Accuracy of airplane: 35% (356/1000)
# Test Accuracy of automobile: 24% (243/1000)
# Test Accuracy of  bird: 55% (555/1000)
# Test Accuracy of   cat:  8% (88/1000)
# Test Accuracy of  deer:  3% (37/1000)
# Test Accuracy of   dog: 19% (192/1000)
# Test Accuracy of  frog: 89% (891/1000)
# Test Accuracy of horse:  6% (61/1000)
# Test Accuracy of  ship: 70% (700/1000)
# Test Accuracy of truck: 22% (224/1000)
#
# Test Accuracy (Overall): 33% (3347/10000)
# [52] time: 1394.1883058547974 loss: 1.285 val_loss:2.0313209038746507 current_lr=0.005217
# Test Loss: 1.397523
#
# Test Accuracy of airplane: 78% (780/1000)
# Test Accuracy of automobile: 60% (608/1000)
# Test Accuracy of  bird: 22% (221/1000)
# Test Accuracy of   cat: 11% (112/1000)
# Test Accuracy of  deer: 42% (429/1000)
# Test Accuracy of   dog: 46% (468/1000)
# Test Accuracy of  frog: 38% (388/1000)
# Test Accuracy of horse: 76% (762/1000)
# Test Accuracy of  ship: 39% (399/1000)
# Test Accuracy of truck: 72% (720/1000)
#
# Test Accuracy (Overall): 48% (4887/10000)
# [53] time: 1421.8393847942352 loss: 1.281 val_loss:1.3975228825701942 current_lr=0.005077
# Test Loss: 1.390110
#
# Test Accuracy of airplane: 56% (567/1000)
# Test Accuracy of automobile: 44% (444/1000)
# Test Accuracy of  bird: 40% (409/1000)
# Test Accuracy of   cat: 32% (323/1000)
# Test Accuracy of  deer: 64% (648/1000)
# Test Accuracy of   dog: 22% (226/1000)
# Test Accuracy of  frog: 66% (663/1000)
# Test Accuracy of horse: 50% (505/1000)
# Test Accuracy of  ship: 67% (679/1000)
# Test Accuracy of truck: 55% (553/1000)
#
# Test Accuracy (Overall): 50% (5017/10000)
# [54] time: 1448.7714505195618 loss: 1.277 val_loss:1.390109628061705 current_lr=0.004936
# Test Loss: 1.666316
#
# Test Accuracy of airplane: 83% (830/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 28% (280/1000)
# Test Accuracy of   cat:  6% (62/1000)
# Test Accuracy of  deer: 68% (682/1000)
# Test Accuracy of   dog: 16% (167/1000)
# Test Accuracy of  frog: 23% (230/1000)
# Test Accuracy of horse: 41% (415/1000)
# Test Accuracy of  ship: 49% (491/1000)
# Test Accuracy of truck: 15% (152/1000)
#
# Test Accuracy (Overall): 41% (4198/10000)
# [55] time: 1475.8318660259247 loss: 1.263 val_loss:1.666315932817097 current_lr=0.004796
# Test Loss: 1.549145
#
# Test Accuracy of airplane: 31% (316/1000)
# Test Accuracy of automobile: 55% (551/1000)
# Test Accuracy of  bird: 23% (232/1000)
# Test Accuracy of   cat: 37% (373/1000)
# Test Accuracy of  deer: 21% (213/1000)
# Test Accuracy of   dog: 71% (716/1000)
# Test Accuracy of  frog: 58% (580/1000)
# Test Accuracy of horse: 18% (180/1000)
# Test Accuracy of  ship: 85% (855/1000)
# Test Accuracy of truck: 37% (375/1000)
#
# Test Accuracy (Overall): 43% (4391/10000)
# [56] time: 1502.6443367004395 loss: 1.257 val_loss:1.5491446573523027 current_lr=0.004657
# Test Loss: 1.351026
#
# Test Accuracy of airplane: 60% (606/1000)
# Test Accuracy of automobile: 69% (694/1000)
# Test Accuracy of  bird: 38% (386/1000)
# Test Accuracy of   cat: 13% (138/1000)
# Test Accuracy of  deer: 52% (520/1000)
# Test Accuracy of   dog: 35% (355/1000)
# Test Accuracy of  frog: 61% (619/1000)
# Test Accuracy of horse: 69% (697/1000)
# Test Accuracy of  ship: 63% (633/1000)
# Test Accuracy of truck: 53% (537/1000)
#
# Test Accuracy (Overall): 51% (5185/10000)
# [57] time: 1529.8083493709564 loss: 1.254 val_loss:1.3510262347474884 current_lr=0.004518
# Test Loss: 1.410335
#
# Test Accuracy of airplane: 55% (559/1000)
# Test Accuracy of automobile: 47% (470/1000)
# Test Accuracy of  bird: 16% (169/1000)
# Test Accuracy of   cat: 10% (100/1000)
# Test Accuracy of  deer: 37% (373/1000)
# Test Accuracy of   dog: 32% (323/1000)
# Test Accuracy of  frog: 61% (610/1000)
# Test Accuracy of horse: 81% (816/1000)
# Test Accuracy of  ship: 64% (641/1000)
# Test Accuracy of truck: 86% (863/1000)
#
# Test Accuracy (Overall): 49% (4924/10000)
# [58] time: 1556.4768216609955 loss: 1.254 val_loss:1.4103349613237985 current_lr=0.004381
# Test Loss: 1.580133
#
# Test Accuracy of airplane: 55% (558/1000)
# Test Accuracy of automobile: 74% (743/1000)
# Test Accuracy of  bird: 21% (210/1000)
# Test Accuracy of   cat: 16% (165/1000)
# Test Accuracy of  deer: 48% (488/1000)
# Test Accuracy of   dog: 30% (300/1000)
# Test Accuracy of  frog: 64% (641/1000)
# Test Accuracy of horse: 32% (328/1000)
# Test Accuracy of  ship: 85% (853/1000)
# Test Accuracy of truck: 39% (396/1000)
#
# Test Accuracy (Overall): 46% (4682/10000)
# [59] time: 1582.8385508060455 loss: 1.248 val_loss:1.5801328254651419 current_lr=0.004245
# Test Loss: 1.362812
#
# Test Accuracy of airplane: 63% (632/1000)
# Test Accuracy of automobile: 82% (820/1000)
# Test Accuracy of  bird: 32% (325/1000)
# Test Accuracy of   cat: 23% (239/1000)
# Test Accuracy of  deer: 22% (225/1000)
# Test Accuracy of   dog: 32% (325/1000)
# Test Accuracy of  frog: 71% (716/1000)
# Test Accuracy of horse: 51% (513/1000)
# Test Accuracy of  ship: 78% (787/1000)
# Test Accuracy of truck: 56% (569/1000)
#
# Test Accuracy (Overall): 51% (5151/10000)
# [60] time: 1609.452616930008 loss: 1.243 val_loss:1.3628123244152794 current_lr=0.004109
# Test Loss: 1.557485
#
# Test Accuracy of airplane: 36% (367/1000)
# Test Accuracy of automobile: 74% (740/1000)
# Test Accuracy of  bird:  2% (24/1000)
# Test Accuracy of   cat: 20% (203/1000)
# Test Accuracy of  deer: 56% (561/1000)
# Test Accuracy of   dog: 31% (315/1000)
# Test Accuracy of  frog: 41% (416/1000)
# Test Accuracy of horse: 60% (606/1000)
# Test Accuracy of  ship: 88% (887/1000)
# Test Accuracy of truck: 50% (501/1000)
#
# Test Accuracy (Overall): 46% (4620/10000)
# [61] time: 1636.5969715118408 loss: 1.236 val_loss:1.5574850507929354 current_lr=0.003976
# Test Loss: 1.399731
#
# Test Accuracy of airplane: 63% (633/1000)
# Test Accuracy of automobile: 58% (588/1000)
# Test Accuracy of  bird: 32% (329/1000)
# Test Accuracy of   cat:  8% (82/1000)
# Test Accuracy of  deer: 34% (341/1000)
# Test Accuracy of   dog: 58% (580/1000)
# Test Accuracy of  frog: 35% (357/1000)
# Test Accuracy of horse: 83% (835/1000)
# Test Accuracy of  ship: 56% (566/1000)
# Test Accuracy of truck: 65% (654/1000)
#
# Test Accuracy (Overall): 49% (4965/10000)
# [62] time: 1663.186999797821 loss: 1.231 val_loss:1.399731076216396 current_lr=0.003843
# Test Loss: 1.634513
#
# Test Accuracy of airplane: 34% (345/1000)
# Test Accuracy of automobile: 16% (164/1000)
# Test Accuracy of  bird: 55% (555/1000)
# Test Accuracy of   cat: 30% (307/1000)
# Test Accuracy of  deer:  4% (44/1000)
# Test Accuracy of   dog: 55% (550/1000)
# Test Accuracy of  frog: 75% (755/1000)
# Test Accuracy of horse: 40% (409/1000)
# Test Accuracy of  ship: 93% (932/1000)
# Test Accuracy of truck: 24% (244/1000)
#
# Test Accuracy (Overall): 43% (4305/10000)
# [63] time: 1689.7652316093445 loss: 1.226 val_loss:1.6345131306708613 current_lr=0.003713
# Test Loss: 1.349288
#
# Test Accuracy of airplane: 29% (298/1000)
# Test Accuracy of automobile: 50% (504/1000)
# Test Accuracy of  bird: 19% (191/1000)
# Test Accuracy of   cat: 42% (423/1000)
# Test Accuracy of  deer: 40% (402/1000)
# Test Accuracy of   dog: 59% (595/1000)
# Test Accuracy of  frog: 67% (678/1000)
# Test Accuracy of horse: 51% (514/1000)
# Test Accuracy of  ship: 81% (813/1000)
# Test Accuracy of truck: 70% (709/1000)
#
# Test Accuracy (Overall): 51% (5127/10000)
# [64] time: 1716.3859102725983 loss: 1.217 val_loss:1.3492877996420558 current_lr=0.003584
# Test Loss: 1.335946
#
# Test Accuracy of airplane: 60% (608/1000)
# Test Accuracy of automobile: 53% (531/1000)
# Test Accuracy of  bird: 14% (149/1000)
# Test Accuracy of   cat: 24% (245/1000)
# Test Accuracy of  deer: 64% (644/1000)
# Test Accuracy of   dog: 36% (362/1000)
# Test Accuracy of  frog: 36% (369/1000)
# Test Accuracy of horse: 70% (703/1000)
# Test Accuracy of  ship: 78% (786/1000)
# Test Accuracy of truck: 78% (781/1000)
#
# Test Accuracy (Overall): 51% (5178/10000)
# [65] time: 1744.1678552627563 loss: 1.214 val_loss:1.3359463199784485 current_lr=0.003457
# Test Loss: 1.475050
#
# Test Accuracy of airplane: 41% (415/1000)
# Test Accuracy of automobile: 37% (370/1000)
# Test Accuracy of  bird: 18% (181/1000)
# Test Accuracy of   cat: 33% (338/1000)
# Test Accuracy of  deer: 48% (481/1000)
# Test Accuracy of   dog: 34% (346/1000)
# Test Accuracy of  frog: 78% (789/1000)
# Test Accuracy of horse: 51% (512/1000)
# Test Accuracy of  ship: 95% (951/1000)
# Test Accuracy of truck: 46% (463/1000)
#
# Test Accuracy (Overall): 48% (4846/10000)
# [66] time: 1771.4427812099457 loss: 1.208 val_loss:1.4750502169886721 current_lr=0.003332
# Test Loss: 1.258237
#
# Test Accuracy of airplane: 74% (743/1000)
# Test Accuracy of automobile: 67% (674/1000)
# Test Accuracy of  bird: 35% (355/1000)
# Test Accuracy of   cat: 18% (183/1000)
# Test Accuracy of  deer: 51% (512/1000)
# Test Accuracy of   dog: 34% (343/1000)
# Test Accuracy of  frog: 70% (709/1000)
# Test Accuracy of horse: 76% (761/1000)
# Test Accuracy of  ship: 69% (691/1000)
# Test Accuracy of truck: 56% (566/1000)
#
# Test Accuracy (Overall): 55% (5537/10000)
# [67] time: 1798.682175397873 loss: 1.207 val_loss:1.2582370978367479 current_lr=0.003209
# Test Loss: 1.245332
#
# Test Accuracy of airplane: 62% (626/1000)
# Test Accuracy of automobile: 68% (687/1000)
# Test Accuracy of  bird: 36% (365/1000)
# Test Accuracy of   cat: 34% (349/1000)
# Test Accuracy of  deer: 30% (309/1000)
# Test Accuracy of   dog: 33% (330/1000)
# Test Accuracy of  frog: 89% (890/1000)
# Test Accuracy of horse: 59% (592/1000)
# Test Accuracy of  ship: 69% (697/1000)
# Test Accuracy of truck: 69% (694/1000)
#
# Test Accuracy (Overall): 55% (5539/10000)
# [68] time: 1826.1074044704437 loss: 1.204 val_loss:1.2453319000292429 current_lr=0.003089
# Test Loss: 1.221442
#
# Test Accuracy of airplane: 62% (620/1000)
# Test Accuracy of automobile: 62% (620/1000)
# Test Accuracy of  bird: 36% (360/1000)
# Test Accuracy of   cat: 32% (328/1000)
# Test Accuracy of  deer: 30% (306/1000)
# Test Accuracy of   dog: 53% (539/1000)
# Test Accuracy of  frog: 66% (660/1000)
# Test Accuracy of horse: 78% (789/1000)
# Test Accuracy of  ship: 67% (675/1000)
# Test Accuracy of truck: 74% (747/1000)
#
# Test Accuracy (Overall): 56% (5644/10000)
# [69] time: 1852.8651168346405 loss: 1.201 val_loss:1.221441617494897 current_lr=0.002971
# Test Loss: 1.262933
#
# Test Accuracy of airplane: 64% (648/1000)
# Test Accuracy of automobile: 62% (629/1000)
# Test Accuracy of  bird: 42% (423/1000)
# Test Accuracy of   cat: 33% (330/1000)
# Test Accuracy of  deer: 49% (498/1000)
# Test Accuracy of   dog: 33% (337/1000)
# Test Accuracy of  frog: 65% (653/1000)
# Test Accuracy of horse: 61% (617/1000)
# Test Accuracy of  ship: 52% (526/1000)
# Test Accuracy of truck: 84% (843/1000)
#
# Test Accuracy (Overall): 55% (5504/10000)
# [70] time: 1879.4533739089966 loss: 1.186 val_loss:1.262932898123053 current_lr=0.002855
# Test Loss: 1.289231
#
# Test Accuracy of airplane: 77% (777/1000)
# Test Accuracy of automobile: 79% (794/1000)
# Test Accuracy of  bird: 22% (222/1000)
# Test Accuracy of   cat: 25% (252/1000)
# Test Accuracy of  deer: 64% (645/1000)
# Test Accuracy of   dog: 41% (417/1000)
# Test Accuracy of  frog: 37% (379/1000)
# Test Accuracy of horse: 71% (716/1000)
# Test Accuracy of  ship: 56% (561/1000)
# Test Accuracy of truck: 63% (636/1000)
#
# Test Accuracy (Overall): 53% (5399/10000)
# [71] time: 1906.1623902320862 loss: 1.187 val_loss:1.2892314708685573 current_lr=0.002742
# Test Loss: 1.449460
#
# Test Accuracy of airplane: 47% (478/1000)
# Test Accuracy of automobile: 61% (613/1000)
# Test Accuracy of  bird: 52% (526/1000)
# Test Accuracy of   cat: 29% (294/1000)
# Test Accuracy of  deer: 10% (109/1000)
# Test Accuracy of   dog: 38% (382/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 27% (275/1000)
# Test Accuracy of  ship: 85% (859/1000)
# Test Accuracy of truck: 43% (435/1000)
#
# Test Accuracy (Overall): 48% (4837/10000)
# [72] time: 1933.7530281543732 loss: 1.178 val_loss:1.449460147302362 current_lr=0.002632
# Test Loss: 1.408262
#
# Test Accuracy of airplane: 55% (551/1000)
# Test Accuracy of automobile: 55% (551/1000)
# Test Accuracy of  bird: 34% (342/1000)
# Test Accuracy of   cat: 23% (232/1000)
# Test Accuracy of  deer: 54% (543/1000)
# Test Accuracy of   dog: 25% (259/1000)
# Test Accuracy of  frog: 61% (611/1000)
# Test Accuracy of horse: 45% (453/1000)
# Test Accuracy of  ship: 71% (713/1000)
# Test Accuracy of truck: 83% (837/1000)
#
# Test Accuracy (Overall): 50% (5092/10000)
# [73] time: 1960.6915843486786 loss: 1.172 val_loss:1.408262394651582 current_lr=0.002524
# Test Loss: 1.227487
#
# Test Accuracy of airplane: 50% (505/1000)
# Test Accuracy of automobile: 61% (612/1000)
# Test Accuracy of  bird: 29% (299/1000)
# Test Accuracy of   cat: 33% (330/1000)
# Test Accuracy of  deer: 46% (461/1000)
# Test Accuracy of   dog: 46% (464/1000)
# Test Accuracy of  frog: 82% (821/1000)
# Test Accuracy of horse: 64% (644/1000)
# Test Accuracy of  ship: 85% (859/1000)
# Test Accuracy of truck: 62% (622/1000)
#
# Test Accuracy (Overall): 56% (5617/10000)
# [74] time: 1987.5198607444763 loss: 1.174 val_loss:1.227487131010128 current_lr=0.002420
# Test Loss: 1.203084
#
# Test Accuracy of airplane: 61% (616/1000)
# Test Accuracy of automobile: 70% (700/1000)
# Test Accuracy of  bird: 45% (451/1000)
# Test Accuracy of   cat: 25% (255/1000)
# Test Accuracy of  deer: 39% (397/1000)
# Test Accuracy of   dog: 46% (469/1000)
# Test Accuracy of  frog: 79% (798/1000)
# Test Accuracy of horse: 51% (511/1000)
# Test Accuracy of  ship: 75% (754/1000)
# Test Accuracy of truck: 71% (716/1000)
#
# Test Accuracy (Overall): 56% (5667/10000)
# [75] time: 2014.2900772094727 loss: 1.164 val_loss:1.2030839889864378 current_lr=0.002318
# Test Loss: 1.893693
#
# Test Accuracy of airplane: 46% (466/1000)
# Test Accuracy of automobile: 24% (244/1000)
# Test Accuracy of  bird: 20% (208/1000)
# Test Accuracy of   cat: 31% (315/1000)
# Test Accuracy of  deer: 12% (126/1000)
# Test Accuracy of   dog: 26% (266/1000)
# Test Accuracy of  frog: 96% (963/1000)
# Test Accuracy of horse: 36% (369/1000)
# Test Accuracy of  ship: 51% (517/1000)
# Test Accuracy of truck: 32% (322/1000)
#
# Test Accuracy (Overall): 37% (3796/10000)
# [76] time: 2041.283874988556 loss: 1.164 val_loss:1.8936930306350128 current_lr=0.002220
# Test Loss: 1.388912
#
# Test Accuracy of airplane: 77% (772/1000)
# Test Accuracy of automobile: 67% (672/1000)
# Test Accuracy of  bird: 29% (294/1000)
# Test Accuracy of   cat: 14% (145/1000)
# Test Accuracy of  deer: 40% (407/1000)
# Test Accuracy of   dog: 37% (370/1000)
# Test Accuracy of  frog: 25% (250/1000)
# Test Accuracy of horse: 82% (825/1000)
# Test Accuracy of  ship: 76% (761/1000)
# Test Accuracy of truck: 70% (709/1000)
#
# Test Accuracy (Overall): 52% (5205/10000)
# [77] time: 2067.771147251129 loss: 1.153 val_loss:1.3889124257655083 current_lr=0.002125
# Test Loss: 1.191914
#
# Test Accuracy of airplane: 69% (695/1000)
# Test Accuracy of automobile: 73% (734/1000)
# Test Accuracy of  bird: 46% (466/1000)
# Test Accuracy of   cat: 38% (383/1000)
# Test Accuracy of  deer: 39% (391/1000)
# Test Accuracy of   dog: 56% (564/1000)
# Test Accuracy of  frog: 74% (744/1000)
# Test Accuracy of horse: 61% (616/1000)
# Test Accuracy of  ship: 56% (567/1000)
# Test Accuracy of truck: 60% (608/1000)
#
# Test Accuracy (Overall): 57% (5768/10000)
# [78] time: 2094.1453778743744 loss: 1.150 val_loss:1.1919143811056885 current_lr=0.002033
# Test Loss: 1.768622
#
# Test Accuracy of airplane: 54% (544/1000)
# Test Accuracy of automobile: 41% (411/1000)
# Test Accuracy of  bird: 54% (540/1000)
# Test Accuracy of   cat: 15% (154/1000)
# Test Accuracy of  deer:  7% (75/1000)
# Test Accuracy of   dog: 83% (835/1000)
# Test Accuracy of  frog: 37% (374/1000)
# Test Accuracy of horse: 59% (593/1000)
# Test Accuracy of  ship: 20% (201/1000)
# Test Accuracy of truck: 37% (379/1000)
#
# Test Accuracy (Overall): 41% (4106/10000)
# [79] time: 2120.5391952991486 loss: 1.144 val_loss:1.7686220120780076 current_lr=0.001944
# Test Loss: 1.182232
#
# Test Accuracy of airplane: 54% (549/1000)
# Test Accuracy of automobile: 58% (585/1000)
# Test Accuracy of  bird: 54% (540/1000)
# Test Accuracy of   cat: 35% (359/1000)
# Test Accuracy of  deer: 45% (453/1000)
# Test Accuracy of   dog: 56% (568/1000)
# Test Accuracy of  frog: 56% (564/1000)
# Test Accuracy of horse: 66% (669/1000)
# Test Accuracy of  ship: 77% (776/1000)
# Test Accuracy of truck: 70% (702/1000)
#
# Test Accuracy (Overall): 57% (5765/10000)
# [80] time: 2147.590025663376 loss: 1.143 val_loss:1.1822323218176636 current_lr=0.001859
# Test Loss: 1.243383
#
# Test Accuracy of airplane: 72% (729/1000)
# Test Accuracy of automobile: 58% (583/1000)
# Test Accuracy of  bird: 25% (255/1000)
# Test Accuracy of   cat: 22% (226/1000)
# Test Accuracy of  deer: 58% (580/1000)
# Test Accuracy of   dog: 46% (466/1000)
# Test Accuracy of  frog: 47% (477/1000)
# Test Accuracy of horse: 77% (770/1000)
# Test Accuracy of  ship: 69% (696/1000)
# Test Accuracy of truck: 73% (739/1000)
#
# Test Accuracy (Overall): 55% (5521/10000)
# [81] time: 2173.9518251419067 loss: 1.138 val_loss:1.2433828492707844 current_lr=0.001778
# Test Loss: 1.317087
#
# Test Accuracy of airplane: 49% (496/1000)
# Test Accuracy of automobile: 79% (793/1000)
# Test Accuracy of  bird: 25% (254/1000)
# Test Accuracy of   cat: 41% (412/1000)
# Test Accuracy of  deer: 22% (224/1000)
# Test Accuracy of   dog: 70% (704/1000)
# Test Accuracy of  frog: 61% (612/1000)
# Test Accuracy of horse: 54% (544/1000)
# Test Accuracy of  ship: 65% (659/1000)
# Test Accuracy of truck: 50% (500/1000)
#
# Test Accuracy (Overall): 51% (5198/10000)
# [82] time: 2200.292186975479 loss: 1.130 val_loss:1.3170871357374554 current_lr=0.001701
# Test Loss: 1.222920
#
# Test Accuracy of airplane: 59% (596/1000)
# Test Accuracy of automobile: 76% (761/1000)
# Test Accuracy of  bird: 41% (414/1000)
# Test Accuracy of   cat: 54% (545/1000)
# Test Accuracy of  deer: 65% (652/1000)
# Test Accuracy of   dog: 42% (422/1000)
# Test Accuracy of  frog: 63% (636/1000)
# Test Accuracy of horse: 35% (350/1000)
# Test Accuracy of  ship: 71% (719/1000)
# Test Accuracy of truck: 58% (586/1000)
#
# Test Accuracy (Overall): 56% (5681/10000)
# [83] time: 2226.6661353111267 loss: 1.128 val_loss:1.222919848900807 current_lr=0.001627
# Test Loss: 1.279418
#
# Test Accuracy of airplane: 50% (509/1000)
# Test Accuracy of automobile: 52% (527/1000)
# Test Accuracy of  bird: 53% (531/1000)
# Test Accuracy of   cat: 50% (507/1000)
# Test Accuracy of  deer: 39% (390/1000)
# Test Accuracy of   dog: 39% (393/1000)
# Test Accuracy of  frog: 74% (745/1000)
# Test Accuracy of horse: 33% (332/1000)
# Test Accuracy of  ship: 90% (901/1000)
# Test Accuracy of truck: 58% (583/1000)
#
# Test Accuracy (Overall): 54% (5418/10000)
# [84] time: 2253.56303358078 loss: 1.124 val_loss:1.2794183130505719 current_lr=0.001557
# Test Loss: 1.175920
#
# Test Accuracy of airplane: 65% (656/1000)
# Test Accuracy of automobile: 79% (795/1000)
# Test Accuracy of  bird: 27% (274/1000)
# Test Accuracy of   cat: 31% (314/1000)
# Test Accuracy of  deer: 74% (745/1000)
# Test Accuracy of   dog: 34% (340/1000)
# Test Accuracy of  frog: 77% (779/1000)
# Test Accuracy of horse: 56% (561/1000)
# Test Accuracy of  ship: 70% (702/1000)
# Test Accuracy of truck: 71% (712/1000)
#
# Test Accuracy (Overall): 58% (5878/10000)
# [85] time: 2279.988452196121 loss: 1.117 val_loss:1.175919767422012 current_lr=0.001490
# Test Loss: 1.133349
#
# Test Accuracy of airplane: 73% (739/1000)
# Test Accuracy of automobile: 52% (526/1000)
# Test Accuracy of  bird: 43% (435/1000)
# Test Accuracy of   cat: 38% (387/1000)
# Test Accuracy of  deer: 63% (633/1000)
# Test Accuracy of   dog: 40% (404/1000)
# Test Accuracy of  frog: 65% (655/1000)
# Test Accuracy of horse: 69% (691/1000)
# Test Accuracy of  ship: 76% (762/1000)
# Test Accuracy of truck: 74% (746/1000)
#
# Test Accuracy (Overall): 59% (5978/10000)
# [86] time: 2306.295188188553 loss: 1.112 val_loss:1.133349282077596 current_lr=0.001428
# Test Loss: 1.349798
#
# Test Accuracy of airplane: 55% (556/1000)
# Test Accuracy of automobile: 59% (591/1000)
# Test Accuracy of  bird: 26% (268/1000)
# Test Accuracy of   cat: 46% (462/1000)
# Test Accuracy of  deer: 38% (387/1000)
# Test Accuracy of   dog: 69% (694/1000)
# Test Accuracy of  frog: 58% (584/1000)
# Test Accuracy of horse: 62% (625/1000)
# Test Accuracy of  ship: 63% (636/1000)
# Test Accuracy of truck: 54% (543/1000)
#
# Test Accuracy (Overall): 53% (5346/10000)
# [87] time: 2332.9060015678406 loss: 1.101 val_loss:1.349797958060156 current_lr=0.001370
# Test Loss: 1.155916
#
# Test Accuracy of airplane: 68% (684/1000)
# Test Accuracy of automobile: 71% (719/1000)
# Test Accuracy of  bird: 52% (522/1000)
# Test Accuracy of   cat: 31% (310/1000)
# Test Accuracy of  deer: 41% (418/1000)
# Test Accuracy of   dog: 38% (386/1000)
# Test Accuracy of  frog: 66% (669/1000)
# Test Accuracy of horse: 70% (701/1000)
# Test Accuracy of  ship: 84% (841/1000)
# Test Accuracy of truck: 68% (681/1000)
#
# Test Accuracy (Overall): 59% (5931/10000)
# [88] time: 2359.672523021698 loss: 1.098 val_loss:1.1559156511403337 current_lr=0.001316
# Test Loss: 1.155203
#
# Test Accuracy of airplane: 50% (502/1000)
# Test Accuracy of automobile: 54% (546/1000)
# Test Accuracy of  bird: 35% (359/1000)
# Test Accuracy of   cat: 44% (441/1000)
# Test Accuracy of  deer: 54% (544/1000)
# Test Accuracy of   dog: 38% (382/1000)
# Test Accuracy of  frog: 83% (836/1000)
# Test Accuracy of horse: 59% (592/1000)
# Test Accuracy of  ship: 87% (874/1000)
# Test Accuracy of truck: 72% (720/1000)
#
# Test Accuracy (Overall): 57% (5796/10000)
# [89] time: 2386.5571250915527 loss: 1.097 val_loss:1.1552025275894358 current_lr=0.001266
# Test Loss: 1.155567
#
# Test Accuracy of airplane: 76% (760/1000)
# Test Accuracy of automobile: 75% (759/1000)
# Test Accuracy of  bird: 65% (654/1000)
# Test Accuracy of   cat: 26% (268/1000)
# Test Accuracy of  deer: 25% (258/1000)
# Test Accuracy of   dog: 52% (524/1000)
# Test Accuracy of  frog: 59% (597/1000)
# Test Accuracy of horse: 67% (678/1000)
# Test Accuracy of  ship: 75% (754/1000)
# Test Accuracy of truck: 62% (621/1000)
#
# Test Accuracy (Overall): 58% (5873/10000)
# [90] time: 2412.9164583683014 loss: 1.088 val_loss:1.1555665761609621 current_lr=0.001220
# Test Loss: 1.156873
#
# Test Accuracy of airplane: 76% (766/1000)
# Test Accuracy of automobile: 62% (620/1000)
# Test Accuracy of  bird: 59% (594/1000)
# Test Accuracy of   cat: 37% (373/1000)
# Test Accuracy of  deer: 42% (426/1000)
# Test Accuracy of   dog: 47% (476/1000)
# Test Accuracy of  frog: 63% (636/1000)
# Test Accuracy of horse: 63% (630/1000)
# Test Accuracy of  ship: 62% (628/1000)
# Test Accuracy of truck: 71% (717/1000)
#
# Test Accuracy (Overall): 58% (5866/10000)
# [91] time: 2439.436159133911 loss: 1.082 val_loss:1.15687316354317 current_lr=0.001179
# Test Loss: 1.113768
#
# Test Accuracy of airplane: 64% (649/1000)
# Test Accuracy of automobile: 75% (754/1000)
# Test Accuracy of  bird: 45% (456/1000)
# Test Accuracy of   cat: 32% (321/1000)
# Test Accuracy of  deer: 64% (640/1000)
# Test Accuracy of   dog: 44% (443/1000)
# Test Accuracy of  frog: 60% (609/1000)
# Test Accuracy of horse: 73% (731/1000)
# Test Accuracy of  ship: 76% (763/1000)
# Test Accuracy of truck: 69% (699/1000)
#
# Test Accuracy (Overall): 60% (6065/10000)
# [92] time: 2466.186642408371 loss: 1.082 val_loss:1.1137679068348076 current_lr=0.001141
# Test Loss: 1.086843
#
# Test Accuracy of airplane: 64% (648/1000)
# Test Accuracy of automobile: 68% (684/1000)
# Test Accuracy of  bird: 38% (388/1000)
# Test Accuracy of   cat: 35% (352/1000)
# Test Accuracy of  deer: 56% (564/1000)
# Test Accuracy of   dog: 54% (547/1000)
# Test Accuracy of  frog: 69% (691/1000)
# Test Accuracy of horse: 73% (735/1000)
# Test Accuracy of  ship: 83% (834/1000)
# Test Accuracy of truck: 73% (739/1000)
#
# Test Accuracy (Overall): 61% (6182/10000)
# [93] time: 2493.01554274559 loss: 1.073 val_loss:1.0868429073804542 current_lr=0.001108
# Test Loss: 1.128403
#
# Test Accuracy of airplane: 77% (773/1000)
# Test Accuracy of automobile: 64% (645/1000)
# Test Accuracy of  bird: 39% (395/1000)
# Test Accuracy of   cat: 27% (275/1000)
# Test Accuracy of  deer: 39% (394/1000)
# Test Accuracy of   dog: 49% (494/1000)
# Test Accuracy of  frog: 70% (707/1000)
# Test Accuracy of horse: 85% (852/1000)
# Test Accuracy of  ship: 70% (706/1000)
# Test Accuracy of truck: 79% (790/1000)
#
# Test Accuracy (Overall): 60% (6031/10000)
# [94] time: 2519.2172796726227 loss: 1.071 val_loss:1.1284025273745573 current_lr=0.001080
# Test Loss: 1.178573
#
# Test Accuracy of airplane: 68% (684/1000)
# Test Accuracy of automobile: 79% (795/1000)
# Test Accuracy of  bird: 31% (315/1000)
# Test Accuracy of   cat: 26% (269/1000)
# Test Accuracy of  deer: 69% (698/1000)
# Test Accuracy of   dog: 34% (348/1000)
# Test Accuracy of  frog: 50% (504/1000)
# Test Accuracy of horse: 69% (697/1000)
# Test Accuracy of  ship: 80% (802/1000)
# Test Accuracy of truck: 69% (695/1000)
#
# Test Accuracy (Overall): 58% (5807/10000)
# [95] time: 2545.390374183655 loss: 1.069 val_loss:1.1785732952854302 current_lr=0.001055
# Test Loss: 1.111262
#
# Test Accuracy of airplane: 66% (665/1000)
# Test Accuracy of automobile: 60% (603/1000)
# Test Accuracy of  bird: 36% (361/1000)
# Test Accuracy of   cat: 51% (517/1000)
# Test Accuracy of  deer: 65% (650/1000)
# Test Accuracy of   dog: 47% (479/1000)
# Test Accuracy of  frog: 54% (547/1000)
# Test Accuracy of horse: 69% (693/1000)
# Test Accuracy of  ship: 77% (770/1000)
# Test Accuracy of truck: 80% (802/1000)
#
# Test Accuracy (Overall): 60% (6087/10000)
# [96] time: 2571.690571784973 loss: 1.067 val_loss:1.1112624663340895 current_lr=0.001035
# Test Loss: 1.182829
#
# Test Accuracy of airplane: 72% (721/1000)
# Test Accuracy of automobile: 64% (649/1000)
# Test Accuracy of  bird: 41% (415/1000)
# Test Accuracy of   cat: 28% (284/1000)
# Test Accuracy of  deer: 57% (573/1000)
# Test Accuracy of   dog: 57% (579/1000)
# Test Accuracy of  frog: 69% (691/1000)
# Test Accuracy of horse: 80% (805/1000)
# Test Accuracy of  ship: 40% (409/1000)
# Test Accuracy of truck: 72% (728/1000)
#
# Test Accuracy (Overall): 58% (5854/10000)
# [97] time: 2598.3720076084137 loss: 1.063 val_loss:1.1828285116183608 current_lr=0.001020
# Test Loss: 1.118157
#
# Test Accuracy of airplane: 62% (628/1000)
# Test Accuracy of automobile: 70% (706/1000)
# Test Accuracy of  bird: 46% (469/1000)
# Test Accuracy of   cat: 50% (505/1000)
# Test Accuracy of  deer: 46% (460/1000)
# Test Accuracy of   dog: 58% (585/1000)
# Test Accuracy of  frog: 67% (677/1000)
# Test Accuracy of horse: 48% (485/1000)
# Test Accuracy of  ship: 80% (805/1000)
# Test Accuracy of truck: 70% (706/1000)
#
# Test Accuracy (Overall): 60% (6026/10000)
# [98] time: 2624.6107108592987 loss: 1.067 val_loss:1.1181572419178636 current_lr=0.001009
# Test Loss: 1.056339
#
# Test Accuracy of airplane: 66% (661/1000)
# Test Accuracy of automobile: 77% (778/1000)
# Test Accuracy of  bird: 48% (487/1000)
# Test Accuracy of   cat: 39% (395/1000)
# Test Accuracy of  deer: 52% (520/1000)
# Test Accuracy of   dog: 52% (521/1000)
# Test Accuracy of  frog: 78% (789/1000)
# Test Accuracy of horse: 67% (676/1000)
# Test Accuracy of  ship: 74% (746/1000)
# Test Accuracy of truck: 69% (693/1000)
#
# Test Accuracy (Overall): 62% (6266/10000)
# [99] time: 2650.841150999069 loss: 1.062 val_loss:1.0563388828989826 current_lr=0.001002
# Test Loss: 1.101260
#
# Test Accuracy of airplane: 77% (779/1000)
# Test Accuracy of automobile: 67% (679/1000)
# Test Accuracy of  bird: 36% (369/1000)
# Test Accuracy of   cat: 39% (398/1000)
# Test Accuracy of  deer: 72% (722/1000)
# Test Accuracy of   dog: 33% (336/1000)
# Test Accuracy of  frog: 74% (747/1000)
# Test Accuracy of horse: 55% (556/1000)
# Test Accuracy of  ship: 76% (768/1000)
# Test Accuracy of truck: 73% (733/1000)
#
# Test Accuracy (Overall): 60% (6087/10000)
# [100] time: 2676.967535018921 loss: 1.059 val_loss:1.1012595454348793 current_lr=0.001000
# Training finished!
# Training finished!

# %%
class AdaOrthOptimizer(BaseOptimizer):
  def __init__(self,model,criterion,epochs):
    super().__init__(model,criterion,epochs)
    self.old_state_dict = {}
  def initialize_optimizer(self, learning_rate):
    optimizer = AdaOrth(self.model.parameters(),nu=1, lr=learning_rate, weight_decay=0.01,gamma=0.1)
    # Cosine annealing: lr → eta_min by the end
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=self.epochs,   # period (usually = total epochs)
        eta_min=0.1*learning_rate      # minimum LR (here 0.1× of 0.01)
    )
    self.optimizer,self.scheduler =  optimizer, scheduler
  def zero_grad(self,inputs=None,labels=None):
    model, old_state_dict = self.model, self.old_state_dict
    optimizer = self.optimizer
    # Store the current model state
    cur_state_dict = {k: v.data.clone() for k, v in model.state_dict().items()}
    if self.old_state_dict:
        # Load the previous model state to compute the old gradient
        model.load_state_dict(old_state_dict)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.update_last_grad()
    #restore state
    model.load_state_dict(cur_state_dict)
    self.old_state_dict = {k: v.data.clone() for k, v in cur_state_dict.items()}
    self.optimizer.zero_grad()

# %% [markdown]
# #**AdaOrth Learning Rate Search**

# %%
def get_adaorth(model, learning_rate):
    optimizer = AdaOrthOptimizer(model, criterion, epochs)
    optimizer.initialize_optimizer(learning_rate)
    return optimizer
#42
#4242
#on val loader
result_adaorth = [1.6128161698579788, 1.2770381271839142, 1.1453768983483315,
                  0.978053979575634, 1.0300138369202614, 0.9962790831923485, 1.0214162468910217]
#on test loader
# result_adaorth = [1.4681750982999802, 1.1907282695174217, 1.0202817395329475, 1.0218846872448921, 1.0013282299041748, 1.0016121491789818, 1.0007075443863869]

if not result_adaorth:
    result_adaorth = grids_search_val(get_adaorth)
    #result_adaorth = [float(x.cpu()) for x in result_adaorth]
print(result_adaorth)
min_index = result_adaorth.index(min(result_adaorth))
learning_rate = learning_rates[min_index]
print(f"Best learning rate: {learning_rate}, Min val loss: {result_adaorth[min_index]}")
plt.figure(figsize=(6,4))
plt.xscale('log')   # good practice for learning rates
plt.xlabel("Learning rate")
plt.ylabel("Min Validation Loss")
plt.title("Learning Rate Grid Search")
plt.xticks(learning_rates, labels=[str(lr) for lr in learning_rates],rotation=45)
plt.plot(learning_rates, result_adaorth, label="Grid Search(Validataion Loss)", linewidth=2, marker='o')
# Out:
# [1.6128161698579788, 1.2770381271839142, 1.1453768983483315, 0.978053979575634, 1.0300138369202614, 0.9962790831923485, 1.0214162468910217]
# Best learning rate: 0.005, Min val loss: 0.978053979575634

# %% [markdown]
# #**AdaOrth Training with best learning rate**

# %%
model_adaorth = initialize_model(device)
optimizer = AdaOrthOptimizer(model_adaorth,criterion,epochs)
optimizer.initialize_optimizer(learning_rate)
losses_adaorth,losses_adaorth_val, adaorth_acc ,adaorth_time_cost = train_once(model_adaorth,criterion,optimizer,train_loader,test_loader,learning_rate,epochs)
print("Training finished!")
# Out:
# Test Loss: 1.112355
#
# Test Accuracy of airplane: 58% (587/1000)
# Test Accuracy of automobile: 80% (806/1000)
# Test Accuracy of  bird: 65% (658/1000)
# Test Accuracy of   cat: 20% (203/1000)
# Test Accuracy of  deer: 37% (377/1000)
# Test Accuracy of   dog: 66% (663/1000)
# Test Accuracy of  frog: 76% (764/1000)
# Test Accuracy of horse: 57% (577/1000)
# Test Accuracy of  ship: 78% (782/1000)
# Test Accuracy of truck: 64% (648/1000)
#
# Test Accuracy (Overall): 60% (6065/10000)
# [1] time: 43.36950397491455 loss: 1.372 val_loss:1.1123547342759144 current_lr=0.004999
# Test Loss: 0.960063
#
# Test Accuracy of airplane: 70% (708/1000)
# Test Accuracy of automobile: 93% (938/1000)
# Test Accuracy of  bird: 49% (496/1000)
# Test Accuracy of   cat: 50% (507/1000)
# Test Accuracy of  deer: 65% (655/1000)
# Test Accuracy of   dog: 59% (595/1000)
# Test Accuracy of  frog: 76% (769/1000)
# Test Accuracy of horse: 69% (697/1000)
# Test Accuracy of  ship: 68% (689/1000)
# Test Accuracy of truck: 58% (583/1000)
#
# Test Accuracy (Overall): 66% (6637/10000)
# [2] time: 87.02725887298584 loss: 0.960 val_loss:0.9600629263286349 current_lr=0.004996
# Test Loss: 0.793683
#
# Test Accuracy of airplane: 71% (715/1000)
# Test Accuracy of automobile: 86% (861/1000)
# Test Accuracy of  bird: 61% (618/1000)
# Test Accuracy of   cat: 47% (475/1000)
# Test Accuracy of  deer: 74% (746/1000)
# Test Accuracy of   dog: 66% (664/1000)
# Test Accuracy of  frog: 84% (842/1000)
# Test Accuracy of horse: 76% (766/1000)
# Test Accuracy of  ship: 77% (779/1000)
# Test Accuracy of truck: 75% (752/1000)
#
# Test Accuracy (Overall): 72% (7218/10000)
# [3] time: 129.97677850723267 loss: 0.807 val_loss:0.7936826635010635 current_lr=0.004990
# Test Loss: 0.762533
#
# Test Accuracy of airplane: 68% (689/1000)
# Test Accuracy of automobile: 85% (856/1000)
# Test Accuracy of  bird: 61% (610/1000)
# Test Accuracy of   cat: 55% (553/1000)
# Test Accuracy of  deer: 74% (742/1000)
# Test Accuracy of   dog: 66% (665/1000)
# Test Accuracy of  frog: 72% (727/1000)
# Test Accuracy of horse: 81% (819/1000)
# Test Accuracy of  ship: 88% (888/1000)
# Test Accuracy of truck: 81% (815/1000)
#
# Test Accuracy (Overall): 73% (7364/10000)
# [4] time: 173.10254430770874 loss: 0.713 val_loss:0.762533304812033 current_lr=0.004982
# Test Loss: 0.721062
#
# Test Accuracy of airplane: 79% (792/1000)
# Test Accuracy of automobile: 83% (831/1000)
# Test Accuracy of  bird: 62% (629/1000)
# Test Accuracy of   cat: 55% (554/1000)
# Test Accuracy of  deer: 86% (864/1000)
# Test Accuracy of   dog: 59% (598/1000)
# Test Accuracy of  frog: 77% (779/1000)
# Test Accuracy of horse: 70% (709/1000)
# Test Accuracy of  ship: 88% (881/1000)
# Test Accuracy of truck: 83% (838/1000)
#
# Test Accuracy (Overall): 74% (7475/10000)
# [5] time: 216.41954398155212 loss: 0.638 val_loss:0.7210624708405023 current_lr=0.004972
# Test Loss: 0.658929
#
# Test Accuracy of airplane: 87% (872/1000)
# Test Accuracy of automobile: 87% (871/1000)
# Test Accuracy of  bird: 75% (751/1000)
# Test Accuracy of   cat: 51% (516/1000)
# Test Accuracy of  deer: 75% (752/1000)
# Test Accuracy of   dog: 65% (652/1000)
# Test Accuracy of  frog: 84% (841/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 86% (860/1000)
# Test Accuracy of truck: 83% (832/1000)
#
# Test Accuracy (Overall): 77% (7783/10000)
# [6] time: 259.7502748966217 loss: 0.575 val_loss:0.6589292483993724 current_lr=0.004960
# Test Loss: 0.643910
#
# Test Accuracy of airplane: 84% (844/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 69% (692/1000)
# Test Accuracy of   cat: 67% (679/1000)
# Test Accuracy of  deer: 71% (719/1000)
# Test Accuracy of   dog: 67% (673/1000)
# Test Accuracy of  frog: 84% (840/1000)
# Test Accuracy of horse: 84% (841/1000)
# Test Accuracy of  ship: 86% (860/1000)
# Test Accuracy of truck: 78% (789/1000)
#
# Test Accuracy (Overall): 78% (7803/10000)
# [7] time: 303.14367604255676 loss: 0.526 val_loss:0.6439101314997371 current_lr=0.004946
# Test Loss: 0.632427
#
# Test Accuracy of airplane: 81% (812/1000)
# Test Accuracy of automobile: 85% (853/1000)
# Test Accuracy of  bird: 73% (734/1000)
# Test Accuracy of   cat: 62% (627/1000)
# Test Accuracy of  deer: 81% (819/1000)
# Test Accuracy of   dog: 64% (649/1000)
# Test Accuracy of  frog: 83% (835/1000)
# Test Accuracy of horse: 82% (825/1000)
# Test Accuracy of  ship: 87% (874/1000)
# Test Accuracy of truck: 83% (833/1000)
#
# Test Accuracy (Overall): 78% (7861/10000)
# [8] time: 346.3685555458069 loss: 0.482 val_loss:0.6324268217328228 current_lr=0.004929
# Test Loss: 0.644224
#
# Test Accuracy of airplane: 78% (780/1000)
# Test Accuracy of automobile: 83% (838/1000)
# Test Accuracy of  bird: 68% (686/1000)
# Test Accuracy of   cat: 66% (662/1000)
# Test Accuracy of  deer: 76% (761/1000)
# Test Accuracy of   dog: 64% (649/1000)
# Test Accuracy of  frog: 78% (789/1000)
# Test Accuracy of horse: 86% (862/1000)
# Test Accuracy of  ship: 90% (901/1000)
# Test Accuracy of truck: 90% (906/1000)
#
# Test Accuracy (Overall): 78% (7834/10000)
# [9] time: 389.7450358867645 loss: 0.436 val_loss:0.6442240589781653 current_lr=0.004911
# Test Loss: 0.628639
#
# Test Accuracy of airplane: 85% (853/1000)
# Test Accuracy of automobile: 87% (876/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 57% (571/1000)
# Test Accuracy of  deer: 77% (772/1000)
# Test Accuracy of   dog: 76% (760/1000)
# Test Accuracy of  frog: 84% (840/1000)
# Test Accuracy of horse: 80% (800/1000)
# Test Accuracy of  ship: 83% (832/1000)
# Test Accuracy of truck: 84% (841/1000)
#
# Test Accuracy (Overall): 79% (7901/10000)
# [10] time: 433.1020698547363 loss: 0.397 val_loss:0.6286392249638522 current_lr=0.004890
# Test Loss: 0.660894
#
# Test Accuracy of airplane: 86% (860/1000)
# Test Accuracy of automobile: 83% (836/1000)
# Test Accuracy of  bird: 70% (703/1000)
# Test Accuracy of   cat: 66% (668/1000)
# Test Accuracy of  deer: 76% (760/1000)
# Test Accuracy of   dog: 64% (648/1000)
# Test Accuracy of  frog: 89% (891/1000)
# Test Accuracy of horse: 76% (763/1000)
# Test Accuracy of  ship: 92% (920/1000)
# Test Accuracy of truck: 85% (857/1000)
#
# Test Accuracy (Overall): 79% (7906/10000)
# [11] time: 476.3072385787964 loss: 0.360 val_loss:0.6608940751492223 current_lr=0.004867
# Test Loss: 0.630236
#
# Test Accuracy of airplane: 84% (842/1000)
# Test Accuracy of automobile: 92% (928/1000)
# Test Accuracy of  bird: 65% (659/1000)
# Test Accuracy of   cat: 65% (657/1000)
# Test Accuracy of  deer: 75% (751/1000)
# Test Accuracy of   dog: 71% (718/1000)
# Test Accuracy of  frog: 88% (885/1000)
# Test Accuracy of horse: 83% (832/1000)
# Test Accuracy of  ship: 84% (845/1000)
# Test Accuracy of truck: 83% (832/1000)
#
# Test Accuracy (Overall): 79% (7949/10000)
# [12] time: 519.6533756256104 loss: 0.335 val_loss:0.6302363023727755 current_lr=0.004842
# Test Loss: 0.636727
#
# Test Accuracy of airplane: 83% (831/1000)
# Test Accuracy of automobile: 92% (924/1000)
# Test Accuracy of  bird: 73% (738/1000)
# Test Accuracy of   cat: 59% (592/1000)
# Test Accuracy of  deer: 74% (747/1000)
# Test Accuracy of   dog: 70% (707/1000)
# Test Accuracy of  frog: 87% (878/1000)
# Test Accuracy of horse: 84% (845/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 81% (815/1000)
#
# Test Accuracy (Overall): 79% (7962/10000)
# [13] time: 563.1934704780579 loss: 0.298 val_loss:0.6367270218420632 current_lr=0.004815
# Test Loss: 0.627270
#
# Test Accuracy of airplane: 82% (820/1000)
# Test Accuracy of automobile: 84% (848/1000)
# Test Accuracy of  bird: 74% (741/1000)
# Test Accuracy of   cat: 68% (681/1000)
# Test Accuracy of  deer: 80% (807/1000)
# Test Accuracy of   dog: 70% (701/1000)
# Test Accuracy of  frog: 83% (833/1000)
# Test Accuracy of horse: 79% (794/1000)
# Test Accuracy of  ship: 90% (901/1000)
# Test Accuracy of truck: 88% (889/1000)
#
# Test Accuracy (Overall): 80% (8015/10000)
# [14] time: 606.2017433643341 loss: 0.276 val_loss:0.627270076471039 current_lr=0.004786
# Test Loss: 0.675068
#
# Test Accuracy of airplane: 85% (851/1000)
# Test Accuracy of automobile: 86% (862/1000)
# Test Accuracy of  bird: 75% (754/1000)
# Test Accuracy of   cat: 61% (617/1000)
# Test Accuracy of  deer: 74% (741/1000)
# Test Accuracy of   dog: 68% (689/1000)
# Test Accuracy of  frog: 86% (865/1000)
# Test Accuracy of horse: 82% (823/1000)
# Test Accuracy of  ship: 92% (924/1000)
# Test Accuracy of truck: 82% (828/1000)
#
# Test Accuracy (Overall): 79% (7954/10000)
# [15] time: 649.832980632782 loss: 0.255 val_loss:0.6750679276412046 current_lr=0.004755
# Test Loss: 0.664735
#
# Test Accuracy of airplane: 86% (860/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 69% (699/1000)
# Test Accuracy of   cat: 69% (699/1000)
# Test Accuracy of  deer: 80% (800/1000)
# Test Accuracy of   dog: 64% (646/1000)
# Test Accuracy of  frog: 88% (883/1000)
# Test Accuracy of horse: 81% (810/1000)
# Test Accuracy of  ship: 88% (888/1000)
# Test Accuracy of truck: 84% (849/1000)
#
# Test Accuracy (Overall): 80% (8023/10000)
# [16] time: 693.638664484024 loss: 0.235 val_loss:0.6647348207763478 current_lr=0.004722
# Test Loss: 0.694196
#
# Test Accuracy of airplane: 78% (784/1000)
# Test Accuracy of automobile: 89% (895/1000)
# Test Accuracy of  bird: 76% (766/1000)
# Test Accuracy of   cat: 70% (700/1000)
# Test Accuracy of  deer: 81% (813/1000)
# Test Accuracy of   dog: 66% (669/1000)
# Test Accuracy of  frog: 84% (840/1000)
# Test Accuracy of horse: 78% (789/1000)
# Test Accuracy of  ship: 92% (923/1000)
# Test Accuracy of truck: 82% (820/1000)
#
# Test Accuracy (Overall): 79% (7999/10000)
# [17] time: 737.3877387046814 loss: 0.211 val_loss:0.6941961276380322 current_lr=0.004687
# Test Loss: 0.708093
#
# Test Accuracy of airplane: 88% (881/1000)
# Test Accuracy of automobile: 92% (920/1000)
# Test Accuracy of  bird: 73% (738/1000)
# Test Accuracy of   cat: 55% (559/1000)
# Test Accuracy of  deer: 79% (790/1000)
# Test Accuracy of   dog: 70% (708/1000)
# Test Accuracy of  frog: 80% (806/1000)
# Test Accuracy of horse: 89% (891/1000)
# Test Accuracy of  ship: 84% (842/1000)
# Test Accuracy of truck: 82% (828/1000)
#
# Test Accuracy (Overall): 79% (7963/10000)
# [18] time: 780.6760416030884 loss: 0.198 val_loss:0.7080926031251497 current_lr=0.004650
# Test Loss: 0.729748
#
# Test Accuracy of airplane: 83% (833/1000)
# Test Accuracy of automobile: 87% (877/1000)
# Test Accuracy of  bird: 75% (759/1000)
# Test Accuracy of   cat: 71% (710/1000)
# Test Accuracy of  deer: 75% (754/1000)
# Test Accuracy of   dog: 63% (635/1000)
# Test Accuracy of  frog: 84% (848/1000)
# Test Accuracy of horse: 81% (811/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 85% (856/1000)
#
# Test Accuracy (Overall): 79% (7968/10000)
# [19] time: 824.0911147594452 loss: 0.185 val_loss:0.7297484618199023 current_lr=0.004611
# Test Loss: 0.752291
#
# Test Accuracy of airplane: 81% (810/1000)
# Test Accuracy of automobile: 82% (821/1000)
# Test Accuracy of  bird: 76% (765/1000)
# Test Accuracy of   cat: 61% (615/1000)
# Test Accuracy of  deer: 77% (771/1000)
# Test Accuracy of   dog: 69% (691/1000)
# Test Accuracy of  frog: 84% (847/1000)
# Test Accuracy of horse: 84% (848/1000)
# Test Accuracy of  ship: 90% (907/1000)
# Test Accuracy of truck: 88% (884/1000)
#
# Test Accuracy (Overall): 79% (7959/10000)
# [20] time: 867.235068321228 loss: 0.170 val_loss:0.7522908030431482 current_lr=0.004570
# Test Loss: 0.750131
#
# Test Accuracy of airplane: 86% (866/1000)
# Test Accuracy of automobile: 87% (876/1000)
# Test Accuracy of  bird: 80% (800/1000)
# Test Accuracy of   cat: 69% (692/1000)
# Test Accuracy of  deer: 69% (694/1000)
# Test Accuracy of   dog: 67% (676/1000)
# Test Accuracy of  frog: 83% (835/1000)
# Test Accuracy of horse: 83% (834/1000)
# Test Accuracy of  ship: 89% (890/1000)
# Test Accuracy of truck: 80% (805/1000)
#
# Test Accuracy (Overall): 79% (7968/10000)
# [21] time: 910.6719386577606 loss: 0.163 val_loss:0.7501312614996222 current_lr=0.004528
# Test Loss: 0.732928
#
# Test Accuracy of airplane: 83% (835/1000)
# Test Accuracy of automobile: 88% (885/1000)
# Test Accuracy of  bird: 74% (747/1000)
# Test Accuracy of   cat: 64% (646/1000)
# Test Accuracy of  deer: 79% (799/1000)
# Test Accuracy of   dog: 72% (724/1000)
# Test Accuracy of  frog: 83% (830/1000)
# Test Accuracy of horse: 83% (837/1000)
# Test Accuracy of  ship: 85% (859/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 80% (8042/10000)
# [22] time: 954.3989112377167 loss: 0.148 val_loss:0.7329283971575242 current_lr=0.004484
# Test Loss: 0.734447
#
# Test Accuracy of airplane: 83% (835/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 76% (761/1000)
# Test Accuracy of   cat: 60% (601/1000)
# Test Accuracy of  deer: 75% (757/1000)
# Test Accuracy of   dog: 72% (727/1000)
# Test Accuracy of  frog: 87% (870/1000)
# Test Accuracy of horse: 86% (862/1000)
# Test Accuracy of  ship: 87% (878/1000)
# Test Accuracy of truck: 84% (847/1000)
#
# Test Accuracy (Overall): 80% (8034/10000)
# [23] time: 997.8289172649384 loss: 0.138 val_loss:0.7344468681118156 current_lr=0.004438
# Test Loss: 0.761960
#
# Test Accuracy of airplane: 83% (837/1000)
# Test Accuracy of automobile: 88% (883/1000)
# Test Accuracy of  bird: 74% (743/1000)
# Test Accuracy of   cat: 65% (656/1000)
# Test Accuracy of  deer: 80% (806/1000)
# Test Accuracy of   dog: 64% (646/1000)
# Test Accuracy of  frog: 88% (882/1000)
# Test Accuracy of horse: 81% (819/1000)
# Test Accuracy of  ship: 86% (868/1000)
# Test Accuracy of truck: 87% (876/1000)
#
# Test Accuracy (Overall): 80% (8016/10000)
# [24] time: 1041.767389535904 loss: 0.128 val_loss:0.7619597383692295 current_lr=0.004390
# Test Loss: 0.779463
#
# Test Accuracy of airplane: 84% (849/1000)
# Test Accuracy of automobile: 87% (875/1000)
# Test Accuracy of  bird: 73% (733/1000)
# Test Accuracy of   cat: 62% (622/1000)
# Test Accuracy of  deer: 75% (757/1000)
# Test Accuracy of   dog: 73% (730/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 86% (865/1000)
# Test Accuracy of  ship: 86% (860/1000)
# Test Accuracy of truck: 86% (862/1000)
#
# Test Accuracy (Overall): 80% (8019/10000)
# [25] time: 1085.7905824184418 loss: 0.125 val_loss:0.7794628682770307 current_lr=0.004341
# Test Loss: 0.782221
#
# Test Accuracy of airplane: 84% (840/1000)
# Test Accuracy of automobile: 86% (862/1000)
# Test Accuracy of  bird: 74% (745/1000)
# Test Accuracy of   cat: 62% (624/1000)
# Test Accuracy of  deer: 80% (801/1000)
# Test Accuracy of   dog: 67% (673/1000)
# Test Accuracy of  frog: 88% (882/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 88% (886/1000)
# Test Accuracy of truck: 86% (863/1000)
#
# Test Accuracy (Overall): 80% (8023/10000)
# [26] time: 1129.6188654899597 loss: 0.119 val_loss:0.7822207057777839 current_lr=0.004290
# Test Loss: 0.789073
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 84% (847/1000)
# Test Accuracy of  bird: 74% (741/1000)
# Test Accuracy of   cat: 64% (640/1000)
# Test Accuracy of  deer: 77% (771/1000)
# Test Accuracy of   dog: 71% (710/1000)
# Test Accuracy of  frog: 85% (859/1000)
# Test Accuracy of horse: 85% (852/1000)
# Test Accuracy of  ship: 88% (887/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 80% (8026/10000)
# [27] time: 1173.2679097652435 loss: 0.113 val_loss:0.7890725569634498 current_lr=0.004238
# Test Loss: 0.821762
#
# Test Accuracy of airplane: 81% (818/1000)
# Test Accuracy of automobile: 89% (892/1000)
# Test Accuracy of  bird: 75% (755/1000)
# Test Accuracy of   cat: 63% (631/1000)
# Test Accuracy of  deer: 81% (819/1000)
# Test Accuracy of   dog: 67% (670/1000)
# Test Accuracy of  frog: 83% (839/1000)
# Test Accuracy of horse: 86% (861/1000)
# Test Accuracy of  ship: 88% (887/1000)
# Test Accuracy of truck: 84% (845/1000)
#
# Test Accuracy (Overall): 80% (8017/10000)
# [28] time: 1217.0093483924866 loss: 0.102 val_loss:0.8217622003977811 current_lr=0.004184
# Test Loss: 0.851878
#
# Test Accuracy of airplane: 76% (769/1000)
# Test Accuracy of automobile: 87% (873/1000)
# Test Accuracy of  bird: 74% (748/1000)
# Test Accuracy of   cat: 65% (656/1000)
# Test Accuracy of  deer: 77% (770/1000)
# Test Accuracy of   dog: 68% (686/1000)
# Test Accuracy of  frog: 87% (873/1000)
# Test Accuracy of horse: 83% (839/1000)
# Test Accuracy of  ship: 85% (858/1000)
# Test Accuracy of truck: 90% (900/1000)
#
# Test Accuracy (Overall): 79% (7972/10000)
# [29] time: 1261.0745372772217 loss: 0.100 val_loss:0.851878250701518 current_lr=0.004129
# Test Loss: 0.812070
#
# Test Accuracy of airplane: 82% (821/1000)
# Test Accuracy of automobile: 88% (880/1000)
# Test Accuracy of  bird: 76% (763/1000)
# Test Accuracy of   cat: 63% (637/1000)
# Test Accuracy of  deer: 74% (747/1000)
# Test Accuracy of   dog: 66% (660/1000)
# Test Accuracy of  frog: 88% (885/1000)
# Test Accuracy of horse: 84% (845/1000)
# Test Accuracy of  ship: 90% (902/1000)
# Test Accuracy of truck: 87% (876/1000)
#
# Test Accuracy (Overall): 80% (8016/10000)
# [30] time: 1304.8802173137665 loss: 0.100 val_loss:0.812070339540892 current_lr=0.004073
# Test Loss: 0.836161
#
# Test Accuracy of airplane: 80% (803/1000)
# Test Accuracy of automobile: 89% (898/1000)
# Test Accuracy of  bird: 73% (738/1000)
# Test Accuracy of   cat: 64% (641/1000)
# Test Accuracy of  deer: 77% (777/1000)
# Test Accuracy of   dog: 69% (690/1000)
# Test Accuracy of  frog: 84% (841/1000)
# Test Accuracy of horse: 86% (865/1000)
# Test Accuracy of  ship: 88% (881/1000)
# Test Accuracy of truck: 86% (863/1000)
#
# Test Accuracy (Overall): 79% (7997/10000)
# [31] time: 1348.8372588157654 loss: 0.089 val_loss:0.8361613260039801 current_lr=0.004015
# Test Loss: 0.822618
#
# Test Accuracy of airplane: 84% (849/1000)
# Test Accuracy of automobile: 90% (906/1000)
# Test Accuracy of  bird: 73% (737/1000)
# Test Accuracy of   cat: 67% (672/1000)
# Test Accuracy of  deer: 77% (771/1000)
# Test Accuracy of   dog: 69% (695/1000)
# Test Accuracy of  frog: 86% (860/1000)
# Test Accuracy of horse: 82% (825/1000)
# Test Accuracy of  ship: 84% (848/1000)
# Test Accuracy of truck: 85% (852/1000)
#
# Test Accuracy (Overall): 80% (8015/10000)
# [32] time: 1393.5243673324585 loss: 0.090 val_loss:0.8226177179360692 current_lr=0.003956
# Test Loss: 0.810734
#
# Test Accuracy of airplane: 84% (847/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 73% (730/1000)
# Test Accuracy of   cat: 62% (620/1000)
# Test Accuracy of  deer: 74% (744/1000)
# Test Accuracy of   dog: 71% (716/1000)
# Test Accuracy of  frog: 85% (858/1000)
# Test Accuracy of horse: 85% (859/1000)
# Test Accuracy of  ship: 89% (890/1000)
# Test Accuracy of truck: 85% (851/1000)
#
# Test Accuracy (Overall): 80% (8011/10000)
# [33] time: 1437.9130461215973 loss: 0.083 val_loss:0.8107343316078186 current_lr=0.003895
# Test Loss: 0.847684
#
# Test Accuracy of airplane: 83% (835/1000)
# Test Accuracy of automobile: 86% (869/1000)
# Test Accuracy of  bird: 72% (726/1000)
# Test Accuracy of   cat: 62% (624/1000)
# Test Accuracy of  deer: 79% (799/1000)
# Test Accuracy of   dog: 72% (721/1000)
# Test Accuracy of  frog: 84% (848/1000)
# Test Accuracy of horse: 85% (857/1000)
# Test Accuracy of  ship: 86% (867/1000)
# Test Accuracy of truck: 88% (881/1000)
#
# Test Accuracy (Overall): 80% (8027/10000)
# [34] time: 1483.0412604808807 loss: 0.084 val_loss:0.8476843524582779 current_lr=0.003834
# Test Loss: 0.857809
#
# Test Accuracy of airplane: 82% (828/1000)
# Test Accuracy of automobile: 90% (908/1000)
# Test Accuracy of  bird: 76% (767/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 73% (738/1000)
# Test Accuracy of   dog: 76% (760/1000)
# Test Accuracy of  frog: 82% (828/1000)
# Test Accuracy of horse: 83% (830/1000)
# Test Accuracy of  ship: 87% (877/1000)
# Test Accuracy of truck: 85% (850/1000)
#
# Test Accuracy (Overall): 80% (8025/10000)
# [35] time: 1527.4195666313171 loss: 0.078 val_loss:0.8578093406520312 current_lr=0.003771
# Test Loss: 0.880884
#
# Test Accuracy of airplane: 82% (827/1000)
# Test Accuracy of automobile: 89% (897/1000)
# Test Accuracy of  bird: 72% (724/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 76% (764/1000)
# Test Accuracy of   dog: 71% (713/1000)
# Test Accuracy of  frog: 83% (830/1000)
# Test Accuracy of horse: 84% (842/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 86% (865/1000)
#
# Test Accuracy (Overall): 79% (7986/10000)
# [36] time: 1572.0346384048462 loss: 0.075 val_loss:0.8808836318269561 current_lr=0.003708
# Test Loss: 0.871999
#
# Test Accuracy of airplane: 82% (825/1000)
# Test Accuracy of automobile: 88% (886/1000)
# Test Accuracy of  bird: 71% (714/1000)
# Test Accuracy of   cat: 64% (643/1000)
# Test Accuracy of  deer: 81% (816/1000)
# Test Accuracy of   dog: 70% (709/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 79% (796/1000)
# Test Accuracy of  ship: 90% (908/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 80% (8042/10000)
# [37] time: 1615.933170080185 loss: 0.072 val_loss:0.8719994969005826 current_lr=0.003644
# Test Loss: 0.877179
#
# Test Accuracy of airplane: 84% (847/1000)
# Test Accuracy of automobile: 90% (906/1000)
# Test Accuracy of  bird: 69% (699/1000)
# Test Accuracy of   cat: 65% (659/1000)
# Test Accuracy of  deer: 73% (731/1000)
# Test Accuracy of   dog: 71% (712/1000)
# Test Accuracy of  frog: 85% (859/1000)
# Test Accuracy of horse: 86% (861/1000)
# Test Accuracy of  ship: 89% (890/1000)
# Test Accuracy of truck: 86% (860/1000)
#
# Test Accuracy (Overall): 80% (8024/10000)
# [38] time: 1660.663108587265 loss: 0.065 val_loss:0.8771794502493702 current_lr=0.003578
# Test Loss: 0.871018
#
# Test Accuracy of airplane: 80% (808/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 78% (784/1000)
# Test Accuracy of   cat: 64% (642/1000)
# Test Accuracy of  deer: 78% (785/1000)
# Test Accuracy of   dog: 67% (678/1000)
# Test Accuracy of  frog: 83% (830/1000)
# Test Accuracy of horse: 82% (823/1000)
# Test Accuracy of  ship: 90% (903/1000)
# Test Accuracy of truck: 84% (845/1000)
#
# Test Accuracy (Overall): 79% (7987/10000)
# [39] time: 1705.6833260059357 loss: 0.064 val_loss:0.8710182007355026 current_lr=0.003512
# Test Loss: 0.860770
#
# Test Accuracy of airplane: 84% (842/1000)
# Test Accuracy of automobile: 90% (906/1000)
# Test Accuracy of  bird: 78% (784/1000)
# Test Accuracy of   cat: 64% (647/1000)
# Test Accuracy of  deer: 80% (809/1000)
# Test Accuracy of   dog: 64% (642/1000)
# Test Accuracy of  frog: 86% (863/1000)
# Test Accuracy of horse: 83% (839/1000)
# Test Accuracy of  ship: 90% (900/1000)
# Test Accuracy of truck: 83% (838/1000)
#
# Test Accuracy (Overall): 80% (8070/10000)
# [40] time: 1750.7959856987 loss: 0.063 val_loss:0.8607704228238214 current_lr=0.003445
# Test Loss: 0.925910
#
# Test Accuracy of airplane: 83% (837/1000)
# Test Accuracy of automobile: 88% (880/1000)
# Test Accuracy of  bird: 75% (751/1000)
# Test Accuracy of   cat: 68% (683/1000)
# Test Accuracy of  deer: 78% (785/1000)
# Test Accuracy of   dog: 63% (634/1000)
# Test Accuracy of  frog: 82% (827/1000)
# Test Accuracy of horse: 83% (839/1000)
# Test Accuracy of  ship: 91% (913/1000)
# Test Accuracy of truck: 84% (847/1000)
#
# Test Accuracy (Overall): 79% (7996/10000)
# [41] time: 1795.447645664215 loss: 0.057 val_loss:0.9259100903438616 current_lr=0.003378
# Test Loss: 0.894847
#
# Test Accuracy of airplane: 86% (861/1000)
# Test Accuracy of automobile: 87% (873/1000)
# Test Accuracy of  bird: 74% (749/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 78% (789/1000)
# Test Accuracy of   dog: 69% (691/1000)
# Test Accuracy of  frog: 83% (837/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 87% (873/1000)
#
# Test Accuracy (Overall): 80% (8063/10000)
# [42] time: 1839.9268634319305 loss: 0.056 val_loss:0.894847420197499 current_lr=0.003310
# Test Loss: 0.902523
#
# Test Accuracy of airplane: 85% (853/1000)
# Test Accuracy of automobile: 87% (871/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 64% (641/1000)
# Test Accuracy of  deer: 80% (808/1000)
# Test Accuracy of   dog: 73% (737/1000)
# Test Accuracy of  frog: 85% (855/1000)
# Test Accuracy of horse: 82% (821/1000)
# Test Accuracy of  ship: 87% (875/1000)
# Test Accuracy of truck: 87% (874/1000)
#
# Test Accuracy (Overall): 80% (8074/10000)
# [43] time: 1884.7897806167603 loss: 0.053 val_loss:0.9025227910355677 current_lr=0.003241
# Test Loss: 0.901753
#
# Test Accuracy of airplane: 85% (858/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 75% (755/1000)
# Test Accuracy of   cat: 67% (670/1000)
# Test Accuracy of  deer: 80% (805/1000)
# Test Accuracy of   dog: 68% (684/1000)
# Test Accuracy of  frog: 83% (838/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 87% (870/1000)
# Test Accuracy of truck: 86% (860/1000)
#
# Test Accuracy (Overall): 80% (8061/10000)
# [44] time: 1930.246598482132 loss: 0.052 val_loss:0.9017525783068017 current_lr=0.003172
# Test Loss: 0.923639
#
# Test Accuracy of airplane: 87% (872/1000)
# Test Accuracy of automobile: 87% (877/1000)
# Test Accuracy of  bird: 73% (731/1000)
# Test Accuracy of   cat: 69% (694/1000)
# Test Accuracy of  deer: 78% (789/1000)
# Test Accuracy of   dog: 66% (669/1000)
# Test Accuracy of  frog: 84% (842/1000)
# Test Accuracy of horse: 85% (850/1000)
# Test Accuracy of  ship: 89% (897/1000)
# Test Accuracy of truck: 85% (857/1000)
#
# Test Accuracy (Overall): 80% (8078/10000)
# [45] time: 1974.8446588516235 loss: 0.049 val_loss:0.923638676540761 current_lr=0.003102
# Test Loss: 0.946115
#
# Test Accuracy of airplane: 86% (869/1000)
# Test Accuracy of automobile: 91% (914/1000)
# Test Accuracy of  bird: 72% (728/1000)
# Test Accuracy of   cat: 67% (676/1000)
# Test Accuracy of  deer: 79% (792/1000)
# Test Accuracy of   dog: 66% (660/1000)
# Test Accuracy of  frog: 87% (874/1000)
# Test Accuracy of horse: 81% (812/1000)
# Test Accuracy of  ship: 89% (893/1000)
# Test Accuracy of truck: 81% (815/1000)
#
# Test Accuracy (Overall): 80% (8033/10000)
# [46] time: 2019.5555522441864 loss: 0.046 val_loss:0.9461145604713054 current_lr=0.003032
# Test Loss: 0.929994
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 75% (752/1000)
# Test Accuracy of   cat: 62% (626/1000)
# Test Accuracy of  deer: 78% (785/1000)
# Test Accuracy of   dog: 73% (730/1000)
# Test Accuracy of  frog: 85% (859/1000)
# Test Accuracy of horse: 84% (842/1000)
# Test Accuracy of  ship: 86% (863/1000)
# Test Accuracy of truck: 87% (870/1000)
#
# Test Accuracy (Overall): 80% (8059/10000)
# [47] time: 2063.936314344406 loss: 0.047 val_loss:0.9299942835976805 current_lr=0.002962
# Test Loss: 0.924051
#
# Test Accuracy of airplane: 83% (833/1000)
# Test Accuracy of automobile: 88% (882/1000)
# Test Accuracy of  bird: 73% (730/1000)
# Test Accuracy of   cat: 61% (610/1000)
# Test Accuracy of  deer: 81% (816/1000)
# Test Accuracy of   dog: 77% (771/1000)
# Test Accuracy of  frog: 85% (857/1000)
# Test Accuracy of horse: 83% (837/1000)
# Test Accuracy of  ship: 87% (879/1000)
# Test Accuracy of truck: 89% (893/1000)
#
# Test Accuracy (Overall): 81% (8108/10000)
# [48] time: 2108.7789504528046 loss: 0.040 val_loss:0.9240508811383308 current_lr=0.002891
# Test Loss: 0.940025
#
# Test Accuracy of airplane: 85% (858/1000)
# Test Accuracy of automobile: 85% (851/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 68% (680/1000)
# Test Accuracy of  deer: 79% (790/1000)
# Test Accuracy of   dog: 65% (658/1000)
# Test Accuracy of  frog: 88% (881/1000)
# Test Accuracy of horse: 83% (837/1000)
# Test Accuracy of  ship: 89% (894/1000)
# Test Accuracy of truck: 89% (898/1000)
#
# Test Accuracy (Overall): 81% (8103/10000)
# [49] time: 2152.625490427017 loss: 0.041 val_loss:0.9400247161901449 current_lr=0.002821
# Test Loss: 0.936211
#
# Test Accuracy of airplane: 86% (868/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 66% (665/1000)
# Test Accuracy of  deer: 78% (784/1000)
# Test Accuracy of   dog: 70% (707/1000)
# Test Accuracy of  frog: 88% (887/1000)
# Test Accuracy of horse: 83% (834/1000)
# Test Accuracy of  ship: 86% (869/1000)
# Test Accuracy of truck: 85% (853/1000)
#
# Test Accuracy (Overall): 80% (8099/10000)
# [50] time: 2196.75097823143 loss: 0.038 val_loss:0.9362111861192728 current_lr=0.002750
# Test Loss: 0.938794
#
# Test Accuracy of airplane: 88% (888/1000)
# Test Accuracy of automobile: 90% (908/1000)
# Test Accuracy of  bird: 72% (720/1000)
# Test Accuracy of   cat: 64% (643/1000)
# Test Accuracy of  deer: 81% (813/1000)
# Test Accuracy of   dog: 71% (711/1000)
# Test Accuracy of  frog: 82% (828/1000)
# Test Accuracy of horse: 85% (851/1000)
# Test Accuracy of  ship: 84% (847/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 80% (8084/10000)
# [51] time: 2241.0222890377045 loss: 0.035 val_loss:0.9387939677962774 current_lr=0.002679
# Test Loss: 0.926426
#
# Test Accuracy of airplane: 84% (842/1000)
# Test Accuracy of automobile: 89% (890/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 60% (602/1000)
# Test Accuracy of  deer: 83% (831/1000)
# Test Accuracy of   dog: 72% (728/1000)
# Test Accuracy of  frog: 88% (887/1000)
# Test Accuracy of horse: 84% (841/1000)
# Test Accuracy of  ship: 88% (880/1000)
# Test Accuracy of truck: 85% (856/1000)
#
# Test Accuracy (Overall): 80% (8096/10000)
# [52] time: 2285.4661798477173 loss: 0.033 val_loss:0.9264262152623527 current_lr=0.002609
# Test Loss: 0.944372
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 75% (751/1000)
# Test Accuracy of   cat: 64% (642/1000)
# Test Accuracy of  deer: 79% (794/1000)
# Test Accuracy of   dog: 68% (688/1000)
# Test Accuracy of  frog: 88% (880/1000)
# Test Accuracy of horse: 82% (822/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 88% (886/1000)
#
# Test Accuracy (Overall): 80% (8081/10000)
# [53] time: 2329.0287477970123 loss: 0.032 val_loss:0.9443715482572966 current_lr=0.002538
# Test Loss: 0.964217
#
# Test Accuracy of airplane: 83% (833/1000)
# Test Accuracy of automobile: 88% (885/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 61% (618/1000)
# Test Accuracy of  deer: 81% (817/1000)
# Test Accuracy of   dog: 68% (687/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 84% (843/1000)
# Test Accuracy of  ship: 90% (906/1000)
# Test Accuracy of truck: 88% (883/1000)
#
# Test Accuracy (Overall): 80% (8094/10000)
# [54] time: 2372.8375470638275 loss: 0.030 val_loss:0.9642165431493446 current_lr=0.002468
# Test Loss: 0.987914
#
# Test Accuracy of airplane: 83% (830/1000)
# Test Accuracy of automobile: 92% (923/1000)
# Test Accuracy of  bird: 76% (764/1000)
# Test Accuracy of   cat: 66% (669/1000)
# Test Accuracy of  deer: 78% (787/1000)
# Test Accuracy of   dog: 65% (658/1000)
# Test Accuracy of  frog: 84% (845/1000)
# Test Accuracy of horse: 86% (860/1000)
# Test Accuracy of  ship: 85% (857/1000)
# Test Accuracy of truck: 85% (851/1000)
#
# Test Accuracy (Overall): 80% (8044/10000)
# [55] time: 2417.228365421295 loss: 0.031 val_loss:0.987914032951186 current_lr=0.002398
# Test Loss: 0.969372
#
# Test Accuracy of airplane: 85% (851/1000)
# Test Accuracy of automobile: 89% (899/1000)
# Test Accuracy of  bird: 74% (746/1000)
# Test Accuracy of   cat: 60% (607/1000)
# Test Accuracy of  deer: 80% (802/1000)
# Test Accuracy of   dog: 76% (769/1000)
# Test Accuracy of  frog: 82% (826/1000)
# Test Accuracy of horse: 84% (842/1000)
# Test Accuracy of  ship: 87% (877/1000)
# Test Accuracy of truck: 89% (895/1000)
#
# Test Accuracy (Overall): 81% (8114/10000)
# [56] time: 2460.6900753974915 loss: 0.029 val_loss:0.969371579870393 current_lr=0.002328
# Test Loss: 0.976421
#
# Test Accuracy of airplane: 83% (838/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 76% (766/1000)
# Test Accuracy of   cat: 61% (618/1000)
# Test Accuracy of  deer: 81% (814/1000)
# Test Accuracy of   dog: 68% (687/1000)
# Test Accuracy of  frog: 88% (880/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 89% (894/1000)
# Test Accuracy of truck: 85% (859/1000)
#
# Test Accuracy (Overall): 80% (8099/10000)
# [57] time: 2504.679993391037 loss: 0.027 val_loss:0.9764206413226791 current_lr=0.002259
# Test Loss: 0.985285
#
# Test Accuracy of airplane: 88% (886/1000)
# Test Accuracy of automobile: 88% (888/1000)
# Test Accuracy of  bird: 76% (761/1000)
# Test Accuracy of   cat: 62% (623/1000)
# Test Accuracy of  deer: 79% (794/1000)
# Test Accuracy of   dog: 70% (706/1000)
# Test Accuracy of  frog: 86% (862/1000)
# Test Accuracy of horse: 83% (838/1000)
# Test Accuracy of  ship: 89% (898/1000)
# Test Accuracy of truck: 85% (853/1000)
#
# Test Accuracy (Overall): 81% (8109/10000)
# [58] time: 2549.0420236587524 loss: 0.025 val_loss:0.985284790208068 current_lr=0.002190
# Test Loss: 0.986819
#
# Test Accuracy of airplane: 86% (860/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 75% (755/1000)
# Test Accuracy of   cat: 69% (691/1000)
# Test Accuracy of  deer: 81% (814/1000)
# Test Accuracy of   dog: 68% (687/1000)
# Test Accuracy of  frog: 83% (833/1000)
# Test Accuracy of horse: 85% (856/1000)
# Test Accuracy of  ship: 88% (886/1000)
# Test Accuracy of truck: 85% (859/1000)
#
# Test Accuracy (Overall): 81% (8141/10000)
# [59] time: 2592.5134239196777 loss: 0.023 val_loss:0.9868187617652023 current_lr=0.002122
# Test Loss: 1.016920
#
# Test Accuracy of airplane: 79% (793/1000)
# Test Accuracy of automobile: 91% (914/1000)
# Test Accuracy of  bird: 76% (764/1000)
# Test Accuracy of   cat: 62% (621/1000)
# Test Accuracy of  deer: 76% (769/1000)
# Test Accuracy of   dog: 74% (744/1000)
# Test Accuracy of  frog: 84% (843/1000)
# Test Accuracy of horse: 86% (865/1000)
# Test Accuracy of  ship: 86% (860/1000)
# Test Accuracy of truck: 86% (868/1000)
#
# Test Accuracy (Overall): 80% (8041/10000)
# [60] time: 2636.1371114254 loss: 0.021 val_loss:1.01691972379443 current_lr=0.002055
# Test Loss: 1.022847
#
# Test Accuracy of airplane: 86% (863/1000)
# Test Accuracy of automobile: 89% (897/1000)
# Test Accuracy of  bird: 79% (798/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 78% (789/1000)
# Test Accuracy of   dog: 67% (676/1000)
# Test Accuracy of  frog: 87% (876/1000)
# Test Accuracy of horse: 82% (820/1000)
# Test Accuracy of  ship: 86% (862/1000)
# Test Accuracy of truck: 85% (851/1000)
#
# Test Accuracy (Overall): 80% (8071/10000)
# [61] time: 2680.0374460220337 loss: 0.021 val_loss:1.0228470247003096 current_lr=0.001988
# Test Loss: 1.002997
#
# Test Accuracy of airplane: 84% (842/1000)
# Test Accuracy of automobile: 86% (865/1000)
# Test Accuracy of  bird: 74% (746/1000)
# Test Accuracy of   cat: 64% (647/1000)
# Test Accuracy of  deer: 79% (798/1000)
# Test Accuracy of   dog: 71% (718/1000)
# Test Accuracy of  frog: 88% (883/1000)
# Test Accuracy of horse: 85% (858/1000)
# Test Accuracy of  ship: 88% (882/1000)
# Test Accuracy of truck: 90% (901/1000)
#
# Test Accuracy (Overall): 81% (8140/10000)
# [62] time: 2723.978656768799 loss: 0.018 val_loss:1.0029968008210388 current_lr=0.001922
# Test Loss: 1.019527
#
# Test Accuracy of airplane: 83% (833/1000)
# Test Accuracy of automobile: 89% (891/1000)
# Test Accuracy of  bird: 75% (758/1000)
# Test Accuracy of   cat: 65% (657/1000)
# Test Accuracy of  deer: 81% (810/1000)
# Test Accuracy of   dog: 71% (717/1000)
# Test Accuracy of  frog: 87% (874/1000)
# Test Accuracy of horse: 82% (826/1000)
# Test Accuracy of  ship: 89% (890/1000)
# Test Accuracy of truck: 87% (874/1000)
#
# Test Accuracy (Overall): 81% (8130/10000)
# [63] time: 2768.022676706314 loss: 0.018 val_loss:1.0195267811606201 current_lr=0.001856
# Test Loss: 1.007267
#
# Test Accuracy of airplane: 85% (851/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 79% (790/1000)
# Test Accuracy of   cat: 62% (628/1000)
# Test Accuracy of  deer: 82% (820/1000)
# Test Accuracy of   dog: 73% (733/1000)
# Test Accuracy of  frog: 87% (876/1000)
# Test Accuracy of horse: 83% (834/1000)
# Test Accuracy of  ship: 90% (900/1000)
# Test Accuracy of truck: 86% (869/1000)
#
# Test Accuracy (Overall): 81% (8190/10000)
# [64] time: 2811.953118085861 loss: 0.017 val_loss:1.007267398170278 current_lr=0.001792
# Test Loss: 0.998988
#
# Test Accuracy of airplane: 85% (852/1000)
# Test Accuracy of automobile: 89% (892/1000)
# Test Accuracy of  bird: 75% (753/1000)
# Test Accuracy of   cat: 66% (669/1000)
# Test Accuracy of  deer: 78% (789/1000)
# Test Accuracy of   dog: 68% (685/1000)
# Test Accuracy of  frog: 88% (883/1000)
# Test Accuracy of horse: 85% (852/1000)
# Test Accuracy of  ship: 90% (909/1000)
# Test Accuracy of truck: 87% (874/1000)
#
# Test Accuracy (Overall): 81% (8158/10000)
# [65] time: 2856.5060999393463 loss: 0.017 val_loss:0.9989881304245961 current_lr=0.001729
# Test Loss: 1.022508
#
# Test Accuracy of airplane: 82% (829/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 75% (752/1000)
# Test Accuracy of   cat: 66% (664/1000)
# Test Accuracy of  deer: 80% (802/1000)
# Test Accuracy of   dog: 72% (723/1000)
# Test Accuracy of  frog: 83% (836/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 91% (910/1000)
# Test Accuracy of truck: 86% (861/1000)
#
# Test Accuracy (Overall): 81% (8131/10000)
# [66] time: 2899.8204765319824 loss: 0.016 val_loss:1.0225082703783541 current_lr=0.001666
# Test Loss: 1.066692
#
# Test Accuracy of airplane: 85% (851/1000)
# Test Accuracy of automobile: 84% (846/1000)
# Test Accuracy of  bird: 75% (757/1000)
# Test Accuracy of   cat: 66% (663/1000)
# Test Accuracy of  deer: 81% (811/1000)
# Test Accuracy of   dog: 70% (703/1000)
# Test Accuracy of  frog: 86% (863/1000)
# Test Accuracy of horse: 81% (818/1000)
# Test Accuracy of  ship: 87% (879/1000)
# Test Accuracy of truck: 88% (885/1000)
#
# Test Accuracy (Overall): 80% (8076/10000)
# [67] time: 2943.3803470134735 loss: 0.014 val_loss:1.066692279109472 current_lr=0.001605
# Test Loss: 1.019016
#
# Test Accuracy of airplane: 84% (840/1000)
# Test Accuracy of automobile: 89% (890/1000)
# Test Accuracy of  bird: 75% (755/1000)
# Test Accuracy of   cat: 62% (628/1000)
# Test Accuracy of  deer: 81% (815/1000)
# Test Accuracy of   dog: 71% (715/1000)
# Test Accuracy of  frog: 87% (878/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 88% (886/1000)
# Test Accuracy of truck: 88% (888/1000)
#
# Test Accuracy (Overall): 81% (8149/10000)
# [68] time: 2987.350016117096 loss: 0.012 val_loss:1.0190160787558253 current_lr=0.001544
# Test Loss: 1.086807
#
# Test Accuracy of airplane: 84% (843/1000)
# Test Accuracy of automobile: 86% (862/1000)
# Test Accuracy of  bird: 76% (763/1000)
# Test Accuracy of   cat: 67% (678/1000)
# Test Accuracy of  deer: 79% (793/1000)
# Test Accuracy of   dog: 69% (699/1000)
# Test Accuracy of  frog: 87% (878/1000)
# Test Accuracy of horse: 82% (825/1000)
# Test Accuracy of  ship: 89% (899/1000)
# Test Accuracy of truck: 89% (892/1000)
#
# Test Accuracy (Overall): 81% (8132/10000)
# [69] time: 3030.7946438789368 loss: 0.011 val_loss:1.0868074501617044 current_lr=0.001485
# Test Loss: 1.039081
#
# Test Accuracy of airplane: 85% (852/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 72% (725/1000)
# Test Accuracy of   cat: 65% (650/1000)
# Test Accuracy of  deer: 81% (810/1000)
# Test Accuracy of   dog: 70% (705/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 90% (906/1000)
# Test Accuracy of truck: 87% (873/1000)
#
# Test Accuracy (Overall): 81% (8137/10000)
# [70] time: 3074.3665528297424 loss: 0.012 val_loss:1.0390808333324482 current_lr=0.001427
# Test Loss: 1.076546
#
# Test Accuracy of airplane: 87% (874/1000)
# Test Accuracy of automobile: 90% (908/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 63% (630/1000)
# Test Accuracy of  deer: 81% (810/1000)
# Test Accuracy of   dog: 70% (704/1000)
# Test Accuracy of  frog: 84% (841/1000)
# Test Accuracy of horse: 85% (859/1000)
# Test Accuracy of  ship: 89% (891/1000)
# Test Accuracy of truck: 86% (862/1000)
#
# Test Accuracy (Overall): 81% (8149/10000)
# [71] time: 3118.527590036392 loss: 0.010 val_loss:1.0765464207794093 current_lr=0.001371
# Test Loss: 1.069503
#
# Test Accuracy of airplane: 85% (852/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 76% (767/1000)
# Test Accuracy of   cat: 67% (671/1000)
# Test Accuracy of  deer: 80% (808/1000)
# Test Accuracy of   dog: 71% (710/1000)
# Test Accuracy of  frog: 85% (851/1000)
# Test Accuracy of horse: 84% (849/1000)
# Test Accuracy of  ship: 86% (869/1000)
# Test Accuracy of truck: 90% (909/1000)
#
# Test Accuracy (Overall): 81% (8175/10000)
# [72] time: 3162.2609894275665 loss: 0.009 val_loss:1.0695031790793696 current_lr=0.001316
# Test Loss: 1.096200
#
# Test Accuracy of airplane: 86% (860/1000)
# Test Accuracy of automobile: 88% (885/1000)
# Test Accuracy of  bird: 79% (793/1000)
# Test Accuracy of   cat: 68% (684/1000)
# Test Accuracy of  deer: 80% (802/1000)
# Test Accuracy of   dog: 66% (660/1000)
# Test Accuracy of  frog: 88% (881/1000)
# Test Accuracy of horse: 83% (831/1000)
# Test Accuracy of  ship: 89% (895/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 81% (8166/10000)
# [73] time: 3206.0914578437805 loss: 0.008 val_loss:1.0961996829962428 current_lr=0.001262
# Test Loss: 1.082906
#
# Test Accuracy of airplane: 84% (844/1000)
# Test Accuracy of automobile: 89% (897/1000)
# Test Accuracy of  bird: 75% (757/1000)
# Test Accuracy of   cat: 62% (629/1000)
# Test Accuracy of  deer: 81% (815/1000)
# Test Accuracy of   dog: 73% (737/1000)
# Test Accuracy of  frog: 86% (865/1000)
# Test Accuracy of horse: 84% (845/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 85% (859/1000)
#
# Test Accuracy (Overall): 81% (8133/10000)
# [74] time: 3250.164186000824 loss: 0.009 val_loss:1.082905507540401 current_lr=0.001210
# Test Loss: 1.064024
#
# Test Accuracy of airplane: 85% (850/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 76% (761/1000)
# Test Accuracy of   cat: 65% (656/1000)
# Test Accuracy of  deer: 82% (825/1000)
# Test Accuracy of   dog: 70% (700/1000)
# Test Accuracy of  frog: 88% (885/1000)
# Test Accuracy of horse: 83% (838/1000)
# Test Accuracy of  ship: 89% (897/1000)
# Test Accuracy of truck: 89% (890/1000)
#
# Test Accuracy (Overall): 81% (8198/10000)
# [75] time: 3294.0346834659576 loss: 0.007 val_loss:1.0640243721913687 current_lr=0.001159
# Test Loss: 1.099653
#
# Test Accuracy of airplane: 85% (851/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 76% (766/1000)
# Test Accuracy of   cat: 61% (619/1000)
# Test Accuracy of  deer: 82% (829/1000)
# Test Accuracy of   dog: 71% (713/1000)
# Test Accuracy of  frog: 85% (850/1000)
# Test Accuracy of horse: 84% (848/1000)
# Test Accuracy of  ship: 87% (872/1000)
# Test Accuracy of truck: 88% (886/1000)
#
# Test Accuracy (Overall): 81% (8134/10000)
# [76] time: 3338.14520406723 loss: 0.006 val_loss:1.0996529392049283 current_lr=0.001110
# Test Loss: 1.093061
#
# Test Accuracy of airplane: 84% (840/1000)
# Test Accuracy of automobile: 88% (885/1000)
# Test Accuracy of  bird: 76% (765/1000)
# Test Accuracy of   cat: 68% (686/1000)
# Test Accuracy of  deer: 78% (783/1000)
# Test Accuracy of   dog: 71% (711/1000)
# Test Accuracy of  frog: 88% (881/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 90% (902/1000)
# Test Accuracy of truck: 88% (889/1000)
#
# Test Accuracy (Overall): 81% (8178/10000)
# [77] time: 3382.4128925800323 loss: 0.007 val_loss:1.0930609748333315 current_lr=0.001062
# Test Loss: 1.076663
#
# Test Accuracy of airplane: 85% (851/1000)
# Test Accuracy of automobile: 88% (880/1000)
# Test Accuracy of  bird: 77% (775/1000)
# Test Accuracy of   cat: 65% (653/1000)
# Test Accuracy of  deer: 80% (807/1000)
# Test Accuracy of   dog: 70% (705/1000)
# Test Accuracy of  frog: 87% (876/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 89% (893/1000)
# Test Accuracy of truck: 87% (876/1000)
#
# Test Accuracy (Overall): 81% (8170/10000)
# [78] time: 3426.9838020801544 loss: 0.006 val_loss:1.0766631643983382 current_lr=0.001016
# Test Loss: 1.107577
#
# Test Accuracy of airplane: 85% (852/1000)
# Test Accuracy of automobile: 89% (894/1000)
# Test Accuracy of  bird: 81% (812/1000)
# Test Accuracy of   cat: 63% (637/1000)
# Test Accuracy of  deer: 82% (821/1000)
# Test Accuracy of   dog: 68% (684/1000)
# Test Accuracy of  frog: 88% (880/1000)
# Test Accuracy of horse: 82% (829/1000)
# Test Accuracy of  ship: 87% (874/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 81% (8149/10000)
# [79] time: 3471.0246322155 loss: 0.005 val_loss:1.1075765324544302 current_lr=0.000972
# Test Loss: 1.094996
#
# Test Accuracy of airplane: 84% (844/1000)
# Test Accuracy of automobile: 89% (892/1000)
# Test Accuracy of  bird: 75% (757/1000)
# Test Accuracy of   cat: 65% (652/1000)
# Test Accuracy of  deer: 82% (825/1000)
# Test Accuracy of   dog: 73% (733/1000)
# Test Accuracy of  frog: 88% (884/1000)
# Test Accuracy of horse: 83% (834/1000)
# Test Accuracy of  ship: 87% (876/1000)
# Test Accuracy of truck: 88% (889/1000)
#
# Test Accuracy (Overall): 81% (8186/10000)
# [80] time: 3515.3268718719482 loss: 0.004 val_loss:1.0949958932550647 current_lr=0.000930
# Test Loss: 1.091370
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 77% (772/1000)
# Test Accuracy of   cat: 63% (632/1000)
# Test Accuracy of  deer: 82% (827/1000)
# Test Accuracy of   dog: 74% (743/1000)
# Test Accuracy of  frog: 89% (890/1000)
# Test Accuracy of horse: 85% (851/1000)
# Test Accuracy of  ship: 89% (898/1000)
# Test Accuracy of truck: 87% (872/1000)
#
# Test Accuracy (Overall): 82% (8214/10000)
# [81] time: 3559.966195344925 loss: 0.004 val_loss:1.0913696349421633 current_lr=0.000889
# Test Loss: 1.106721
#
# Test Accuracy of airplane: 85% (855/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 65% (651/1000)
# Test Accuracy of  deer: 80% (804/1000)
# Test Accuracy of   dog: 71% (718/1000)
# Test Accuracy of  frog: 87% (872/1000)
# Test Accuracy of horse: 84% (846/1000)
# Test Accuracy of  ship: 90% (900/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 81% (8184/10000)
# [82] time: 3603.5526733398438 loss: 0.004 val_loss:1.1067208391201646 current_lr=0.000850
# Test Loss: 1.120631
#
# Test Accuracy of airplane: 85% (859/1000)
# Test Accuracy of automobile: 89% (895/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 64% (642/1000)
# Test Accuracy of  deer: 79% (791/1000)
# Test Accuracy of   dog: 72% (724/1000)
# Test Accuracy of  frog: 87% (878/1000)
# Test Accuracy of horse: 83% (830/1000)
# Test Accuracy of  ship: 87% (878/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 81% (8132/10000)
# [83] time: 3647.505567073822 loss: 0.003 val_loss:1.1206308837178387 current_lr=0.000813
# Test Loss: 1.107403
#
# Test Accuracy of airplane: 83% (838/1000)
# Test Accuracy of automobile: 91% (911/1000)
# Test Accuracy of  bird: 76% (765/1000)
# Test Accuracy of   cat: 64% (644/1000)
# Test Accuracy of  deer: 80% (806/1000)
# Test Accuracy of   dog: 73% (730/1000)
# Test Accuracy of  frog: 87% (878/1000)
# Test Accuracy of horse: 84% (843/1000)
# Test Accuracy of  ship: 89% (897/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 81% (8187/10000)
# [84] time: 3691.7034702301025 loss: 0.003 val_loss:1.1074031425427786 current_lr=0.000778
# Test Loss: 1.103178
#
# Test Accuracy of airplane: 85% (856/1000)
# Test Accuracy of automobile: 89% (898/1000)
# Test Accuracy of  bird: 76% (760/1000)
# Test Accuracy of   cat: 65% (653/1000)
# Test Accuracy of  deer: 82% (824/1000)
# Test Accuracy of   dog: 74% (742/1000)
# Test Accuracy of  frog: 87% (875/1000)
# Test Accuracy of horse: 83% (831/1000)
# Test Accuracy of  ship: 87% (879/1000)
# Test Accuracy of truck: 89% (894/1000)
#
# Test Accuracy (Overall): 82% (8212/10000)
# [85] time: 3735.7621314525604 loss: 0.002 val_loss:1.1031775678260416 current_lr=0.000745
# Test Loss: 1.128413
#
# Test Accuracy of airplane: 84% (849/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 78% (780/1000)
# Test Accuracy of   cat: 62% (621/1000)
# Test Accuracy of  deer: 80% (806/1000)
# Test Accuracy of   dog: 75% (750/1000)
# Test Accuracy of  frog: 87% (879/1000)
# Test Accuracy of horse: 84% (849/1000)
# Test Accuracy of  ship: 88% (888/1000)
# Test Accuracy of truck: 86% (868/1000)
#
# Test Accuracy (Overall): 81% (8186/10000)
# [86] time: 3780.1876900196075 loss: 0.003 val_loss:1.1284133678750148 current_lr=0.000714
# Test Loss: 1.119015
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 66% (667/1000)
# Test Accuracy of  deer: 79% (792/1000)
# Test Accuracy of   dog: 73% (730/1000)
# Test Accuracy of  frog: 87% (870/1000)
# Test Accuracy of horse: 86% (861/1000)
# Test Accuracy of  ship: 89% (891/1000)
# Test Accuracy of truck: 88% (881/1000)
#
# Test Accuracy (Overall): 81% (8199/10000)
# [87] time: 3824.4652881622314 loss: 0.002 val_loss:1.119015253797362 current_lr=0.000685
# Test Loss: 1.138481
#
# Test Accuracy of airplane: 84% (844/1000)
# Test Accuracy of automobile: 90% (905/1000)
# Test Accuracy of  bird: 77% (771/1000)
# Test Accuracy of   cat: 66% (669/1000)
# Test Accuracy of  deer: 82% (827/1000)
# Test Accuracy of   dog: 71% (714/1000)
# Test Accuracy of  frog: 89% (890/1000)
# Test Accuracy of horse: 82% (823/1000)
# Test Accuracy of  ship: 89% (897/1000)
# Test Accuracy of truck: 87% (872/1000)
#
# Test Accuracy (Overall): 82% (8212/10000)
# [88] time: 3869.056922674179 loss: 0.002 val_loss:1.1384814306150508 current_lr=0.000658
# Test Loss: 1.151185
#
# Test Accuracy of airplane: 85% (854/1000)
# Test Accuracy of automobile: 91% (910/1000)
# Test Accuracy of  bird: 76% (768/1000)
# Test Accuracy of   cat: 63% (635/1000)
# Test Accuracy of  deer: 79% (797/1000)
# Test Accuracy of   dog: 72% (726/1000)
# Test Accuracy of  frog: 88% (885/1000)
# Test Accuracy of horse: 86% (861/1000)
# Test Accuracy of  ship: 89% (891/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 82% (8202/10000)
# [89] time: 3913.0483169555664 loss: 0.002 val_loss:1.1511853299563444 current_lr=0.000633
# Test Loss: 1.145883
#
# Test Accuracy of airplane: 86% (861/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 79% (790/1000)
# Test Accuracy of   cat: 66% (665/1000)
# Test Accuracy of  deer: 80% (804/1000)
# Test Accuracy of   dog: 71% (718/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 89% (893/1000)
# Test Accuracy of truck: 87% (873/1000)
#
# Test Accuracy (Overall): 82% (8217/10000)
# [90] time: 3957.4118387699127 loss: 0.001 val_loss:1.1458827143982997 current_lr=0.000610
# Test Loss: 1.132959
#
# Test Accuracy of airplane: 83% (837/1000)
# Test Accuracy of automobile: 90% (908/1000)
# Test Accuracy of  bird: 77% (771/1000)
# Test Accuracy of   cat: 66% (663/1000)
# Test Accuracy of  deer: 79% (794/1000)
# Test Accuracy of   dog: 71% (712/1000)
# Test Accuracy of  frog: 84% (849/1000)
# Test Accuracy of horse: 86% (868/1000)
# Test Accuracy of  ship: 90% (900/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 81% (8181/10000)
# [91] time: 4001.7304236888885 loss: 0.002 val_loss:1.13295911610881 current_lr=0.000589
# Test Loss: 1.146802
#
# Test Accuracy of airplane: 86% (862/1000)
# Test Accuracy of automobile: 89% (895/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 64% (645/1000)
# Test Accuracy of  deer: 80% (807/1000)
# Test Accuracy of   dog: 71% (711/1000)
# Test Accuracy of  frog: 87% (876/1000)
# Test Accuracy of horse: 88% (886/1000)
# Test Accuracy of  ship: 89% (890/1000)
# Test Accuracy of truck: 88% (888/1000)
#
# Test Accuracy (Overall): 82% (8230/10000)
# [92] time: 4045.7327914237976 loss: 0.001 val_loss:1.146802051157891 current_lr=0.000571
# Test Loss: 1.172839
#
# Test Accuracy of airplane: 87% (873/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 77% (775/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 80% (801/1000)
# Test Accuracy of   dog: 73% (732/1000)
# Test Accuracy of  frog: 89% (890/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 88% (887/1000)
# Test Accuracy of truck: 86% (861/1000)
#
# Test Accuracy (Overall): 82% (8205/10000)
# [93] time: 4089.4189558029175 loss: 0.001 val_loss:1.1728393382663969 current_lr=0.000554
# Test Loss: 1.163918
#
# Test Accuracy of airplane: 85% (852/1000)
# Test Accuracy of automobile: 89% (892/1000)
# Test Accuracy of  bird: 75% (754/1000)
# Test Accuracy of   cat: 64% (642/1000)
# Test Accuracy of  deer: 82% (827/1000)
# Test Accuracy of   dog: 74% (746/1000)
# Test Accuracy of  frog: 87% (878/1000)
# Test Accuracy of horse: 85% (850/1000)
# Test Accuracy of  ship: 89% (890/1000)
# Test Accuracy of truck: 88% (883/1000)
#
# Test Accuracy (Overall): 82% (8214/10000)
# [94] time: 4133.100188493729 loss: 0.001 val_loss:1.1639183239091802 current_lr=0.000540
# Test Loss: 1.179612
#
# Test Accuracy of airplane: 86% (862/1000)
# Test Accuracy of automobile: 90% (904/1000)
# Test Accuracy of  bird: 75% (758/1000)
# Test Accuracy of   cat: 66% (662/1000)
# Test Accuracy of  deer: 82% (827/1000)
# Test Accuracy of   dog: 71% (719/1000)
# Test Accuracy of  frog: 87% (874/1000)
# Test Accuracy of horse: 85% (857/1000)
# Test Accuracy of  ship: 89% (897/1000)
# Test Accuracy of truck: 86% (869/1000)
#
# Test Accuracy (Overall): 82% (8229/10000)
# [95] time: 4176.9107229709625 loss: 0.001 val_loss:1.17961201713055 current_lr=0.000528
# Test Loss: 1.171076
#
# Test Accuracy of airplane: 86% (862/1000)
# Test Accuracy of automobile: 89% (891/1000)
# Test Accuracy of  bird: 77% (777/1000)
# Test Accuracy of   cat: 66% (664/1000)
# Test Accuracy of  deer: 82% (826/1000)
# Test Accuracy of   dog: 70% (706/1000)
# Test Accuracy of  frog: 89% (890/1000)
# Test Accuracy of horse: 82% (829/1000)
# Test Accuracy of  ship: 89% (893/1000)
# Test Accuracy of truck: 88% (888/1000)
#
# Test Accuracy (Overall): 82% (8226/10000)
# [96] time: 4220.488135814667 loss: 0.001 val_loss:1.1710764305501045 current_lr=0.000518
# Test Loss: 1.205468
#
# Test Accuracy of airplane: 84% (841/1000)
# Test Accuracy of automobile: 89% (899/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 62% (620/1000)
# Test Accuracy of  deer: 82% (820/1000)
# Test Accuracy of   dog: 75% (750/1000)
# Test Accuracy of  frog: 88% (888/1000)
# Test Accuracy of horse: 84% (845/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 88% (884/1000)
#
# Test Accuracy (Overall): 82% (8221/10000)
# [97] time: 4264.54106926918 loss: 0.001 val_loss:1.2054682132564014 current_lr=0.000510
# Test Loss: 1.202159
#
# Test Accuracy of airplane: 86% (866/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 76% (767/1000)
# Test Accuracy of   cat: 66% (660/1000)
# Test Accuracy of  deer: 83% (836/1000)
# Test Accuracy of   dog: 71% (718/1000)
# Test Accuracy of  frog: 87% (873/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 87% (873/1000)
# Test Accuracy of truck: 87% (877/1000)
#
# Test Accuracy (Overall): 82% (8217/10000)
# [98] time: 4308.999891996384 loss: 0.001 val_loss:1.2021593398685697 current_lr=0.000504
# Test Loss: 1.230303
#
# Test Accuracy of airplane: 85% (854/1000)
# Test Accuracy of automobile: 89% (895/1000)
# Test Accuracy of  bird: 77% (777/1000)
# Test Accuracy of   cat: 64% (646/1000)
# Test Accuracy of  deer: 80% (808/1000)
# Test Accuracy of   dog: 71% (714/1000)
# Test Accuracy of  frog: 88% (889/1000)
# Test Accuracy of horse: 84% (842/1000)
# Test Accuracy of  ship: 89% (895/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 82% (8200/10000)
# [99] time: 4352.361091375351 loss: 0.001 val_loss:1.2303028287766855 current_lr=0.000501
# Test Loss: 1.225407
#
# Test Accuracy of airplane: 83% (835/1000)
# Test Accuracy of automobile: 89% (891/1000)
# Test Accuracy of  bird: 78% (780/1000)
# Test Accuracy of   cat: 65% (659/1000)
# Test Accuracy of  deer: 82% (823/1000)
# Test Accuracy of   dog: 73% (734/1000)
# Test Accuracy of  frog: 87% (872/1000)
# Test Accuracy of horse: 86% (862/1000)
# Test Accuracy of  ship: 90% (908/1000)
# Test Accuracy of truck: 88% (886/1000)
#
# Test Accuracy (Overall): 82% (8250/10000)
# [100] time: 4396.322798728943 loss: 0.001 val_loss:1.2254068353508092 current_lr=0.000500
# Training finished!
# Training finished!

# %%
class AdaOrthLMinusOptimizer(BaseOptimizer):
  def __init__(self,model,criterion,epochs):
    super().__init__(model,criterion,epochs)
  def initialize_optimizer(self, learning_rate):
    #weight_decay=0.01,gamma=0.1
    optimizer = AdaOrth(self.model.parameters(),nu=0, lr=learning_rate, weight_decay=0.01,gamma=0.1)
    # Cosine annealing: lr → eta_min by the end
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=self.epochs,   # period (usually = total epochs)
        eta_min=0.1*learning_rate      # minimum LR (here 0.1× of 0.01)
    )
    self.optimizer,self.scheduler =  optimizer, scheduler

# %%
def get_adaorthlminus(model, learning_rate):
    optimizer = AdaOrthLMinusOptimizer(model, criterion, epochs)
    optimizer.initialize_optimizer(learning_rate)
    return optimizer
#42
#4242
result_adaorthlminus = [1.4950318336486816, 1.2349185049533844, 1.1676776334643364,
                        1.0449151247739792, 1.0672575160861015, 1.1173424050211906, 1.0885105580091476]

# on test loader
#[1.518645703792572, 1.2098605260252953, 1.118162177503109, 0.9749591164290905, 0.9899768754839897, 0.9824965074658394, 0.9662566855549812]


if not result_adaorthlminus:
    result_adaorthlminus = grids_search_val(get_adaorthlminus)
print(result_adaorthlminus)
min_index = result_adaorthlminus.index(min(result_adaorthlminus))
learning_rate = learning_rates[min_index]
print(f"Best learning rate: {learning_rate}, Min val loss: {result_adaorthlminus[min_index]}")
plt.figure(figsize=(6,4))
plt.xscale('log')   # good practice for learning rates
plt.xlabel("Learning rate")
plt.ylabel("Min Validation Loss")
plt.title("Learning Rate Grid Search")
plt.xticks(learning_rates, labels=[str(lr) for lr in learning_rates],rotation=45)
plt.plot(learning_rates, result_adaorthlminus, label="Grid Search(Validataion Loss)", linewidth=2, marker='o')
# Out:
# [1.4950318336486816, 1.2349185049533844, 1.1676776334643364, 1.0449151247739792, 1.0672575160861015, 1.1173424050211906, 1.0885105580091476]
# Best learning rate: 0.005, Min val loss: 1.0449151247739792

# %%
model_adaorthlminus = initialize_model(device)
optimizer = AdaOrthLMinusOptimizer(model_adaorthlminus,criterion,epochs)
optimizer.initialize_optimizer(learning_rate)
losses_adaorthlminus,losses_adaorthlminus_val, \
adaorthlminus_acc ,adaorthlminus_time_cost = \
train_once(model_adaorthlminus,criterion,optimizer,train_loader,test_loader,learning_rate,epochs)
print("Training finished!")
# Out:
# Test Loss: 1.224460
#
# Test Accuracy of airplane: 74% (744/1000)
# Test Accuracy of automobile: 76% (766/1000)
# Test Accuracy of  bird: 56% (560/1000)
# Test Accuracy of   cat: 48% (486/1000)
# Test Accuracy of  deer: 30% (306/1000)
# Test Accuracy of   dog: 43% (434/1000)
# Test Accuracy of  frog: 74% (745/1000)
# Test Accuracy of horse: 61% (611/1000)
# Test Accuracy of  ship: 53% (533/1000)
# Test Accuracy of truck: 43% (435/1000)
#
# Test Accuracy (Overall): 56% (5620/10000)
# [1] time: 31.642887353897095 loss: 1.473 val_loss:1.2244600163230412 current_lr=0.004999
# Test Loss: 1.098096
#
# Test Accuracy of airplane: 65% (650/1000)
# Test Accuracy of automobile: 66% (663/1000)
# Test Accuracy of  bird: 36% (361/1000)
# Test Accuracy of   cat: 39% (393/1000)
# Test Accuracy of  deer: 40% (403/1000)
# Test Accuracy of   dog: 59% (596/1000)
# Test Accuracy of  frog: 81% (818/1000)
# Test Accuracy of horse: 67% (679/1000)
# Test Accuracy of  ship: 76% (763/1000)
# Test Accuracy of truck: 85% (850/1000)
#
# Test Accuracy (Overall): 61% (6176/10000)
# [2] time: 62.543262004852295 loss: 1.042 val_loss:1.0980957512614093 current_lr=0.004996
# Test Loss: 0.858834
#
# Test Accuracy of airplane: 66% (664/1000)
# Test Accuracy of automobile: 85% (856/1000)
# Test Accuracy of  bird: 64% (648/1000)
# Test Accuracy of   cat: 56% (564/1000)
# Test Accuracy of  deer: 69% (691/1000)
# Test Accuracy of   dog: 53% (531/1000)
# Test Accuracy of  frog: 74% (744/1000)
# Test Accuracy of horse: 68% (682/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 73% (738/1000)
#
# Test Accuracy (Overall): 70% (7003/10000)
# [3] time: 94.05076313018799 loss: 0.861 val_loss:0.8588340667229665 current_lr=0.004990
# Test Loss: 0.745293
#
# Test Accuracy of airplane: 77% (779/1000)
# Test Accuracy of automobile: 80% (802/1000)
# Test Accuracy of  bird: 64% (645/1000)
# Test Accuracy of   cat: 56% (561/1000)
# Test Accuracy of  deer: 64% (649/1000)
# Test Accuracy of   dog: 63% (639/1000)
# Test Accuracy of  frog: 83% (836/1000)
# Test Accuracy of horse: 80% (809/1000)
# Test Accuracy of  ship: 82% (829/1000)
# Test Accuracy of truck: 84% (840/1000)
#
# Test Accuracy (Overall): 73% (7389/10000)
# [4] time: 125.87624883651733 loss: 0.737 val_loss:0.745293452015406 current_lr=0.004982
# Test Loss: 0.718080
#
# Test Accuracy of airplane: 80% (809/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 62% (628/1000)
# Test Accuracy of   cat: 60% (602/1000)
# Test Accuracy of  deer: 63% (632/1000)
# Test Accuracy of   dog: 61% (612/1000)
# Test Accuracy of  frog: 86% (863/1000)
# Test Accuracy of horse: 80% (807/1000)
# Test Accuracy of  ship: 86% (860/1000)
# Test Accuracy of truck: 80% (805/1000)
#
# Test Accuracy (Overall): 75% (7514/10000)
# [5] time: 157.1365852355957 loss: 0.641 val_loss:0.7180799042122273 current_lr=0.004972
# Test Loss: 0.677288
#
# Test Accuracy of airplane: 86% (863/1000)
# Test Accuracy of automobile: 82% (825/1000)
# Test Accuracy of  bird: 58% (582/1000)
# Test Accuracy of   cat: 59% (592/1000)
# Test Accuracy of  deer: 80% (808/1000)
# Test Accuracy of   dog: 63% (630/1000)
# Test Accuracy of  frog: 87% (874/1000)
# Test Accuracy of horse: 75% (757/1000)
# Test Accuracy of  ship: 88% (880/1000)
# Test Accuracy of truck: 83% (836/1000)
#
# Test Accuracy (Overall): 76% (7647/10000)
# [6] time: 189.15207290649414 loss: 0.570 val_loss:0.6772876596903499 current_lr=0.004960
# Test Loss: 0.669090
#
# Test Accuracy of airplane: 78% (786/1000)
# Test Accuracy of automobile: 83% (837/1000)
# Test Accuracy of  bird: 68% (686/1000)
# Test Accuracy of   cat: 62% (624/1000)
# Test Accuracy of  deer: 73% (739/1000)
# Test Accuracy of   dog: 69% (690/1000)
# Test Accuracy of  frog: 76% (761/1000)
# Test Accuracy of horse: 86% (860/1000)
# Test Accuracy of  ship: 89% (892/1000)
# Test Accuracy of truck: 82% (829/1000)
#
# Test Accuracy (Overall): 77% (7704/10000)
# [7] time: 221.1722264289856 loss: 0.511 val_loss:0.6690904226484178 current_lr=0.004946
# Test Loss: 0.650081
#
# Test Accuracy of airplane: 81% (817/1000)
# Test Accuracy of automobile: 90% (904/1000)
# Test Accuracy of  bird: 67% (673/1000)
# Test Accuracy of   cat: 53% (536/1000)
# Test Accuracy of  deer: 70% (705/1000)
# Test Accuracy of   dog: 79% (791/1000)
# Test Accuracy of  frog: 87% (870/1000)
# Test Accuracy of horse: 81% (818/1000)
# Test Accuracy of  ship: 84% (849/1000)
# Test Accuracy of truck: 81% (815/1000)
#
# Test Accuracy (Overall): 77% (7778/10000)
# [8] time: 252.35160899162292 loss: 0.451 val_loss:0.6500808332539811 current_lr=0.004929
# Test Loss: 0.689362
#
# Test Accuracy of airplane: 87% (876/1000)
# Test Accuracy of automobile: 78% (781/1000)
# Test Accuracy of  bird: 71% (713/1000)
# Test Accuracy of   cat: 62% (629/1000)
# Test Accuracy of  deer: 75% (756/1000)
# Test Accuracy of   dog: 55% (552/1000)
# Test Accuracy of  frog: 88% (884/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 83% (831/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 77% (7756/10000)
# [9] time: 284.03494334220886 loss: 0.396 val_loss:0.6893616895886916 current_lr=0.004911
# Test Loss: 0.646515
#
# Test Accuracy of airplane: 80% (803/1000)
# Test Accuracy of automobile: 88% (884/1000)
# Test Accuracy of  bird: 66% (662/1000)
# Test Accuracy of   cat: 67% (674/1000)
# Test Accuracy of  deer: 78% (782/1000)
# Test Accuracy of   dog: 68% (688/1000)
# Test Accuracy of  frog: 82% (825/1000)
# Test Accuracy of horse: 82% (826/1000)
# Test Accuracy of  ship: 90% (900/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 79% (7919/10000)
# [10] time: 316.18033504486084 loss: 0.357 val_loss:0.6465151140206977 current_lr=0.004890
# Test Loss: 0.691268
#
# Test Accuracy of airplane: 85% (859/1000)
# Test Accuracy of automobile: 87% (874/1000)
# Test Accuracy of  bird: 70% (709/1000)
# Test Accuracy of   cat: 60% (600/1000)
# Test Accuracy of  deer: 75% (757/1000)
# Test Accuracy of   dog: 65% (657/1000)
# Test Accuracy of  frog: 84% (847/1000)
# Test Accuracy of horse: 84% (848/1000)
# Test Accuracy of  ship: 83% (830/1000)
# Test Accuracy of truck: 87% (877/1000)
#
# Test Accuracy (Overall): 78% (7858/10000)
# [11] time: 347.42322754859924 loss: 0.320 val_loss:0.691268347486665 current_lr=0.004867
# Test Loss: 0.666690
#
# Test Accuracy of airplane: 86% (867/1000)
# Test Accuracy of automobile: 86% (869/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 59% (595/1000)
# Test Accuracy of  deer: 81% (816/1000)
# Test Accuracy of   dog: 70% (706/1000)
# Test Accuracy of  frog: 79% (797/1000)
# Test Accuracy of horse: 81% (816/1000)
# Test Accuracy of  ship: 89% (893/1000)
# Test Accuracy of truck: 83% (832/1000)
#
# Test Accuracy (Overall): 79% (7947/10000)
# [12] time: 378.95073437690735 loss: 0.280 val_loss:0.6666896037663086 current_lr=0.004842
# Test Loss: 0.701152
#
# Test Accuracy of airplane: 84% (849/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 65% (655/1000)
# Test Accuracy of   cat: 64% (641/1000)
# Test Accuracy of  deer: 77% (770/1000)
# Test Accuracy of   dog: 72% (726/1000)
# Test Accuracy of  frog: 84% (846/1000)
# Test Accuracy of horse: 80% (806/1000)
# Test Accuracy of  ship: 89% (898/1000)
# Test Accuracy of truck: 85% (853/1000)
#
# Test Accuracy (Overall): 79% (7910/10000)
# [13] time: 410.5457806587219 loss: 0.253 val_loss:0.7011522009402891 current_lr=0.004815
# Test Loss: 0.688113
#
# Test Accuracy of airplane: 84% (840/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 73% (733/1000)
# Test Accuracy of   cat: 62% (629/1000)
# Test Accuracy of  deer: 78% (788/1000)
# Test Accuracy of   dog: 72% (726/1000)
# Test Accuracy of  frog: 83% (831/1000)
# Test Accuracy of horse: 83% (838/1000)
# Test Accuracy of  ship: 88% (886/1000)
# Test Accuracy of truck: 83% (832/1000)
#
# Test Accuracy (Overall): 79% (7984/10000)
# [14] time: 441.710253238678 loss: 0.227 val_loss:0.6881127202812629 current_lr=0.004786
# Test Loss: 0.737851
#
# Test Accuracy of airplane: 82% (828/1000)
# Test Accuracy of automobile: 87% (872/1000)
# Test Accuracy of  bird: 73% (735/1000)
# Test Accuracy of   cat: 55% (554/1000)
# Test Accuracy of  deer: 73% (733/1000)
# Test Accuracy of   dog: 78% (784/1000)
# Test Accuracy of  frog: 84% (845/1000)
# Test Accuracy of horse: 83% (835/1000)
# Test Accuracy of  ship: 88% (883/1000)
# Test Accuracy of truck: 87% (877/1000)
#
# Test Accuracy (Overall): 79% (7946/10000)
# [15] time: 473.29238271713257 loss: 0.203 val_loss:0.7378508482552781 current_lr=0.004755
# Test Loss: 0.752673
#
# Test Accuracy of airplane: 83% (834/1000)
# Test Accuracy of automobile: 90% (904/1000)
# Test Accuracy of  bird: 73% (734/1000)
# Test Accuracy of   cat: 62% (620/1000)
# Test Accuracy of  deer: 78% (780/1000)
# Test Accuracy of   dog: 65% (658/1000)
# Test Accuracy of  frog: 85% (856/1000)
# Test Accuracy of horse: 81% (814/1000)
# Test Accuracy of  ship: 87% (871/1000)
# Test Accuracy of truck: 85% (852/1000)
#
# Test Accuracy (Overall): 79% (7923/10000)
# [16] time: 504.7313423156738 loss: 0.185 val_loss:0.752672942378853 current_lr=0.004722
# Test Loss: 0.744386
#
# Test Accuracy of airplane: 81% (810/1000)
# Test Accuracy of automobile: 89% (899/1000)
# Test Accuracy of  bird: 71% (716/1000)
# Test Accuracy of   cat: 61% (611/1000)
# Test Accuracy of  deer: 80% (806/1000)
# Test Accuracy of   dog: 68% (688/1000)
# Test Accuracy of  frog: 88% (887/1000)
# Test Accuracy of horse: 80% (800/1000)
# Test Accuracy of  ship: 89% (899/1000)
# Test Accuracy of truck: 83% (838/1000)
#
# Test Accuracy (Overall): 79% (7954/10000)
# [17] time: 535.4596381187439 loss: 0.169 val_loss:0.7443862746033487 current_lr=0.004687
# Test Loss: 0.755064
#
# Test Accuracy of airplane: 84% (847/1000)
# Test Accuracy of automobile: 87% (875/1000)
# Test Accuracy of  bird: 71% (711/1000)
# Test Accuracy of   cat: 63% (634/1000)
# Test Accuracy of  deer: 78% (786/1000)
# Test Accuracy of   dog: 67% (673/1000)
# Test Accuracy of  frog: 86% (865/1000)
# Test Accuracy of horse: 86% (860/1000)
# Test Accuracy of  ship: 86% (866/1000)
# Test Accuracy of truck: 85% (850/1000)
#
# Test Accuracy (Overall): 79% (7967/10000)
# [18] time: 566.7150285243988 loss: 0.156 val_loss:0.7550635733936406 current_lr=0.004650
# Test Loss: 0.779494
#
# Test Accuracy of airplane: 80% (808/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 79% (791/1000)
# Test Accuracy of   cat: 62% (626/1000)
# Test Accuracy of  deer: 75% (752/1000)
# Test Accuracy of   dog: 66% (662/1000)
# Test Accuracy of  frog: 85% (854/1000)
# Test Accuracy of horse: 84% (849/1000)
# Test Accuracy of  ship: 86% (860/1000)
# Test Accuracy of truck: 83% (832/1000)
#
# Test Accuracy (Overall): 79% (7915/10000)
# [19] time: 597.4593660831451 loss: 0.146 val_loss:0.7794941399670854 current_lr=0.004611
# Test Loss: 0.829642
#
# Test Accuracy of airplane: 85% (850/1000)
# Test Accuracy of automobile: 84% (847/1000)
# Test Accuracy of  bird: 71% (710/1000)
# Test Accuracy of   cat: 59% (599/1000)
# Test Accuracy of  deer: 78% (783/1000)
# Test Accuracy of   dog: 71% (713/1000)
# Test Accuracy of  frog: 78% (786/1000)
# Test Accuracy of horse: 85% (852/1000)
# Test Accuracy of  ship: 83% (837/1000)
# Test Accuracy of truck: 89% (899/1000)
#
# Test Accuracy (Overall): 78% (7876/10000)
# [20] time: 628.6867291927338 loss: 0.134 val_loss:0.8296423131906534 current_lr=0.004570
# Test Loss: 0.824892
#
# Test Accuracy of airplane: 81% (815/1000)
# Test Accuracy of automobile: 87% (870/1000)
# Test Accuracy of  bird: 74% (742/1000)
# Test Accuracy of   cat: 59% (593/1000)
# Test Accuracy of  deer: 75% (753/1000)
# Test Accuracy of   dog: 73% (738/1000)
# Test Accuracy of  frog: 84% (843/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 84% (848/1000)
# Test Accuracy of truck: 86% (864/1000)
#
# Test Accuracy (Overall): 79% (7913/10000)
# [21] time: 660.5713911056519 loss: 0.131 val_loss:0.8248915702481813 current_lr=0.004528
# Test Loss: 0.838322
#
# Test Accuracy of airplane: 82% (827/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 72% (728/1000)
# Test Accuracy of   cat: 67% (675/1000)
# Test Accuracy of  deer: 75% (759/1000)
# Test Accuracy of   dog: 70% (701/1000)
# Test Accuracy of  frog: 79% (797/1000)
# Test Accuracy of horse: 86% (861/1000)
# Test Accuracy of  ship: 85% (858/1000)
# Test Accuracy of truck: 83% (837/1000)
#
# Test Accuracy (Overall): 79% (7924/10000)
# [22] time: 691.4849400520325 loss: 0.119 val_loss:0.8383221965801867 current_lr=0.004484
# Test Loss: 0.839155
#
# Test Accuracy of airplane: 81% (818/1000)
# Test Accuracy of automobile: 91% (910/1000)
# Test Accuracy of  bird: 74% (748/1000)
# Test Accuracy of   cat: 61% (612/1000)
# Test Accuracy of  deer: 76% (769/1000)
# Test Accuracy of   dog: 71% (710/1000)
# Test Accuracy of  frog: 83% (836/1000)
# Test Accuracy of horse: 82% (823/1000)
# Test Accuracy of  ship: 88% (882/1000)
# Test Accuracy of truck: 80% (807/1000)
#
# Test Accuracy (Overall): 79% (7915/10000)
# [23] time: 722.7002520561218 loss: 0.111 val_loss:0.8391550145571745 current_lr=0.004438
# Test Loss: 0.817560
#
# Test Accuracy of airplane: 83% (837/1000)
# Test Accuracy of automobile: 88% (888/1000)
# Test Accuracy of  bird: 75% (753/1000)
# Test Accuracy of   cat: 65% (657/1000)
# Test Accuracy of  deer: 76% (768/1000)
# Test Accuracy of   dog: 67% (670/1000)
# Test Accuracy of  frog: 84% (844/1000)
# Test Accuracy of horse: 84% (848/1000)
# Test Accuracy of  ship: 87% (875/1000)
# Test Accuracy of truck: 85% (852/1000)
#
# Test Accuracy (Overall): 79% (7992/10000)
# [24] time: 754.2120471000671 loss: 0.107 val_loss:0.8175604667844651 current_lr=0.004390
# Test Loss: 0.865199
#
# Test Accuracy of airplane: 84% (844/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 68% (683/1000)
# Test Accuracy of   cat: 68% (685/1000)
# Test Accuracy of  deer: 78% (780/1000)
# Test Accuracy of   dog: 64% (648/1000)
# Test Accuracy of  frog: 85% (854/1000)
# Test Accuracy of horse: 82% (823/1000)
# Test Accuracy of  ship: 88% (881/1000)
# Test Accuracy of truck: 85% (856/1000)
#
# Test Accuracy (Overall): 79% (7920/10000)
# [25] time: 785.0424182415009 loss: 0.097 val_loss:0.8651990520803234 current_lr=0.004341
# Test Loss: 0.879549
#
# Test Accuracy of airplane: 85% (857/1000)
# Test Accuracy of automobile: 88% (884/1000)
# Test Accuracy of  bird: 68% (683/1000)
# Test Accuracy of   cat: 59% (594/1000)
# Test Accuracy of  deer: 79% (799/1000)
# Test Accuracy of   dog: 73% (732/1000)
# Test Accuracy of  frog: 81% (810/1000)
# Test Accuracy of horse: 88% (882/1000)
# Test Accuracy of  ship: 83% (837/1000)
# Test Accuracy of truck: 86% (865/1000)
#
# Test Accuracy (Overall): 79% (7943/10000)
# [26] time: 816.4824910163879 loss: 0.096 val_loss:0.8795489072799683 current_lr=0.004290
# Test Loss: 0.892738
#
# Test Accuracy of airplane: 82% (826/1000)
# Test Accuracy of automobile: 85% (852/1000)
# Test Accuracy of  bird: 73% (736/1000)
# Test Accuracy of   cat: 58% (587/1000)
# Test Accuracy of  deer: 75% (751/1000)
# Test Accuracy of   dog: 69% (690/1000)
# Test Accuracy of  frog: 84% (848/1000)
# Test Accuracy of horse: 83% (838/1000)
# Test Accuracy of  ship: 92% (926/1000)
# Test Accuracy of truck: 81% (817/1000)
#
# Test Accuracy (Overall): 78% (7871/10000)
# [27] time: 847.7872095108032 loss: 0.089 val_loss:0.8927380389805082 current_lr=0.004238
# Test Loss: 0.915043
#
# Test Accuracy of airplane: 80% (808/1000)
# Test Accuracy of automobile: 81% (815/1000)
# Test Accuracy of  bird: 74% (744/1000)
# Test Accuracy of   cat: 68% (680/1000)
# Test Accuracy of  deer: 77% (774/1000)
# Test Accuracy of   dog: 67% (673/1000)
# Test Accuracy of  frog: 81% (817/1000)
# Test Accuracy of horse: 81% (811/1000)
# Test Accuracy of  ship: 92% (927/1000)
# Test Accuracy of truck: 85% (855/1000)
#
# Test Accuracy (Overall): 79% (7904/10000)
# [28] time: 879.4534857273102 loss: 0.084 val_loss:0.9150427594969545 current_lr=0.004184
# Test Loss: 0.890577
#
# Test Accuracy of airplane: 84% (845/1000)
# Test Accuracy of automobile: 87% (879/1000)
# Test Accuracy of  bird: 75% (752/1000)
# Test Accuracy of   cat: 61% (617/1000)
# Test Accuracy of  deer: 78% (782/1000)
# Test Accuracy of   dog: 70% (709/1000)
# Test Accuracy of  frog: 81% (813/1000)
# Test Accuracy of horse: 85% (859/1000)
# Test Accuracy of  ship: 86% (868/1000)
# Test Accuracy of truck: 82% (828/1000)
#
# Test Accuracy (Overall): 79% (7952/10000)
# [29] time: 911.0772504806519 loss: 0.081 val_loss:0.8905769231953199 current_lr=0.004129
# Test Loss: 0.865769
#
# Test Accuracy of airplane: 83% (837/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 68% (682/1000)
# Test Accuracy of   cat: 63% (635/1000)
# Test Accuracy of  deer: 79% (791/1000)
# Test Accuracy of   dog: 75% (752/1000)
# Test Accuracy of  frog: 83% (830/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 88% (888/1000)
# Test Accuracy of truck: 87% (877/1000)
#
# Test Accuracy (Overall): 80% (8009/10000)
# [30] time: 942.2872784137726 loss: 0.082 val_loss:0.8657693447945993 current_lr=0.004073
# Test Loss: 0.900651
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 72% (727/1000)
# Test Accuracy of   cat: 64% (645/1000)
# Test Accuracy of  deer: 73% (732/1000)
# Test Accuracy of   dog: 69% (694/1000)
# Test Accuracy of  frog: 86% (869/1000)
# Test Accuracy of horse: 83% (838/1000)
# Test Accuracy of  ship: 89% (891/1000)
# Test Accuracy of truck: 80% (804/1000)
#
# Test Accuracy (Overall): 79% (7939/10000)
# [31] time: 973.6550829410553 loss: 0.073 val_loss:0.9006508596335785 current_lr=0.004015
# Test Loss: 0.916817
#
# Test Accuracy of airplane: 84% (844/1000)
# Test Accuracy of automobile: 82% (827/1000)
# Test Accuracy of  bird: 77% (777/1000)
# Test Accuracy of   cat: 64% (640/1000)
# Test Accuracy of  deer: 73% (732/1000)
# Test Accuracy of   dog: 68% (680/1000)
# Test Accuracy of  frog: 84% (843/1000)
# Test Accuracy of horse: 85% (852/1000)
# Test Accuracy of  ship: 82% (829/1000)
# Test Accuracy of truck: 89% (890/1000)
#
# Test Accuracy (Overall): 79% (7914/10000)
# [32] time: 1005.4490213394165 loss: 0.071 val_loss:0.9168169913412649 current_lr=0.003956
# Test Loss: 0.894237
#
# Test Accuracy of airplane: 84% (849/1000)
# Test Accuracy of automobile: 89% (894/1000)
# Test Accuracy of  bird: 69% (699/1000)
# Test Accuracy of   cat: 64% (647/1000)
# Test Accuracy of  deer: 75% (752/1000)
# Test Accuracy of   dog: 72% (723/1000)
# Test Accuracy of  frog: 86% (861/1000)
# Test Accuracy of horse: 83% (838/1000)
# Test Accuracy of  ship: 90% (903/1000)
# Test Accuracy of truck: 83% (831/1000)
#
# Test Accuracy (Overall): 79% (7997/10000)
# [33] time: 1036.820652961731 loss: 0.066 val_loss:0.8942373696761795 current_lr=0.003895
# Test Loss: 0.907416
#
# Test Accuracy of airplane: 81% (816/1000)
# Test Accuracy of automobile: 87% (879/1000)
# Test Accuracy of  bird: 75% (752/1000)
# Test Accuracy of   cat: 61% (617/1000)
# Test Accuracy of  deer: 71% (710/1000)
# Test Accuracy of   dog: 74% (747/1000)
# Test Accuracy of  frog: 83% (839/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 88% (884/1000)
# Test Accuracy of truck: 86% (861/1000)
#
# Test Accuracy (Overall): 79% (7960/10000)
# [34] time: 1068.177812576294 loss: 0.066 val_loss:0.9074155295951457 current_lr=0.003834
# Test Loss: 0.946643
#
# Test Accuracy of airplane: 85% (857/1000)
# Test Accuracy of automobile: 87% (872/1000)
# Test Accuracy of  bird: 76% (762/1000)
# Test Accuracy of   cat: 64% (648/1000)
# Test Accuracy of  deer: 71% (718/1000)
# Test Accuracy of   dog: 68% (681/1000)
# Test Accuracy of  frog: 88% (886/1000)
# Test Accuracy of horse: 82% (821/1000)
# Test Accuracy of  ship: 84% (848/1000)
# Test Accuracy of truck: 84% (849/1000)
#
# Test Accuracy (Overall): 79% (7942/10000)
# [35] time: 1099.8741376399994 loss: 0.065 val_loss:0.9466428756713867 current_lr=0.003771
# Test Loss: 0.919081
#
# Test Accuracy of airplane: 84% (841/1000)
# Test Accuracy of automobile: 82% (826/1000)
# Test Accuracy of  bird: 70% (703/1000)
# Test Accuracy of   cat: 62% (625/1000)
# Test Accuracy of  deer: 76% (760/1000)
# Test Accuracy of   dog: 71% (714/1000)
# Test Accuracy of  frog: 88% (889/1000)
# Test Accuracy of horse: 81% (814/1000)
# Test Accuracy of  ship: 91% (912/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 79% (7959/10000)
# [36] time: 1130.8725368976593 loss: 0.062 val_loss:0.9190813103054143 current_lr=0.003708
# Test Loss: 0.894424
#
# Test Accuracy of airplane: 85% (856/1000)
# Test Accuracy of automobile: 86% (868/1000)
# Test Accuracy of  bird: 77% (774/1000)
# Test Accuracy of   cat: 61% (619/1000)
# Test Accuracy of  deer: 77% (771/1000)
# Test Accuracy of   dog: 69% (694/1000)
# Test Accuracy of  frog: 86% (864/1000)
# Test Accuracy of horse: 84% (840/1000)
# Test Accuracy of  ship: 86% (866/1000)
# Test Accuracy of truck: 84% (846/1000)
#
# Test Accuracy (Overall): 79% (7998/10000)
# [37] time: 1162.112604856491 loss: 0.059 val_loss:0.8944243581234654 current_lr=0.003644
# Test Loss: 0.954148
#
# Test Accuracy of airplane: 87% (873/1000)
# Test Accuracy of automobile: 88% (883/1000)
# Test Accuracy of  bird: 68% (685/1000)
# Test Accuracy of   cat: 66% (663/1000)
# Test Accuracy of  deer: 77% (779/1000)
# Test Accuracy of   dog: 67% (679/1000)
# Test Accuracy of  frog: 87% (875/1000)
# Test Accuracy of horse: 81% (819/1000)
# Test Accuracy of  ship: 86% (867/1000)
# Test Accuracy of truck: 82% (823/1000)
#
# Test Accuracy (Overall): 79% (7946/10000)
# [38] time: 1193.5787074565887 loss: 0.053 val_loss:0.9541480993922753 current_lr=0.003578
# Test Loss: 0.910228
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 87% (879/1000)
# Test Accuracy of  bird: 72% (726/1000)
# Test Accuracy of   cat: 62% (628/1000)
# Test Accuracy of  deer: 78% (786/1000)
# Test Accuracy of   dog: 70% (708/1000)
# Test Accuracy of  frog: 85% (854/1000)
# Test Accuracy of horse: 85% (859/1000)
# Test Accuracy of  ship: 89% (891/1000)
# Test Accuracy of truck: 84% (847/1000)
#
# Test Accuracy (Overall): 80% (8026/10000)
# [39] time: 1224.5939404964447 loss: 0.054 val_loss:0.9102279981480369 current_lr=0.003512
# Test Loss: 0.929463
#
# Test Accuracy of airplane: 83% (836/1000)
# Test Accuracy of automobile: 85% (857/1000)
# Test Accuracy of  bird: 70% (704/1000)
# Test Accuracy of   cat: 64% (640/1000)
# Test Accuracy of  deer: 77% (771/1000)
# Test Accuracy of   dog: 69% (692/1000)
# Test Accuracy of  frog: 83% (831/1000)
# Test Accuracy of horse: 87% (873/1000)
# Test Accuracy of  ship: 87% (871/1000)
# Test Accuracy of truck: 89% (893/1000)
#
# Test Accuracy (Overall): 79% (7968/10000)
# [40] time: 1255.949034690857 loss: 0.050 val_loss:0.9294633744638178 current_lr=0.003445
# Test Loss: 0.970323
#
# Test Accuracy of airplane: 80% (802/1000)
# Test Accuracy of automobile: 87% (873/1000)
# Test Accuracy of  bird: 68% (682/1000)
# Test Accuracy of   cat: 61% (616/1000)
# Test Accuracy of  deer: 80% (806/1000)
# Test Accuracy of   dog: 71% (718/1000)
# Test Accuracy of  frog: 86% (865/1000)
# Test Accuracy of horse: 86% (869/1000)
# Test Accuracy of  ship: 89% (895/1000)
# Test Accuracy of truck: 84% (845/1000)
#
# Test Accuracy (Overall): 79% (7971/10000)
# [41] time: 1287.0735485553741 loss: 0.050 val_loss:0.9703226813787147 current_lr=0.003378
# Test Loss: 0.936063
#
# Test Accuracy of airplane: 82% (822/1000)
# Test Accuracy of automobile: 87% (878/1000)
# Test Accuracy of  bird: 68% (689/1000)
# Test Accuracy of   cat: 65% (655/1000)
# Test Accuracy of  deer: 78% (785/1000)
# Test Accuracy of   dog: 68% (680/1000)
# Test Accuracy of  frog: 86% (861/1000)
# Test Accuracy of horse: 84% (843/1000)
# Test Accuracy of  ship: 91% (915/1000)
# Test Accuracy of truck: 87% (878/1000)
#
# Test Accuracy (Overall): 80% (8006/10000)
# [42] time: 1317.8415925502777 loss: 0.048 val_loss:0.9360630746129193 current_lr=0.003310
# Test Loss: 0.954690
#
# Test Accuracy of airplane: 82% (826/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 75% (752/1000)
# Test Accuracy of   cat: 62% (622/1000)
# Test Accuracy of  deer: 77% (777/1000)
# Test Accuracy of   dog: 72% (724/1000)
# Test Accuracy of  frog: 83% (838/1000)
# Test Accuracy of horse: 83% (833/1000)
# Test Accuracy of  ship: 90% (906/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 80% (8033/10000)
# [43] time: 1349.1318938732147 loss: 0.042 val_loss:0.9546895117699346 current_lr=0.003241
# Test Loss: 0.960287
#
# Test Accuracy of airplane: 85% (854/1000)
# Test Accuracy of automobile: 87% (874/1000)
# Test Accuracy of  bird: 74% (744/1000)
# Test Accuracy of   cat: 62% (626/1000)
# Test Accuracy of  deer: 76% (764/1000)
# Test Accuracy of   dog: 74% (744/1000)
# Test Accuracy of  frog: 80% (808/1000)
# Test Accuracy of horse: 83% (837/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 85% (850/1000)
#
# Test Accuracy (Overall): 80% (8005/10000)
# [44] time: 1380.038033246994 loss: 0.044 val_loss:0.9602872193614139 current_lr=0.003172
# Test Loss: 0.976971
#
# Test Accuracy of airplane: 87% (873/1000)
# Test Accuracy of automobile: 87% (871/1000)
# Test Accuracy of  bird: 68% (680/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 79% (796/1000)
# Test Accuracy of   dog: 69% (697/1000)
# Test Accuracy of  frog: 87% (872/1000)
# Test Accuracy of horse: 84% (841/1000)
# Test Accuracy of  ship: 86% (865/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 80% (8014/10000)
# [45] time: 1411.4079790115356 loss: 0.040 val_loss:0.976971270162848 current_lr=0.003102
# Test Loss: 1.002877
#
# Test Accuracy of airplane: 78% (786/1000)
# Test Accuracy of automobile: 86% (864/1000)
# Test Accuracy of  bird: 74% (742/1000)
# Test Accuracy of   cat: 67% (679/1000)
# Test Accuracy of  deer: 73% (736/1000)
# Test Accuracy of   dog: 71% (714/1000)
# Test Accuracy of  frog: 83% (834/1000)
# Test Accuracy of horse: 81% (818/1000)
# Test Accuracy of  ship: 93% (930/1000)
# Test Accuracy of truck: 83% (832/1000)
#
# Test Accuracy (Overall): 79% (7935/10000)
# [46] time: 1442.8026614189148 loss: 0.039 val_loss:1.0028768898565559 current_lr=0.003032
# Test Loss: 0.964757
#
# Test Accuracy of airplane: 83% (834/1000)
# Test Accuracy of automobile: 86% (861/1000)
# Test Accuracy of  bird: 70% (708/1000)
# Test Accuracy of   cat: 64% (642/1000)
# Test Accuracy of  deer: 77% (778/1000)
# Test Accuracy of   dog: 68% (689/1000)
# Test Accuracy of  frog: 87% (874/1000)
# Test Accuracy of horse: 83% (830/1000)
# Test Accuracy of  ship: 87% (876/1000)
# Test Accuracy of truck: 88% (886/1000)
#
# Test Accuracy (Overall): 79% (7978/10000)
# [47] time: 1473.6668782234192 loss: 0.036 val_loss:0.9647565378418451 current_lr=0.002962
# Test Loss: 0.987509
#
# Test Accuracy of airplane: 85% (856/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 72% (721/1000)
# Test Accuracy of   cat: 65% (652/1000)
# Test Accuracy of  deer: 81% (810/1000)
# Test Accuracy of   dog: 70% (704/1000)
# Test Accuracy of  frog: 80% (806/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 86% (860/1000)
# Test Accuracy of truck: 86% (868/1000)
#
# Test Accuracy (Overall): 80% (8031/10000)
# [48] time: 1504.9218573570251 loss: 0.032 val_loss:0.987509241586999 current_lr=0.002891
# Test Loss: 0.957990
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 75% (753/1000)
# Test Accuracy of   cat: 64% (642/1000)
# Test Accuracy of  deer: 77% (778/1000)
# Test Accuracy of   dog: 71% (712/1000)
# Test Accuracy of  frog: 85% (855/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 89% (894/1000)
# Test Accuracy of truck: 86% (861/1000)
#
# Test Accuracy (Overall): 80% (8051/10000)
# [49] time: 1536.1909294128418 loss: 0.037 val_loss:0.9579898179331913 current_lr=0.002821
# Test Loss: 0.981805
#
# Test Accuracy of airplane: 85% (857/1000)
# Test Accuracy of automobile: 90% (904/1000)
# Test Accuracy of  bird: 69% (699/1000)
# Test Accuracy of   cat: 61% (613/1000)
# Test Accuracy of  deer: 78% (780/1000)
# Test Accuracy of   dog: 72% (722/1000)
# Test Accuracy of  frog: 89% (899/1000)
# Test Accuracy of horse: 86% (863/1000)
# Test Accuracy of  ship: 89% (894/1000)
# Test Accuracy of truck: 83% (831/1000)
#
# Test Accuracy (Overall): 80% (8062/10000)
# [50] time: 1567.498564004898 loss: 0.030 val_loss:0.9818048130107832 current_lr=0.002750
# Test Loss: 1.002867
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 85% (851/1000)
# Test Accuracy of  bird: 72% (720/1000)
# Test Accuracy of   cat: 65% (655/1000)
# Test Accuracy of  deer: 77% (777/1000)
# Test Accuracy of   dog: 68% (686/1000)
# Test Accuracy of  frog: 85% (853/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 87% (871/1000)
# Test Accuracy of truck: 87% (871/1000)
#
# Test Accuracy (Overall): 79% (7986/10000)
# [51] time: 1598.8533425331116 loss: 0.030 val_loss:1.0028672135328944 current_lr=0.002679
# Test Loss: 0.988995
#
# Test Accuracy of airplane: 83% (831/1000)
# Test Accuracy of automobile: 90% (900/1000)
# Test Accuracy of  bird: 70% (702/1000)
# Test Accuracy of   cat: 62% (623/1000)
# Test Accuracy of  deer: 82% (829/1000)
# Test Accuracy of   dog: 73% (732/1000)
# Test Accuracy of  frog: 84% (842/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 88% (889/1000)
# Test Accuracy of truck: 86% (862/1000)
#
# Test Accuracy (Overall): 80% (8065/10000)
# [52] time: 1629.9099943637848 loss: 0.026 val_loss:0.9889945485923863 current_lr=0.002609
# Test Loss: 0.961558
#
# Test Accuracy of airplane: 85% (859/1000)
# Test Accuracy of automobile: 89% (891/1000)
# Test Accuracy of  bird: 74% (743/1000)
# Test Accuracy of   cat: 62% (620/1000)
# Test Accuracy of  deer: 78% (786/1000)
# Test Accuracy of   dog: 69% (695/1000)
# Test Accuracy of  frog: 85% (854/1000)
# Test Accuracy of horse: 85% (850/1000)
# Test Accuracy of  ship: 91% (913/1000)
# Test Accuracy of truck: 85% (850/1000)
#
# Test Accuracy (Overall): 80% (8061/10000)
# [53] time: 1660.9733791351318 loss: 0.028 val_loss:0.9615578542027292 current_lr=0.002538
# Test Loss: 1.001169
#
# Test Accuracy of airplane: 85% (853/1000)
# Test Accuracy of automobile: 89% (899/1000)
# Test Accuracy of  bird: 71% (717/1000)
# Test Accuracy of   cat: 66% (668/1000)
# Test Accuracy of  deer: 79% (792/1000)
# Test Accuracy of   dog: 69% (691/1000)
# Test Accuracy of  frog: 84% (840/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 89% (891/1000)
# Test Accuracy of truck: 85% (854/1000)
#
# Test Accuracy (Overall): 80% (8041/10000)
# [54] time: 1692.4062151908875 loss: 0.026 val_loss:1.0011689647843567 current_lr=0.002468
# Test Loss: 1.011641
#
# Test Accuracy of airplane: 88% (885/1000)
# Test Accuracy of automobile: 86% (861/1000)
# Test Accuracy of  bird: 72% (720/1000)
# Test Accuracy of   cat: 65% (657/1000)
# Test Accuracy of  deer: 75% (751/1000)
# Test Accuracy of   dog: 70% (703/1000)
# Test Accuracy of  frog: 84% (849/1000)
# Test Accuracy of horse: 84% (845/1000)
# Test Accuracy of  ship: 90% (901/1000)
# Test Accuracy of truck: 87% (870/1000)
#
# Test Accuracy (Overall): 80% (8042/10000)
# [55] time: 1723.1274046897888 loss: 0.023 val_loss:1.0116405668137949 current_lr=0.002398
# Test Loss: 0.986645
#
# Test Accuracy of airplane: 84% (849/1000)
# Test Accuracy of automobile: 89% (899/1000)
# Test Accuracy of  bird: 75% (757/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 80% (805/1000)
# Test Accuracy of   dog: 68% (686/1000)
# Test Accuracy of  frog: 86% (860/1000)
# Test Accuracy of horse: 85% (853/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 86% (867/1000)
#
# Test Accuracy (Overall): 81% (8100/10000)
# [56] time: 1754.250467300415 loss: 0.022 val_loss:0.9866448195674752 current_lr=0.002328
# Test Loss: 0.988895
#
# Test Accuracy of airplane: 85% (850/1000)
# Test Accuracy of automobile: 89% (891/1000)
# Test Accuracy of  bird: 75% (755/1000)
# Test Accuracy of   cat: 64% (648/1000)
# Test Accuracy of  deer: 78% (782/1000)
# Test Accuracy of   dog: 72% (720/1000)
# Test Accuracy of  frog: 84% (842/1000)
# Test Accuracy of horse: 84% (843/1000)
# Test Accuracy of  ship: 89% (893/1000)
# Test Accuracy of truck: 86% (862/1000)
#
# Test Accuracy (Overall): 80% (8086/10000)
# [57] time: 1785.0995151996613 loss: 0.020 val_loss:0.9888949786560445 current_lr=0.002259
# Test Loss: 1.007218
#
# Test Accuracy of airplane: 87% (875/1000)
# Test Accuracy of automobile: 87% (870/1000)
# Test Accuracy of  bird: 75% (751/1000)
# Test Accuracy of   cat: 64% (646/1000)
# Test Accuracy of  deer: 77% (775/1000)
# Test Accuracy of   dog: 70% (703/1000)
# Test Accuracy of  frog: 85% (851/1000)
# Test Accuracy of horse: 83% (838/1000)
# Test Accuracy of  ship: 90% (908/1000)
# Test Accuracy of truck: 86% (867/1000)
#
# Test Accuracy (Overall): 80% (8084/10000)
# [58] time: 1816.0982146263123 loss: 0.020 val_loss:1.0072182745118685 current_lr=0.002190
# Test Loss: 1.029691
#
# Test Accuracy of airplane: 82% (820/1000)
# Test Accuracy of automobile: 88% (887/1000)
# Test Accuracy of  bird: 72% (720/1000)
# Test Accuracy of   cat: 64% (645/1000)
# Test Accuracy of  deer: 80% (803/1000)
# Test Accuracy of   dog: 73% (739/1000)
# Test Accuracy of  frog: 82% (821/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 88% (883/1000)
# Test Accuracy of truck: 87% (872/1000)
#
# Test Accuracy (Overall): 80% (8026/10000)
# [59] time: 1847.488909482956 loss: 0.019 val_loss:1.0296908435942251 current_lr=0.002122
# Test Loss: 1.042330
#
# Test Accuracy of airplane: 88% (882/1000)
# Test Accuracy of automobile: 88% (885/1000)
# Test Accuracy of  bird: 69% (697/1000)
# Test Accuracy of   cat: 63% (632/1000)
# Test Accuracy of  deer: 77% (772/1000)
# Test Accuracy of   dog: 72% (726/1000)
# Test Accuracy of  frog: 85% (859/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 88% (887/1000)
# Test Accuracy of truck: 88% (886/1000)
#
# Test Accuracy (Overall): 80% (8080/10000)
# [60] time: 1878.5941355228424 loss: 0.018 val_loss:1.0423303978352607 current_lr=0.002055
# Test Loss: 1.003282
#
# Test Accuracy of airplane: 85% (857/1000)
# Test Accuracy of automobile: 87% (879/1000)
# Test Accuracy of  bird: 72% (725/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 82% (822/1000)
# Test Accuracy of   dog: 72% (728/1000)
# Test Accuracy of  frog: 84% (848/1000)
# Test Accuracy of horse: 86% (866/1000)
# Test Accuracy of  ship: 87% (873/1000)
# Test Accuracy of truck: 87% (870/1000)
#
# Test Accuracy (Overall): 81% (8107/10000)
# [61] time: 1909.9160318374634 loss: 0.017 val_loss:1.0032820377168776 current_lr=0.001988
# Test Loss: 1.086805
#
# Test Accuracy of airplane: 86% (865/1000)
# Test Accuracy of automobile: 86% (869/1000)
# Test Accuracy of  bird: 72% (727/1000)
# Test Accuracy of   cat: 57% (574/1000)
# Test Accuracy of  deer: 78% (782/1000)
# Test Accuracy of   dog: 70% (705/1000)
# Test Accuracy of  frog: 86% (867/1000)
# Test Accuracy of horse: 87% (872/1000)
# Test Accuracy of  ship: 85% (858/1000)
# Test Accuracy of truck: 89% (897/1000)
#
# Test Accuracy (Overall): 80% (8016/10000)
# [62] time: 1941.313175201416 loss: 0.015 val_loss:1.0868045476418506 current_lr=0.001922
# Test Loss: 1.069855
#
# Test Accuracy of airplane: 85% (855/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 75% (752/1000)
# Test Accuracy of   cat: 64% (643/1000)
# Test Accuracy of  deer: 77% (776/1000)
# Test Accuracy of   dog: 68% (686/1000)
# Test Accuracy of  frog: 84% (848/1000)
# Test Accuracy of horse: 83% (834/1000)
# Test Accuracy of  ship: 91% (910/1000)
# Test Accuracy of truck: 85% (852/1000)
#
# Test Accuracy (Overall): 80% (8037/10000)
# [63] time: 1972.163186788559 loss: 0.015 val_loss:1.0698553255841703 current_lr=0.001856
# Test Loss: 1.040174
#
# Test Accuracy of airplane: 82% (823/1000)
# Test Accuracy of automobile: 88% (888/1000)
# Test Accuracy of  bird: 72% (728/1000)
# Test Accuracy of   cat: 64% (648/1000)
# Test Accuracy of  deer: 81% (813/1000)
# Test Accuracy of   dog: 70% (703/1000)
# Test Accuracy of  frog: 85% (856/1000)
# Test Accuracy of horse: 88% (883/1000)
# Test Accuracy of  ship: 88% (882/1000)
# Test Accuracy of truck: 88% (884/1000)
#
# Test Accuracy (Overall): 81% (8108/10000)
# [64] time: 2003.2495656013489 loss: 0.014 val_loss:1.0401737252368202 current_lr=0.001792
# Test Loss: 1.056395
#
# Test Accuracy of airplane: 86% (863/1000)
# Test Accuracy of automobile: 89% (895/1000)
# Test Accuracy of  bird: 74% (743/1000)
# Test Accuracy of   cat: 59% (596/1000)
# Test Accuracy of  deer: 81% (818/1000)
# Test Accuracy of   dog: 69% (692/1000)
# Test Accuracy of  frog: 87% (879/1000)
# Test Accuracy of horse: 83% (832/1000)
# Test Accuracy of  ship: 88% (883/1000)
# Test Accuracy of truck: 86% (862/1000)
#
# Test Accuracy (Overall): 80% (8063/10000)
# [65] time: 2034.3429682254791 loss: 0.012 val_loss:1.0563945030864281 current_lr=0.001729
# Test Loss: 1.108492
#
# Test Accuracy of airplane: 83% (836/1000)
# Test Accuracy of automobile: 89% (894/1000)
# Test Accuracy of  bird: 72% (721/1000)
# Test Accuracy of   cat: 57% (575/1000)
# Test Accuracy of  deer: 81% (815/1000)
# Test Accuracy of   dog: 75% (753/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 84% (847/1000)
# Test Accuracy of  ship: 88% (881/1000)
# Test Accuracy of truck: 86% (863/1000)
#
# Test Accuracy (Overall): 80% (8051/10000)
# [66] time: 2065.2095766067505 loss: 0.012 val_loss:1.1084923646118068 current_lr=0.001666
# Test Loss: 1.068328
#
# Test Accuracy of airplane: 85% (855/1000)
# Test Accuracy of automobile: 87% (876/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 61% (614/1000)
# Test Accuracy of  deer: 79% (794/1000)
# Test Accuracy of   dog: 75% (757/1000)
# Test Accuracy of  frog: 87% (879/1000)
# Test Accuracy of horse: 85% (852/1000)
# Test Accuracy of  ship: 88% (886/1000)
# Test Accuracy of truck: 87% (877/1000)
#
# Test Accuracy (Overall): 81% (8129/10000)
# [67] time: 2096.463779449463 loss: 0.010 val_loss:1.068327922609788 current_lr=0.001605
# Test Loss: 1.077112
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 88% (886/1000)
# Test Accuracy of  bird: 71% (716/1000)
# Test Accuracy of   cat: 63% (636/1000)
# Test Accuracy of  deer: 81% (811/1000)
# Test Accuracy of   dog: 68% (688/1000)
# Test Accuracy of  frog: 85% (850/1000)
# Test Accuracy of horse: 86% (868/1000)
# Test Accuracy of  ship: 88% (887/1000)
# Test Accuracy of truck: 89% (891/1000)
#
# Test Accuracy (Overall): 80% (8072/10000)
# [68] time: 2127.3649094104767 loss: 0.012 val_loss:1.077112338210963 current_lr=0.001544
# Test Loss: 1.082035
#
# Test Accuracy of airplane: 82% (827/1000)
# Test Accuracy of automobile: 86% (866/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 66% (665/1000)
# Test Accuracy of  deer: 80% (801/1000)
# Test Accuracy of   dog: 71% (710/1000)
# Test Accuracy of  frog: 86% (867/1000)
# Test Accuracy of horse: 84% (841/1000)
# Test Accuracy of  ship: 89% (899/1000)
# Test Accuracy of truck: 84% (844/1000)
#
# Test Accuracy (Overall): 80% (8076/10000)
# [69] time: 2158.5559763908386 loss: 0.010 val_loss:1.082034928134725 current_lr=0.001485
# Test Loss: 1.104193
#
# Test Accuracy of airplane: 86% (865/1000)
# Test Accuracy of automobile: 87% (879/1000)
# Test Accuracy of  bird: 76% (769/1000)
# Test Accuracy of   cat: 67% (675/1000)
# Test Accuracy of  deer: 80% (809/1000)
# Test Accuracy of   dog: 67% (677/1000)
# Test Accuracy of  frog: 82% (826/1000)
# Test Accuracy of horse: 84% (846/1000)
# Test Accuracy of  ship: 89% (893/1000)
# Test Accuracy of truck: 85% (854/1000)
#
# Test Accuracy (Overall): 80% (8093/10000)
# [70] time: 2190.183522462845 loss: 0.008 val_loss:1.1041926266271858 current_lr=0.001427
# Test Loss: 1.104058
#
# Test Accuracy of airplane: 84% (843/1000)
# Test Accuracy of automobile: 89% (897/1000)
# Test Accuracy of  bird: 75% (757/1000)
# Test Accuracy of   cat: 62% (622/1000)
# Test Accuracy of  deer: 78% (787/1000)
# Test Accuracy of   dog: 72% (726/1000)
# Test Accuracy of  frog: 85% (854/1000)
# Test Accuracy of horse: 85% (857/1000)
# Test Accuracy of  ship: 88% (881/1000)
# Test Accuracy of truck: 86% (861/1000)
#
# Test Accuracy (Overall): 80% (8085/10000)
# [71] time: 2220.9342555999756 loss: 0.008 val_loss:1.1040584761885148 current_lr=0.001371
# Test Loss: 1.088888
#
# Test Accuracy of airplane: 85% (850/1000)
# Test Accuracy of automobile: 89% (892/1000)
# Test Accuracy of  bird: 73% (730/1000)
# Test Accuracy of   cat: 64% (644/1000)
# Test Accuracy of  deer: 80% (809/1000)
# Test Accuracy of   dog: 73% (733/1000)
# Test Accuracy of  frog: 85% (856/1000)
# Test Accuracy of horse: 83% (836/1000)
# Test Accuracy of  ship: 89% (898/1000)
# Test Accuracy of truck: 86% (865/1000)
#
# Test Accuracy (Overall): 81% (8113/10000)
# [72] time: 2252.0395658016205 loss: 0.007 val_loss:1.0888882241671598 current_lr=0.001316
# Test Loss: 1.093418
#
# Test Accuracy of airplane: 84% (844/1000)
# Test Accuracy of automobile: 87% (872/1000)
# Test Accuracy of  bird: 73% (736/1000)
# Test Accuracy of   cat: 63% (637/1000)
# Test Accuracy of  deer: 76% (764/1000)
# Test Accuracy of   dog: 72% (729/1000)
# Test Accuracy of  frog: 85% (853/1000)
# Test Accuracy of horse: 88% (880/1000)
# Test Accuracy of  ship: 89% (892/1000)
# Test Accuracy of truck: 86% (869/1000)
#
# Test Accuracy (Overall): 80% (8076/10000)
# [73] time: 2283.0285613536835 loss: 0.006 val_loss:1.0934183854091017 current_lr=0.001262
# Test Loss: 1.108816
#
# Test Accuracy of airplane: 86% (868/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 71% (719/1000)
# Test Accuracy of   cat: 67% (678/1000)
# Test Accuracy of  deer: 81% (812/1000)
# Test Accuracy of   dog: 65% (655/1000)
# Test Accuracy of  frog: 84% (845/1000)
# Test Accuracy of horse: 84% (844/1000)
# Test Accuracy of  ship: 89% (895/1000)
# Test Accuracy of truck: 86% (868/1000)
#
# Test Accuracy (Overall): 80% (8077/10000)
# [74] time: 2314.0696296691895 loss: 0.007 val_loss:1.1088162238084818 current_lr=0.001210
# Test Loss: 1.103903
#
# Test Accuracy of airplane: 83% (836/1000)
# Test Accuracy of automobile: 88% (888/1000)
# Test Accuracy of  bird: 73% (735/1000)
# Test Accuracy of   cat: 65% (658/1000)
# Test Accuracy of  deer: 80% (802/1000)
# Test Accuracy of   dog: 72% (728/1000)
# Test Accuracy of  frog: 88% (881/1000)
# Test Accuracy of horse: 84% (845/1000)
# Test Accuracy of  ship: 89% (890/1000)
# Test Accuracy of truck: 85% (855/1000)
#
# Test Accuracy (Overall): 81% (8118/10000)
# [75] time: 2345.3852531909943 loss: 0.006 val_loss:1.103903280028814 current_lr=0.001159
# Test Loss: 1.121797
#
# Test Accuracy of airplane: 86% (861/1000)
# Test Accuracy of automobile: 88% (881/1000)
# Test Accuracy of  bird: 75% (755/1000)
# Test Accuracy of   cat: 65% (656/1000)
# Test Accuracy of  deer: 79% (799/1000)
# Test Accuracy of   dog: 68% (685/1000)
# Test Accuracy of  frog: 87% (873/1000)
# Test Accuracy of horse: 86% (861/1000)
# Test Accuracy of  ship: 91% (910/1000)
# Test Accuracy of truck: 86% (864/1000)
#
# Test Accuracy (Overall): 81% (8145/10000)
# [76] time: 2376.5057418346405 loss: 0.005 val_loss:1.1217967332163943 current_lr=0.001110
# Test Loss: 1.110727
#
# Test Accuracy of airplane: 84% (848/1000)
# Test Accuracy of automobile: 88% (884/1000)
# Test Accuracy of  bird: 71% (715/1000)
# Test Accuracy of   cat: 67% (673/1000)
# Test Accuracy of  deer: 76% (769/1000)
# Test Accuracy of   dog: 72% (727/1000)
# Test Accuracy of  frog: 86% (867/1000)
# Test Accuracy of horse: 85% (851/1000)
# Test Accuracy of  ship: 90% (907/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 81% (8121/10000)
# [77] time: 2407.6666605472565 loss: 0.005 val_loss:1.1107270532771 current_lr=0.001062
# Test Loss: 1.103938
#
# Test Accuracy of airplane: 86% (862/1000)
# Test Accuracy of automobile: 89% (899/1000)
# Test Accuracy of  bird: 73% (735/1000)
# Test Accuracy of   cat: 67% (674/1000)
# Test Accuracy of  deer: 82% (823/1000)
# Test Accuracy of   dog: 70% (706/1000)
# Test Accuracy of  frog: 84% (843/1000)
# Test Accuracy of horse: 86% (863/1000)
# Test Accuracy of  ship: 89% (896/1000)
# Test Accuracy of truck: 83% (838/1000)
#
# Test Accuracy (Overall): 81% (8139/10000)
# [78] time: 2439.1274449825287 loss: 0.004 val_loss:1.1039377624475504 current_lr=0.001016
# Test Loss: 1.139896
#
# Test Accuracy of airplane: 87% (874/1000)
# Test Accuracy of automobile: 90% (907/1000)
# Test Accuracy of  bird: 75% (756/1000)
# Test Accuracy of   cat: 64% (641/1000)
# Test Accuracy of  deer: 77% (775/1000)
# Test Accuracy of   dog: 72% (724/1000)
# Test Accuracy of  frog: 86% (861/1000)
# Test Accuracy of horse: 86% (867/1000)
# Test Accuracy of  ship: 84% (840/1000)
# Test Accuracy of truck: 86% (864/1000)
#
# Test Accuracy (Overall): 81% (8109/10000)
# [79] time: 2470.212503671646 loss: 0.004 val_loss:1.139895702464671 current_lr=0.000972
# Test Loss: 1.104416
#
# Test Accuracy of airplane: 86% (864/1000)
# Test Accuracy of automobile: 92% (920/1000)
# Test Accuracy of  bird: 74% (746/1000)
# Test Accuracy of   cat: 64% (648/1000)
# Test Accuracy of  deer: 79% (798/1000)
# Test Accuracy of   dog: 68% (684/1000)
# Test Accuracy of  frog: 87% (873/1000)
# Test Accuracy of horse: 87% (870/1000)
# Test Accuracy of  ship: 88% (888/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 81% (8170/10000)
# [80] time: 2501.6209301948547 loss: 0.004 val_loss:1.1044158490398261 current_lr=0.000930
# Test Loss: 1.130875
#
# Test Accuracy of airplane: 86% (867/1000)
# Test Accuracy of automobile: 88% (889/1000)
# Test Accuracy of  bird: 74% (740/1000)
# Test Accuracy of   cat: 63% (639/1000)
# Test Accuracy of  deer: 78% (789/1000)
# Test Accuracy of   dog: 73% (734/1000)
# Test Accuracy of  frog: 88% (881/1000)
# Test Accuracy of horse: 86% (861/1000)
# Test Accuracy of  ship: 89% (899/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 81% (8165/10000)
# [81] time: 2533.163450241089 loss: 0.003 val_loss:1.1308745960646038 current_lr=0.000889
# Test Loss: 1.143330
#
# Test Accuracy of airplane: 84% (845/1000)
# Test Accuracy of automobile: 89% (895/1000)
# Test Accuracy of  bird: 73% (738/1000)
# Test Accuracy of   cat: 65% (652/1000)
# Test Accuracy of  deer: 80% (806/1000)
# Test Accuracy of   dog: 71% (717/1000)
# Test Accuracy of  frog: 86% (862/1000)
# Test Accuracy of horse: 85% (852/1000)
# Test Accuracy of  ship: 90% (901/1000)
# Test Accuracy of truck: 86% (866/1000)
#
# Test Accuracy (Overall): 81% (8134/10000)
# [82] time: 2564.3240251541138 loss: 0.003 val_loss:1.1433299930789802 current_lr=0.000850
# Test Loss: 1.148162
#
# Test Accuracy of airplane: 85% (851/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 75% (755/1000)
# Test Accuracy of   cat: 66% (667/1000)
# Test Accuracy of  deer: 78% (781/1000)
# Test Accuracy of   dog: 69% (692/1000)
# Test Accuracy of  frog: 86% (867/1000)
# Test Accuracy of horse: 85% (853/1000)
# Test Accuracy of  ship: 90% (903/1000)
# Test Accuracy of truck: 87% (873/1000)
#
# Test Accuracy (Overall): 81% (8138/10000)
# [83] time: 2595.6859078407288 loss: 0.002 val_loss:1.1481620133677615 current_lr=0.000813
# Test Loss: 1.182764
#
# Test Accuracy of airplane: 83% (839/1000)
# Test Accuracy of automobile: 89% (898/1000)
# Test Accuracy of  bird: 72% (728/1000)
# Test Accuracy of   cat: 67% (679/1000)
# Test Accuracy of  deer: 78% (785/1000)
# Test Accuracy of   dog: 70% (706/1000)
# Test Accuracy of  frog: 86% (860/1000)
# Test Accuracy of horse: 85% (858/1000)
# Test Accuracy of  ship: 89% (894/1000)
# Test Accuracy of truck: 87% (878/1000)
#
# Test Accuracy (Overall): 81% (8125/10000)
# [84] time: 2627.0528235435486 loss: 0.002 val_loss:1.1827635538728931 current_lr=0.000778
# Test Loss: 1.149619
#
# Test Accuracy of airplane: 84% (840/1000)
# Test Accuracy of automobile: 88% (880/1000)
# Test Accuracy of  bird: 72% (726/1000)
# Test Accuracy of   cat: 68% (680/1000)
# Test Accuracy of  deer: 79% (790/1000)
# Test Accuracy of   dog: 72% (725/1000)
# Test Accuracy of  frog: 85% (852/1000)
# Test Accuracy of horse: 85% (856/1000)
# Test Accuracy of  ship: 89% (897/1000)
# Test Accuracy of truck: 87% (877/1000)
#
# Test Accuracy (Overall): 81% (8123/10000)
# [85] time: 2658.6578090190887 loss: 0.003 val_loss:1.1496191734000096 current_lr=0.000745
# Test Loss: 1.172141
#
# Test Accuracy of airplane: 84% (842/1000)
# Test Accuracy of automobile: 88% (884/1000)
# Test Accuracy of  bird: 73% (732/1000)
# Test Accuracy of   cat: 67% (678/1000)
# Test Accuracy of  deer: 77% (777/1000)
# Test Accuracy of   dog: 71% (717/1000)
# Test Accuracy of  frog: 87% (879/1000)
# Test Accuracy of horse: 84% (845/1000)
# Test Accuracy of  ship: 89% (896/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 81% (8125/10000)
# [86] time: 2690.582572221756 loss: 0.001 val_loss:1.1721410721163206 current_lr=0.000714
# Test Loss: 1.184479
#
# Test Accuracy of airplane: 86% (861/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 74% (748/1000)
# Test Accuracy of   cat: 65% (652/1000)
# Test Accuracy of  deer: 78% (785/1000)
# Test Accuracy of   dog: 70% (709/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 86% (868/1000)
# Test Accuracy of  ship: 90% (904/1000)
# Test Accuracy of truck: 86% (867/1000)
#
# Test Accuracy (Overall): 81% (8153/10000)
# [87] time: 2721.872761964798 loss: 0.002 val_loss:1.184478746939309 current_lr=0.000685
# Test Loss: 1.193710
#
# Test Accuracy of airplane: 84% (845/1000)
# Test Accuracy of automobile: 87% (879/1000)
# Test Accuracy of  bird: 73% (738/1000)
# Test Accuracy of   cat: 66% (666/1000)
# Test Accuracy of  deer: 79% (796/1000)
# Test Accuracy of   dog: 71% (713/1000)
# Test Accuracy of  frog: 87% (872/1000)
# Test Accuracy of horse: 85% (850/1000)
# Test Accuracy of  ship: 89% (898/1000)
# Test Accuracy of truck: 88% (883/1000)
#
# Test Accuracy (Overall): 81% (8140/10000)
# [88] time: 2753.063454389572 loss: 0.002 val_loss:1.1937096782877474 current_lr=0.000658
# Test Loss: 1.197975
#
# Test Accuracy of airplane: 84% (843/1000)
# Test Accuracy of automobile: 88% (886/1000)
# Test Accuracy of  bird: 77% (770/1000)
# Test Accuracy of   cat: 66% (661/1000)
# Test Accuracy of  deer: 79% (798/1000)
# Test Accuracy of   dog: 69% (693/1000)
# Test Accuracy of  frog: 86% (862/1000)
# Test Accuracy of horse: 85% (853/1000)
# Test Accuracy of  ship: 90% (900/1000)
# Test Accuracy of truck: 88% (880/1000)
#
# Test Accuracy (Overall): 81% (8146/10000)
# [89] time: 2784.5187034606934 loss: 0.001 val_loss:1.1979752763917175 current_lr=0.000633
# Test Loss: 1.179798
#
# Test Accuracy of airplane: 85% (851/1000)
# Test Accuracy of automobile: 89% (892/1000)
# Test Accuracy of  bird: 75% (757/1000)
# Test Accuracy of   cat: 65% (656/1000)
# Test Accuracy of  deer: 79% (796/1000)
# Test Accuracy of   dog: 70% (701/1000)
# Test Accuracy of  frog: 86% (869/1000)
# Test Accuracy of horse: 86% (864/1000)
# Test Accuracy of  ship: 88% (884/1000)
# Test Accuracy of truck: 87% (878/1000)
#
# Test Accuracy (Overall): 81% (8148/10000)
# [90] time: 2815.3165023326874 loss: 0.002 val_loss:1.1797980009755002 current_lr=0.000610
# Test Loss: 1.182226
#
# Test Accuracy of airplane: 87% (874/1000)
# Test Accuracy of automobile: 89% (894/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 64% (647/1000)
# Test Accuracy of  deer: 79% (794/1000)
# Test Accuracy of   dog: 71% (717/1000)
# Test Accuracy of  frog: 87% (873/1000)
# Test Accuracy of horse: 85% (857/1000)
# Test Accuracy of  ship: 88% (889/1000)
# Test Accuracy of truck: 89% (893/1000)
#
# Test Accuracy (Overall): 81% (8177/10000)
# [91] time: 2846.5594708919525 loss: 0.001 val_loss:1.1822255438641658 current_lr=0.000589
# Test Loss: 1.194211
#
# Test Accuracy of airplane: 86% (863/1000)
# Test Accuracy of automobile: 88% (887/1000)
# Test Accuracy of  bird: 75% (754/1000)
# Test Accuracy of   cat: 67% (670/1000)
# Test Accuracy of  deer: 76% (769/1000)
# Test Accuracy of   dog: 70% (706/1000)
# Test Accuracy of  frog: 85% (857/1000)
# Test Accuracy of horse: 86% (866/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 88% (884/1000)
#
# Test Accuracy (Overall): 81% (8141/10000)
# [92] time: 2877.9782836437225 loss: 0.001 val_loss:1.194210712668262 current_lr=0.000571
# Test Loss: 1.216635
#
# Test Accuracy of airplane: 84% (843/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 75% (750/1000)
# Test Accuracy of   cat: 64% (645/1000)
# Test Accuracy of  deer: 80% (808/1000)
# Test Accuracy of   dog: 74% (749/1000)
# Test Accuracy of  frog: 86% (863/1000)
# Test Accuracy of horse: 86% (869/1000)
# Test Accuracy of  ship: 88% (884/1000)
# Test Accuracy of truck: 87% (877/1000)
#
# Test Accuracy (Overall): 81% (8184/10000)
# [93] time: 2908.9586198329926 loss: 0.001 val_loss:1.2166351400598694 current_lr=0.000554
# Test Loss: 1.208112
#
# Test Accuracy of airplane: 85% (857/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 74% (743/1000)
# Test Accuracy of   cat: 65% (658/1000)
# Test Accuracy of  deer: 79% (797/1000)
# Test Accuracy of   dog: 70% (700/1000)
# Test Accuracy of  frog: 88% (889/1000)
# Test Accuracy of horse: 84% (844/1000)
# Test Accuracy of  ship: 87% (879/1000)
# Test Accuracy of truck: 86% (864/1000)
#
# Test Accuracy (Overall): 81% (8127/10000)
# [94] time: 2940.8428406715393 loss: 0.001 val_loss:1.208112198340742 current_lr=0.000540
# Test Loss: 1.216705
#
# Test Accuracy of airplane: 86% (861/1000)
# Test Accuracy of automobile: 89% (893/1000)
# Test Accuracy of  bird: 72% (723/1000)
# Test Accuracy of   cat: 61% (618/1000)
# Test Accuracy of  deer: 79% (797/1000)
# Test Accuracy of   dog: 75% (751/1000)
# Test Accuracy of  frog: 86% (861/1000)
# Test Accuracy of horse: 86% (865/1000)
# Test Accuracy of  ship: 88% (885/1000)
# Test Accuracy of truck: 88% (882/1000)
#
# Test Accuracy (Overall): 81% (8136/10000)
# [95] time: 2972.642016649246 loss: 0.001 val_loss:1.216704826943482 current_lr=0.000528
# Test Loss: 1.221984
#
# Test Accuracy of airplane: 83% (836/1000)
# Test Accuracy of automobile: 89% (896/1000)
# Test Accuracy of  bird: 73% (739/1000)
# Test Accuracy of   cat: 63% (637/1000)
# Test Accuracy of  deer: 81% (814/1000)
# Test Accuracy of   dog: 73% (730/1000)
# Test Accuracy of  frog: 87% (870/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 91% (911/1000)
# Test Accuracy of truck: 85% (853/1000)
#
# Test Accuracy (Overall): 81% (8141/10000)
# [96] time: 3003.909441947937 loss: 0.001 val_loss:1.2219842717617373 current_lr=0.000518
# Test Loss: 1.220907
#
# Test Accuracy of airplane: 86% (866/1000)
# Test Accuracy of automobile: 91% (911/1000)
# Test Accuracy of  bird: 71% (718/1000)
# Test Accuracy of   cat: 65% (659/1000)
# Test Accuracy of  deer: 80% (807/1000)
# Test Accuracy of   dog: 74% (745/1000)
# Test Accuracy of  frog: 86% (866/1000)
# Test Accuracy of horse: 85% (853/1000)
# Test Accuracy of  ship: 88% (887/1000)
# Test Accuracy of truck: 87% (875/1000)
#
# Test Accuracy (Overall): 81% (8187/10000)
# [97] time: 3035.4471347332 loss: 0.001 val_loss:1.2209071351003042 current_lr=0.000510
# Test Loss: 1.236086
#
# Test Accuracy of airplane: 86% (861/1000)
# Test Accuracy of automobile: 90% (902/1000)
# Test Accuracy of  bird: 74% (744/1000)
# Test Accuracy of   cat: 65% (650/1000)
# Test Accuracy of  deer: 79% (796/1000)
# Test Accuracy of   dog: 73% (736/1000)
# Test Accuracy of  frog: 87% (871/1000)
# Test Accuracy of horse: 85% (855/1000)
# Test Accuracy of  ship: 89% (898/1000)
# Test Accuracy of truck: 86% (864/1000)
#
# Test Accuracy (Overall): 81% (8177/10000)
# [98] time: 3066.6696231365204 loss: 0.000 val_loss:1.2360863308363323 current_lr=0.000504
# Test Loss: 1.233965
#
# Test Accuracy of airplane: 85% (850/1000)
# Test Accuracy of automobile: 90% (904/1000)
# Test Accuracy of  bird: 72% (728/1000)
# Test Accuracy of   cat: 66% (666/1000)
# Test Accuracy of  deer: 81% (814/1000)
# Test Accuracy of   dog: 71% (718/1000)
# Test Accuracy of  frog: 87% (879/1000)
# Test Accuracy of horse: 85% (854/1000)
# Test Accuracy of  ship: 90% (900/1000)
# Test Accuracy of truck: 87% (879/1000)
#
# Test Accuracy (Overall): 81% (8192/10000)
# [99] time: 3097.3528175354004 loss: 0.001 val_loss:1.2339653395399262 current_lr=0.000501
# Test Loss: 1.219968
#
# Test Accuracy of airplane: 85% (856/1000)
# Test Accuracy of automobile: 91% (916/1000)
# Test Accuracy of  bird: 74% (740/1000)
# Test Accuracy of   cat: 66% (668/1000)
# Test Accuracy of  deer: 80% (803/1000)
# Test Accuracy of   dog: 72% (722/1000)
# Test Accuracy of  frog: 86% (867/1000)
# Test Accuracy of horse: 86% (861/1000)
# Test Accuracy of  ship: 90% (902/1000)
# Test Accuracy of truck: 85% (857/1000)
#
# Test Accuracy (Overall): 81% (8192/10000)
# [100] time: 3128.855474948883 loss: 0.000 val_loss:1.219967951502981 current_lr=0.000500
# Training finished!
# Training finished!

# %% [markdown]
# #**Plot Training Loss and Val Loss**

# %%
plt.figure(figsize=(10,8))
epochs_range = range(1, epochs + 1)
# 定义每个算法的颜色（可自定义）
# colors = {
#     "mvr2": "#1f77b4",     # 蓝色
#     "sgd": "#2ca02c",      # 绿色
#     "adamw": "#d62728",    # 红色
#     "adaorth": "#9467bd",  # 紫色
# }
colors = {
    # 🔴 Bright red — strong attention color; highlights the best or main method
    "Muon-MVR2": "#d62728",

    # 🟠 Orange — warm tone; second-best or related variant of the main method
    "Muon-MVR1": "#ff7f0e",

    # 🟢 Green/Teal — balanced, calm color; used for the γ=0 ablation variant
    "Muon-MVR1 (γ=0)": "#2ca02c",

    # 🌸 Pink — soft complementary tone; represents Adam (adaptive optimizer family)
    "Adam": "#e377c2",

    # 🟣 Purple — cool, classic hue; represents SGD (baseline optimizer)
    "SGD": "#9467bd",

    # 🔵 Deep blue — reliable, professional color; for AdaOrth-L (new proposed variant)
    "AdaOrthL-": "#1f77b4",

    # 🟡 Olive-yellow — contrasting, bright accent; for AdaOrth-AL+ (advanced/larger version)
    "AdaOrthL+": "#bcbd22",
}


plt.plot(epochs_range, losses_mvr2, label="Muon-MVR2", linewidth=2, color=colors["Muon-MVR2"])
plt.plot(epochs_range, losses_sgd, label="SGD", linewidth=2,color=colors["SGD"])
plt.plot(epochs_range, losses_adam, label="Adam", linewidth=2,color=colors["Adam"])
plt.plot(epochs_range, losses_adaorth, label="AdaOrthL+", linewidth=2,color=colors["AdaOrthL+"])
plt.plot(epochs_range, losses_adaorthlminus, label="AdaOrthL-", linewidth=2,color=colors["AdaOrthL-"])

plt.plot(epochs_range ,losses_mvr2_val, label="Muon-MVR2(Val)", linewidth=2, linestyle='--',color=colors["Muon-MVR2"])
plt.plot(epochs_range, losses_sgd_val, label="SGD(Val)", linewidth=2, linestyle='--',color=colors["SGD"])
plt.plot(epochs_range, losses_adam_val, label="Adam(Val)", linewidth=2, linestyle='--',color=colors["Adam"])
plt.plot(epochs_range, losses_adaorth_val, label="AdaOrthL+(Val)", linewidth=2, linestyle='--',color=colors["AdaOrthL+"])
plt.plot(epochs_range, losses_adaorthlminus_val, label="AdaOrthL-(Val)", linewidth=2, linestyle='--',color=colors["AdaOrthL-"])

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training/Val Loss Comparison")
plt.legend(fontsize=11, frameon=True)
plt.xlim(0, len(epochs_range))
plt.tight_layout()

# %% [markdown]
# #**Plot Validation Accuracy**

# %%
# plt.figure(figsize=(10,6))
epochs_range = range(1, epochs + 1)
plt.plot(epochs_range, mvr2_acc, label="Muon-MVR2", linewidth=2)
plt.plot(epochs_range, sgd_acc, label="SGD", linewidth=2)
plt.plot(epochs_range, adam_acc, label="Adam", linewidth=2)
plt.plot(epochs_range, adaorth_acc, label="AdaOrthL+", linewidth=2)
plt.plot(epochs_range, adaorthlminus_acc, label="AdaOrthL-", linewidth=2)

plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy (%)")
plt.title("Validation Accuracy Comparison")
plt.grid(True)
plt.legend()
plt.xlim(0, len(epochs_range))
plt.tight_layout()
plt.show()

# %% [markdown]
# #**Plot Validation Accuracy with Wall Clock Time**

# %%
import matplotlib.pyplot as plt
plt.plot(mvr2_time_cost, mvr2_acc, label = "Muon-MVR2")
plt.plot(sgd_time_cost, sgd_acc, label="SGD")
plt.plot(adam_time_cost, adam_acc, label="Adam")
plt.plot(adaorth_time_cost, adaorth_acc, label="AdamOrthL+")
plt.plot(adaorthlminus_time_cost, adaorthlminus_acc, label="AdamOrthL-")

plt.xlabel("Wall Clock Time (s)")
plt.ylabel("Validation Accuracy (%)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #**show losses for two optimizer**

# %%
# epochs_list = range(1,epochs+1)
# plt.figure(figsize=(8, 5))  # larger, readable figure

# # plot both losses
# plt.plot(epochs_list, losses_mvr2, label="MuonMVR Loss", linewidth=2)
# plt.plot(epochs_list, losses_sgd, label="SGD Loss", linewidth=2, linestyle="--")

# # formatting
# plt.xlabel("Epoch", fontsize=12)
# plt.ylabel("Loss", fontsize=12)
# plt.title("Training Loss Comparison with CIFAR10", fontsize=14)
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# #**Testing Loop**
# The real test of the model architecture how well does the model recognizes the image and what is the accuracy on the test data

# %%
# ResNet18.eval()
# correct, total = 0, 0
# with torch.no_grad():
#     for inputs, labels in test_loader:
#         inputs, labels = inputs.to(device), labels.to(device)
#         outputs = ResNet18(inputs)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# print(f"Accuracy: {100 * correct / total:.2f}%")

# %%
# test_loss,acc = test_model(ResNet18_adamw, criterion, test_loader)
# print("adam",test_loss, acc)
# test_loss,acc = test_model(ResNet18, criterion, test_loader)
# print("", test_loss, acc)
# test_loss,acc = test_model(model, criterion, test_loader)
# print("",test_loss, acc)
